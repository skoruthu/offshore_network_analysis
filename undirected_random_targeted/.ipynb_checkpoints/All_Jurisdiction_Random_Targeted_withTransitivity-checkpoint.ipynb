# %%
import pandas as pd
import numpy as np
import igraph as ig
import matplotlib.pyplot as plt 
import collections

# %%
df_unweighted = pd.read_csv('../combined_final_unweighted.csv')
df_unweighted
# Out:
#           node_start                node_end        status
# 0          Hong Kong                   Samoa  jurisdiction
# 1          Hong Kong                   Samoa  jurisdiction
# 2          Hong Kong                   Samoa  jurisdiction
# 3          Hong Kong                   Samoa  jurisdiction
# 4          Hong Kong                   Samoa  jurisdiction
# ...              ...                     ...           ...
# 338127     Indonesia  British Virgin Islands  officer_base
# 338128  Cook Islands  British Virgin Islands  officer_base
# 338129     Hong Kong  British Virgin Islands  officer_base
# 338130  Cook Islands          United Kingdom  officer_base
# 338131     Hong Kong          United Kingdom  officer_base
#
# [338132 rows x 3 columns]

# %%
df_weighted = pd.read_csv('../combined_final_weighted.csv')
df_weighted
# Out:
#           node_start                node_end        status  weight
# 0          Hong Kong                   Samoa  jurisdiction     2.0
# 1          Hong Kong                   Samoa  jurisdiction     2.0
# 2          Hong Kong                   Samoa  jurisdiction     2.0
# 3          Hong Kong                   Samoa  jurisdiction     2.0
# 4          Hong Kong                   Samoa  jurisdiction     2.0
# ...              ...                     ...           ...     ...
# 338119     Indonesia  British Virgin Islands  officer_base     1.0
# 338120  Cook Islands  British Virgin Islands  officer_base     1.0
# 338121     Hong Kong  British Virgin Islands  officer_base     1.0
# 338122  Cook Islands          United Kingdom  officer_base     1.0
# 338123     Hong Kong          United Kingdom  officer_base     1.0
#
# [338124 rows x 4 columns]

# %%
## Have all Jurisdiction from Susan's
jurisdiction_status_list = ['jurisdiction', 'intermediary_jurisdiction', 'officer_jurisdiction']

# %%
df_weighted_jur = df_weighted[df_weighted['status'].isin(jurisdiction_status_list)]
df_jur = df_weighted_jur.drop(['weight','status'], axis = 1)
df_jur
# Out:
#           node_start                node_end
# 0          Hong Kong                   Samoa
# 1          Hong Kong                   Samoa
# 2          Hong Kong                   Samoa
# 3          Hong Kong                   Samoa
# 4          Hong Kong                   Samoa
# ...              ...                     ...
# 221140         China  British Virgin Islands
# 221175   New Zealand  British Virgin Islands
# 221176  Cook Islands  British Virgin Islands
# 221177     Singapore  British Virgin Islands
# 221178        Russia               Singapore
#
# [218952 rows x 2 columns]

# %%
df_jur_grouped = df_jur.groupby(['node_start','node_end'], as_index = False).size()
df_jur_grouped
# Out:
#      node_start                node_end  size
# 0       Albania                 Bahamas     2
# 1       Andorra                 Bahamas    26
# 2       Andorra  British Virgin Islands    39
# 3       Andorra          Cayman Islands     1
# 4       Andorra            Cook Islands     1
# ...         ...                     ...   ...
# 1293    Vietnam                  Panama     1
# 1294      Yemen                  Panama     1
# 1295     Zambia  British Virgin Islands     2
# 1296   Zimbabwe  British Virgin Islands     5
# 1297   Zimbabwe                  Panama     3
#
# [1298 rows x 3 columns]

# %% [markdown]
# ### Convert Data to an Undirected Edge List

# %%
df_jur_grouped_list = df_jur_grouped.values.tolist()
df_jur_grouped_list
# Out:
# [['Albania', 'Bahamas', 2],
#  ['Andorra', 'Bahamas', 26],
#  ['Andorra', 'British Virgin Islands', 39],
#  ['Andorra', 'Cayman Islands', 1],
#  ['Andorra', 'Cook Islands', 1],
#  ['Andorra', 'Costa Rica', 3],
#  ['Andorra', 'Hong Kong', 9],
#  ['Andorra', 'Nevada', 24],
#  ['Andorra', 'Niue', 12],
#  ['Andorra', 'Panama', 279],
#  ['Andorra', 'Samoa', 9],
#  ['Andorra', 'Seychelles', 72],
#  ['Andorra', 'United Kingdom', 1],
#  ['Andorra', 'Uruguay', 15],
#  ['Angola', 'Bermuda', 1],
#  ['Angola', 'British Virgin Islands', 11],
#  ['Antigua and Barbuda', 'Barbados', 8],
#  ['Antigua and Barbuda', 'British Virgin Islands', 4],
#  ['Antigua and Barbuda', 'Cayman Islands', 1],
#  ['Antigua and Barbuda', 'Niue', 2],
#  ['Antigua and Barbuda', 'Panama', 15],
#  ['Antigua and Barbuda', 'Saint Kitts and Nevis', 1],
#  ['Antigua and Barbuda', 'Samoa', 1],
#  ['Antigua and Barbuda', 'Seychelles', 3],
#  ['Argentina', 'Bahamas', 23],
#  ['Argentina', 'Barbados', 1],
#  ['Argentina', 'British Virgin Islands', 83],
#  ['Argentina', 'Cayman Islands', 3],
#  ['Argentina', 'Costa Rica', 1],
#  ['Argentina', 'Hong Kong', 4],
#  ['Argentina', 'Nevada', 4],
#  ['Argentina', 'New Zealand', 1],
#  ['Argentina', 'Niue', 2],
#  ['Argentina', 'Panama', 146],
#  ['Argentina', 'Seychelles', 6],
#  ['Aruba', 'Barbados', 1],
#  ['Aruba', 'British Anguilla', 4],
#  ['Aruba', 'British Virgin Islands', 19],
#  ['Aruba', 'Panama', 4],
#  ['Australia', 'Bahamas', 2],
#  ['Australia', 'Barbados', 2],
#  ['Australia', 'Bermuda', 42],
#  ['Australia', 'British Anguilla', 1],
#  ['Australia', 'British Virgin Islands', 104],
#  ['Australia', 'Cayman Islands', 8],
#  ['Australia', 'Cook Islands', 3],
#  ['Australia', 'Hong Kong', 2],
#  ['Australia', 'Isle of Man', 3],
#  ['Australia', 'Labuan', 1],
#  ['Australia', 'Niue', 4],
#  ['Australia', 'Panama', 20],
#  ['Australia', 'Saint Kitts and Nevis', 2],
#  ['Australia', 'Samoa', 1],
#  ['Australia', 'Seychelles', 4],
#  ['Austria', 'Bahamas', 4],
#  ['Austria', 'Bermuda', 4],
#  ['Austria', 'British Anguilla', 1],
#  ['Austria', 'British Virgin Islands', 10],
#  ['Austria', 'Cayman Islands', 2],
#  ['Austria', 'Panama', 12],
#  ['Austria', 'Saint Kitts and Nevis', 2],
#  ['Austria', 'Samoa', 1],
#  ['Azerbaijan', 'Bahamas', 4],
#  ['Azerbaijan', 'British Virgin Islands', 4],
#  ['Azerbaijan', 'Saint Kitts and Nevis', 2],
#  ['Bahamas', 'Barbados', 50],
#  ['Bahamas', 'Bermuda', 9],
#  ['Bahamas', 'British Anguilla', 45],
#  ['Bahamas', 'British Virgin Islands', 1769],
#  ['Bahamas', 'Cayman Islands', 23],
#  ['Bahamas', 'Cook Islands', 2],
#  ['Bahamas', 'Costa Rica', 9],
#  ['Bahamas', 'Cyprus', 2],
#  ['Bahamas', 'Hong Kong', 6],
#  ['Bahamas', 'Malta', 1],
#  ['Bahamas', 'Netherlands Antilles', 1],
#  ['Bahamas', 'Nevada', 291],
#  ['Bahamas', 'Niue', 58],
#  ['Bahamas', 'Panama', 2256],
#  ['Bahamas', 'Saint Lucia', 1],
#  ['Bahamas', 'Samoa', 27],
#  ['Bahamas', 'Seychelles', 105],
#  ['Bahamas', 'United Kingdom', 4],
#  ['Bahamas', 'Uruguay', 2],
#  ['Bahamas', 'Wyoming', 15],
#  ['Bahrain', 'Bermuda', 3],
#  ['Bahrain', 'British Virgin Islands', 10],
#  ['Bahrain', 'Panama', 3],
#  ['Bahrain', 'United Arab Emirates', 1],
#  ['Bangladesh', 'Bermuda', 1],
#  ['Bangladesh', 'British Virgin Islands', 2],
#  ['Barbados', 'Bahamas', 2],
#  ['Barbados', 'Bermuda', 8],
#  ['Barbados', 'British Virgin Islands', 15],
#  ['Barbados', 'Cayman Islands', 4],
#  ['Barbados', 'Panama', 18],
#  ['Belarus', 'British Virgin Islands', 15],
#  ['Belarus', 'Hong Kong', 1],
#  ['Belarus', 'Panama', 1],
#  ['Belgium', 'Bahamas', 8],
#  ['Belgium', 'Barbados', 1],
#  ['Belgium', 'Bermuda', 1],
#  ['Belgium', 'British Anguilla', 1],
#  ['Belgium', 'British Virgin Islands', 22],
#  ['Belgium', 'Isle of Man', 1],
#  ['Belgium', 'Niue', 1],
#  ['Belgium', 'Panama', 25],
#  ['Belgium', 'Saint Kitts and Nevis', 1],
#  ['Belgium', 'Samoa', 1],
#  ['Belgium', 'Seychelles', 5],
#  ['Belize', 'Bahamas', 250],
#  ['Belize', 'Barbados', 3],
#  ['Belize', 'British Anguilla', 19],
#  ['Belize', 'British Virgin Islands', 167],
#  ['Belize', 'Cayman Islands', 1],
#  ['Belize', 'Hong Kong', 44],
#  ['Belize', 'Mauritius', 1],
#  ['Belize', 'Niue', 228],
#  ['Belize', 'Panama', 423],
#  ['Belize', 'Saint Kitts and Nevis', 1],
#  ['Belize', 'Samoa', 45],
#  ['Belize', 'Seychelles', 175],
#  ['Belize', 'Wyoming', 1],
#  ['Bermuda', 'Bahamas', 21],
#  ['Bermuda', 'Barbados', 37],
#  ['Bermuda', 'British Virgin Islands', 139],
#  ['Bermuda', 'Cayman Islands', 17],
#  ['Bermuda', 'Cook Islands', 1],
#  ['Bermuda', 'Cyprus', 1],
#  ['Bermuda', 'Jersey', 3],
#  ['Bermuda', 'Liberia', 4],
#  ['Bermuda', 'Liechtenstein', 5],
#  ['Bermuda', 'Netherlands', 5],
#  ['Bermuda', 'Netherlands Antilles', 1],
#  ['Bermuda', 'Panama', 21],
#  ['Bermuda', 'Saint Kitts and Nevis', 1],
#  ['Bermuda', 'Samoa', 1],
#  ['Bermuda', 'Singapore', 1],
#  ['Bermuda', 'Turks and Caicos Islands', 1],
#  ['Bermuda', 'United States', 21],
#  ['Bolivia', 'British Virgin Islands', 2],
#  ['Bolivia', 'Hong Kong', 2],
#  ['Bolivia', 'Panama', 91],
#  ['Botswana', 'British Virgin Islands', 2],
#  ['Botswana', 'Panama', 1],
#  ['Botswana', 'Seychelles', 3],
#  ['Brazil', 'Bahamas', 33],
#  ['Brazil', 'Barbados', 2],
#  ['Brazil', 'Bermuda', 4],
#  ['Brazil', 'British Anguilla', 14],
#  ['Brazil', 'British Virgin Islands', 474],
#  ['Brazil', 'Cayman Islands', 21],
#  ['Brazil', 'Hong Kong', 2],
#  ['Brazil', 'Isle of Man', 3],
#  ['Brazil', 'Nevada', 132],
#  ['Brazil', 'New Zealand', 1],
#  ['Brazil', 'Niue', 91],
#  ['Brazil', 'Panama', 521],
#  ['Brazil', 'Samoa', 43],
#  ['Brazil', 'Seychelles', 79],
#  ['Brazil', 'United Kingdom', 6],
#  ['Brazil', 'Uruguay', 1],
#  ['Brazil', 'Wyoming', 4],
#  ['British Anguilla', 'Barbados', 7],
#  ['British Anguilla', 'British Anguilla', 21],
#  ['British Anguilla', 'British Virgin Islands', 2],
#  ['British Virgin Islands', 'Bahamas', 145],
#  ['British Virgin Islands', 'Barbados', 1053],
#  ['British Virgin Islands', 'Belize', 1],
#  ['British Virgin Islands', 'Bermuda', 13],
#  ['British Virgin Islands', 'British Anguilla', 1],
#  ['British Virgin Islands', 'Cayman Islands', 9],
#  ['British Virgin Islands', 'Cook Islands', 77],
#  ['British Virgin Islands', 'Hong Kong', 3],
#  ['British Virgin Islands', 'Isle of Man', 2],
#  ['British Virgin Islands', 'Labuan', 1],
#  ['British Virgin Islands', 'Marshall Islands', 1],
#  ['British Virgin Islands', 'Nevada', 2],
#  ['British Virgin Islands', 'Niue', 2],
#  ['British Virgin Islands', 'Panama', 92],
#  ['British Virgin Islands', 'Saint Kitts and Nevis', 2],
#  ['British Virgin Islands', 'Samoa', 3],
#  ['British Virgin Islands', 'Seychelles', 12],
#  ['British Virgin Islands', 'Singapore', 1],
#  ['British Virgin Islands', 'State of Delaware', 1],
#  ['Brunei', 'British Virgin Islands', 4],
#  ['Bulgaria', 'Bahamas', 2],
#  ['Bulgaria', 'British Virgin Islands', 20],
#  ['Bulgaria', 'Niue', 1],
#  ['Bulgaria', 'Panama', 5],
#  ['Bulgaria', 'Seychelles', 22],
#  ['Cameroon', 'Seychelles', 1],
#  ['Canada', 'Bahamas', 36],
#  ['Canada', 'Barbados', 132],
#  ['Canada', 'Bermuda', 79],
#  ['Canada', 'British Anguilla', 2],
#  ['Canada', 'British Virgin Islands', 241],
#  ['Canada', 'Cayman Islands', 65],
#  ['Canada', 'Cook Islands', 9],
#  ['Canada', 'Hong Kong', 3],
#  ['Canada', 'Isle of Man', 5],
#  ['Canada', 'Labuan', 2],
#  ['Canada', 'Nevada', 2],
#  ['Canada', 'Niue', 31],
#  ['Canada', 'Panama', 74],
#  ['Canada', 'Saint Kitts and Nevis', 1],
#  ['Canada', 'Samoa', 8],
#  ['Canada', 'Seychelles', 17],
#  ['Canada', 'Singapore', 5],
#  ['Cayman Islands', 'Antigua and Barbuda', 3],
#  ['Cayman Islands', 'Aruba', 2],
#  ['Cayman Islands', 'Bahamas', 43],
#  ['Cayman Islands', 'Barbados', 113],
#  ['Cayman Islands', 'Bermuda', 21],
#  ['Cayman Islands', 'British Virgin Islands', 1059],
#  ['Cayman Islands', 'Cook Islands', 37],
#  ['Cayman Islands', 'Cyprus', 3],
#  ['Cayman Islands', 'Gibraltar', 1],
#  ['Cayman Islands', 'Grenada', 1],
#  ['Cayman Islands', 'Guernsey', 9],
#  ['Cayman Islands', 'Hong Kong', 76],
#  ['Cayman Islands', 'Isle of Man', 8],
#  ['Cayman Islands', 'Jersey', 2],
#  ['Cayman Islands', 'Liberia', 1],
#  ['Cayman Islands', 'Liechtenstein', 1],
#  ['Cayman Islands', 'Luxembourg', 1],
#  ['Cayman Islands', 'Malta', 1],
#  ['Cayman Islands', 'Marshall Islands', 1],
#  ['Cayman Islands', 'Netherlands', 1],
#  ['Cayman Islands', 'Netherlands Antilles', 2],
#  ['Cayman Islands', 'New Zealand', 2],
#  ['Cayman Islands', 'Niue', 1],
#  ['Cayman Islands', 'Panama', 53],
#  ['Cayman Islands', 'Saint Kitts and Nevis', 96],
#  ['Cayman Islands', 'Saint Vincent and the Grenadines', 12],
#  ['Cayman Islands', 'Samoa', 855],
#  ['Cayman Islands', 'Singapore', 6],
#  ['Cayman Islands', 'State of Delaware', 116],
#  ['Cayman Islands', 'Turks and Caicos Islands', 1],
#  ['Cayman Islands', 'US Virgin Islands', 1],
#  ['Cayman Islands', 'United States', 22],
#  ['Central African Republic', 'British Virgin Islands', 1],
#  ['Chad', 'British Virgin Islands', 10],
#  ['Chad', 'Panama', 1],
#  ['Chile', 'Bahamas', 14],
#  ['Chile', 'Barbados', 1],
#  ['Chile', 'Bermuda', 1],
#  ['Chile', 'British Anguilla', 2],
#  ['Chile', 'British Virgin Islands', 31],
#  ['Chile', 'Costa Rica', 1],
#  ['Chile', 'Nevada', 6],
#  ['Chile', 'Panama', 83],
#  ['Chile', 'Seychelles', 2],
#  ['Chile', 'Wyoming', 1],
#  ['China', 'Bahamas', 5],
#  ['China', 'Barbados', 1],
#  ['China', 'Belize', 1],
#  ['China', 'Bermuda', 77],
#  ['China', 'British Anguilla', 148],
#  ['China', 'British Virgin Islands', 2384],
#  ['China', 'Cayman Islands', 148],
#  ['China', 'Cook Islands', 6],
#  ['China', 'Hong Kong', 11],
#  ['China', 'Isle of Man', 1],
#  ['China', 'Labuan', 1],
#  ['China', 'Nevada', 9],
#  ['China', 'Niue', 12],
#  ['China', 'Panama', 13],
#  ['China', 'Saint Kitts and Nevis', 2],
#  ['China', 'Samoa', 378],
#  ['China', 'Seychelles', 627],
#  ['China', 'Singapore', 3],
#  ['Colombia', 'Bahamas', 22],
#  ['Colombia', 'Belize', 19],
#  ['Colombia', 'Bermuda', 2],
#  ['Colombia', 'British Anguilla', 59],
#  ['Colombia', 'British Virgin Islands', 265],
#  ['Colombia', 'Cayman Islands', 3],
#  ['Colombia', 'Costa Rica', 42],
#  ['Colombia', 'Cyprus', 1],
#  ['Colombia', 'Hong Kong', 1],
#  ['Colombia', 'Malta', 1],
#  ['Colombia', 'Nevada', 10],
#  ['Colombia', 'New Zealand', 3],
#  ['Colombia', 'Niue', 2],
#  ['Colombia', 'Panama', 1357],
#  ['Colombia', 'Saint Kitts and Nevis', 3],
#  ['Colombia', 'Samoa', 6],
#  ['Colombia', 'Seychelles', 18],
#  ['Colombia', 'United Kingdom', 51],
#  ['Colombia', 'Uruguay', 1],
#  ['Cook Islands', 'Bermuda', 1],
#  ['Cook Islands', 'British Virgin Islands', 11],
#  ['Cook Islands', 'Hong Kong', 1],
#  ['Cook Islands', 'Niue', 1],
#  ['Cook Islands', 'Samoa', 1],
#  ['Costa Rica', 'Bahamas', 32],
#  ['Costa Rica', 'British Anguilla', 11],
#  ['Costa Rica', 'British Virgin Islands', 141],
#  ['Costa Rica', 'Cayman Islands', 2],
#  ['Costa Rica', 'Hong Kong', 5],
#  ['Costa Rica', 'Isle of Man', 1],
#  ['Costa Rica', 'Nevada', 2],
#  ['Costa Rica', 'Niue', 4],
#  ['Costa Rica', 'Panama', 686],
#  ['Costa Rica', 'Samoa', 3],
#  ['Costa Rica', 'Seychelles', 2],
#  ['Costa Rica', 'United Kingdom', 1],
#  ['Croatia', 'Barbados', 1],
#  ['Croatia', 'British Virgin Islands', 3],
#  ['Croatia', 'Panama', 1],
#  ['Cuba', 'Barbados', 1],
#  ['Cuba', 'British Virgin Islands', 8],
#  ['Cuba', 'Cayman Islands', 1],
#  ['Cuba', 'Panama', 3],
#  ['Curaçao', 'Barbados', 19],
#  ['Curaçao', 'Bermuda', 1],
#  ['Curaçao', 'British Virgin Islands', 11],
#  ['Curaçao', 'Panama', 8],
#  ['Curaçao', 'Seychelles', 12],
#  ['Curaçao', 'Singapore', 1],
#  ['Cyprus', 'Bahamas', 649],
#  ['Cyprus', 'Barbados', 5],
#  ['Cyprus', 'Belize', 11],
#  ['Cyprus', 'Bermuda', 8],
#  ['Cyprus', 'British Anguilla', 5],
#  ['Cyprus', 'British Virgin Islands', 1894],
#  ['Cyprus', 'Cayman Islands', 10],
#  ['Cyprus', 'Cook Islands', 4],
#  ['Cyprus', 'Hong Kong', 4],
#  ['Cyprus', 'Isle of Man', 4],
#  ['Cyprus', 'Labuan', 2],
#  ['Cyprus', 'Mauritius', 1],
#  ['Cyprus', 'Nevada', 1],
#  ['Cyprus', 'Niue', 313],
#  ['Cyprus', 'Panama', 305],
#  ['Cyprus', 'Saint Kitts and Nevis', 3],
#  ['Cyprus', 'Saint Lucia', 1],
#  ['Cyprus', 'Samoa', 14],
#  ['Cyprus', 'Seychelles', 448],
#  ['Cyprus', 'Singapore', 2],
#  ['Czech Republic', 'Bahamas', 2],
#  ['Czech Republic', 'Barbados', 1],
#  ['Czech Republic', 'British Virgin Islands', 29],
#  ['Czech Republic', 'Isle of Man', 1],
#  ['Czech Republic', 'Panama', 6],
#  ['Czech Republic', 'Samoa', 1],
#  ['Czech Republic', 'Seychelles', 1],
#  ["Côte d'Ivoire", 'British Virgin Islands', 10],
#  ["Côte d'Ivoire", 'Nevada', 1],
#  ["Côte d'Ivoire", 'Niue', 1],
#  ["Côte d'Ivoire", 'Panama', 7],
#  ["Côte d'Ivoire", 'Samoa', 2],
#  ['Denmark', 'Bahamas', 4],
#  ['Denmark', 'Barbados', 1],
#  ['Denmark', 'Bermuda', 2],
#  ['Denmark', 'British Virgin Islands', 4],
#  ['Denmark', 'Panama', 4],
#  ['Denmark', 'Seychelles', 2],
#  ['Djibouti', 'Panama', 1],
#  ['Dominica', 'Barbados', 1],
#  ['Dominica', 'British Virgin Islands', 4],
#  ['Dominica', 'Panama', 62],
#  ['Dominican Republic', 'Bahamas', 8],
#  ['Dominican Republic', 'Barbados', 3],
#  ['Dominican Republic', 'British Anguilla', 24],
#  ['Dominican Republic', 'British Virgin Islands', 132],
#  ['Dominican Republic', 'Cayman Islands', 5],
#  ['Dominican Republic', 'Panama', 312],
#  ['Dominican Republic', 'Samoa', 1],
#  ['Dominican Republic', 'Seychelles', 11],
#  ['Ecuador', 'Bahamas', 49],
#  ['Ecuador', 'Barbados', 2],
#  ['Ecuador', 'Belize', 5],
#  ['Ecuador', 'Bermuda', 1],
#  ['Ecuador', 'British Anguilla', 146],
#  ['Ecuador', 'British Virgin Islands', 252],
#  ['Ecuador', 'Cayman Islands', 1],
#  ['Ecuador', 'Costa Rica', 8],
#  ['Ecuador', 'Hong Kong', 2],
#  ['Ecuador', 'Nevada', 199],
#  ['Ecuador', 'New Zealand', 9],
#  ['Ecuador', 'Niue', 26],
#  ['Ecuador', 'Panama', 1101],
#  ['Ecuador', 'Samoa', 20],
#  ['Ecuador', 'Seychelles', 26],
#  ['Ecuador', 'United Kingdom', 7],
#  ['Ecuador', 'Uruguay', 2],
#  ['Egypt', 'Bahamas', 5],
#  ['Egypt', 'Barbados', 1],
#  ['Egypt', 'Bermuda', 3],
#  ['Egypt', 'British Virgin Islands', 17],
#  ['Egypt', 'Cayman Islands', 1],
#  ['Egypt', 'Panama', 20],
#  ['Egypt', 'Seychelles', 1],
#  ['El Salvador', 'Bahamas', 6],
#  ['El Salvador', 'Barbados', 2],
#  ['El Salvador', 'British Anguilla', 1],
#  ['El Salvador', 'British Virgin Islands', 19],
#  ['El Salvador', 'Nevada', 7],
#  ['El Salvador', 'Niue', 1],
#  ['El Salvador', 'Panama', 195],
#  ['El Salvador', 'Seychelles', 5],
#  ['Estonia', 'Bahamas', 114],
#  ['Estonia', 'British Anguilla', 1],
#  ['Estonia', 'British Virgin Islands', 645],
#  ['Estonia', 'Cyprus', 1],
#  ['Estonia', 'Isle of Man', 1],
#  ['Estonia', 'Malta', 1],
#  ['Estonia', 'Niue', 68],
#  ['Estonia', 'Panama', 14],
#  ['Estonia', 'Samoa', 3],
#  ['Estonia', 'Seychelles', 34],
#  ['Fiji', 'British Virgin Islands', 2],
#  ['Fiji', 'Cook Islands', 1],
#  ['Fiji', 'Singapore', 1],
#  ['Finland', 'Bahamas', 32],
#  ['Finland', 'British Virgin Islands', 26],
#  ['Finland', 'Cayman Islands', 7],
#  ['Finland', 'Niue', 1],
#  ['Finland', 'Panama', 3],
#  ['Finland', 'Seychelles', 4],
#  ['France', 'Bahamas', 23],
#  ['France', 'Barbados', 2],
#  ['France', 'Bermuda', 25],
#  ['France', 'British Anguilla', 10],
#  ['France', 'British Virgin Islands', 145],
#  ['France', 'Cayman Islands', 6],
#  ['France', 'Cook Islands', 3],
#  ['France', 'Cyprus', 1],
#  ['France', 'Hong Kong', 2],
#  ['France', 'Isle of Man', 1],
#  ['France', 'Labuan', 1],
#  ['France', 'Nevada', 1],
#  ['France', 'Niue', 18],
#  ['France', 'Panama', 78],
#  ['France', 'Samoa', 4],
#  ['France', 'Seychelles', 14],
#  ['French Guiana', 'British Virgin Islands', 20],
#  ['French Guiana', 'Cayman Islands', 8],
#  ['French Guiana', 'Guernsey', 2],
#  ['Georgia', 'British Anguilla', 1],
#  ['Georgia', 'Cook Islands', 1],
#  ['Germany', 'Bahamas', 1],
#  ['Germany', 'Barbados', 3],
#  ['Germany', 'Bermuda', 4],
#  ['Germany', 'British Anguilla', 1],
#  ['Germany', 'British Virgin Islands', 38],
#  ['Germany', 'Cayman Islands', 5],
#  ['Germany', 'Cyprus', 1],
#  ['Germany', 'Isle of Man', 1],
#  ['Germany', 'Niue', 2],
#  ['Germany', 'Panama', 129],
#  ['Germany', 'Samoa', 1],
#  ['Germany', 'Seychelles', 8],
#  ['Ghana', 'Bahamas', 1],
#  ['Ghana', 'British Anguilla', 1],
#  ['Ghana', 'British Virgin Islands', 1],
#  ['Gibraltar', 'Bahamas', 150],
#  ['Gibraltar', 'Barbados', 8],
#  ['Gibraltar', 'Belize', 2],
#  ['Gibraltar', 'British Virgin Islands', 1585],
#  ['Gibraltar', 'Cayman Islands', 1],
#  ['Gibraltar', 'Isle of Man', 4],
#  ['Gibraltar', 'Malta', 1],
#  ['Gibraltar', 'Nevada', 2],
#  ['Gibraltar', 'Niue', 28],
#  ['Gibraltar', 'Panama', 195],
#  ['Gibraltar', 'Samoa', 14],
#  ['Gibraltar', 'Seychelles', 64],
#  ['Gibraltar', 'Singapore', 1],
#  ['Greece', 'Bahamas', 7],
#  ['Greece', 'Bermuda', 5],
#  ['Greece', 'British Virgin Islands', 64],
#  ['Greece', 'Cayman Islands', 1],
#  ['Greece', 'Liberia', 1],
#  ['Greece', 'Panama', 134],
#  ['Greece', 'Seychelles', 21],
#  ['Grenada', 'Barbados', 2],
#  ['Grenada', 'British Virgin Islands', 2],
#  ['Grenada', 'Saint Kitts and Nevis', 4],
#  ['Guam', 'British Virgin Islands', 1],
#  ['Guatemala', 'Bahamas', 39],
#  ['Guatemala', 'British Anguilla', 23],
#  ['Guatemala', 'British Virgin Islands', 185],
#  ['Guatemala', 'Cayman Islands', 8],
#  ['Guatemala', 'Niue', 140],
#  ['Guatemala', 'Panama', 801],
#  ['Guatemala', 'Saint Kitts and Nevis', 4],
#  ['Guatemala', 'Samoa', 16],
#  ['Guatemala', 'Seychelles', 30],
#  ['Guernsey', 'Bahamas', 1504],
#  ['Guernsey', 'Barbados', 13],
#  ['Guernsey', 'Bermuda', 3],
#  ['Guernsey', 'British Anguilla', 27],
#  ['Guernsey', 'British Virgin Islands', 4736],
#  ['Guernsey', 'Cayman Islands', 4],
#  ['Guernsey', 'Cook Islands', 2],
#  ['Guernsey', 'Cyprus', 1],
#  ['Guernsey', 'Hong Kong', 2],
#  ['Guernsey', 'Isle of Man', 22],
#  ['Guernsey', 'Jersey', 8],
#  ['Guernsey', 'Niue', 302],
#  ['Guernsey', 'Panama', 705],
#  ['Guernsey', 'Samoa', 19],
#  ['Guernsey', 'Seychelles', 52],
#  ['Guernsey', 'Turks and Caicos Islands', 1],
#  ['Guernsey', 'Uruguay', 1],
#  ['Guyana', 'Barbados', 2],
#  ['Haiti', 'British Virgin Islands', 3],
#  ['Haiti', 'Nevada', 5],
#  ['Honduras', 'Bahamas', 1],
#  ['Honduras', 'British Virgin Islands', 4],
#  ['Honduras', 'Cayman Islands', 1],
#  ['Honduras', 'Panama', 19],
#  ['Hong Kong', 'Bahamas', 962],
#  ['Hong Kong', 'Barbados', 5],
#  ['Hong Kong', 'Belize', 6],
#  ['Hong Kong', 'Bermuda', 393],
#  ['Hong Kong', 'British Anguilla', 1366],
#  ['Hong Kong', 'British Virgin Islands', 28007],
#  ['Hong Kong', 'Cayman Islands', 234],
#  ['Hong Kong', 'Cook Islands', 32],
#  ['Hong Kong', 'Isle of Man', 10],
#  ['Hong Kong', 'Labuan', 19],
#  ['Hong Kong', 'Marshall Islands', 1],
#  ['Hong Kong', 'Mauritius', 5],
#  ['Hong Kong', 'Netherlands', 1],
#  ['Hong Kong', 'Nevada', 43],
#  ['Hong Kong', 'Niue', 1055],
#  ['Hong Kong', 'Panama', 610],
#  ['Hong Kong', 'Samoa', 3052],
#  ['Hong Kong', 'Seychelles', 3754],
#  ['Hong Kong', 'Singapore', 25],
#  ['Hong Kong', 'Thailand', 1],
#  ['Hong Kong', 'Vanuatu', 1],
#  ['Hungary', 'Bahamas', 4],
#  ['Hungary', 'Barbados', 3],
#  ['Hungary', 'British Virgin Islands', 25],
#  ['Hungary', 'Nevada', 1],
#  ['Hungary', 'Niue', 25],
#  ['Hungary', 'Panama', 7],
#  ['Hungary', 'Samoa', 1],
#  ['Hungary', 'Seychelles', 27],
#  ['Iceland', 'Bermuda', 2],
#  ['Iceland', 'British Virgin Islands', 14],
#  ['Iceland', 'Panama', 1],
#  ['India', 'Barbados', 1],
#  ['India', 'Bermuda', 10],
#  ['India', 'British Virgin Islands', 23],
#  ['India', 'Cayman Islands', 2],
#  ['India', 'Isle of Man', 8],
#  ['India', 'Niue', 1],
#  ['India', 'Panama', 2],
#  ['India', 'Samoa', 2],
#  ['India', 'Seychelles', 6],
#  ['India', 'Singapore', 1],
#  ['Indonesia', 'Bahamas', 1],
#  ['Indonesia', 'Bermuda', 5],
#  ['Indonesia', 'British Virgin Islands', 145],
#  ['Indonesia', 'Cayman Islands', 10],
#  ['Indonesia', 'Cook Islands', 8],
#  ['Indonesia', 'Hong Kong', 3],
#  ['Indonesia', 'Panama', 1],
#  ['Indonesia', 'Samoa', 15],
#  ['Indonesia', 'Seychelles', 4],
#  ['Indonesia', 'Singapore', 9],
#  ['Iran', 'Panama', 4],
#  ['Ireland', 'Bahamas', 25],
#  ['Ireland', 'Barbados', 13],
#  ['Ireland', 'Bermuda', 20],
#  ['Ireland', 'British Anguilla', 1],
#  ['Ireland', 'British Virgin Islands', 190],
#  ['Ireland', 'Cayman Islands', 9],
#  ['Ireland', 'Guernsey', 2],
#  ['Ireland', 'Hong Kong', 1],
#  ['Ireland', 'Isle of Man', 30],
#  ['Ireland', 'Jersey', 1],
#  ['Ireland', 'Niue', 31],
#  ['Ireland', 'Panama', 56],
#  ['Ireland', 'Samoa', 11],
#  ['Ireland', 'Seychelles', 13],
#  ['Isle of Man', 'Bahamas', 885],
#  ['Isle of Man', 'Barbados', 26],
#  ['Isle of Man', 'Bermuda', 5],
#  ['Isle of Man', 'British Anguilla', 35],
#  ['Isle of Man', 'British Virgin Islands', 3065],
#  ['Isle of Man', 'Cayman Islands', 12],
#  ['Isle of Man', 'Cyprus', 7],
#  ['Isle of Man', 'Guernsey', 4],
#  ['Isle of Man', 'Hong Kong', 7],
#  ['Isle of Man', 'Isle of Man', 7],
#  ['Isle of Man', 'Jersey', 9],
#  ['Isle of Man', 'Malta', 1],
#  ['Isle of Man', 'Nevada', 7],
#  ['Isle of Man', 'Niue', 271],
#  ['Isle of Man', 'Panama', 500],
#  ['Isle of Man', 'Samoa', 70],
#  ['Isle of Man', 'Seychelles', 80],
#  ['Isle of Man', 'United Arab Emirates', 1],
#  ['Isle of Man', 'United Kingdom', 2],
#  ['Isle of Man', 'Uruguay', 1],
#  ['Israel', 'Bahamas', 16],
#  ['Israel', 'Barbados', 1],
#  ['Israel', 'Belize', 10],
#  ['Israel', 'Bermuda', 1],
#  ['Israel', 'British Anguilla', 150],
#  ['Israel', 'British Virgin Islands', 179],
#  ['Israel', 'Cayman Islands', 4],
#  ['Israel', 'Cyprus', 4],
#  ['Israel', 'Hong Kong', 1],
#  ['Israel', 'Isle of Man', 2],
#  ['Israel', 'Malta', 4],
#  ['Israel', 'Niue', 11],
#  ['Israel', 'Panama', 127],
#  ['Israel', 'Samoa', 47],
#  ['Israel', 'Seychelles', 122],
#  ['Italy', 'Bahamas', 3],
#  ['Italy', 'British Anguilla', 204],
#  ['Italy', 'British Virgin Islands', 33],
#  ['Italy', 'Cayman Islands', 2],
#  ['Italy', 'Cook Islands', 1],
#  ['Italy', 'Cyprus', 13],
#  ['Italy', 'Hong Kong', 1],
#  ['Italy', 'Isle of Man', 2],
#  ['Italy', 'Nevada', 7],
#  ['Italy', 'Niue', 22],
#  ['Italy', 'Panama', 40],
#  ['Italy', 'Samoa', 3],
#  ['Italy', 'Seychelles', 22],
#  ['Jamaica', 'Bahamas', 1],
#  ['Jamaica', 'Barbados', 12],
#  ['Jamaica', 'British Virgin Islands', 4],
#  ['Jamaica', 'Cayman Islands', 5],
#  ['Japan', 'Bermuda', 8],
#  ['Japan', 'British Virgin Islands', 23],
#  ['Japan', 'Cayman Islands', 16],
#  ['Japan', 'Cook Islands', 1],
#  ['Japan', 'Niue', 2],
#  ['Japan', 'Panama', 7],
#  ['Japan', 'Samoa', 1],
#  ['Japan', 'Seychelles', 1],
#  ['Japan', 'Singapore', 1],
#  ['Jersey', 'Bahamas', 1244],
#  ['Jersey', 'Barbados', 44],
#  ['Jersey', 'Bermuda', 13],
#  ['Jersey', 'British Anguilla', 2],
#  ['Jersey', 'British Virgin Islands', 10611],
#  ['Jersey', 'Cayman Islands', 10],
#  ['Jersey', 'Cook Islands', 2],
#  ['Jersey', 'Cyprus', 1],
#  ['Jersey', 'Hong Kong', 66],
#  ['Jersey', 'Isle of Man', 19],
#  ['Jersey', 'Malta', 4],
#  ['Jersey', 'Mauritius', 1],
#  ['Jersey', 'Nevada', 3],
#  ['Jersey', 'Niue', 344],
#  ['Jersey', 'Panama', 2129],
#  ['Jersey', 'Saint Kitts and Nevis', 1],
#  ['Jersey', 'Samoa', 19],
#  ['Jersey', 'Seychelles', 18],
#  ['Jersey', 'Singapore', 1],
#  ['Jersey', 'United Kingdom', 6],
#  ['Jersey', 'Wyoming', 1],
#  ['Jordan', 'Bahamas', 14],
#  ['Jordan', 'Bermuda', 1],
#  ['Jordan', 'British Virgin Islands', 1146],
#  ['Jordan', 'Panama', 394],
#  ['Jordan', 'Seychelles', 1],
#  ['Kazakhstan', 'Bermuda', 1],
#  ['Kazakhstan', 'British Virgin Islands', 8],
#  ['Kazakhstan', 'Cayman Islands', 1],
#  ['Kazakhstan', 'Labuan', 1],
#  ['Kenya', 'Bahamas', 1],
#  ['Kenya', 'British Anguilla', 2],
#  ['Kenya', 'British Virgin Islands', 15],
#  ['Kenya', 'Cayman Islands', 1],
#  ['Kenya', 'Isle of Man', 1],
#  ['Kenya', 'Panama', 6],
#  ['Kenya', 'Seychelles', 1],
#  ['Kuwait', 'Bahamas', 2],
#  ['Kuwait', 'Bermuda', 1],
#  ['Kuwait', 'British Virgin Islands', 9],
#  ['Kuwait', 'Cayman Islands', 4],
#  ['Kuwait', 'Panama', 36],
#  ['Kuwait', 'Seychelles', 13],
#  ['Kyrgyzstan', 'Isle of Man', 1],
#  ['Latvia', 'Bahamas', 51],
#  ['Latvia', 'British Virgin Islands', 1305],
#  ['Latvia', 'Cook Islands', 1],
#  ['Latvia', 'Hong Kong', 1],
#  ['Latvia', 'Niue', 13],
#  ['Latvia', 'Panama', 12],
#  ['Latvia', 'Seychelles', 1],
#  ['Lebanon', 'Bahamas', 7],
#  ['Lebanon', 'Bermuda', 1],
#  ['Lebanon', 'British Virgin Islands', 213],
#  ['Lebanon', 'Cayman Islands', 1],
#  ['Lebanon', 'Hong Kong', 3],
#  ['Lebanon', 'Niue', 46],
#  ['Lebanon', 'Panama', 121],
#  ['Lebanon', 'Samoa', 12],
#  ['Lebanon', 'Seychelles', 88],
#  ['Lesotho', 'Seychelles', 1],
#  ['Liberia', 'Barbados', 19],
#  ['Liberia', 'Bermuda', 4],
#  ['Liberia', 'Liechtenstein', 36],
#  ['Liberia', 'Panama', 2],
#  ['Libya', 'British Virgin Islands', 1],
#  ['Libya', 'Panama', 1],
#  ['Liechtenstein', 'Bahamas', 87],
#  ['Liechtenstein', 'Barbados', 5],
#  ['Liechtenstein', 'Bermuda', 4],
#  ['Liechtenstein', 'British Anguilla', 5],
#  ['Liechtenstein', 'British Virgin Islands', 1270],
#  ['Liechtenstein', 'Cayman Islands', 5],
#  ['Liechtenstein', 'Cyprus', 1],
#  ['Liechtenstein', 'Hong Kong', 11],
#  ['Liechtenstein', 'Niue', 49],
#  ['Liechtenstein', 'Panama', 444],
#  ['Liechtenstein', 'Samoa', 32],
#  ['Liechtenstein', 'Seychelles', 169],
#  ['Liechtenstein', 'Singapore', 3],
#  ['Lithuania', 'Bahamas', 2],
#  ['Lithuania', 'British Anguilla', 1],
#  ['Lithuania', 'British Virgin Islands', 4],
#  ['Lithuania', 'Niue', 20],
#  ['Lithuania', 'Panama', 6],
#  ['Luxembourg', 'Bahamas', 423],
#  ['Luxembourg', 'Barbados', 11],
#  ['Luxembourg', 'Belize', 8],
#  ['Luxembourg', 'Bermuda', 4],
#  ['Luxembourg', 'British Anguilla', 7],
#  ['Luxembourg', 'British Virgin Islands', 3083],
#  ['Luxembourg', 'Cayman Islands', 8],
#  ['Luxembourg', 'Costa Rica', 1],
#  ['Luxembourg', 'Cyprus', 6],
#  ['Luxembourg', 'Hong Kong', 39],
#  ['Luxembourg', 'Malta', 6],
#  ['Luxembourg', 'Nevada', 29],
#  ['Luxembourg', 'Niue', 219],
#  ['Luxembourg', 'Panama', 5584],
#  ['Luxembourg', 'Samoa', 13],
#  ['Luxembourg', 'Seychelles', 1421],
#  ['Luxembourg', 'United Kingdom', 1],
#  ['Luxembourg', 'Uruguay', 1],
#  ['Luxembourg', 'Wyoming', 1],
#  ['Macao', 'Bermuda', 2],
#  ['Macao', 'British Virgin Islands', 28],
#  ['Macao', 'Cook Islands', 1],
#  ['Macao', 'Malta', 115],
#  ['Macao', 'Seychelles', 1],
#  ['Macedonia', 'British Virgin Islands', 1],
#  ['Macedonia', 'Seychelles', 1],
#  ['Malawi', 'British Virgin Islands', 1],
#  ['Malaysia', 'Bahamas', 1],
#  ['Malaysia', 'Barbados', 1],
#  ['Malaysia', 'Bermuda', 17],
#  ['Malaysia', 'British Anguilla', 1],
#  ['Malaysia', 'British Virgin Islands', 113],
#  ['Malaysia', 'Cayman Islands', 2],
#  ['Malaysia', 'Cook Islands', 2],
#  ['Malaysia', 'Hong Kong', 3],
#  ['Malaysia', 'Labuan', 424],
#  ['Malaysia', 'Niue', 4],
#  ['Malaysia', 'Panama', 2],
#  ['Malaysia', 'Saint Lucia', 1],
#  ['Malaysia', 'Samoa', 7],
#  ['Malaysia', 'Seychelles', 1],
#  ['Malaysia', 'Singapore', 4],
#  ['Mali', 'British Virgin Islands', 8],
#  ['Malta', 'Bahamas', 11],
#  ['Malta', 'Barbados', 1],
#  ['Malta', 'British Virgin Islands', 466],
#  ['Malta', 'Hong Kong', 1],
#  ['Malta', 'Isle of Man', 1],
#  ['Malta', 'New Zealand', 9],
#  ['Malta', 'Niue', 55],
#  ['Malta', 'Panama', 107],
#  ['Malta', 'Seychelles', 31],
#  ['Marshall Islands', 'Barbados', 1],
#  ['Marshall Islands', 'Cayman Islands', 1],
#  ['Marshall Islands', 'Isle of Man', 1],
#  ['Mauritius', 'Bahamas', 136],
#  ['Mauritius', 'Barbados', 3],
#  ['Mauritius', 'Bermuda', 2],
#  ['Mauritius', 'British Virgin Islands', 928],
#  ['Mauritius', 'Cayman Islands', 2],
#  ['Mauritius', 'Cook Islands', 1],
#  ['Mauritius', 'Isle of Man', 1],
#  ['Mauritius', 'Jersey', 3],
#  ['Mauritius', 'Niue', 32],
#  ['Mauritius', 'Panama', 108],
#  ['Mauritius', 'Samoa', 12],
#  ['Mauritius', 'Seychelles', 15],
#  ['Mexico', 'Bahamas', 3],
#  ['Mexico', 'Barbados', 3],
#  ['Mexico', 'Bermuda', 1],
#  ['Mexico', 'British Virgin Islands', 16],
#  ['Mexico', 'Cayman Islands', 5],
#  ['Mexico', 'Hong Kong', 1],
#  ['Mexico', 'Nevada', 1],
#  ['Mexico', 'Panama', 39],
#  ['Mexico', 'Seychelles', 6],
#  ['Mexico', 'United Kingdom', 1],
#  ['Moldova', 'British Virgin Islands', 2],
#  ['Monaco', 'Bahamas', 83],
#  ['Monaco', 'Belize', 2],
#  ['Monaco', 'Bermuda', 32],
#  ['Monaco', 'British Anguilla', 4],
#  ['Monaco', 'British Virgin Islands', 1041],
#  ['Monaco', 'Cayman Islands', 8],
#  ['Monaco', 'Hong Kong', 1],
#  ['Monaco', 'Isle of Man', 2],
#  ['Monaco', 'Nevada', 6],
#  ['Monaco', 'Niue', 49],
#  ['Monaco', 'Panama', 1402],
#  ['Monaco', 'Samoa', 20],
#  ['Monaco', 'Seychelles', 566],
#  ['Mongolia', 'British Virgin Islands', 3],
#  ['Montenegro', 'British Virgin Islands', 12],
#  ['Montenegro', 'Panama', 1],
#  ['Morocco', 'British Virgin Islands', 21],
#  ['Morocco', 'Panama', 2],
#  ['Morocco', 'Seychelles', 18],
#  ['Mozambique', 'British Virgin Islands', 1],
#  ['Mozambique', 'Seychelles', 2],
#  ['Namibia', 'Seychelles', 2],
#  ['Nauru', 'Panama', 1],
#  ['Netherlands', 'Bahamas', 28],
#  ['Netherlands', 'Barbados', 18],
#  ['Netherlands', 'Bermuda', 11],
#  ['Netherlands', 'British Anguilla', 4],
#  ['Netherlands', 'British Virgin Islands', 82],
#  ['Netherlands', 'Cayman Islands', 6],
#  ['Netherlands', 'Cook Islands', 1],
#  ['Netherlands', 'Isle of Man', 2],
#  ['Netherlands', 'Netherlands Antilles', 1],
#  ['Netherlands', 'Niue', 7],
#  ['Netherlands', 'Panama', 53],
#  ['Netherlands', 'Samoa', 4],
#  ['Netherlands', 'Seychelles', 6],
#  ['Netherlands', 'Singapore', 3],
#  ['New Zealand', 'Bahamas', 7],
#  ['New Zealand', 'Bermuda', 18],
#  ['New Zealand', 'British Virgin Islands', 30],
#  ['New Zealand', 'Cook Islands', 4],
#  ['New Zealand', 'Hong Kong', 1],
#  ['New Zealand', 'Nevada', 1],
#  ['New Zealand', 'Niue', 13],
#  ['New Zealand', 'Panama', 10],
#  ['New Zealand', 'Samoa', 7],
#  ['Nicaragua', 'British Virgin Islands', 2],
#  ['Nicaragua', 'Cayman Islands', 1],
#  ['Nicaragua', 'Panama', 10],
#  ['Nigeria', 'Bahamas', 5],
#  ['Nigeria', 'Barbados', 1],
#  ['Nigeria', 'Bermuda', 1],
#  ['Nigeria', 'British Virgin Islands', 12],
#  ['Nigeria', 'Cayman Islands', 2],
#  ['Nigeria', 'Panama', 2],
#  ['Nigeria', 'Seychelles', 2],
#  ['Niue', 'Bahamas', 1],
#  ['Niue', 'British Virgin Islands', 13],
#  ['Niue', 'Panama', 236],
#  ['Niue', 'Seychelles', 5],
#  ['Northern Mariana Islands', 'British Virgin Islands', 1],
#  ['Norway', 'Bahamas', 1],
#  ['Norway', 'Barbados', 2],
#  ['Norway', 'Bermuda', 26],
#  ['Norway', 'British Virgin Islands', 8],
#  ['Norway', 'Cayman Islands', 6],
#  ['Norway', 'Panama', 8],
#  ['Oman', 'British Virgin Islands', 3],
#  ['Oman', 'Cayman Islands', 1],
#  ['Pakistan', 'Bahamas', 1],
#  ['Pakistan', 'Bermuda', 1],
#  ['Pakistan', 'British Virgin Islands', 1],
#  ['Pakistan', 'Panama', 1],
#  ['Panama', 'Bahamas', 1120],
#  ['Panama', 'Barbados', 25],
#  ['Panama', 'Belize', 40],
#  ['Panama', 'British Anguilla', 278],
#  ['Panama', 'British Virgin Islands', 4791],
#  ['Panama', 'Cayman Islands', 4],
#  ['Panama', 'Cook Islands', 1],
#  ['Panama', 'Costa Rica', 5],
#  ['Panama', 'Cyprus', 22],
#  ['Panama', 'Hong Kong', 108],
#  ['Panama', 'Malta', 1],
#  ['Panama', 'Nevada', 82],
#  ['Panama', 'New Zealand', 2],
#  ['Panama', 'Niue', 1589],
#  ['Panama', 'Samoa', 410],
#  ['Panama', 'Seychelles', 1273],
#  ['Panama', 'United Kingdom', 5],
#  ['Panama', 'Uruguay', 7],
#  ['Panama', 'Wyoming', 5],
#  ['Paraguay', 'Bahamas', 10],
#  ['Paraguay', 'British Virgin Islands', 27],
#  ['Paraguay', 'Nevada', 5],
#  ['Paraguay', 'Niue', 1],
#  ['Paraguay', 'Panama', 84],
#  ['Peru', 'Bahamas', 2],
#  ['Peru', 'Barbados', 1],
#  ['Peru', 'Bermuda', 1],
#  ['Peru', 'British Virgin Islands', 10],
#  ['Peru', 'Cyprus', 1],
#  ['Peru', 'Hong Kong', 1],
#  ['Peru', 'Isle of Man', 1],
#  ['Peru', 'New Zealand', 1],
#  ['Peru', 'Niue', 1],
#  ['Peru', 'Panama', 35],
#  ['Peru', 'Seychelles', 1],
#  ['Philippines', 'Bahamas', 2],
#  ['Philippines', 'Bermuda', 9],
#  ['Philippines', 'British Anguilla', 1],
#  ['Philippines', 'British Virgin Islands', 31],
#  ['Philippines', 'Cayman Islands', 2],
#  ['Philippines', 'Hong Kong', 1],
#  ['Philippines', 'Niue', 10],
#  ['Philippines', 'Panama', 9],
#  ['Philippines', 'Seychelles', 4],
#  ['Poland', 'Bahamas', 58],
#  ['Poland', 'British Virgin Islands', 30],
#  ['Poland', 'Niue', 40],
#  ['Poland', 'Panama', 4],
#  ['Poland', 'Samoa', 1],
#  ['Poland', 'Seychelles', 26],
#  ['Poland', 'Wyoming', 1],
#  ['Portugal', 'Bahamas', 44],
#  ['Portugal', 'Barbados', 1],
#  ['Portugal', 'Bermuda', 2],
#  ['Portugal', 'British Virgin Islands', 64],
#  ['Portugal', 'Cayman Islands', 1],
#  ['Portugal', 'Cyprus', 5],
#  ['Portugal', 'Hong Kong', 1],
#  ['Portugal', 'Nevada', 2],
#  ['Portugal', 'Niue', 56],
#  ['Portugal', 'Panama', 63],
#  ['Portugal', 'Samoa', 10],
#  ['Puerto Rico', 'Barbados', 1],
#  ['Puerto Rico', 'British Virgin Islands', 1],
#  ['Puerto Rico', 'Panama', 1],
#  ['Qatar', 'Bahamas', 4],
#  ['Qatar', 'Bermuda', 1],
#  ['Qatar', 'British Virgin Islands', 10],
#  ['Qatar', 'Isle of Man', 5],
#  ['Qatar', 'Panama', 12],
#  ['Qatar', 'Seychelles', 1],
#  ['Romania', 'British Anguilla', 2],
#  ['Romania', 'British Virgin Islands', 4],
#  ['Romania', 'Malta', 1],
#  ['Romania', 'Panama', 2],
#  ['Russia', 'Bahamas', 1335],
#  ['Russia', 'Belize', 3],
#  ['Russia', 'Bermuda', 25],
#  ['Russia', 'British Anguilla', 73],
#  ['Russia', 'British Virgin Islands', 2336],
#  ['Russia', 'Cayman Islands', 6],
#  ['Russia', 'Cook Islands', 8],
#  ['Russia', 'Hong Kong', 8],
#  ['Russia', 'Niue', 366],
#  ['Russia', 'Panama', 94],
#  ['Russia', 'Saint Kitts and Nevis', 1],
#  ['Russia', 'Samoa', 9],
#  ['Russia', 'Seychelles', 21],
#  ['Russia', 'Singapore', 1],
#  ['Russia', 'Uruguay', 2],
#  ['Saint Kitts and Nevis', 'Bahamas', 9],
#  ['Saint Kitts and Nevis', 'Barbados', 6],
#  ['Saint Kitts and Nevis', 'British Virgin Islands', 27],
#  ['Saint Kitts and Nevis', 'Cayman Islands', 1],
#  ['Saint Kitts and Nevis', 'Cook Islands', 1],
#  ['Saint Kitts and Nevis', 'Hong Kong', 14],
#  ['Saint Kitts and Nevis', 'Mauritius', 1],
#  ['Saint Kitts and Nevis', 'Nevada', 4],
#  ['Saint Kitts and Nevis', 'Niue', 2],
#  ['Saint Kitts and Nevis', 'Panama', 117],
#  ['Saint Kitts and Nevis', 'Seychelles', 17],
#  ['Saint Lucia', 'Barbados', 115],
#  ['Saint Lucia', 'British Virgin Islands', 4],
#  ['Saint Lucia', 'Panama', 1],
#  ['Saint Lucia', 'Saint Lucia', 4],
#  ['Saint Martin (French part)', 'Barbados', 1],
#  ['Saint Vincent and the Grenadines', 'Barbados', 13],
#  ['Saint Vincent and the Grenadines', 'British Virgin Islands', 3],
#  ['Saint Vincent and the Grenadines', 'Panama', 3],
#  ['Samoa', 'Bahamas', 121],
#  ['Samoa', 'Bermuda', 1],
#  ['Samoa', 'British Anguilla', 2],
#  ['Samoa', 'British Virgin Islands', 252],
#  ['Samoa', 'Cayman Islands', 2],
#  ['Samoa', 'Cook Islands', 1],
#  ['Samoa', 'Hong Kong', 16],
#  ['Samoa', 'Niue', 78],
#  ['Samoa', 'Panama', 160],
#  ['Samoa', 'Seychelles', 850],
#  ['Samoa', 'United Kingdom', 1],
#  ['Saudi Arabia', 'Bahamas', 4],
#  ...]

# %%
d = collections.defaultdict(int)
for n1, n2, v in df_jur_grouped_list:
    d[min(n1, n2), max(n1, n2)] += v
result = [[k[0], k[1], v] for k, v in d.items()]

# %%
df_net = pd.DataFrame(result)
df_net
# Out:
#                            0                       1   2
# 0                    Albania                 Bahamas   2
# 1                    Andorra                 Bahamas  26
# 2                    Andorra  British Virgin Islands  39
# 3                    Andorra          Cayman Islands   1
# 4                    Andorra            Cook Islands   1
# ...                      ...                     ...  ..
# 1203                  Panama                 Vietnam   1
# 1204                  Panama                   Yemen   1
# 1205  British Virgin Islands                  Zambia   2
# 1206  British Virgin Islands                Zimbabwe   5
# 1207                  Panama                Zimbabwe   3
#
# [1208 rows x 3 columns]

# %%
df_net = df_net.rename(columns = {0:'node_1', 1:'node_2', 2: 'weight'})
df_net
# Out:
#                       node_1                  node_2  weight
# 0                    Albania                 Bahamas       2
# 1                    Andorra                 Bahamas      26
# 2                    Andorra  British Virgin Islands      39
# 3                    Andorra          Cayman Islands       1
# 4                    Andorra            Cook Islands       1
# ...                      ...                     ...     ...
# 1203                  Panama                 Vietnam       1
# 1204                  Panama                   Yemen       1
# 1205  British Virgin Islands                  Zambia       2
# 1206  British Virgin Islands                Zimbabwe       5
# 1207                  Panama                Zimbabwe       3
#
# [1208 rows x 3 columns]

# %%
#import df_net to csv later

# %%
g = ig.Graph.TupleList(df_net.itertuples(index=False), directed=False, edge_attrs={'weight': "weight"})

# %%
ig.plot(g)

# %%
g.diameter()
# Out:
# 4

# %%
len(g.vs.indices)
# Out:
# 175

# %%
#g.vs.indices
df_net['node_1'].value_counts()
# Out:
# British Virgin Islands    133
# Bahamas                    95
# Cayman Islands             74
# Bermuda                    69
# Barbados                   68
#                          ...
# Portugal                    1
# Iceland                     1
# Montenegro                  1
# Chad                        1
# Nauru                       1
# Name: node_1, Length: 127, dtype: int64

# %%
uni =df_net['node_1'].unique()

# %%
len(uni)
# Out:
# 127

# %%
list(g.vs)
# Out:
# [igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 0, {'name': 'Albania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 2, {'name': 'Andorra'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 4, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 5, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 6, {'name': 'Costa Rica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 7, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 8, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 9, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 10, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 11, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 12, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 13, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 14, {'name': 'Uruguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 15, {'name': 'Angola'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 16, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 17, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 18, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 19, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 20, {'name': 'Argentina'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 21, {'name': 'New Zealand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 22, {'name': 'Aruba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 23, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 24, {'name': 'Australia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 25, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 26, {'name': 'Labuan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 27, {'name': 'Austria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 28, {'name': 'Azerbaijan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 29, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 30, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 31, {'name': 'Netherlands Antilles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 32, {'name': 'Saint Lucia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 33, {'name': 'Wyoming'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 34, {'name': 'Bahrain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 35, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 36, {'name': 'Bangladesh'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 37, {'name': 'Belarus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 38, {'name': 'Belgium'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 39, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 40, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 42, {'name': 'Liberia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 43, {'name': 'Liechtenstein'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 44, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 45, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 46, {'name': 'Turks and Caicos Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 47, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 48, {'name': 'Bolivia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 49, {'name': 'Botswana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 50, {'name': 'Brazil'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 51, {'name': 'Marshall Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 52, {'name': 'State of Delaware'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 53, {'name': 'Brunei'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 54, {'name': 'Bulgaria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 55, {'name': 'Cameroon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 56, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 57, {'name': 'Gibraltar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 58, {'name': 'Grenada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 59, {'name': 'Guernsey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 60, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 61, {'name': 'Saint Vincent and the Grenadines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 62, {'name': 'US Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 63, {'name': 'Central African Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 64, {'name': 'Chad'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 65, {'name': 'Chile'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 66, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 67, {'name': 'Colombia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 68, {'name': 'Croatia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 69, {'name': 'Cuba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 70, {'name': 'Curaçao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 71, {'name': 'Czech Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 72, {'name': "Côte d'Ivoire"}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 73, {'name': 'Denmark'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 74, {'name': 'Djibouti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 75, {'name': 'Dominica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 76, {'name': 'Dominican Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 77, {'name': 'Ecuador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 78, {'name': 'Egypt'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 79, {'name': 'El Salvador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 80, {'name': 'Estonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 81, {'name': 'Fiji'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 82, {'name': 'Finland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 83, {'name': 'France'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 84, {'name': 'French Guiana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 85, {'name': 'Georgia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 86, {'name': 'Germany'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 87, {'name': 'Ghana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 88, {'name': 'Greece'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 89, {'name': 'Guam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 90, {'name': 'Guatemala'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 91, {'name': 'Guyana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 92, {'name': 'Haiti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 93, {'name': 'Honduras'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 94, {'name': 'Thailand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 95, {'name': 'Vanuatu'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 96, {'name': 'Hungary'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 97, {'name': 'Iceland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 98, {'name': 'India'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 99, {'name': 'Indonesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 100, {'name': 'Iran'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 101, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 102, {'name': 'Israel'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 103, {'name': 'Italy'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 104, {'name': 'Jamaica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 105, {'name': 'Japan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 106, {'name': 'Jordan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 107, {'name': 'Kazakhstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 108, {'name': 'Kenya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 109, {'name': 'Kuwait'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 110, {'name': 'Kyrgyzstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 111, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 112, {'name': 'Lebanon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 113, {'name': 'Lesotho'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 114, {'name': 'Libya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 115, {'name': 'Lithuania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 116, {'name': 'Macao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 117, {'name': 'Macedonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 118, {'name': 'Malawi'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 119, {'name': 'Malaysia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 120, {'name': 'Mali'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 121, {'name': 'Mexico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 122, {'name': 'Moldova'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 123, {'name': 'Monaco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 124, {'name': 'Mongolia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 125, {'name': 'Montenegro'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 126, {'name': 'Morocco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 127, {'name': 'Mozambique'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 128, {'name': 'Namibia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 129, {'name': 'Nauru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 130, {'name': 'Nicaragua'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 131, {'name': 'Nigeria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 132, {'name': 'Northern Mariana Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 133, {'name': 'Norway'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 134, {'name': 'Oman'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 135, {'name': 'Pakistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 136, {'name': 'Paraguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 137, {'name': 'Peru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 138, {'name': 'Philippines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 139, {'name': 'Poland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 140, {'name': 'Portugal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 141, {'name': 'Puerto Rico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 142, {'name': 'Qatar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 143, {'name': 'Romania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 144, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 145, {'name': 'Saint Martin (French part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 146, {'name': 'Saudi Arabia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 147, {'name': 'Senegal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 148, {'name': 'Sierra Leone'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 149, {'name': 'Sint Maarten (Dutch part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 150, {'name': 'Slovakia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 151, {'name': 'Slovenia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 152, {'name': 'South Africa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 153, {'name': 'South Korea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 154, {'name': 'Spain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 155, {'name': 'Sri Lanka'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 156, {'name': 'Sudan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 157, {'name': 'Suriname'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 158, {'name': 'Sweden'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 159, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 160, {'name': 'Syria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 161, {'name': 'Taiwan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 162, {'name': 'Tanzania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 163, {'name': 'Trinidad and Tobago'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 164, {'name': 'Tunisia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 165, {'name': 'Turkey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 166, {'name': 'Uganda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 167, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 168, {'name': 'Dubai'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 169, {'name': 'Uzbekistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 170, {'name': 'Venezuela'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 171, {'name': 'Vietnam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 172, {'name': 'Yemen'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 173, {'name': 'Zambia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7ff70daf8e50>, 174, {'name': 'Zimbabwe'})]

# %%
##similar to mini-proj, try a random target 
import random
random.seed(5104)
def unweighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
         #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'avg_betweenness':bet,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#try another function but this time with g.diameter having weight param 
#https://igraph.org/python/api/latest/igraph._igraph.GraphBase.html#diameter

random.seed(5104)
def weighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #try in-degree
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'avg_weighted_betweenness':bet,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type1_unweighted = unweighted_Type1_random_delete(g)
df_type1_unweighted.head()
# Out:
#    nodes_removed  avg_betweenness  prop_removed  diameter  \
# 0              1        87.178161          0.01       4.0
# 1              2        86.728324          0.01       4.0
# 2              3        85.965116          0.02       4.0
# 3              4        85.549708          0.02       4.0
# 4              5        84.582353          0.03       4.0
#
#    assortativity_degree  avg_unweighted_indegree   density  average_path_len
# 0             -0.567412                13.862069  0.079212          2.007840
# 1             -0.565270                13.791908  0.079264          2.008469
# 2             -0.564758                13.825581  0.079917          2.005440
# 3             -0.563116                13.730994  0.079831          2.006467
# 4             -0.562531                13.800000  0.080702          2.000975

# %%
df_type1_unweighted.tail()
# Out:
#      nodes_removed  avg_betweenness  prop_removed  diameter  \
# 170            171              0.0          0.87       0.0
# 171            172              0.0          0.88       0.0
# 172            173              0.0          0.88       0.0
# 173            174              0.0          0.89       0.0
# 174            175              0.0          0.89       NaN
#
#      assortativity_degree  avg_unweighted_indegree  density  average_path_len
# 170                   NaN                      0.0      0.0               NaN
# 171                   NaN                      0.0      0.0               NaN
# 172                   NaN                      0.0      0.0               NaN
# 173                   NaN                      0.0      0.0               NaN
# 174                   NaN                      0.0      NaN               NaN

# %%
df_type1_weighted = weighted_Type1_random_delete(g)
df_type1_weighted.head()
# Out:
#    nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 0              1          0.01      15.0                182.538869
# 1              2          0.01      15.0                181.457542
# 2              3          0.02      15.0                180.540995
# 3              4          0.02      15.0                179.216738
# 4              5          0.03      15.0                178.286595
#
#    assortativity_degree  avg_weighted_indegree   density  average_path_len
# 0             -0.568830            2349.160920  0.077635          2.010498
# 1             -0.569087            2362.705202  0.078400          2.009544
# 2             -0.569178            2370.732558  0.078438          2.010132
# 3             -0.570649            2382.479532  0.079083          2.009288
# 4             -0.568382            2394.211765  0.079188          2.010164

# %%
df_type1_weighted.tail(15)
# Out:
#      nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 160            161          0.82     124.0                  2.714286
# 161            162          0.83     124.0                  2.923077
# 162            163          0.83     926.0                  0.833333
# 163            164          0.84     926.0                  0.545455
# 164            165          0.84     926.0                  0.300000
# 165            166          0.85      27.0                  0.111111
# 166            167          0.85      27.0                  0.125000
# 167            168          0.86       0.0                  0.000000
# 168            169          0.86       0.0                  0.000000
# 169            170          0.87       0.0                  0.000000
# 170            171          0.87       0.0                  0.000000
# 171            172          0.88       0.0                  0.000000
# 172            173          0.88       0.0                  0.000000
# 173            174          0.89       0.0                  0.000000
# 174            175          0.89       NaN                  0.000000
#
#      assortativity_degree  avg_weighted_indegree   density  average_path_len
# 160             -0.811321             147.285714  0.076190          2.071429
# 161             -0.811321             158.615385  0.087912          2.071429
# 162             -1.000000             154.833333  0.064103          1.666667
# 163             -1.000000             168.727273  0.060606          1.600000
# 164             -1.000000             185.400000  0.054545          1.500000
# 165             -1.000000               6.000000  0.044444          1.333333
# 166             -1.000000               6.750000  0.055556          1.333333
# 167                   NaN               0.000000  0.000000               NaN
# 168                   NaN               0.000000  0.000000               NaN
# 169                   NaN               0.000000  0.000000               NaN
# 170                   NaN               0.000000  0.000000               NaN
# 171                   NaN               0.000000  0.000000               NaN
# 172                   NaN               0.000000  0.000000               NaN
# 173                   NaN               0.000000  0.000000               NaN
# 174                   NaN               0.000000       NaN               NaN

# %% [markdown]
# ### Targeted attack

# %%
##try sort by transitivity 
temp_df = pd.DataFrame({'Node_indice':g.vs.indices,
                         'Nodes':g.vs['name'],
                         'transitivity':g.transitivity_local_undirected(mode='zero',weights='weight')})

# %%
#sort by largest degree 
temp_df = temp_df.sort_values(by='transitivity',ascending=False)

# %%
temp_df.head(50)
# Out:
#      Node_indice                             Nodes  transitivity
# 62            62                 US Virgin Islands      1.272059
# 32            32                       Saint Lucia      1.250627
# 87            87                             Ghana      1.000000
# 75            75                          Dominica      1.000000
# 97            97                           Iceland      1.000000
# 95            95                           Vanuatu      1.000000
# 93            93                          Honduras      1.000000
# 92            92                             Haiti      1.000000
# 84            84                     French Guiana      1.000000
# 82            82                           Finland      1.000000
# 81            81                              Fiji      1.000000
# 69            69                              Cuba      1.000000
# 48            48                           Bolivia      1.000000
# 68            68                           Croatia      1.000000
# 64            64                              Chad      1.000000
# 61            61  Saint Vincent and the Grenadines      1.000000
# 54            54                          Bulgaria      1.000000
# 52            52                 State of Delaware      1.000000
# 51            51                  Marshall Islands      1.000000
# 104          104                           Jamaica      1.000000
# 111          111                            Latvia      1.000000
# 114          114                             Libya      1.000000
# 147          147                           Senegal      1.000000
# 171          171                           Vietnam      1.000000
# 164          164                           Tunisia      1.000000
# 163          163               Trinidad and Tobago      1.000000
# 162          162                          Tanzania      1.000000
# 160          160                             Syria      1.000000
# 151          151                          Slovenia      1.000000
# 150          150                          Slovakia      1.000000
# 141          141                       Puerto Rico      1.000000
# 117          117                         Macedonia      1.000000
# 135          135                          Pakistan      1.000000
# 134          134                              Oman      1.000000
# 133          133                            Norway      1.000000
# 130          130                         Nicaragua      1.000000
# 127          127                        Mozambique      1.000000
# 126          126                           Morocco      1.000000
# 125          125                        Montenegro      1.000000
# 49            49                          Botswana      1.000000
# 174          174                          Zimbabwe      1.000000
# 31            31              Netherlands Antilles      1.000000
# 28            28                        Azerbaijan      1.000000
# 36            36                        Bangladesh      1.000000
# 37            37                           Belarus      1.000000
# 34            34                           Bahrain      1.000000
# 15            15                            Angola      1.000000
# 106          106                            Jordan      0.999679
# 99            99                         Indonesia      0.995025
# 71            71                    Czech Republic      0.991870

# %%
temp_df.tail(50)
# Out:
#      Node_indice                       Nodes  transitivity
# 30            30                       Malta      0.829595
# 19            19       Saint Kitts and Nevis      0.828712
# 21            21                 New Zealand      0.818229
# 47            47               United States      0.817602
# 33            33                     Wyoming      0.786787
# 103          103                       Italy      0.779037
# 11            11                       Samoa      0.662794
# 5              5                Cook Islands      0.642435
# 116          116                       Macao      0.598639
# 18            18                    Barbados      0.588317
# 4              4              Cayman Islands      0.576880
# 23            23            British Anguilla      0.513541
# 8              8                      Nevada      0.468442
# 119          119                    Malaysia      0.453084
# 9              9                        Niue      0.451341
# 1              1                     Bahamas      0.446761
# 12            12                  Seychelles      0.385241
# 26            26                      Labuan      0.369322
# 16            16                     Bermuda      0.322079
# 10            10                      Panama      0.296842
# 3              3      British Virgin Islands      0.252604
# 100          100                        Iran      0.000000
# 156          156                       Sudan      0.000000
# 166          166                      Uganda      0.000000
# 168          168                       Dubai      0.000000
# 169          169                  Uzbekistan      0.000000
# 85            85                     Georgia      0.000000
# 74            74                    Djibouti      0.000000
# 172          172                       Yemen      0.000000
# 173          173                      Zambia      0.000000
# 157          157                    Suriname      0.000000
# 91            91                      Guyana      0.000000
# 155          155                   Sri Lanka      0.000000
# 118          118                      Malawi      0.000000
# 129          129                       Nauru      0.000000
# 113          113                     Lesotho      0.000000
# 132          132    Northern Mariana Islands      0.000000
# 63            63    Central African Republic      0.000000
# 55            55                    Cameroon      0.000000
# 53            53                      Brunei      0.000000
# 124          124                    Mongolia      0.000000
# 110          110                  Kyrgyzstan      0.000000
# 122          122                     Moldova      0.000000
# 120          120                        Mali      0.000000
# 145          145  Saint Martin (French part)      0.000000
# 89            89                        Guam      0.000000
# 148          148                Sierra Leone      0.000000
# 149          149   Sint Maarten (Dutch part)      0.000000
# 128          128                     Namibia      0.000000
# 0              0                     Albania      0.000000

# %%
#extract out by Node
transitivity_of_del = temp_df['Nodes'].tolist()

# %%
#print the list to check it
transitivity_of_del
# Out:
# ['US Virgin Islands',
#  'Saint Lucia',
#  'Ghana',
#  'Dominica',
#  'Iceland',
#  'Vanuatu',
#  'Honduras',
#  'Haiti',
#  'French Guiana',
#  'Finland',
#  'Fiji',
#  'Cuba',
#  'Bolivia',
#  'Croatia',
#  'Chad',
#  'Saint Vincent and the Grenadines',
#  'Bulgaria',
#  'State of Delaware',
#  'Marshall Islands',
#  'Jamaica',
#  'Latvia',
#  'Libya',
#  'Senegal',
#  'Vietnam',
#  'Tunisia',
#  'Trinidad and Tobago',
#  'Tanzania',
#  'Syria',
#  'Slovenia',
#  'Slovakia',
#  'Puerto Rico',
#  'Macedonia',
#  'Pakistan',
#  'Oman',
#  'Norway',
#  'Nicaragua',
#  'Mozambique',
#  'Morocco',
#  'Montenegro',
#  'Botswana',
#  'Zimbabwe',
#  'Netherlands Antilles',
#  'Azerbaijan',
#  'Bangladesh',
#  'Belarus',
#  'Bahrain',
#  'Angola',
#  'Jordan',
#  'Indonesia',
#  'Czech Republic',
#  'Gibraltar',
#  'South Africa',
#  'Dominican Republic',
#  'Estonia',
#  'Ukraine',
#  'Paraguay',
#  'Qatar',
#  'Mauritius',
#  'Egypt',
#  'Turkey',
#  'Argentina',
#  'Kenya',
#  'Germany',
#  'Nigeria',
#  'Russia',
#  'Guatemala',
#  'El Salvador',
#  'Peru',
#  'Costa Rica',
#  'Guernsey',
#  'Uruguay',
#  'Colombia',
#  'Belgium',
#  'Lebanon',
#  'Venezuela',
#  'Jersey',
#  'Mexico',
#  'Japan',
#  'Monaco',
#  'Ireland',
#  'Switzerland',
#  'Isle of Man',
#  'Andorra',
#  'Kuwait',
#  'Singapore',
#  'Luxembourg',
#  'Denmark',
#  'Taiwan',
#  'Aruba',
#  'Curaçao',
#  'Cyprus',
#  'Austria',
#  "Côte d'Ivoire",
#  'Thailand',
#  'Belize',
#  'Hong Kong',
#  'Spain',
#  'India',
#  'South Korea',
#  'Saudi Arabia',
#  'Chile',
#  'Antigua and Barbuda',
#  'Portugal',
#  'Liechtenstein',
#  'China',
#  'Greece',
#  'Ecuador',
#  'Grenada',
#  'United Kingdom',
#  'Israel',
#  'Sweden',
#  'France',
#  'Turks and Caicos Islands',
#  'Philippines',
#  'Australia',
#  'Poland',
#  'Netherlands',
#  'Romania',
#  'Brazil',
#  'Kazakhstan',
#  'United Arab Emirates',
#  'Hungary',
#  'Canada',
#  'Lithuania',
#  'Liberia',
#  'Malta',
#  'Saint Kitts and Nevis',
#  'New Zealand',
#  'United States',
#  'Wyoming',
#  'Italy',
#  'Samoa',
#  'Cook Islands',
#  'Macao',
#  'Barbados',
#  'Cayman Islands',
#  'British Anguilla',
#  'Nevada',
#  'Malaysia',
#  'Niue',
#  'Bahamas',
#  'Seychelles',
#  'Labuan',
#  'Bermuda',
#  'Panama',
#  'British Virgin Islands',
#  'Iran',
#  'Sudan',
#  'Uganda',
#  'Dubai',
#  'Uzbekistan',
#  'Georgia',
#  'Djibouti',
#  'Yemen',
#  'Zambia',
#  'Suriname',
#  'Guyana',
#  'Sri Lanka',
#  'Malawi',
#  'Nauru',
#  'Lesotho',
#  'Northern Mariana Islands',
#  'Central African Republic',
#  'Cameroon',
#  'Brunei',
#  'Mongolia',
#  'Kyrgyzstan',
#  'Moldova',
#  'Mali',
#  'Saint Martin (French part)',
#  'Guam',
#  'Sierra Leone',
#  'Sint Maarten (Dutch part)',
#  'Namibia',
#  'Albania']

# %%
def unweighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(transitivity_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(transitivity_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#Weighted on diameter
def weighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(transitivity_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(transitivity_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_weighted_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type2_unweighted = unweighted_Type2_targeted_del(g)
df_type2_unweighted.head()
# Out:
#    num_nodes_removed  prop_removed       node_removed  avg_betweenness  \
# 0                  1          0.01  US Virgin Islands        87.264368
# 1                  2          0.01        Saint Lucia        86.774566
# 2                  3          0.02              Ghana        86.197674
# 3                  4          0.02           Dominica        85.666667
# 4                  5          0.03            Iceland        85.129412
#
#    diameter  assortativity_degree  avg_unweighted_indegree   density  \
# 0       4.0             -0.567788                13.793103  0.078818
# 1       4.0             -0.571145                13.768786  0.079131
# 2       4.0             -0.571274                13.813953  0.079849
# 3       4.0             -0.571792                13.859649  0.080579
# 4       4.0             -0.572233                13.905882  0.081321
#
#    average_path_len
# 0          2.008837
# 1          2.009007
# 2          2.008160
# 3          2.007843
# 4          2.007449

# %%
df_type2_unweighted.tail()
# Out:
#      num_nodes_removed  prop_removed               node_removed  \
# 170                171          0.87                       Guam
# 171                172          0.88               Sierra Leone
# 172                173          0.88  Sint Maarten (Dutch part)
# 173                174          0.89                    Namibia
# 174                175          0.89                    Albania
#
#      avg_betweenness  diameter  assortativity_degree  avg_unweighted_indegree  \
# 170              0.0       0.0                   NaN                      0.0
# 171              0.0       0.0                   NaN                      0.0
# 172              0.0       0.0                   NaN                      0.0
# 173              0.0       0.0                   NaN                      0.0
# 174              0.0       NaN                   NaN                      0.0
#
#      density  average_path_len
# 170      0.0               NaN
# 171      0.0               NaN
# 172      0.0               NaN
# 173      0.0               NaN
# 174      NaN               NaN

# %%
df_type2_weighted = weighted_Type2_targeted_del(g)
df_type2_weighted.head(15)
# Out:
#     num_nodes_removed  prop_removed       node_removed  \
# 0                   1          0.01  US Virgin Islands
# 1                   2          0.01        Saint Lucia
# 2                   3          0.02              Ghana
# 3                   4          0.02           Dominica
# 4                   5          0.03            Iceland
# 5                   6          0.03            Vanuatu
# 6                   7          0.04           Honduras
# 7                   8          0.04              Haiti
# 8                   9          0.05      French Guiana
# 9                  10          0.05            Finland
# 10                 11          0.06               Fiji
# 11                 12          0.06               Cuba
# 12                 13          0.07            Bolivia
# 13                 14          0.07            Croatia
# 14                 15          0.08               Chad
#
#     avg_weighted_betweenness  diameter  assortativity_degree  \
# 0                 182.669483      15.0             -0.567788
# 1                 182.096682      15.0             -0.571145
# 2                 181.109382      15.0             -0.571274
# 3                 179.797146      15.0             -0.571792
# 4                 178.714056      15.0             -0.572233
# 5                 178.293622      15.0             -0.574016
# 6                 177.146401      15.0             -0.574131
# 7                 175.706257      15.0             -0.575027
# 8                 173.749453      15.0             -0.576318
# 9                 172.284673      15.0             -0.575526
# 10                171.525238      15.0             -0.576794
# 11                170.549918      15.0             -0.576756
# 12                169.469613      15.0             -0.577476
# 13                168.532925      15.0             -0.577920
# 14                167.058920      15.0             -0.578872
#
#     avg_weighted_indegree   density  average_path_len
# 0             2516.505747  0.078818          2.008837
# 1             2529.560694  0.079131          2.009007
# 2             2544.232558  0.079849          2.008160
# 3             2558.327485  0.080579          2.007843
# 4             2573.176471  0.081321          2.007449
# 5             2588.284024  0.081866          2.007185
# 6             2603.392857  0.082558          2.006843
# 7             2618.886228  0.083405          2.005555
# 8             2634.301205  0.084193          2.004454
# 9             2649.381818  0.084775          2.004435
# 10            2665.487805  0.085588          2.003217
# 11            2681.680982  0.086338          2.002954
# 12            2697.061728  0.087177          2.002300
# 13            2713.751553  0.088030          2.001863
# 14            2730.575000  0.088975          2.001101

# %%
df_type2_weighted.tail(150)
# Out:
#      num_nodes_removed  prop_removed               node_removed  \
# 25                  26          0.13        Trinidad and Tobago
# 26                  27          0.14                   Tanzania
# 27                  28          0.14                      Syria
# 28                  29          0.15                   Slovenia
# 29                  30          0.15                   Slovakia
# ..                 ...           ...                        ...
# 170                171          0.87                       Guam
# 171                172          0.88               Sierra Leone
# 172                173          0.88  Sint Maarten (Dutch part)
# 173                174          0.89                    Namibia
# 174                175          0.89                    Albania
#
#      avg_weighted_betweenness  diameter  assortativity_degree  \
# 25                 155.483683      15.0             -0.582931
# 26                 154.252889      15.0             -0.583787
# 27                 153.205966      15.0             -0.584293
# 28                 151.983578      15.0             -0.584430
# 29                 150.764345      15.0             -0.585238
# ..                        ...       ...                   ...
# 170                  0.000000       0.0                   NaN
# 171                  0.000000       0.0                   NaN
# 172                  0.000000       0.0                   NaN
# 173                  0.000000       0.0                   NaN
# 174                  0.000000       NaN                   NaN
#
#      avg_weighted_indegree   density  average_path_len
# 25             2907.959732  0.098255          1.993198
# 26             2927.567568  0.099401          1.992186
# 27             2947.414966  0.100478          1.991427
# 28             2967.301370  0.101482          1.990836
# 29             2987.737931  0.102692          1.989751
# ..                     ...       ...               ...
# 170               0.000000  0.000000               NaN
# 171               0.000000  0.000000               NaN
# 172               0.000000  0.000000               NaN
# 173               0.000000  0.000000               NaN
# 174               0.000000       NaN               NaN
#
# [150 rows x 9 columns]

# %% [markdown]
# #### Unweighted

# %%
## Commented out to not confuse; use the weighted one below

#Try plotting unweighted
#fig, ax = plt.subplots(1,2,figsize=(14,6),sharey=True)
#ax2_1 = ax[0].twinx()
#ax[0].plot('prop_removed','diameter',data=df_type1_unweighted,ls='--',color='darkblue')
#ax[0].plot('prop_removed','density',data=df_type1_unweighted,ls='--',color='darkviolet')
#set ylimit to 0 - 12 (to be same as type1; else there's a jump to 100)
#ax[0].set_ylim([0,12])
#ax[0].plot('prop_removed','avg_betweenness',data=df_type1_unweighted,ls='--',color='darkgreen')
#ax2_1.plot('prop_removed','avg_unweighted_indegree',data=df_type1_unweighted,ls='--',color='darkred')
#ax[0].plot('prop_removed','assortativity_degree',data=df_type1_unweighted,ls='--',color='darkturquoise')
#ax[0].plot('prop_removed','average_path_len',data=df_type1_unweighted,ls='--',color='darkorange')
#ax[0].legend(loc='upper right')
#ax[0].set_xlabel('Proportion of nodes removed')
#ax[0].set_title('Random deletion')
#ax2_1.tick_params('y',colors='darkred')
#ax2_1.set_ylabel('Avg inDegree')
#ax2_1.legend(loc='upper left')

#ax2_2 = ax[1].twinx()
#ax[1].plot('prop_removed','diameter',data=df_type2_unweighted,ls='--',color='blue')
#ax[1].plot('prop_removed','density',data=df_type2_unweighted,ls='--',color='violet')
#ax[1].plot('prop_removed','avg_betweenness',data=df_type2_unweighted,ls='--',color='green')
#ax2_2.plot('prop_removed','avg_unweighted_indegree',data=df_type2_unweighted,ls='--',color='red')
#ax[1].plot('prop_removed','assortativity_degree',data=df_type2_unweighted,ls='--',color='turquoise')
#ax[1].plot('prop_removed','average_path_len',data=df_type2_unweighted,ls='--',color='orange')
#ax[1].legend(loc='upper right')
#ax[1].set_xlabel('Proportion of nodes removed')
#ax[1].set_title('Targeted deletion')
#ax2_2.tick_params('y',colors='darkred')
#ax2_2.set_ylabel('Avg inDegree')
#ax2_2.legend(loc='upper left')
#plt.show()

# %% [markdown]
# #### Weighted

# %%
#Same but weighted
#Don't share y axis for type2
fig, ax = plt.subplots(2,2,figsize=(18,12),sharey=False)

#Random attack LHS graphs

ax[0,1].plot('prop_removed','diameter',data=df_type1_weighted,ls='-',color='darkblue')
ax[0,0].plot('prop_removed','density',data=df_type1_weighted,ls='-',color='darkviolet')
ax[0,0].plot('prop_removed','assortativity_degree',data=df_type1_weighted,ls='-',color='darkturquoise')
ax[0,0].plot('prop_removed','average_path_len',data=df_type1_weighted,ls='-',color='darkorange')
ax[0,0].legend(loc='upper right')
ax[0,0].set_xlabel('Proportion of nodes removed')
ax[0,0].set_title('Random deletion')

ax2_1 = ax[0,0].twinx()
ax2_1.plot('prop_removed','avg_weighted_indegree',data=df_type1_weighted,ls='-',color='darkred')
ax2_1.tick_params('y',colors='darkred')
ax2_1.set_ylabel('Avg inDegree')
ax2_1.legend(loc='upper left')

#Random attack RHS Graphs - Betweenness & Diameter
ax[0,1].set_title('Random deletion - Betweenness & Diameter')
ax[0,1].legend(loc='upper left')

ax_bet_rand = ax[0,1].twinx()
ax_bet_rand.plot('prop_removed','avg_weighted_betweenness',data=df_type1_weighted,ls='--',color='darkgreen')
ax_bet_rand.tick_params('y',colors='darkgreen')
ax_bet_rand.set_ylabel('Avg_weighted_betweenness')
ax_bet_rand.legend(loc='upper right')


#Targeted attack LHS Graphs

ax[1,1].plot('prop_removed','diameter',data=df_type2_weighted,ls='-',color='blue')
ax[1,0].plot('prop_removed','density',data=df_type2_weighted,ls='-',color='violet')
ax[1,0].plot('prop_removed','assortativity_degree',data=df_type2_weighted,ls='-',color='turquoise')
ax[1,0].plot('prop_removed','average_path_len',data=df_type2_weighted,ls='-',color='orange')
ax[1,0].legend(loc='upper right')
ax[1,0].set_xlabel('Proportion of nodes removed')
ax[1,0].set_title('Targeted deletion')

ax2_2 = ax[1,0].twinx()
ax2_2.plot('prop_removed','avg_weighted_indegree',data=df_type2_weighted,ls='-',color='darkred')
ax2_2.set_ylabel('Avg inDegree')
ax2_2.legend(loc='upper left')
ax2_2.tick_params('y',colors='darkred')


#Targeted attack RHS Graphs - Betweenness & Diameter 

ax[1,1].set_title('Targeted deletion - Betweenness & Diameter')
ax[1,1].legend(loc='upper left')

ax_bet_tar = ax[1,1].twinx()
ax_bet_tar.plot('prop_removed','avg_weighted_betweenness',data=df_type2_weighted,ls='--',color='green')
ax_bet_tar.tick_params('y',colors='green')
ax_bet_tar.set_ylabel('avg weighted betweenness')
ax_bet_tar.legend(loc='upper right')
plt.show()
