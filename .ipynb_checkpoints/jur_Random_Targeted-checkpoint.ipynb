# %%
import pandas as pd
import numpy as np
import igraph as ig
import matplotlib.pyplot as plt 
import collections

# %%
df_unweighted = pd.read_csv('combined_final_unweighted.csv')
df_unweighted
# Out:
#           node_start                node_end        status
# 0          Hong Kong                   Samoa  jurisdiction
# 1          Hong Kong                   Samoa  jurisdiction
# 2          Hong Kong                   Samoa  jurisdiction
# 3          Hong Kong                   Samoa  jurisdiction
# 4          Hong Kong                   Samoa  jurisdiction
# ...              ...                     ...           ...
# 338127     Indonesia  British Virgin Islands  officer_base
# 338128  Cook Islands  British Virgin Islands  officer_base
# 338129     Hong Kong  British Virgin Islands  officer_base
# 338130  Cook Islands          United Kingdom  officer_base
# 338131     Hong Kong          United Kingdom  officer_base
#
# [338132 rows x 3 columns]

# %%
df_weighted = pd.read_csv('combined_final_weighted.csv')
df_weighted
# Out:
#           node_start                node_end        status  weight
# 0          Hong Kong                   Samoa  jurisdiction     2.0
# 1          Hong Kong                   Samoa  jurisdiction     2.0
# 2          Hong Kong                   Samoa  jurisdiction     2.0
# 3          Hong Kong                   Samoa  jurisdiction     2.0
# 4          Hong Kong                   Samoa  jurisdiction     2.0
# ...              ...                     ...           ...     ...
# 338119     Indonesia  British Virgin Islands  officer_base     1.0
# 338120  Cook Islands  British Virgin Islands  officer_base     1.0
# 338121     Hong Kong  British Virgin Islands  officer_base     1.0
# 338122  Cook Islands          United Kingdom  officer_base     1.0
# 338123     Hong Kong          United Kingdom  officer_base     1.0
#
# [338124 rows x 4 columns]

# %%
df_weighted_jur = df_weighted[df_weighted['status'] == 'jurisdiction']
df_jur = df_weighted_jur.drop(['weight','status'], axis = 1)
df_jur
# Out:
#                     node_start      node_end
# 0                    Hong Kong         Samoa
# 1                    Hong Kong         Samoa
# 2                    Hong Kong         Samoa
# 3                    Hong Kong         Samoa
# 4                    Hong Kong         Samoa
# ...                        ...           ...
# 216554  British Virgin Islands  Cook Islands
# 216555  British Virgin Islands  Cook Islands
# 216556  British Virgin Islands  Cook Islands
# 216557  British Virgin Islands  Cook Islands
# 216558                 Vanuatu  Cook Islands
#
# [216559 rows x 2 columns]

# %%
df_jur_grouped = df_jur.groupby(['node_start','node_end'], as_index = False).size()
df_jur_grouped
# Out:
#      node_start                node_end  size
# 0       Albania                 Bahamas     2
# 1       Andorra                 Bahamas    26
# 2       Andorra  British Virgin Islands    39
# 3       Andorra          Cayman Islands     1
# 4       Andorra              Costa Rica     3
# ...         ...                     ...   ...
# 1212    Vietnam                  Panama     1
# 1213      Yemen                  Panama     1
# 1214     Zambia  British Virgin Islands     2
# 1215   Zimbabwe  British Virgin Islands     5
# 1216   Zimbabwe                  Panama     3
#
# [1217 rows x 3 columns]

# %% [markdown]
# ### Convert Data to an Undirected Edge List

# %%
df_jur_grouped_list = df_jur_grouped.values.tolist()
df_jur_grouped_list
# Out:
# [['Albania', 'Bahamas', 2],
#  ['Andorra', 'Bahamas', 26],
#  ['Andorra', 'British Virgin Islands', 39],
#  ['Andorra', 'Cayman Islands', 1],
#  ['Andorra', 'Costa Rica', 3],
#  ['Andorra', 'Hong Kong', 9],
#  ['Andorra', 'Nevada', 24],
#  ['Andorra', 'Niue', 12],
#  ['Andorra', 'Panama', 279],
#  ['Andorra', 'Samoa', 9],
#  ['Andorra', 'Seychelles', 72],
#  ['Andorra', 'United Kingdom', 1],
#  ['Andorra', 'Uruguay', 15],
#  ['Angola', 'Bermuda', 1],
#  ['Angola', 'British Virgin Islands', 11],
#  ['Antigua and Barbuda', 'Barbados', 8],
#  ['Antigua and Barbuda', 'British Virgin Islands', 1],
#  ['Antigua and Barbuda', 'Cayman Islands', 1],
#  ['Antigua and Barbuda', 'Niue', 2],
#  ['Antigua and Barbuda', 'Panama', 15],
#  ['Antigua and Barbuda', 'Saint Kitts and Nevis', 1],
#  ['Antigua and Barbuda', 'Seychelles', 3],
#  ['Argentina', 'Bahamas', 23],
#  ['Argentina', 'Barbados', 1],
#  ['Argentina', 'British Virgin Islands', 83],
#  ['Argentina', 'Cayman Islands', 3],
#  ['Argentina', 'Costa Rica', 1],
#  ['Argentina', 'Hong Kong', 4],
#  ['Argentina', 'Nevada', 4],
#  ['Argentina', 'New Zealand', 1],
#  ['Argentina', 'Niue', 2],
#  ['Argentina', 'Panama', 146],
#  ['Argentina', 'Seychelles', 6],
#  ['Aruba', 'Barbados', 1],
#  ['Aruba', 'British Anguilla', 4],
#  ['Aruba', 'British Virgin Islands', 19],
#  ['Aruba', 'Panama', 4],
#  ['Australia', 'Bahamas', 2],
#  ['Australia', 'Barbados', 2],
#  ['Australia', 'Bermuda', 42],
#  ['Australia', 'British Anguilla', 1],
#  ['Australia', 'British Virgin Islands', 75],
#  ['Australia', 'Cayman Islands', 6],
#  ['Australia', 'Cook Islands', 1],
#  ['Australia', 'Isle of Man', 3],
#  ['Australia', 'Niue', 4],
#  ['Australia', 'Panama', 20],
#  ['Australia', 'Saint Kitts and Nevis', 2],
#  ['Australia', 'Seychelles', 4],
#  ['Austria', 'Bahamas', 4],
#  ['Austria', 'Bermuda', 4],
#  ['Austria', 'British Anguilla', 1],
#  ['Austria', 'British Virgin Islands', 7],
#  ['Austria', 'Cayman Islands', 2],
#  ['Austria', 'Panama', 12],
#  ['Austria', 'Saint Kitts and Nevis', 2],
#  ['Azerbaijan', 'Bahamas', 4],
#  ['Azerbaijan', 'British Virgin Islands', 4],
#  ['Azerbaijan', 'Saint Kitts and Nevis', 2],
#  ['Bahamas', 'Barbados', 50],
#  ['Bahamas', 'Bermuda', 9],
#  ['Bahamas', 'British Anguilla', 45],
#  ['Bahamas', 'British Virgin Islands', 1764],
#  ['Bahamas', 'Cayman Islands', 23],
#  ['Bahamas', 'Cook Islands', 1],
#  ['Bahamas', 'Costa Rica', 9],
#  ['Bahamas', 'Cyprus', 2],
#  ['Bahamas', 'Hong Kong', 6],
#  ['Bahamas', 'Malta', 1],
#  ['Bahamas', 'Netherlands Antilles', 1],
#  ['Bahamas', 'Nevada', 291],
#  ['Bahamas', 'Niue', 58],
#  ['Bahamas', 'Panama', 2256],
#  ['Bahamas', 'Samoa', 27],
#  ['Bahamas', 'Seychelles', 105],
#  ['Bahamas', 'United Kingdom', 4],
#  ['Bahamas', 'Uruguay', 2],
#  ['Bahamas', 'Wyoming', 15],
#  ['Bahrain', 'Bermuda', 3],
#  ['Bahrain', 'British Virgin Islands', 10],
#  ['Bahrain', 'Panama', 3],
#  ['Bahrain', 'United Arab Emirates', 1],
#  ['Bangladesh', 'Bermuda', 1],
#  ['Bangladesh', 'British Virgin Islands', 2],
#  ['Barbados', 'Bahamas', 2],
#  ['Barbados', 'Bermuda', 8],
#  ['Barbados', 'British Virgin Islands', 15],
#  ['Barbados', 'Cayman Islands', 4],
#  ['Barbados', 'Panama', 18],
#  ['Belarus', 'British Virgin Islands', 14],
#  ['Belarus', 'Hong Kong', 1],
#  ['Belarus', 'Panama', 1],
#  ['Belgium', 'Bahamas', 8],
#  ['Belgium', 'Barbados', 1],
#  ['Belgium', 'Bermuda', 1],
#  ['Belgium', 'British Anguilla', 1],
#  ['Belgium', 'British Virgin Islands', 18],
#  ['Belgium', 'Isle of Man', 1],
#  ['Belgium', 'Niue', 1],
#  ['Belgium', 'Panama', 25],
#  ['Belgium', 'Saint Kitts and Nevis', 1],
#  ['Belgium', 'Samoa', 1],
#  ['Belgium', 'Seychelles', 5],
#  ['Belize', 'Bahamas', 250],
#  ['Belize', 'Barbados', 3],
#  ['Belize', 'British Anguilla', 19],
#  ['Belize', 'British Virgin Islands', 166],
#  ['Belize', 'Cayman Islands', 1],
#  ['Belize', 'Hong Kong', 44],
#  ['Belize', 'Mauritius', 1],
#  ['Belize', 'Niue', 228],
#  ['Belize', 'Panama', 423],
#  ['Belize', 'Saint Kitts and Nevis', 1],
#  ['Belize', 'Samoa', 45],
#  ['Belize', 'Seychelles', 175],
#  ['Belize', 'Wyoming', 1],
#  ['Bermuda', 'Bahamas', 21],
#  ['Bermuda', 'Barbados', 37],
#  ['Bermuda', 'British Virgin Islands', 138],
#  ['Bermuda', 'Cayman Islands', 17],
#  ['Bermuda', 'Cook Islands', 1],
#  ['Bermuda', 'Cyprus', 1],
#  ['Bermuda', 'Jersey', 3],
#  ['Bermuda', 'Liberia', 4],
#  ['Bermuda', 'Liechtenstein', 5],
#  ['Bermuda', 'Netherlands', 5],
#  ['Bermuda', 'Netherlands Antilles', 1],
#  ['Bermuda', 'Panama', 21],
#  ['Bermuda', 'Saint Kitts and Nevis', 1],
#  ['Bermuda', 'Singapore', 1],
#  ['Bermuda', 'Turks and Caicos Islands', 1],
#  ['Bermuda', 'United States', 21],
#  ['Bolivia', 'British Virgin Islands', 2],
#  ['Bolivia', 'Hong Kong', 2],
#  ['Bolivia', 'Panama', 91],
#  ['Botswana', 'British Virgin Islands', 2],
#  ['Botswana', 'Panama', 1],
#  ['Botswana', 'Seychelles', 3],
#  ['Brazil', 'Bahamas', 33],
#  ['Brazil', 'Barbados', 2],
#  ['Brazil', 'Bermuda', 4],
#  ['Brazil', 'British Anguilla', 14],
#  ['Brazil', 'British Virgin Islands', 473],
#  ['Brazil', 'Cayman Islands', 21],
#  ['Brazil', 'Hong Kong', 2],
#  ['Brazil', 'Isle of Man', 3],
#  ['Brazil', 'Nevada', 132],
#  ['Brazil', 'New Zealand', 1],
#  ['Brazil', 'Niue', 91],
#  ['Brazil', 'Panama', 521],
#  ['Brazil', 'Samoa', 43],
#  ['Brazil', 'Seychelles', 79],
#  ['Brazil', 'United Kingdom', 6],
#  ['Brazil', 'Uruguay', 1],
#  ['Brazil', 'Wyoming', 4],
#  ['British Anguilla', 'Barbados', 7],
#  ['British Anguilla', 'British Anguilla', 21],
#  ['British Anguilla', 'British Virgin Islands', 2],
#  ['British Virgin Islands', 'Bahamas', 145],
#  ['British Virgin Islands', 'Barbados', 1053],
#  ['British Virgin Islands', 'Belize', 1],
#  ['British Virgin Islands', 'Bermuda', 13],
#  ['British Virgin Islands', 'British Anguilla', 1],
#  ['British Virgin Islands', 'Cayman Islands', 9],
#  ['British Virgin Islands', 'Cook Islands', 75],
#  ['British Virgin Islands', 'Hong Kong', 3],
#  ['British Virgin Islands', 'Isle of Man', 2],
#  ['British Virgin Islands', 'Nevada', 2],
#  ['British Virgin Islands', 'Niue', 2],
#  ['British Virgin Islands', 'Panama', 92],
#  ['British Virgin Islands', 'Saint Kitts and Nevis', 2],
#  ['British Virgin Islands', 'Seychelles', 11],
#  ['British Virgin Islands', 'State of Delaware', 1],
#  ['Brunei', 'British Virgin Islands', 3],
#  ['Bulgaria', 'Bahamas', 2],
#  ['Bulgaria', 'British Virgin Islands', 20],
#  ['Bulgaria', 'Niue', 1],
#  ['Bulgaria', 'Panama', 5],
#  ['Bulgaria', 'Seychelles', 22],
#  ['Cameroon', 'Seychelles', 1],
#  ['Canada', 'Bahamas', 36],
#  ['Canada', 'Barbados', 132],
#  ['Canada', 'Bermuda', 79],
#  ['Canada', 'British Anguilla', 2],
#  ['Canada', 'British Virgin Islands', 198],
#  ['Canada', 'Cayman Islands', 64],
#  ['Canada', 'Hong Kong', 1],
#  ['Canada', 'Isle of Man', 5],
#  ['Canada', 'Nevada', 2],
#  ['Canada', 'Niue', 31],
#  ['Canada', 'Panama', 74],
#  ['Canada', 'Saint Kitts and Nevis', 1],
#  ['Canada', 'Seychelles', 17],
#  ['Canada', 'Singapore', 1],
#  ['Cayman Islands', 'Antigua and Barbuda', 3],
#  ['Cayman Islands', 'Aruba', 2],
#  ['Cayman Islands', 'Bahamas', 43],
#  ['Cayman Islands', 'Barbados', 113],
#  ['Cayman Islands', 'Bermuda', 21],
#  ['Cayman Islands', 'British Virgin Islands', 1057],
#  ['Cayman Islands', 'Cook Islands', 36],
#  ['Cayman Islands', 'Cyprus', 3],
#  ['Cayman Islands', 'Gibraltar', 1],
#  ['Cayman Islands', 'Grenada', 1],
#  ['Cayman Islands', 'Guernsey', 9],
#  ['Cayman Islands', 'Hong Kong', 76],
#  ['Cayman Islands', 'Isle of Man', 8],
#  ['Cayman Islands', 'Jersey', 2],
#  ['Cayman Islands', 'Liberia', 1],
#  ['Cayman Islands', 'Liechtenstein', 1],
#  ['Cayman Islands', 'Luxembourg', 1],
#  ['Cayman Islands', 'Malta', 1],
#  ['Cayman Islands', 'Marshall Islands', 1],
#  ['Cayman Islands', 'Netherlands', 1],
#  ['Cayman Islands', 'Netherlands Antilles', 2],
#  ['Cayman Islands', 'New Zealand', 2],
#  ['Cayman Islands', 'Niue', 1],
#  ['Cayman Islands', 'Panama', 53],
#  ['Cayman Islands', 'Saint Kitts and Nevis', 96],
#  ['Cayman Islands', 'Saint Vincent and the Grenadines', 12],
#  ['Cayman Islands', 'Samoa', 853],
#  ['Cayman Islands', 'Singapore', 4],
#  ['Cayman Islands', 'State of Delaware', 116],
#  ['Cayman Islands', 'Turks and Caicos Islands', 1],
#  ['Cayman Islands', 'US Virgin Islands', 1],
#  ['Cayman Islands', 'United States', 22],
#  ['Central African Republic', 'British Virgin Islands', 1],
#  ['Chad', 'British Virgin Islands', 10],
#  ['Chad', 'Panama', 1],
#  ['Chile', 'Bahamas', 14],
#  ['Chile', 'Barbados', 1],
#  ['Chile', 'Bermuda', 1],
#  ['Chile', 'British Anguilla', 2],
#  ['Chile', 'British Virgin Islands', 31],
#  ['Chile', 'Costa Rica', 1],
#  ['Chile', 'Nevada', 6],
#  ['Chile', 'Panama', 83],
#  ['Chile', 'Seychelles', 2],
#  ['Chile', 'Wyoming', 1],
#  ['China', 'Bahamas', 5],
#  ['China', 'Barbados', 1],
#  ['China', 'Belize', 1],
#  ['China', 'Bermuda', 77],
#  ['China', 'British Anguilla', 148],
#  ['China', 'British Virgin Islands', 2290],
#  ['China', 'Cayman Islands', 147],
#  ['China', 'Hong Kong', 9],
#  ['China', 'Isle of Man', 1],
#  ['China', 'Nevada', 9],
#  ['China', 'Niue', 12],
#  ['China', 'Panama', 13],
#  ['China', 'Saint Kitts and Nevis', 2],
#  ['China', 'Samoa', 363],
#  ['China', 'Seychelles', 625],
#  ['Colombia', 'Bahamas', 22],
#  ['Colombia', 'Belize', 19],
#  ['Colombia', 'Bermuda', 2],
#  ['Colombia', 'British Anguilla', 59],
#  ['Colombia', 'British Virgin Islands', 265],
#  ['Colombia', 'Cayman Islands', 3],
#  ['Colombia', 'Costa Rica', 42],
#  ['Colombia', 'Cyprus', 1],
#  ['Colombia', 'Hong Kong', 1],
#  ['Colombia', 'Malta', 1],
#  ['Colombia', 'Nevada', 10],
#  ['Colombia', 'New Zealand', 3],
#  ['Colombia', 'Niue', 2],
#  ['Colombia', 'Panama', 1357],
#  ['Colombia', 'Saint Kitts and Nevis', 3],
#  ['Colombia', 'Samoa', 6],
#  ['Colombia', 'Seychelles', 18],
#  ['Colombia', 'United Kingdom', 51],
#  ['Colombia', 'Uruguay', 1],
#  ['Cook Islands', 'Bermuda', 1],
#  ['Cook Islands', 'British Virgin Islands', 4],
#  ['Cook Islands', 'Hong Kong', 1],
#  ['Cook Islands', 'Niue', 1],
#  ['Cook Islands', 'Samoa', 1],
#  ['Costa Rica', 'Bahamas', 32],
#  ['Costa Rica', 'British Anguilla', 11],
#  ['Costa Rica', 'British Virgin Islands', 141],
#  ['Costa Rica', 'Cayman Islands', 2],
#  ['Costa Rica', 'Hong Kong', 5],
#  ['Costa Rica', 'Isle of Man', 1],
#  ['Costa Rica', 'Nevada', 2],
#  ['Costa Rica', 'Niue', 4],
#  ['Costa Rica', 'Panama', 686],
#  ['Costa Rica', 'Samoa', 2],
#  ['Costa Rica', 'Seychelles', 2],
#  ['Costa Rica', 'United Kingdom', 1],
#  ['Croatia', 'Barbados', 1],
#  ['Croatia', 'British Virgin Islands', 2],
#  ['Croatia', 'Panama', 1],
#  ['Cuba', 'Barbados', 1],
#  ['Cuba', 'British Virgin Islands', 8],
#  ['Cuba', 'Cayman Islands', 1],
#  ['Cuba', 'Panama', 3],
#  ['Curaçao', 'Barbados', 19],
#  ['Curaçao', 'Bermuda', 1],
#  ['Curaçao', 'British Virgin Islands', 10],
#  ['Curaçao', 'Panama', 8],
#  ['Curaçao', 'Seychelles', 12],
#  ['Cyprus', 'Bahamas', 649],
#  ['Cyprus', 'Barbados', 5],
#  ['Cyprus', 'Belize', 11],
#  ['Cyprus', 'Bermuda', 8],
#  ['Cyprus', 'British Anguilla', 5],
#  ['Cyprus', 'British Virgin Islands', 1869],
#  ['Cyprus', 'Cayman Islands', 10],
#  ['Cyprus', 'Hong Kong', 4],
#  ['Cyprus', 'Isle of Man', 4],
#  ['Cyprus', 'Mauritius', 1],
#  ['Cyprus', 'Nevada', 1],
#  ['Cyprus', 'Niue', 313],
#  ['Cyprus', 'Panama', 305],
#  ['Cyprus', 'Saint Kitts and Nevis', 3],
#  ['Cyprus', 'Samoa', 5],
#  ['Cyprus', 'Seychelles', 448],
#  ['Czech Republic', 'Bahamas', 2],
#  ['Czech Republic', 'Barbados', 1],
#  ['Czech Republic', 'British Virgin Islands', 25],
#  ['Czech Republic', 'Isle of Man', 1],
#  ['Czech Republic', 'Panama', 6],
#  ['Czech Republic', 'Samoa', 1],
#  ['Czech Republic', 'Seychelles', 1],
#  ["Côte d'Ivoire", 'British Virgin Islands', 10],
#  ["Côte d'Ivoire", 'Nevada', 1],
#  ["Côte d'Ivoire", 'Niue', 1],
#  ["Côte d'Ivoire", 'Panama', 7],
#  ["Côte d'Ivoire", 'Samoa', 2],
#  ['Denmark', 'Bahamas', 4],
#  ['Denmark', 'Barbados', 1],
#  ['Denmark', 'Bermuda', 2],
#  ['Denmark', 'British Virgin Islands', 4],
#  ['Denmark', 'Panama', 4],
#  ['Denmark', 'Seychelles', 2],
#  ['Djibouti', 'Panama', 1],
#  ['Dominica', 'Barbados', 1],
#  ['Dominica', 'British Virgin Islands', 4],
#  ['Dominica', 'Panama', 62],
#  ['Dominican Republic', 'Bahamas', 8],
#  ['Dominican Republic', 'Barbados', 3],
#  ['Dominican Republic', 'British Anguilla', 24],
#  ['Dominican Republic', 'British Virgin Islands', 132],
#  ['Dominican Republic', 'Cayman Islands', 5],
#  ['Dominican Republic', 'Panama', 312],
#  ['Dominican Republic', 'Samoa', 1],
#  ['Dominican Republic', 'Seychelles', 11],
#  ['Ecuador', 'Bahamas', 49],
#  ['Ecuador', 'Barbados', 2],
#  ['Ecuador', 'Belize', 5],
#  ['Ecuador', 'Bermuda', 1],
#  ['Ecuador', 'British Anguilla', 146],
#  ['Ecuador', 'British Virgin Islands', 252],
#  ['Ecuador', 'Cayman Islands', 1],
#  ['Ecuador', 'Costa Rica', 8],
#  ['Ecuador', 'Hong Kong', 2],
#  ['Ecuador', 'Nevada', 199],
#  ['Ecuador', 'New Zealand', 9],
#  ['Ecuador', 'Niue', 26],
#  ['Ecuador', 'Panama', 1101],
#  ['Ecuador', 'Samoa', 20],
#  ['Ecuador', 'Seychelles', 26],
#  ['Ecuador', 'United Kingdom', 7],
#  ['Ecuador', 'Uruguay', 2],
#  ['Egypt', 'Bahamas', 5],
#  ['Egypt', 'Barbados', 1],
#  ['Egypt', 'Bermuda', 3],
#  ['Egypt', 'British Virgin Islands', 17],
#  ['Egypt', 'Cayman Islands', 1],
#  ['Egypt', 'Panama', 20],
#  ['Egypt', 'Seychelles', 1],
#  ['El Salvador', 'Bahamas', 6],
#  ['El Salvador', 'Barbados', 2],
#  ['El Salvador', 'British Anguilla', 1],
#  ['El Salvador', 'British Virgin Islands', 19],
#  ['El Salvador', 'Nevada', 7],
#  ['El Salvador', 'Niue', 1],
#  ['El Salvador', 'Panama', 195],
#  ['El Salvador', 'Seychelles', 5],
#  ['Estonia', 'Bahamas', 114],
#  ['Estonia', 'British Anguilla', 1],
#  ['Estonia', 'British Virgin Islands', 644],
#  ['Estonia', 'Cyprus', 1],
#  ['Estonia', 'Isle of Man', 1],
#  ['Estonia', 'Malta', 1],
#  ['Estonia', 'Niue', 68],
#  ['Estonia', 'Panama', 14],
#  ['Estonia', 'Samoa', 3],
#  ['Estonia', 'Seychelles', 34],
#  ['Fiji', 'Cook Islands', 1],
#  ['Finland', 'Bahamas', 32],
#  ['Finland', 'British Virgin Islands', 25],
#  ['Finland', 'Cayman Islands', 7],
#  ['Finland', 'Niue', 1],
#  ['Finland', 'Panama', 3],
#  ['Finland', 'Seychelles', 4],
#  ['France', 'Bahamas', 23],
#  ['France', 'Barbados', 2],
#  ['France', 'Bermuda', 25],
#  ['France', 'British Anguilla', 10],
#  ['France', 'British Virgin Islands', 138],
#  ['France', 'Cayman Islands', 6],
#  ['France', 'Cook Islands', 1],
#  ['France', 'Hong Kong', 2],
#  ['France', 'Isle of Man', 1],
#  ['France', 'Nevada', 1],
#  ['France', 'Niue', 18],
#  ['France', 'Panama', 78],
#  ['France', 'Samoa', 3],
#  ['France', 'Seychelles', 14],
#  ['French Guiana', 'British Virgin Islands', 20],
#  ['French Guiana', 'Cayman Islands', 8],
#  ['French Guiana', 'Guernsey', 2],
#  ['Georgia', 'British Anguilla', 1],
#  ['Germany', 'Bahamas', 1],
#  ['Germany', 'Barbados', 3],
#  ['Germany', 'Bermuda', 4],
#  ['Germany', 'British Anguilla', 1],
#  ['Germany', 'British Virgin Islands', 35],
#  ['Germany', 'Cayman Islands', 5],
#  ['Germany', 'Cyprus', 1],
#  ['Germany', 'Isle of Man', 1],
#  ['Germany', 'Niue', 2],
#  ['Germany', 'Panama', 129],
#  ['Germany', 'Seychelles', 8],
#  ['Ghana', 'Bahamas', 1],
#  ['Ghana', 'British Anguilla', 1],
#  ['Ghana', 'British Virgin Islands', 1],
#  ['Gibraltar', 'Bahamas', 150],
#  ['Gibraltar', 'Barbados', 8],
#  ['Gibraltar', 'Belize', 2],
#  ['Gibraltar', 'British Virgin Islands', 1584],
#  ['Gibraltar', 'Cayman Islands', 1],
#  ['Gibraltar', 'Isle of Man', 4],
#  ['Gibraltar', 'Malta', 1],
#  ['Gibraltar', 'Nevada', 2],
#  ['Gibraltar', 'Niue', 28],
#  ['Gibraltar', 'Panama', 195],
#  ['Gibraltar', 'Samoa', 14],
#  ['Gibraltar', 'Seychelles', 64],
#  ['Greece', 'Bahamas', 7],
#  ['Greece', 'Bermuda', 5],
#  ['Greece', 'British Virgin Islands', 62],
#  ['Greece', 'Cayman Islands', 1],
#  ['Greece', 'Liberia', 1],
#  ['Greece', 'Panama', 134],
#  ['Greece', 'Seychelles', 21],
#  ['Grenada', 'Barbados', 2],
#  ['Grenada', 'Saint Kitts and Nevis', 4],
#  ['Guam', 'British Virgin Islands', 1],
#  ['Guatemala', 'Bahamas', 39],
#  ['Guatemala', 'British Anguilla', 23],
#  ['Guatemala', 'British Virgin Islands', 185],
#  ['Guatemala', 'Cayman Islands', 8],
#  ['Guatemala', 'Niue', 140],
#  ['Guatemala', 'Panama', 801],
#  ['Guatemala', 'Saint Kitts and Nevis', 4],
#  ['Guatemala', 'Samoa', 16],
#  ['Guatemala', 'Seychelles', 30],
#  ['Guernsey', 'Bahamas', 1504],
#  ['Guernsey', 'Barbados', 13],
#  ['Guernsey', 'Bermuda', 3],
#  ['Guernsey', 'British Anguilla', 27],
#  ['Guernsey', 'British Virgin Islands', 4734],
#  ['Guernsey', 'Cayman Islands', 4],
#  ['Guernsey', 'Cook Islands', 2],
#  ['Guernsey', 'Cyprus', 1],
#  ['Guernsey', 'Hong Kong', 2],
#  ['Guernsey', 'Isle of Man', 22],
#  ['Guernsey', 'Jersey', 8],
#  ['Guernsey', 'Niue', 302],
#  ['Guernsey', 'Panama', 705],
#  ['Guernsey', 'Samoa', 19],
#  ['Guernsey', 'Seychelles', 52],
#  ['Guernsey', 'Turks and Caicos Islands', 1],
#  ['Guernsey', 'Uruguay', 1],
#  ['Guyana', 'Barbados', 2],
#  ['Haiti', 'British Virgin Islands', 3],
#  ['Haiti', 'Nevada', 5],
#  ['Honduras', 'Bahamas', 1],
#  ['Honduras', 'British Virgin Islands', 4],
#  ['Honduras', 'Cayman Islands', 1],
#  ['Honduras', 'Panama', 19],
#  ['Hong Kong', 'Bahamas', 960],
#  ['Hong Kong', 'Barbados', 5],
#  ['Hong Kong', 'Belize', 6],
#  ['Hong Kong', 'Bermuda', 393],
#  ['Hong Kong', 'British Anguilla', 1366],
#  ['Hong Kong', 'British Virgin Islands', 27498],
#  ['Hong Kong', 'Cayman Islands', 229],
#  ['Hong Kong', 'Cook Islands', 12],
#  ['Hong Kong', 'Isle of Man', 10],
#  ['Hong Kong', 'Labuan', 2],
#  ['Hong Kong', 'Netherlands', 1],
#  ['Hong Kong', 'Nevada', 43],
#  ['Hong Kong', 'Niue', 1055],
#  ['Hong Kong', 'Panama', 609],
#  ['Hong Kong', 'Samoa', 3012],
#  ['Hong Kong', 'Seychelles', 3749],
#  ['Hong Kong', 'Singapore', 6],
#  ['Hong Kong', 'Thailand', 1],
#  ['Hungary', 'Bahamas', 4],
#  ['Hungary', 'Barbados', 3],
#  ['Hungary', 'British Virgin Islands', 25],
#  ['Hungary', 'Nevada', 1],
#  ['Hungary', 'Niue', 25],
#  ['Hungary', 'Panama', 7],
#  ['Hungary', 'Samoa', 1],
#  ['Hungary', 'Seychelles', 27],
#  ['Iceland', 'Bermuda', 2],
#  ['Iceland', 'British Virgin Islands', 14],
#  ['Iceland', 'Panama', 1],
#  ['India', 'Barbados', 1],
#  ['India', 'Bermuda', 10],
#  ['India', 'British Virgin Islands', 14],
#  ['India', 'Cayman Islands', 2],
#  ['India', 'Isle of Man', 8],
#  ['India', 'Niue', 1],
#  ['India', 'Panama', 2],
#  ['India', 'Seychelles', 6],
#  ['India', 'Singapore', 1],
#  ['Indonesia', 'Bermuda', 5],
#  ['Indonesia', 'British Virgin Islands', 51],
#  ['Indonesia', 'Cayman Islands', 10],
#  ['Indonesia', 'Cook Islands', 6],
#  ['Indonesia', 'Panama', 1],
#  ['Indonesia', 'Samoa', 2],
#  ['Indonesia', 'Seychelles', 2],
#  ['Indonesia', 'Singapore', 4],
#  ['Iran', 'Panama', 4],
#  ['Ireland', 'Bahamas', 25],
#  ['Ireland', 'Barbados', 13],
#  ['Ireland', 'Bermuda', 20],
#  ['Ireland', 'British Anguilla', 1],
#  ['Ireland', 'British Virgin Islands', 186],
#  ['Ireland', 'Cayman Islands', 9],
#  ['Ireland', 'Guernsey', 2],
#  ['Ireland', 'Hong Kong', 1],
#  ['Ireland', 'Isle of Man', 30],
#  ['Ireland', 'Jersey', 1],
#  ['Ireland', 'Niue', 31],
#  ['Ireland', 'Panama', 56],
#  ['Ireland', 'Samoa', 11],
#  ['Ireland', 'Seychelles', 13],
#  ['Isle of Man', 'Bahamas', 885],
#  ['Isle of Man', 'Barbados', 26],
#  ['Isle of Man', 'Bermuda', 5],
#  ['Isle of Man', 'British Anguilla', 35],
#  ['Isle of Man', 'British Virgin Islands', 3064],
#  ['Isle of Man', 'Cayman Islands', 12],
#  ['Isle of Man', 'Cyprus', 7],
#  ['Isle of Man', 'Guernsey', 4],
#  ['Isle of Man', 'Hong Kong', 7],
#  ['Isle of Man', 'Isle of Man', 7],
#  ['Isle of Man', 'Jersey', 9],
#  ['Isle of Man', 'Malta', 1],
#  ['Isle of Man', 'Nevada', 7],
#  ['Isle of Man', 'Niue', 271],
#  ['Isle of Man', 'Panama', 500],
#  ['Isle of Man', 'Samoa', 70],
#  ['Isle of Man', 'Seychelles', 80],
#  ['Isle of Man', 'United Arab Emirates', 1],
#  ['Isle of Man', 'United Kingdom', 2],
#  ['Isle of Man', 'Uruguay', 1],
#  ['Israel', 'Bahamas', 16],
#  ['Israel', 'Barbados', 1],
#  ['Israel', 'Belize', 10],
#  ['Israel', 'Bermuda', 1],
#  ['Israel', 'British Anguilla', 150],
#  ['Israel', 'British Virgin Islands', 174],
#  ['Israel', 'Cayman Islands', 4],
#  ['Israel', 'Cyprus', 4],
#  ['Israel', 'Hong Kong', 1],
#  ['Israel', 'Isle of Man', 2],
#  ['Israel', 'Malta', 4],
#  ['Israel', 'Niue', 11],
#  ['Israel', 'Panama', 127],
#  ['Israel', 'Samoa', 47],
#  ['Israel', 'Seychelles', 122],
#  ['Italy', 'Bahamas', 3],
#  ['Italy', 'British Anguilla', 204],
#  ['Italy', 'British Virgin Islands', 31],
#  ['Italy', 'Cayman Islands', 2],
#  ['Italy', 'Cyprus', 13],
#  ['Italy', 'Hong Kong', 1],
#  ['Italy', 'Isle of Man', 2],
#  ['Italy', 'Nevada', 7],
#  ['Italy', 'Niue', 22],
#  ['Italy', 'Panama', 40],
#  ['Italy', 'Samoa', 3],
#  ['Italy', 'Seychelles', 22],
#  ['Jamaica', 'Bahamas', 1],
#  ['Jamaica', 'Barbados', 12],
#  ['Jamaica', 'British Virgin Islands', 4],
#  ['Jamaica', 'Cayman Islands', 5],
#  ['Japan', 'Bermuda', 8],
#  ['Japan', 'British Virgin Islands', 15],
#  ['Japan', 'Cayman Islands', 16],
#  ['Japan', 'Cook Islands', 1],
#  ['Japan', 'Niue', 2],
#  ['Japan', 'Panama', 7],
#  ['Japan', 'Seychelles', 1],
#  ['Japan', 'Singapore', 1],
#  ['Jersey', 'Bahamas', 1244],
#  ['Jersey', 'Barbados', 44],
#  ['Jersey', 'Bermuda', 13],
#  ['Jersey', 'British Anguilla', 2],
#  ['Jersey', 'British Virgin Islands', 10602],
#  ['Jersey', 'Cayman Islands', 10],
#  ['Jersey', 'Cook Islands', 2],
#  ['Jersey', 'Cyprus', 1],
#  ['Jersey', 'Hong Kong', 66],
#  ['Jersey', 'Isle of Man', 19],
#  ['Jersey', 'Malta', 4],
#  ['Jersey', 'Mauritius', 1],
#  ['Jersey', 'Nevada', 3],
#  ['Jersey', 'Niue', 344],
#  ['Jersey', 'Panama', 2129],
#  ['Jersey', 'Saint Kitts and Nevis', 1],
#  ['Jersey', 'Samoa', 17],
#  ['Jersey', 'Seychelles', 18],
#  ['Jersey', 'Singapore', 1],
#  ['Jersey', 'United Kingdom', 6],
#  ['Jersey', 'Wyoming', 1],
#  ['Jordan', 'Bahamas', 14],
#  ['Jordan', 'Bermuda', 1],
#  ['Jordan', 'British Virgin Islands', 1146],
#  ['Jordan', 'Panama', 394],
#  ['Jordan', 'Seychelles', 1],
#  ['Kazakhstan', 'Bermuda', 1],
#  ['Kazakhstan', 'British Virgin Islands', 8],
#  ['Kenya', 'Bahamas', 1],
#  ['Kenya', 'British Anguilla', 2],
#  ['Kenya', 'British Virgin Islands', 15],
#  ['Kenya', 'Cayman Islands', 1],
#  ['Kenya', 'Isle of Man', 1],
#  ['Kenya', 'Panama', 6],
#  ['Kenya', 'Seychelles', 1],
#  ['Kuwait', 'Bahamas', 2],
#  ['Kuwait', 'Bermuda', 1],
#  ['Kuwait', 'British Virgin Islands', 9],
#  ['Kuwait', 'Cayman Islands', 4],
#  ['Kuwait', 'Panama', 36],
#  ['Kuwait', 'Seychelles', 13],
#  ['Kyrgyzstan', 'Isle of Man', 1],
#  ['Latvia', 'Bahamas', 51],
#  ['Latvia', 'British Virgin Islands', 1303],
#  ['Latvia', 'Hong Kong', 1],
#  ['Latvia', 'Niue', 13],
#  ['Latvia', 'Panama', 12],
#  ['Latvia', 'Seychelles', 1],
#  ['Lebanon', 'Bahamas', 7],
#  ['Lebanon', 'Bermuda', 1],
#  ['Lebanon', 'British Virgin Islands', 213],
#  ['Lebanon', 'Cayman Islands', 1],
#  ['Lebanon', 'Hong Kong', 3],
#  ['Lebanon', 'Niue', 46],
#  ['Lebanon', 'Panama', 121],
#  ['Lebanon', 'Samoa', 12],
#  ['Lebanon', 'Seychelles', 88],
#  ['Lesotho', 'Seychelles', 1],
#  ['Liberia', 'Barbados', 19],
#  ['Liberia', 'Bermuda', 4],
#  ['Liberia', 'Liechtenstein', 36],
#  ['Liberia', 'Panama', 2],
#  ['Libya', 'British Virgin Islands', 1],
#  ['Libya', 'Panama', 1],
#  ['Liechtenstein', 'Bahamas', 87],
#  ['Liechtenstein', 'Barbados', 5],
#  ['Liechtenstein', 'Bermuda', 4],
#  ['Liechtenstein', 'British Anguilla', 5],
#  ['Liechtenstein', 'British Virgin Islands', 1268],
#  ['Liechtenstein', 'Cayman Islands', 3],
#  ['Liechtenstein', 'Cyprus', 1],
#  ['Liechtenstein', 'Hong Kong', 11],
#  ['Liechtenstein', 'Niue', 49],
#  ['Liechtenstein', 'Panama', 444],
#  ['Liechtenstein', 'Samoa', 32],
#  ['Liechtenstein', 'Seychelles', 169],
#  ['Liechtenstein', 'Singapore', 3],
#  ['Lithuania', 'Bahamas', 2],
#  ['Lithuania', 'British Anguilla', 1],
#  ['Lithuania', 'British Virgin Islands', 4],
#  ['Lithuania', 'Niue', 20],
#  ['Lithuania', 'Panama', 6],
#  ['Luxembourg', 'Bahamas', 423],
#  ['Luxembourg', 'Barbados', 11],
#  ['Luxembourg', 'Belize', 8],
#  ['Luxembourg', 'Bermuda', 4],
#  ['Luxembourg', 'British Anguilla', 7],
#  ['Luxembourg', 'British Virgin Islands', 3082],
#  ['Luxembourg', 'Cayman Islands', 8],
#  ['Luxembourg', 'Costa Rica', 1],
#  ['Luxembourg', 'Cyprus', 6],
#  ['Luxembourg', 'Hong Kong', 39],
#  ['Luxembourg', 'Malta', 6],
#  ['Luxembourg', 'Nevada', 29],
#  ['Luxembourg', 'Niue', 219],
#  ['Luxembourg', 'Panama', 5584],
#  ['Luxembourg', 'Samoa', 13],
#  ['Luxembourg', 'Seychelles', 1421],
#  ['Luxembourg', 'United Kingdom', 1],
#  ['Luxembourg', 'Uruguay', 1],
#  ['Luxembourg', 'Wyoming', 1],
#  ['Macao', 'Bermuda', 2],
#  ['Macao', 'British Virgin Islands', 24],
#  ['Macao', 'Malta', 115],
#  ['Macao', 'Seychelles', 1],
#  ['Macedonia', 'British Virgin Islands', 1],
#  ['Macedonia', 'Seychelles', 1],
#  ['Malawi', 'British Virgin Islands', 1],
#  ['Malaysia', 'Bahamas', 1],
#  ['Malaysia', 'Barbados', 1],
#  ['Malaysia', 'Bermuda', 17],
#  ['Malaysia', 'British Anguilla', 1],
#  ['Malaysia', 'British Virgin Islands', 42],
#  ['Malaysia', 'Cayman Islands', 1],
#  ['Malaysia', 'Cook Islands', 1],
#  ['Malaysia', 'Labuan', 422],
#  ['Malaysia', 'Niue', 4],
#  ['Malaysia', 'Panama', 2],
#  ['Malaysia', 'Samoa', 1],
#  ['Malaysia', 'Seychelles', 1],
#  ['Malaysia', 'Singapore', 2],
#  ['Mali', 'British Virgin Islands', 8],
#  ['Malta', 'Bahamas', 11],
#  ['Malta', 'Barbados', 1],
#  ['Malta', 'British Virgin Islands', 462],
#  ['Malta', 'Hong Kong', 1],
#  ['Malta', 'Isle of Man', 1],
#  ['Malta', 'New Zealand', 9],
#  ['Malta', 'Niue', 55],
#  ['Malta', 'Panama', 107],
#  ['Malta', 'Seychelles', 31],
#  ['Marshall Islands', 'Barbados', 1],
#  ['Marshall Islands', 'Cayman Islands', 1],
#  ['Marshall Islands', 'Isle of Man', 1],
#  ['Mauritius', 'Bahamas', 136],
#  ['Mauritius', 'Barbados', 3],
#  ['Mauritius', 'Bermuda', 2],
#  ['Mauritius', 'British Virgin Islands', 920],
#  ['Mauritius', 'Cayman Islands', 2],
#  ['Mauritius', 'Isle of Man', 1],
#  ['Mauritius', 'Jersey', 3],
#  ['Mauritius', 'Niue', 32],
#  ['Mauritius', 'Panama', 108],
#  ['Mauritius', 'Samoa', 9],
#  ['Mauritius', 'Seychelles', 15],
#  ['Mexico', 'Bahamas', 3],
#  ['Mexico', 'Barbados', 3],
#  ['Mexico', 'Bermuda', 1],
#  ['Mexico', 'British Virgin Islands', 14],
#  ['Mexico', 'Cayman Islands', 5],
#  ['Mexico', 'Hong Kong', 1],
#  ['Mexico', 'Nevada', 1],
#  ['Mexico', 'Panama', 39],
#  ['Mexico', 'Seychelles', 6],
#  ['Mexico', 'United Kingdom', 1],
#  ['Moldova', 'British Virgin Islands', 2],
#  ['Monaco', 'Bahamas', 83],
#  ['Monaco', 'Belize', 2],
#  ['Monaco', 'Bermuda', 32],
#  ['Monaco', 'British Anguilla', 4],
#  ['Monaco', 'British Virgin Islands', 1039],
#  ['Monaco', 'Cayman Islands', 8],
#  ['Monaco', 'Hong Kong', 1],
#  ['Monaco', 'Isle of Man', 2],
#  ['Monaco', 'Nevada', 6],
#  ['Monaco', 'Niue', 49],
#  ['Monaco', 'Panama', 1402],
#  ['Monaco', 'Samoa', 20],
#  ['Monaco', 'Seychelles', 566],
#  ['Mongolia', 'British Virgin Islands', 3],
#  ['Montenegro', 'British Virgin Islands', 12],
#  ['Montenegro', 'Panama', 1],
#  ['Morocco', 'British Virgin Islands', 21],
#  ['Morocco', 'Panama', 2],
#  ['Morocco', 'Seychelles', 18],
#  ['Mozambique', 'British Virgin Islands', 1],
#  ['Mozambique', 'Seychelles', 2],
#  ['Namibia', 'Seychelles', 2],
#  ['Nauru', 'Panama', 1],
#  ['Netherlands', 'Bahamas', 28],
#  ['Netherlands', 'Barbados', 18],
#  ['Netherlands', 'Bermuda', 11],
#  ['Netherlands', 'British Anguilla', 4],
#  ['Netherlands', 'British Virgin Islands', 81],
#  ['Netherlands', 'Cayman Islands', 6],
#  ['Netherlands', 'Isle of Man', 2],
#  ['Netherlands', 'Netherlands Antilles', 1],
#  ['Netherlands', 'Niue', 7],
#  ['Netherlands', 'Panama', 53],
#  ['Netherlands', 'Samoa', 3],
#  ['Netherlands', 'Seychelles', 6],
#  ['Netherlands', 'Singapore', 1],
#  ['New Zealand', 'Bahamas', 7],
#  ['New Zealand', 'Bermuda', 18],
#  ['New Zealand', 'British Virgin Islands', 19],
#  ['New Zealand', 'Cook Islands', 1],
#  ['New Zealand', 'Hong Kong', 1],
#  ['New Zealand', 'Nevada', 1],
#  ['New Zealand', 'Niue', 13],
#  ['New Zealand', 'Panama', 10],
#  ['New Zealand', 'Samoa', 3],
#  ['Nicaragua', 'British Virgin Islands', 2],
#  ['Nicaragua', 'Cayman Islands', 1],
#  ['Nicaragua', 'Panama', 10],
#  ['Nigeria', 'Bahamas', 5],
#  ['Nigeria', 'Barbados', 1],
#  ['Nigeria', 'Bermuda', 1],
#  ['Nigeria', 'British Virgin Islands', 12],
#  ['Nigeria', 'Cayman Islands', 2],
#  ['Nigeria', 'Panama', 2],
#  ['Nigeria', 'Seychelles', 2],
#  ['Niue', 'Bahamas', 1],
#  ['Niue', 'British Virgin Islands', 13],
#  ['Niue', 'Panama', 236],
#  ['Niue', 'Seychelles', 5],
#  ['Norway', 'Bahamas', 1],
#  ['Norway', 'Barbados', 2],
#  ['Norway', 'Bermuda', 26],
#  ['Norway', 'British Virgin Islands', 5],
#  ['Norway', 'Cayman Islands', 6],
#  ['Norway', 'Panama', 8],
#  ['Oman', 'British Virgin Islands', 3],
#  ['Oman', 'Cayman Islands', 1],
#  ['Pakistan', 'Bahamas', 1],
#  ['Pakistan', 'Bermuda', 1],
#  ['Pakistan', 'British Virgin Islands', 1],
#  ['Pakistan', 'Panama', 1],
#  ['Panama', 'Bahamas', 1120],
#  ['Panama', 'Barbados', 25],
#  ['Panama', 'Belize', 40],
#  ['Panama', 'British Anguilla', 278],
#  ['Panama', 'British Virgin Islands', 4788],
#  ['Panama', 'Cayman Islands', 4],
#  ['Panama', 'Costa Rica', 5],
#  ['Panama', 'Cyprus', 22],
#  ['Panama', 'Hong Kong', 108],
#  ['Panama', 'Malta', 1],
#  ['Panama', 'Nevada', 82],
#  ['Panama', 'New Zealand', 2],
#  ['Panama', 'Niue', 1589],
#  ['Panama', 'Samoa', 410],
#  ['Panama', 'Seychelles', 1273],
#  ['Panama', 'United Kingdom', 5],
#  ['Panama', 'Uruguay', 7],
#  ['Panama', 'Wyoming', 5],
#  ['Paraguay', 'Bahamas', 10],
#  ['Paraguay', 'British Virgin Islands', 27],
#  ['Paraguay', 'Nevada', 5],
#  ['Paraguay', 'Niue', 1],
#  ['Paraguay', 'Panama', 84],
#  ['Peru', 'Bahamas', 2],
#  ['Peru', 'Barbados', 1],
#  ['Peru', 'Bermuda', 1],
#  ['Peru', 'British Virgin Islands', 10],
#  ['Peru', 'Cyprus', 1],
#  ['Peru', 'Hong Kong', 1],
#  ['Peru', 'Isle of Man', 1],
#  ['Peru', 'New Zealand', 1],
#  ['Peru', 'Niue', 1],
#  ['Peru', 'Panama', 35],
#  ['Peru', 'Seychelles', 1],
#  ['Philippines', 'Bahamas', 2],
#  ['Philippines', 'Bermuda', 9],
#  ['Philippines', 'British Anguilla', 1],
#  ['Philippines', 'British Virgin Islands', 18],
#  ['Philippines', 'Cayman Islands', 2],
#  ['Philippines', 'Niue', 10],
#  ['Philippines', 'Panama', 9],
#  ['Philippines', 'Seychelles', 4],
#  ['Poland', 'Bahamas', 58],
#  ['Poland', 'British Virgin Islands', 28],
#  ['Poland', 'Niue', 40],
#  ['Poland', 'Panama', 4],
#  ['Poland', 'Samoa', 1],
#  ['Poland', 'Seychelles', 26],
#  ['Poland', 'Wyoming', 1],
#  ['Portugal', 'Bahamas', 44],
#  ['Portugal', 'Barbados', 1],
#  ['Portugal', 'Bermuda', 2],
#  ['Portugal', 'British Virgin Islands', 62],
#  ['Portugal', 'Cayman Islands', 1],
#  ['Portugal', 'Cyprus', 5],
#  ['Portugal', 'Hong Kong', 1],
#  ['Portugal', 'Nevada', 2],
#  ['Portugal', 'Niue', 56],
#  ['Portugal', 'Panama', 63],
#  ['Portugal', 'Samoa', 10],
#  ['Puerto Rico', 'Barbados', 1],
#  ['Puerto Rico', 'Panama', 1],
#  ['Qatar', 'Bahamas', 4],
#  ['Qatar', 'Bermuda', 1],
#  ['Qatar', 'British Virgin Islands', 10],
#  ['Qatar', 'Isle of Man', 5],
#  ['Qatar', 'Panama', 12],
#  ['Qatar', 'Seychelles', 1],
#  ['Romania', 'British Anguilla', 2],
#  ['Romania', 'British Virgin Islands', 2],
#  ['Romania', 'Malta', 1],
#  ['Romania', 'Panama', 2],
#  ['Russia', 'Bahamas', 1335],
#  ['Russia', 'Belize', 3],
#  ['Russia', 'Bermuda', 25],
#  ['Russia', 'British Anguilla', 73],
#  ['Russia', 'British Virgin Islands', 2311],
#  ['Russia', 'Cayman Islands', 5],
#  ['Russia', 'Hong Kong', 3],
#  ['Russia', 'Niue', 366],
#  ['Russia', 'Panama', 94],
#  ['Russia', 'Saint Kitts and Nevis', 1],
#  ['Russia', 'Samoa', 5],
#  ['Russia', 'Seychelles', 21],
#  ['Russia', 'Uruguay', 2],
#  ['Saint Kitts and Nevis', 'Bahamas', 9],
#  ['Saint Kitts and Nevis', 'Barbados', 6],
#  ['Saint Kitts and Nevis', 'British Virgin Islands', 26],
#  ['Saint Kitts and Nevis', 'Cayman Islands', 1],
#  ['Saint Kitts and Nevis', 'Cook Islands', 1],
#  ['Saint Kitts and Nevis', 'Hong Kong', 14],
#  ['Saint Kitts and Nevis', 'Mauritius', 1],
#  ['Saint Kitts and Nevis', 'Nevada', 4],
#  ['Saint Kitts and Nevis', 'Niue', 2],
#  ['Saint Kitts and Nevis', 'Panama', 117],
#  ['Saint Kitts and Nevis', 'Seychelles', 17],
#  ['Saint Lucia', 'Barbados', 115],
#  ['Saint Lucia', 'British Virgin Islands', 4],
#  ['Saint Lucia', 'Panama', 1],
#  ['Saint Lucia', 'Saint Lucia', 4],
#  ['Saint Martin (French part)', 'Barbados', 1],
#  ['Saint Vincent and the Grenadines', 'Barbados', 13],
#  ['Saint Vincent and the Grenadines', 'British Virgin Islands', 3],
#  ['Saint Vincent and the Grenadines', 'Panama', 3],
#  ['Samoa', 'Bahamas', 121],
#  ['Samoa', 'Bermuda', 1],
#  ['Samoa', 'British Anguilla', 2],
#  ['Samoa', 'British Virgin Islands', 250],
#  ['Samoa', 'Cayman Islands', 2],
#  ['Samoa', 'Cook Islands', 1],
#  ['Samoa', 'Hong Kong', 16],
#  ['Samoa', 'Niue', 78],
#  ['Samoa', 'Panama', 160],
#  ['Samoa', 'Seychelles', 850],
#  ['Samoa', 'United Kingdom', 1],
#  ['Saudi Arabia', 'Bahamas', 4],
#  ['Saudi Arabia', 'Bermuda', 26],
#  ['Saudi Arabia', 'British Virgin Islands', 76],
#  ['Saudi Arabia', 'Cayman Islands', 2],
#  ['Saudi Arabia', 'Niue', 3],
#  ['Saudi Arabia', 'Panama', 24],
#  ['Saudi Arabia', 'Seychelles', 1],
#  ['Senegal', 'Panama', 1],
#  ['Senegal', 'Seychelles', 2],
#  ['Seychelles', 'Bahamas', 67],
#  ['Seychelles', 'Barbados', 3],
#  ['Seychelles', 'Belize', 1],
#  ['Seychelles', 'British Anguilla', 2],
#  ['Seychelles', 'British Virgin Islands', 161],
#  ['Seychelles', 'Cayman Islands', 2],
#  ['Seychelles', 'Panama', 83],
#  ['Seychelles', 'Saint Kitts and Nevis', 2],
#  ['Seychelles', 'Samoa', 14],
#  ['Sierra Leone', 'Bermuda', 3],
#  ['Singapore', 'Bahamas', 93],
#  ['Singapore', 'Barbados', 1],
#  ['Singapore', 'Belize', 1],
#  ['Singapore', 'Bermuda', 96],
#  ['Singapore', 'British Anguilla', 15],
#  ['Singapore', 'British Virgin Islands', 4034],
#  ['Singapore', 'Cayman Islands', 34],
#  ['Singapore', 'Cook Islands', 48],
#  ['Singapore', 'Hong Kong', 7],
#  ['Singapore', 'Isle of Man', 2],
#  ['Singapore', 'Labuan', 6],
#  ['Singapore', 'Malaysia', 5],
#  ['Singapore', 'Mauritius', 4],
#  ['Singapore', 'Niue', 98],
#  ['Singapore', 'Panama', 68],
#  ['Singapore', 'Saint Lucia', 1],
#  ['Singapore', 'Samoa', 122],
#  ['Singapore', 'Seychelles', 127],
#  ['Singapore', 'United Kingdom', 1],
#  ['Singapore', 'Vanuatu', 1],
#  ['Sint Maarten (Dutch part)', 'Panama', 1],
#  ['Slovakia', 'Panama', 1],
#  ['Slovenia', 'Bahamas', 3],
#  ['Slovenia', 'British Anguilla', 16],
#  ['Slovenia', 'British Virgin Islands', 1],
#  ['Slovenia', 'Panama', 1],
#  ['South Africa', 'Bahamas', 8],
#  ['South Africa', 'Bermuda', 2],
#  ['South Africa', 'British Virgin Islands', 61],
#  ['South Africa', 'Cayman Islands', 4],
#  ['South Africa', 'Isle of Man', 4],
#  ['South Africa', 'Jersey', 1],
#  ['South Africa', 'Niue', 7],
#  ['South Africa', 'Panama', 33],
#  ['South Korea', 'Barbados', 1],
#  ...]

# %%
d = collections.defaultdict(int)
for n1, n2, v in df_jur_grouped_list:
    d[min(n1, n2), max(n1, n2)] += v
result = [[k[0], k[1], v] for k, v in d.items()]

# %%
df_net = pd.DataFrame(result)
df_net
# Out:
#                            0                       1   2
# 0                    Albania                 Bahamas   2
# 1                    Andorra                 Bahamas  26
# 2                    Andorra  British Virgin Islands  39
# 3                    Andorra          Cayman Islands   1
# 4                    Andorra              Costa Rica   3
# ...                      ...                     ...  ..
# 1125                  Panama                 Vietnam   1
# 1126                  Panama                   Yemen   1
# 1127  British Virgin Islands                  Zambia   2
# 1128  British Virgin Islands                Zimbabwe   5
# 1129                  Panama                Zimbabwe   3
#
# [1130 rows x 3 columns]

# %%
df_net = df_net.rename(columns = {0:'node_1', 1:'node_2', 2: 'weight'})
df_net
# Out:
#                       node_1                  node_2  weight
# 0                    Albania                 Bahamas       2
# 1                    Andorra                 Bahamas      26
# 2                    Andorra  British Virgin Islands      39
# 3                    Andorra          Cayman Islands       1
# 4                    Andorra              Costa Rica       3
# ...                      ...                     ...     ...
# 1125                  Panama                 Vietnam       1
# 1126                  Panama                   Yemen       1
# 1127  British Virgin Islands                  Zambia       2
# 1128  British Virgin Islands                Zimbabwe       5
# 1129                  Panama                Zimbabwe       3
#
# [1130 rows x 3 columns]

# %%
#import df_net to csv later

# %%
#plot the unweighted graph (try unweighted first)
g = ig.Graph.TupleList(df_net.itertuples(index=False), directed=False, edge_attrs={'weight': "weight"})

# %%
ig.plot(g)

# %%
g.diameter()
# Out:
# 4

# %%
len(g.vs.indices)
# Out:
# 174

# %%
#g.vs.indices
df_net['node_1'].value_counts()
# Out:
# British Virgin Islands              125
# Bahamas                              93
# Cayman Islands                       73
# Bermuda                              69
# Barbados                             68
#                                    ...
# Saint Vincent and the Grenadines      1
# Haiti                                 1
# Macedonia                             1
# Honduras                              1
# Croatia                               1
# Name: node_1, Length: 123, dtype: int64

# %%
uni =df_net['node_1'].unique()

# %%
len(uni)
# Out:
# 123

# %%
list(g.vs)
# Out:
# [igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 0, {'name': 'Albania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 2, {'name': 'Andorra'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 4, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 5, {'name': 'Costa Rica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 6, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 7, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 8, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 9, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 10, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 11, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 12, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 13, {'name': 'Uruguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 14, {'name': 'Angola'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 15, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 16, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 17, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 18, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 19, {'name': 'Argentina'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 20, {'name': 'New Zealand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 21, {'name': 'Aruba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 22, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 23, {'name': 'Australia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 24, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 25, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 26, {'name': 'Austria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 27, {'name': 'Azerbaijan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 28, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 29, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 30, {'name': 'Netherlands Antilles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 31, {'name': 'Wyoming'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 32, {'name': 'Bahrain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 33, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 34, {'name': 'Bangladesh'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 35, {'name': 'Belarus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 36, {'name': 'Belgium'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 37, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 38, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 39, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 40, {'name': 'Liberia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 41, {'name': 'Liechtenstein'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 42, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 43, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 44, {'name': 'Turks and Caicos Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 45, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 46, {'name': 'Bolivia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 47, {'name': 'Botswana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 48, {'name': 'Brazil'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 49, {'name': 'State of Delaware'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 50, {'name': 'Brunei'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 51, {'name': 'Bulgaria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 52, {'name': 'Cameroon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 53, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 54, {'name': 'Gibraltar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 55, {'name': 'Grenada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 56, {'name': 'Guernsey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 57, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 58, {'name': 'Marshall Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 59, {'name': 'Saint Vincent and the Grenadines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 60, {'name': 'US Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 61, {'name': 'Central African Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 62, {'name': 'Chad'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 63, {'name': 'Chile'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 64, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 65, {'name': 'Colombia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 66, {'name': 'Croatia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 67, {'name': 'Cuba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 68, {'name': 'Curaçao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 69, {'name': 'Czech Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 70, {'name': "Côte d'Ivoire"}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 71, {'name': 'Denmark'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 72, {'name': 'Djibouti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 73, {'name': 'Dominica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 74, {'name': 'Dominican Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 75, {'name': 'Ecuador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 76, {'name': 'Egypt'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 77, {'name': 'El Salvador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 78, {'name': 'Estonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 79, {'name': 'Fiji'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 80, {'name': 'Finland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 81, {'name': 'France'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 82, {'name': 'French Guiana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 83, {'name': 'Georgia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 84, {'name': 'Germany'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 85, {'name': 'Ghana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 86, {'name': 'Greece'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 87, {'name': 'Guam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 88, {'name': 'Guatemala'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 89, {'name': 'Guyana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 90, {'name': 'Haiti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 91, {'name': 'Honduras'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 92, {'name': 'Labuan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 93, {'name': 'Thailand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 94, {'name': 'Hungary'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 95, {'name': 'Iceland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 96, {'name': 'India'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 97, {'name': 'Indonesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 98, {'name': 'Iran'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 99, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 100, {'name': 'Israel'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 101, {'name': 'Italy'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 102, {'name': 'Jamaica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 103, {'name': 'Japan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 104, {'name': 'Jordan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 105, {'name': 'Kazakhstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 106, {'name': 'Kenya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 107, {'name': 'Kuwait'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 108, {'name': 'Kyrgyzstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 109, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 110, {'name': 'Lebanon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 111, {'name': 'Lesotho'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 112, {'name': 'Libya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 113, {'name': 'Lithuania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 114, {'name': 'Macao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 115, {'name': 'Macedonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 116, {'name': 'Malawi'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 117, {'name': 'Malaysia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 118, {'name': 'Mali'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 119, {'name': 'Mexico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 120, {'name': 'Moldova'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 121, {'name': 'Monaco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 122, {'name': 'Mongolia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 123, {'name': 'Montenegro'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 124, {'name': 'Morocco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 125, {'name': 'Mozambique'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 126, {'name': 'Namibia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 127, {'name': 'Nauru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 128, {'name': 'Nicaragua'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 129, {'name': 'Nigeria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 130, {'name': 'Norway'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 131, {'name': 'Oman'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 132, {'name': 'Pakistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 133, {'name': 'Paraguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 134, {'name': 'Peru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 135, {'name': 'Philippines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 136, {'name': 'Poland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 137, {'name': 'Portugal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 138, {'name': 'Puerto Rico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 139, {'name': 'Qatar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 140, {'name': 'Romania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 141, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 142, {'name': 'Saint Lucia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 143, {'name': 'Saint Martin (French part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 144, {'name': 'Saudi Arabia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 145, {'name': 'Senegal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 146, {'name': 'Sierra Leone'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 147, {'name': 'Vanuatu'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 148, {'name': 'Sint Maarten (Dutch part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 149, {'name': 'Slovakia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 150, {'name': 'Slovenia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 151, {'name': 'South Africa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 152, {'name': 'South Korea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 153, {'name': 'Spain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 154, {'name': 'Sri Lanka'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 155, {'name': 'Sudan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 156, {'name': 'Suriname'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 157, {'name': 'Sweden'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 158, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 159, {'name': 'Syria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 160, {'name': 'Taiwan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 161, {'name': 'Tanzania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 162, {'name': 'Trinidad and Tobago'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 163, {'name': 'Tunisia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 164, {'name': 'Turkey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 165, {'name': 'Uganda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 166, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 167, {'name': 'Dubai'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 168, {'name': 'Uzbekistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 169, {'name': 'Venezuela'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 170, {'name': 'Vietnam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 171, {'name': 'Yemen'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 172, {'name': 'Zambia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8af4af5e50>, 173, {'name': 'Zimbabwe'})]

# %%
##similar to mini-proj, try a random target 
import random
random.seed(5104)
def unweighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'avg_betweenness':bet,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#try another function but this time with g.diameter having weight param 
#https://igraph.org/python/api/latest/igraph._igraph.GraphBase.html#diameter

random.seed(5104)
def weighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #try in-degree
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'avg_weighted_betweenness':bet,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type1_unweighted = unweighted_Type1_random_delete(g)
df_type1_unweighted.head()
# Out:
#    nodes_removed  avg_betweenness  prop_removed  diameter  \
# 0              1        89.364162          0.01       4.0
# 1              2        88.895349          0.01       4.0
# 2              3        88.280702          0.02       4.0
# 3              4        87.729412          0.02       4.0
# 4              5        87.201183          0.03       4.0
#
#    assortativity_degree  avg_unweighted_indegree   density  average_path_len
# 0             -0.581407                13.052023  0.075012          2.039118
# 1             -0.580282                13.034884  0.075346          2.039712
# 2             -0.586211                12.994152  0.075547          2.038596
# 3             -0.585468                13.023529  0.076161          2.038218
# 4             -0.585302                13.041420  0.076714          2.038109

# %%
df_type1_unweighted.tail()
# Out:
#      nodes_removed  avg_betweenness  prop_removed  diameter  \
# 169            170              0.0          0.87       0.0
# 170            171              0.0          0.87       0.0
# 171            172              0.0          0.88       0.0
# 172            173              0.0          0.88       0.0
# 173            174              0.0          0.89       NaN
#
#      assortativity_degree  avg_unweighted_indegree  density  average_path_len
# 169                   NaN                      0.0      0.0               NaN
# 170                   NaN                      0.0      0.0               NaN
# 171                   NaN                      0.0      0.0               NaN
# 172                   NaN                      0.0      0.0               NaN
# 173                   NaN                      0.0      NaN               NaN

# %%
df_type1_weighted = weighted_Type1_random_delete(g)
df_type1_weighted.head()
# Out:
#    nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 0              1          0.01      14.0                188.940967
# 1              2          0.01      14.0                188.093295
# 2              3          0.02      14.0                186.890997
# 3              4          0.02      14.0                185.420794
# 4              5          0.03      14.0                184.204076
#
#    assortativity_degree  avg_weighted_indegree   density  average_path_len
# 0             -0.580436            2479.028902  0.074148          2.042613
# 1             -0.578656            2492.709302  0.074271          2.043656
# 2             -0.578963            2501.555556  0.074323          2.044444
# 3             -0.578345            2516.258824  0.075129          2.039262
# 4             -0.578831            2528.414201  0.075531          2.039659

# %%
df_type1_weighted.tail(15)
# Out:
#      nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 159            160          0.82     391.0                  0.428571
# 160            161          0.82     391.0                  0.461538
# 161            162          0.83     391.0                  0.500000
# 162            163          0.83       0.0                  0.000000
# 163            164          0.84       0.0                  0.000000
# 164            165          0.84       0.0                  0.000000
# 165            166          0.85       0.0                  0.000000
# 166            167          0.85       0.0                  0.000000
# 167            168          0.86       0.0                  0.000000
# 168            169          0.86       0.0                  0.000000
# 169            170          0.87       0.0                  0.000000
# 170            171          0.87       0.0                  0.000000
# 171            172          0.88       0.0                  0.000000
# 172            173          0.88       0.0                  0.000000
# 173            174          0.89       NaN                  0.000000
#
#      assortativity_degree  avg_weighted_indegree   density  average_path_len
# 159                  -1.0              56.285714  0.038095               1.6
# 160                  -1.0              60.615385  0.043956               1.6
# 161                  -1.0              65.666667  0.051282               1.6
# 162                   NaN               0.000000  0.000000               NaN
# 163                   NaN               0.000000  0.000000               NaN
# 164                   NaN               0.000000  0.000000               NaN
# 165                   NaN               0.000000  0.000000               NaN
# 166                   NaN               0.000000  0.000000               NaN
# 167                   NaN               0.000000  0.000000               NaN
# 168                   NaN               0.000000  0.000000               NaN
# 169                   NaN               0.000000  0.000000               NaN
# 170                   NaN               0.000000  0.000000               NaN
# 171                   NaN               0.000000  0.000000               NaN
# 172                   NaN               0.000000  0.000000               NaN
# 173                   NaN               0.000000       NaN               NaN

# %% [markdown]
# ### Targeted attack

# %%
##try sort by indegree 
temp_df = pd.DataFrame({'Node_indice':g.vs.indices,
                         'Nodes':g.vs['name'],
                         'In_Degree':g.strength(mode='in',weights='weight')})

# %%
#sort by largest degree 
temp_df = temp_df.sort_values(by='In_Degree',ascending=False)

# %%
temp_df.head(50)
# Out:
#      Node_indice                   Nodes  In_Degree
# 3              3  British Virgin Islands   116270.0
# 9              9                  Panama    52007.0
# 6              6               Hong Kong    39473.0
# 158          158             Switzerland    38152.0
# 1              1                 Bahamas    20201.0
# 11            11              Seychelles    15255.0
# 39            39                  Jersey    14564.0
# 57            57              Luxembourg    10865.0
# 12            12          United Kingdom    10292.0
# 8              8                    Niue     9711.0
# 10            10                   Samoa     7719.0
# 56            56                Guernsey     7425.0
# 33            33    United Arab Emirates     7307.0
# 25            25             Isle of Man     5285.0
# 45            45           United States     4939.0
# 13            13                 Uruguay     4935.0
# 43            43               Singapore     4797.0
# 141          141                  Russia     4244.0
# 4              4          Cayman Islands     3978.0
# 28            28                  Cyprus     3718.0
# 64            64                   China     3703.0
# 22            22        British Anguilla     3270.0
# 121          121                  Monaco     3214.0
# 160          160                  Taiwan     2949.0
# 15            15                 Bermuda     2609.0
# 17            17                Barbados     2408.0
# 41            41           Liechtenstein     2123.0
# 54            54               Gibraltar     2054.0
# 65            65                Colombia     1866.0
# 75            75                 Ecuador     1856.0
# 104          104                  Jordan     1556.0
# 37            37                  Belize     1487.0
# 48            48                  Brazil     1430.0
# 109          109                  Latvia     1381.0
# 7              7                  Nevada     1260.0
# 38            38               Mauritius     1250.0
# 88            88               Guatemala     1246.0
# 153          153                   Spain     1192.0
# 93            93                Thailand      989.0
# 5              5              Costa Rica      967.0
# 78            78                 Estonia      881.0
# 29            29                   Malta      824.0
# 169          169               Venezuela      765.0
# 100          100                  Israel      674.0
# 53            53                  Canada      643.0
# 117          117                Malaysia      501.0
# 74            74      Dominican Republic      496.0
# 110          110                 Lebanon      492.0
# 2              2                 Andorra      490.0
# 92            92                  Labuan      430.0

# %%
temp_df.tail(50)
# Out:
#      Node_indice                       Nodes  In_Degree
# 173          173                    Zimbabwe        8.0
# 90            90                       Haiti        8.0
# 118          118                        Mali        8.0
# 140          140                     Romania        7.0
# 47            47                    Botswana        6.0
# 147          147                     Vanuatu        6.0
# 168          168                  Uzbekistan        5.0
# 30            30        Netherlands Antilles        5.0
# 132          132                    Pakistan        4.0
# 131          131                        Oman        4.0
# 98            98                        Iran        4.0
# 159          159                       Syria        4.0
# 66            66                     Croatia        4.0
# 163          163                     Tunisia        4.0
# 58            58            Marshall Islands        4.0
# 154          154                   Sri Lanka        3.0
# 146          146                Sierra Leone        3.0
# 145          145                     Senegal        3.0
# 85            85                       Ghana        3.0
# 125          125                  Mozambique        3.0
# 161          161                    Tanzania        3.0
# 34            34                  Bangladesh        3.0
# 50            50                      Brunei        3.0
# 122          122                    Mongolia        3.0
# 167          167                       Dubai        2.0
# 172          172                      Zambia        2.0
# 156          156                    Suriname        2.0
# 0              0                     Albania        2.0
# 89            89                      Guyana        2.0
# 138          138                 Puerto Rico        2.0
# 126          126                     Namibia        2.0
# 120          120                     Moldova        2.0
# 115          115                   Macedonia        2.0
# 112          112                       Libya        2.0
# 149          149                    Slovakia        1.0
# 52            52                    Cameroon        1.0
# 171          171                       Yemen        1.0
# 61            61    Central African Republic        1.0
# 72            72                    Djibouti        1.0
# 79            79                        Fiji        1.0
# 83            83                     Georgia        1.0
# 111          111                     Lesotho        1.0
# 165          165                      Uganda        1.0
# 108          108                  Kyrgyzstan        1.0
# 148          148   Sint Maarten (Dutch part)        1.0
# 116          116                      Malawi        1.0
# 127          127                       Nauru        1.0
# 155          155                       Sudan        1.0
# 143          143  Saint Martin (French part)        1.0
# 87            87                        Guam        1.0

# %%
#extract out by Node
order_of_del = temp_df['Nodes'].tolist()

# %%
#print the list to check it
order_of_del
# Out:
# ['British Virgin Islands',
#  'Panama',
#  'Hong Kong',
#  'Switzerland',
#  'Bahamas',
#  'Seychelles',
#  'Jersey',
#  'Luxembourg',
#  'United Kingdom',
#  'Niue',
#  'Samoa',
#  'Guernsey',
#  'United Arab Emirates',
#  'Isle of Man',
#  'United States',
#  'Uruguay',
#  'Singapore',
#  'Russia',
#  'Cayman Islands',
#  'Cyprus',
#  'China',
#  'British Anguilla',
#  'Monaco',
#  'Taiwan',
#  'Bermuda',
#  'Barbados',
#  'Liechtenstein',
#  'Gibraltar',
#  'Colombia',
#  'Ecuador',
#  'Jordan',
#  'Belize',
#  'Brazil',
#  'Latvia',
#  'Nevada',
#  'Mauritius',
#  'Guatemala',
#  'Spain',
#  'Thailand',
#  'Costa Rica',
#  'Estonia',
#  'Malta',
#  'Venezuela',
#  'Israel',
#  'Canada',
#  'Malaysia',
#  'Dominican Republic',
#  'Lebanon',
#  'Andorra',
#  'Labuan',
#  'Ireland',
#  'Italy',
#  'Saint Kitts and Nevis',
#  'France',
#  'Ukraine',
#  'Argentina',
#  'Portugal',
#  'Cook Islands',
#  'El Salvador',
#  'Greece',
#  'Netherlands',
#  'Germany',
#  'State of Delaware',
#  'Australia',
#  'Poland',
#  'Macao',
#  'Chile',
#  'Saudi Arabia',
#  'Saint Lucia',
#  'Paraguay',
#  'South Africa',
#  'Turkey',
#  'New Zealand',
#  'Bolivia',
#  'Hungary',
#  'Indonesia',
#  'Trinidad and Tobago',
#  'Mexico',
#  'Sweden',
#  'Finland',
#  'Dominica',
#  'Liberia',
#  'Kuwait',
#  'Turks and Caicos Islands',
#  'Belgium',
#  'Peru',
#  'Philippines',
#  'Japan',
#  'Curaçao',
#  'Bulgaria',
#  'Norway',
#  'Egypt',
#  'India',
#  'Morocco',
#  'Czech Republic',
#  'Wyoming',
#  'Antigua and Barbuda',
#  'Saint Vincent and the Grenadines',
#  'Lithuania',
#  'Qatar',
#  'Vietnam',
#  'Austria',
#  'Aruba',
#  'French Guiana',
#  'Kenya',
#  'Nigeria',
#  'Honduras',
#  'Jamaica',
#  'Slovenia',
#  "Côte d'Ivoire",
#  'South Korea',
#  'Iceland',
#  'Bahrain',
#  'Denmark',
#  'Belarus',
#  'Cuba',
#  'Nicaragua',
#  'Montenegro',
#  'Angola',
#  'US Virgin Islands',
#  'Chad',
#  'Azerbaijan',
#  'Kazakhstan',
#  'Grenada',
#  'Zimbabwe',
#  'Haiti',
#  'Mali',
#  'Romania',
#  'Botswana',
#  'Vanuatu',
#  'Uzbekistan',
#  'Netherlands Antilles',
#  'Pakistan',
#  'Oman',
#  'Iran',
#  'Syria',
#  'Croatia',
#  'Tunisia',
#  'Marshall Islands',
#  'Sri Lanka',
#  'Sierra Leone',
#  'Senegal',
#  'Ghana',
#  'Mozambique',
#  'Tanzania',
#  'Bangladesh',
#  'Brunei',
#  'Mongolia',
#  'Dubai',
#  'Zambia',
#  'Suriname',
#  'Albania',
#  'Guyana',
#  'Puerto Rico',
#  'Namibia',
#  'Moldova',
#  'Macedonia',
#  'Libya',
#  'Slovakia',
#  'Cameroon',
#  'Yemen',
#  'Central African Republic',
#  'Djibouti',
#  'Fiji',
#  'Georgia',
#  'Lesotho',
#  'Uganda',
#  'Kyrgyzstan',
#  'Sint Maarten (Dutch part)',
#  'Malawi',
#  'Nauru',
#  'Sudan',
#  'Saint Martin (French part)',
#  'Guam']

# %%
def unweighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(order_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(order_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#Weighted on diameter
def weighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(order_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(order_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_weighted_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type2_unweighted = unweighted_Type2_targeted_del(g)
df_type2_unweighted.head()
# Out:
#    num_nodes_removed  prop_removed            node_removed  avg_betweenness  \
# 0                  1          0.01  British Virgin Islands        81.803468
# 1                  2          0.01                  Panama        73.000000
# 2                  3          0.02               Hong Kong        70.222222
# 3                  4          0.02             Switzerland        69.905882
# 4                  5          0.03                 Bahamas        70.579882
#
#    diameter  assortativity_degree  avg_unweighted_indegree   density  \
# 0       4.0             -0.580664                11.387283  0.065444
# 1       4.0             -0.599559                 9.930233  0.057400
# 2       4.0             -0.602303                 9.391813  0.054604
# 3       4.0             -0.604046                 9.211765  0.053870
# 4       4.0             -0.602647                 8.142012  0.047894
#
#    average_path_len
# 0          2.085193
# 1          2.154256
# 2          2.150192
# 3          2.154235
# 4          2.208511

# %%
df_type2_unweighted.tail()
# Out:
#      num_nodes_removed  prop_removed                node_removed  \
# 169                170          0.87                      Malawi
# 170                171          0.87                       Nauru
# 171                172          0.88                       Sudan
# 172                173          0.88  Saint Martin (French part)
# 173                174          0.89                        Guam
#
#      avg_betweenness  diameter  assortativity_degree  avg_unweighted_indegree  \
# 169              0.0       0.0                   NaN                      0.0
# 170              0.0       0.0                   NaN                      0.0
# 171              0.0       0.0                   NaN                      0.0
# 172              0.0       0.0                   NaN                      0.0
# 173              0.0       NaN                   NaN                      0.0
#
#      density  average_path_len
# 169      0.0               NaN
# 170      0.0               NaN
# 171      0.0               NaN
# 172      0.0               NaN
# 173      NaN               NaN

# %%
df_type2_weighted = weighted_Type2_targeted_del(g)
df_type2_weighted.head(15)
# Out:
#     num_nodes_removed  prop_removed            node_removed  \
# 0                   1          0.01  British Virgin Islands
# 1                   2          0.01                  Panama
# 2                   3          0.02               Hong Kong
# 3                   4          0.02             Switzerland
# 4                   5          0.03                 Bahamas
# 5                   6          0.03              Seychelles
# 6                   7          0.04                  Jersey
# 7                   8          0.04              Luxembourg
# 8                   9          0.05          United Kingdom
# 9                  10          0.05                    Niue
# 10                 11          0.06                   Samoa
# 11                 12          0.06                Guernsey
# 12                 13          0.07    United Arab Emirates
# 13                 14          0.07             Isle of Man
# 14                 15          0.08           United States
#
#     avg_weighted_betweenness  diameter  assortativity_degree  \
# 0                 163.481704      13.0             -0.580664
# 1                 131.687774      93.0             -0.599559
# 2                 127.103135      93.0             -0.602303
# 3                 126.142665      93.0             -0.604046
# 4                 121.448800      93.0             -0.602647
# 5                 104.836717      91.0             -0.592480
# 6                 104.370417      91.0             -0.597485
# 7                 103.179701      91.0             -0.598943
# 8                 102.693356     137.0             -0.606099
# 9                  99.328748     137.0             -0.576187
# 10                 99.236251     137.0             -0.566975
# 11                 97.854124     137.0             -0.574019
# 12                 95.060750     137.0             -0.580387
# 13                 93.150669     137.0             -0.586522
# 14                 91.631014     191.0             -0.590294
#
#     avg_weighted_indegree   density  average_path_len
# 0             1159.410405  0.065444          2.085193
# 1              618.162791  0.057400          2.154256
# 2              490.140351  0.054604          2.150192
# 3              413.035294  0.053870          2.154235
# 4              275.562130  0.047894          2.208511
# 5              179.880952  0.042336          2.213856
# 6              174.910180  0.041346          2.219965
# 7              172.156627  0.040834          2.224329
# 8              155.272727  0.039576          2.230984
# 9              115.073171  0.035403          2.248635
# 10              89.276074  0.032396          2.288774
# 11              88.703704  0.031962          2.294912
# 12              85.888199  0.031439          2.292372
# 13              83.612500  0.029115          2.303361
# 14              60.339623  0.028459          2.311494

# %%
df_type2_weighted.tail(150)
# Out:
#      num_nodes_removed  prop_removed                node_removed  \
# 24                  25          0.13                     Bermuda
# 25                  26          0.13                    Barbados
# 26                  27          0.14               Liechtenstein
# 27                  28          0.14                   Gibraltar
# 28                  29          0.15                    Colombia
# ..                 ...           ...                         ...
# 169                170          0.87                      Malawi
# 170                171          0.87                       Nauru
# 171                172          0.88                       Sudan
# 172                173          0.88  Saint Martin (French part)
# 173                174          0.89                        Guam
#
#      avg_weighted_betweenness  diameter  assortativity_degree  \
# 24                  44.065069     539.0             -0.474680
# 25                  18.750724     543.0             -0.436491
# 26                  18.871477     543.0             -0.448080
# 27                  18.747717     543.0             -0.443431
# 28                  17.724138     548.0             -0.441667
# ..                        ...       ...                   ...
# 169                  0.000000       0.0                   NaN
# 170                  0.000000       0.0                   NaN
# 171                  0.000000       0.0                   NaN
# 172                  0.000000       0.0                   NaN
# 173                  0.000000       NaN                   NaN
#
#      avg_weighted_indegree   density  average_path_len
# 24               23.959732  0.011902          2.594399
# 25               16.378378  0.007165          2.761017
# 26               16.000000  0.007170          2.763158
# 27               16.041096  0.006989          2.776106
# 28               15.075862  0.006519          2.836565
# ..                     ...       ...               ...
# 169               0.000000  0.000000               NaN
# 170               0.000000  0.000000               NaN
# 171               0.000000  0.000000               NaN
# 172               0.000000  0.000000               NaN
# 173               0.000000       NaN               NaN
#
# [150 rows x 9 columns]

# %% [markdown]
# #### Unweighted

# %%
#Try plotting unweighted
fig, ax = plt.subplots(1,2,figsize=(14,6),sharey=True)
ax2_1 = ax[0].twinx()
ax[0].plot('prop_removed','diameter',data=df_type1_unweighted,ls='--',color='darkblue')
ax[0].plot('prop_removed','density',data=df_type1_unweighted,ls='--',color='darkviolet')
ax[0].plot('prop_removed','avg_betweenness',data=df_type1_unweighted,ls='--',color='darkgreen')
ax2_1.plot('prop_removed','avg_unweighted_indegree',data=df_type1_unweighted,ls='--',color='darkred')
ax[0].plot('prop_removed','assortativity_degree',data=df_type1_unweighted,ls='--',color='darkturquoise')
ax[0].plot('prop_removed','average_path_len',data=df_type1_unweighted,ls='--',color='darkorange')
ax[0].legend(loc='upper right')
ax[0].set_xlabel('Proportion of nodes removed')
ax[0].set_title('Random deletion')
ax2_1.tick_params('y',colors='darkred')
ax2_1.set_ylabel('Avg inDegree')
ax2_1.legend(loc='upper left')

ax2_2 = ax[1].twinx()
ax[1].plot('prop_removed','diameter',data=df_type2_unweighted,ls='--',color='blue')
ax[1].plot('prop_removed','density',data=df_type2_unweighted,ls='--',color='violet')
ax[1].plot('prop_removed','avg_betweenness',data=df_type2_unweighted,ls='--',color='green')
ax2_2.plot('prop_removed','avg_unweighted_indegree',data=df_type2_unweighted,ls='--',color='red')
ax[1].plot('prop_removed','assortativity_degree',data=df_type2_unweighted,ls='--',color='turquoise')
ax[1].plot('prop_removed','average_path_len',data=df_type2_unweighted,ls='--',color='orange')
ax[1].legend(loc='upper right')
ax[1].set_xlabel('Proportion of nodes removed')
ax[1].set_title('Targeted deletion')
ax2_2.tick_params('y',colors='darkred')
ax2_2.set_ylabel('Avg inDegree')
ax2_2.legend(loc='upper left')
plt.show()

# %% [markdown]
# #### Weighted

# %%
#Same but weighted
#Don't share y axis for type2
fig, ax = plt.subplots(2,2,figsize=(18,12),sharey=False)

#Random attack LHS graphs

ax[0,1].plot('prop_removed','diameter',data=df_type1_weighted,ls='-',color='darkblue')
ax[0,0].plot('prop_removed','density',data=df_type1_weighted,ls='-',color='darkviolet')
ax[0,0].plot('prop_removed','assortativity_degree',data=df_type1_weighted,ls='-',color='darkturquoise')
ax[0,0].plot('prop_removed','average_path_len',data=df_type1_weighted,ls='-',color='darkorange')
ax[0,0].legend(loc='upper right')
ax[0,0].set_xlabel('Proportion of nodes removed')
ax[0,0].set_title('Random deletion')

ax2_1 = ax[0,0].twinx()
ax2_1.plot('prop_removed','avg_weighted_indegree',data=df_type1_weighted,ls='-',color='darkred')
ax2_1.tick_params('y',colors='darkred')
ax2_1.set_ylabel('Avg inDegree')
ax2_1.legend(loc='upper left')

#Random attack RHS Graphs - Betweenness & Diameter
ax[0,1].set_title('Random deletion - Betweenness & Diameter')
ax[0,1].legend(loc='upper left')

ax_bet_rand = ax[0,1].twinx()
ax_bet_rand.plot('prop_removed','avg_weighted_betweenness',data=df_type1_weighted,ls='--',color='darkgreen')
ax_bet_rand.tick_params('y',colors='darkgreen')
ax_bet_rand.set_ylabel('Avg_weighted_betweenness')
ax_bet_rand.legend(loc='upper right')


#Targeted attack LHS Graphs

ax[1,1].plot('prop_removed','diameter',data=df_type2_weighted,ls='-',color='blue')
ax[1,0].plot('prop_removed','density',data=df_type2_weighted,ls='-',color='violet')
ax[1,0].plot('prop_removed','assortativity_degree',data=df_type2_weighted,ls='-',color='turquoise')
ax[1,0].plot('prop_removed','average_path_len',data=df_type2_weighted,ls='-',color='orange')
ax[1,0].legend(loc='upper right')
ax[1,0].set_xlabel('Proportion of nodes removed')
ax[1,0].set_title('Targeted deletion')

ax2_2 = ax[1,0].twinx()
ax2_2.plot('prop_removed','avg_weighted_indegree',data=df_type2_weighted,ls='-',color='darkred')
ax2_2.set_ylabel('Avg inDegree')
ax2_2.legend(loc='upper left')
ax2_2.tick_params('y',colors='darkred')


#Targeted attack RHS Graphs - Betweenness & Diameter 

ax[1,1].set_title('Targeted deletion - Betweenness & Diameter')
ax[1,1].legend(loc='upper left')

ax_bet_tar = ax[1,1].twinx()
ax_bet_tar.plot('prop_removed','avg_weighted_betweenness',data=df_type2_weighted,ls='--',color='green')
ax_bet_tar.tick_params('y',colors='green')
ax_bet_tar.set_ylabel('avg weighted betweenness')
ax_bet_tar.legend(loc='upper right')
plt.show()
