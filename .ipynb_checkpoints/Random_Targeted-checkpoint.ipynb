# %%
import pandas as pd
import numpy as np
import igraph as ig
import matplotlib.pyplot as plt

# %%
df_unweighted = pd.read_csv('combined_final_unweighted.csv')
df_unweighted
# Out:
#           node_start                node_end        status
# 0          Hong Kong                   Samoa  jurisdiction
# 1          Hong Kong                   Samoa  jurisdiction
# 2          Hong Kong                   Samoa  jurisdiction
# 3          Hong Kong                   Samoa  jurisdiction
# 4          Hong Kong                   Samoa  jurisdiction
# ...              ...                     ...           ...
# 338127     Indonesia  British Virgin Islands  officer_base
# 338128  Cook Islands  British Virgin Islands  officer_base
# 338129     Hong Kong  British Virgin Islands  officer_base
# 338130  Cook Islands          United Kingdom  officer_base
# 338131     Hong Kong          United Kingdom  officer_base
#
# [338132 rows x 3 columns]

# %%
df_weighted = pd.read_csv('combined_final_weighted.csv')
df_weighted
# Out:
#           node_start                node_end        status  weight
# 0          Hong Kong                   Samoa  jurisdiction     2.0
# 1          Hong Kong                   Samoa  jurisdiction     2.0
# 2          Hong Kong                   Samoa  jurisdiction     2.0
# 3          Hong Kong                   Samoa  jurisdiction     2.0
# 4          Hong Kong                   Samoa  jurisdiction     2.0
# ...              ...                     ...           ...     ...
# 338119     Indonesia  British Virgin Islands  officer_base     1.0
# 338120  Cook Islands  British Virgin Islands  officer_base     1.0
# 338121     Hong Kong  British Virgin Islands  officer_base     1.0
# 338122  Cook Islands          United Kingdom  officer_base     1.0
# 338123     Hong Kong          United Kingdom  officer_base     1.0
#
# [338124 rows x 4 columns]

# %%
df_undir = pd.read_csv('undirected_weighted_grouped.csv')
df_undir
# Out:
#              node_1                  node_2  weight
# 0           Albania                 Bahamas     4.0
# 1           Algeria  British Virgin Islands     2.0
# 2           Algeria          United Kingdom     2.0
# 3           Algeria           United States     1.0
# 4           Andorra                 Bahamas    52.0
# ...             ...                     ...     ...
# 2383      Hong Kong                Zimbabwe     3.0
# 2384         Jersey                Zimbabwe     1.0
# 2385         Panama                Zimbabwe     6.0
# 2386         Russia                Zimbabwe     2.0
# 2387  United States                Zimbabwe     1.0
#
# [2388 rows x 3 columns]

# %%
#plot the unweighted graph (try unweighted first)
g = ig.Graph.TupleList(df_undir.itertuples(index=False), directed=False, edge_attrs={'weight': "weight"})

# %%
ig.plot(g)

# %%
g.diameter()
# Out:
# 3

# %%
len(g.vs.indices)
# Out:
# 196

# %%
#g.vs.indices
df_undir['node_1'].value_counts()
# Out:
# British Virgin Islands    158
# Bahamas                    95
# Hong Kong                  90
# China                      88
# Cyprus                     81
#                          ...
# Tajikistan                  1
# Djibouti                    1
# Honduras                    1
# Paraguay                    1
# Albania                     1
# Name: node_1, Length: 172, dtype: int64

# %%
uni =df_undir['node_1'].unique()

# %%
len(uni)
# Out:
# 172

# %%
list(g.vs)
# Out:
# [igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 0, {'name': 'Albania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 2, {'name': 'Algeria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 6, {'name': 'Andorra'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 9, {'name': 'Costa Rica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 13, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 19, {'name': 'Uruguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 20, {'name': 'Angola'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 23, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 27, {'name': 'Argentina'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 28, {'name': 'Belarus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 29, {'name': 'New Zealand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 30, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 31, {'name': 'Armenia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 32, {'name': 'Aruba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 34, {'name': 'Australia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 35, {'name': 'Austria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 36, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 38, {'name': 'Czech Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 39, {'name': 'Germany'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 42, {'name': 'Labuan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 43, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 44, {'name': 'Malaysia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 45, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 47, {'name': 'South Africa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 48, {'name': 'Sweden'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 49, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 51, {'name': 'Azerbaijan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 52, {'name': 'Gibraltar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 53, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 54, {'name': 'Netherlands Antilles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 55, {'name': 'Saint Lucia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 56, {'name': 'Wyoming'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 57, {'name': 'Bahrain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 58, {'name': 'Bangladesh'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 59, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 60, {'name': 'Belgium'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 61, {'name': 'Benin'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 62, {'name': 'Liberia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 63, {'name': 'Liechtenstein'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 64, {'name': 'Turks and Caicos Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 65, {'name': 'Vanuatu'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 66, {'name': 'Bhutan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 67, {'name': 'Bolivia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 68, {'name': 'Bosnia and Herzegovina'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 69, {'name': 'Botswana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 70, {'name': 'Brazil'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 71, {'name': 'Croatia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 72, {'name': 'Curaçao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 73, {'name': 'Israel'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 74, {'name': 'Marshall Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 75, {'name': 'State of Delaware'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 76, {'name': 'Thailand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 77, {'name': 'Brunei'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 78, {'name': 'Bulgaria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 79, {'name': 'Cambodia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 80, {'name': 'Cameroon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 81, {'name': 'Indonesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 82, {'name': 'Grenada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 83, {'name': 'Guernsey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 84, {'name': 'Saint Vincent and the Grenadines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 85, {'name': 'US Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 86, {'name': 'Central African Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 87, {'name': 'Chad'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 88, {'name': 'Chile'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 89, {'name': 'France'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 90, {'name': 'Georgia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 91, {'name': 'Kazakhstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 92, {'name': 'Serbia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 93, {'name': 'Colombia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 94, {'name': 'Congo'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 95, {'name': 'Cuba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 96, {'name': "Côte d'Ivoire"}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 97, {'name': 'Denmark'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 98, {'name': 'Djibouti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 99, {'name': 'Dominica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 100, {'name': 'Dominican Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 101, {'name': 'Ecuador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 102, {'name': 'Egypt'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 103, {'name': 'El Salvador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 104, {'name': 'Estonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 105, {'name': 'Fiji'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 106, {'name': 'Finland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 107, {'name': 'French Guiana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 108, {'name': 'French Polynesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 109, {'name': 'Gabon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 110, {'name': 'Ghana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 111, {'name': 'Greece'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 112, {'name': 'Guam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 113, {'name': 'Guatemala'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 114, {'name': 'Guinea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 115, {'name': 'Guyana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 116, {'name': 'Haiti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 117, {'name': 'Honduras'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 118, {'name': 'Japan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 119, {'name': 'Kuwait'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 120, {'name': 'Portugal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 121, {'name': 'South Korea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 122, {'name': 'Taiwan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 123, {'name': 'Hungary'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 124, {'name': 'Iceland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 125, {'name': 'India'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 126, {'name': 'Iran'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 127, {'name': 'Italy'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 128, {'name': 'Jamaica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 129, {'name': 'Jordan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 130, {'name': 'Kenya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 131, {'name': 'Kyrgyzstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 132, {'name': 'Laos'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 133, {'name': 'Lebanon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 134, {'name': 'Lesotho'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 135, {'name': 'Libya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 136, {'name': 'Lithuania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 137, {'name': 'Macao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 138, {'name': 'Macedonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 139, {'name': 'Madagascar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 140, {'name': 'Malawi'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 141, {'name': 'Mali'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 142, {'name': 'Mexico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 143, {'name': 'Moldova'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 144, {'name': 'Monaco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 145, {'name': 'Mongolia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 146, {'name': 'Montenegro'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 147, {'name': 'Morocco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 148, {'name': 'Mozambique'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 149, {'name': 'Myanmar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 150, {'name': 'Namibia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 151, {'name': 'Nauru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 152, {'name': 'Nepal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 153, {'name': 'Nicaragua'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 154, {'name': 'Nigeria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 155, {'name': 'Norfolk Island'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 156, {'name': 'Northern Mariana Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 157, {'name': 'Norway'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 158, {'name': 'Oman'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 159, {'name': 'Pakistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 160, {'name': 'Palestine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 161, {'name': 'Papua New Guinea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 162, {'name': 'Paraguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 163, {'name': 'Peru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 164, {'name': 'Philippines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 165, {'name': 'Poland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 166, {'name': 'Puerto Rico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 167, {'name': 'Qatar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 168, {'name': 'Romania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 169, {'name': 'Saint Martin (French part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 170, {'name': 'Saudi Arabia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 171, {'name': 'Senegal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 172, {'name': 'Sierra Leone'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 173, {'name': 'Sint Maarten (Dutch part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 174, {'name': 'Slovakia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 175, {'name': 'Slovenia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 176, {'name': 'Spain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 177, {'name': 'Sri Lanka'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 178, {'name': 'Sudan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 179, {'name': 'Suriname'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 180, {'name': 'Syria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 181, {'name': 'Tajikistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 182, {'name': 'Tanzania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 183, {'name': 'Tonga'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 184, {'name': 'Trinidad and Tobago'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 185, {'name': 'Tunisia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 186, {'name': 'Turkey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 187, {'name': 'Turkmenistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 188, {'name': 'Uganda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 189, {'name': 'Dubai'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 190, {'name': 'Uzbekistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 191, {'name': 'Venezuela'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 192, {'name': 'Vietnam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 193, {'name': 'Yemen'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 194, {'name': 'Zambia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fdc622e8e50>, 195, {'name': 'Zimbabwe'})]

# %%
##similar to mini-proj, try a random target 
import random
random.seed(5104)
def unweighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'avg_betweenness':bet,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#try another function but this time with g.diameter having weight param 
#https://igraph.org/python/api/latest/igraph._igraph.GraphBase.html#diameter

random.seed(5104)
def weighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #try in-degree
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'avg_weighted_betweenness':bet,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type1_unweighted = unweighted_Type1_random_delete(g)
df_type1_unweighted.head()
# Out:
#    nodes_removed  avg_betweenness  prop_removed  diameter  \
# 0              1        88.805128          0.01       3.0
# 1              2        88.221649          0.01       3.0
# 2              3        87.689119          0.02       3.0
# 3              4        87.197917          0.02       3.0
# 4              5        86.680628          0.03       3.0
#
#    assortativity_degree  avg_unweighted_indegree   density  average_path_len
# 0             -0.556315                24.205128  0.123496          1.915517
# 1             -0.556133                24.288660  0.124557          1.914214
# 2             -0.555478                24.341969  0.125474          1.913428
# 3             -0.554013                24.343750  0.126133          1.913067
# 4             -0.553574                24.376963  0.126963          1.912428

# %%
df_type1_unweighted.tail()
# Out:
#      nodes_removed  avg_betweenness  prop_removed  diameter  \
# 191            192              0.0          0.98       0.0
# 192            193              0.0          0.98       0.0
# 193            194              0.0          0.99       0.0
# 194            195              0.0          0.99       0.0
# 195            196              0.0          1.00       NaN
#
#      assortativity_degree  avg_unweighted_indegree  density  average_path_len
# 191                   NaN                      0.0      0.0               NaN
# 192                   NaN                      0.0      0.0               NaN
# 193                   NaN                      0.0      0.0               NaN
# 194                   NaN                      0.0      0.0               NaN
# 195                   NaN                      0.0      NaN               NaN

# %%
df_type1_weighted = weighted_Type1_random_delete(g)
df_type1_weighted.head()
# Out:
#    nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 0              1          0.01      26.0                192.485242
# 1              2          0.01      26.0                191.790607
# 2              3          0.02      26.0                191.599206
# 3              4          0.02      26.0                190.783371
# 4              5          0.03      26.0                189.921771
#
#    assortativity_degree  avg_weighted_indegree   density  average_path_len
# 0             -0.555287            5676.569231  0.124594          1.913931
# 1             -0.556025            5701.623711  0.124399          1.914481
# 2             -0.557071            5686.906736  0.123872          1.915425
# 3             -0.558547            5715.468750  0.124298          1.915194
# 4             -0.557692            5745.125654  0.125164          1.914577

# %%
df_type1_weighted.tail(15)
# Out:
#      nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 181            182          0.93      58.0                  4.214286
# 182            183          0.93      58.0                  3.153846
# 183            184          0.94      58.0                  2.583333
# 184            185          0.94      58.0                  2.000000
# 185            186          0.95      58.0                  2.200000
# 186            187          0.95      63.0                  1.000000
# 187            188          0.96      63.0                  1.125000
# 188            189          0.96      63.0                  1.285714
# 189            190          0.97      63.0                  1.500000
# 190            191          0.97    4240.0                  0.600000
# 191            192          0.98     118.0                  0.250000
# 192            193          0.98       0.0                  0.000000
# 193            194          0.99       0.0                  0.000000
# 194            195          0.99       0.0                  0.000000
# 195            196          1.00       NaN                  0.000000
#
#      assortativity_degree  avg_weighted_indegree   density  average_path_len
# 181             -0.703963             752.714286  0.161905          1.666667
# 182             -0.696415             810.461538  0.175824          1.555556
# 183             -0.668848             877.666667  0.192308          1.464286
# 184             -0.643192             956.727273  0.212121          1.333333
# 185             -0.643192            1052.400000  0.254545          1.333333
# 186             -0.763780             964.444444  0.177778          1.466667
# 187             -0.763780            1085.000000  0.222222          1.466667
# 188             -0.763780            1240.000000  0.285714          1.466667
# 189             -0.763780            1446.666667  0.380952          1.466667
# 190             -1.000000            1706.400000  0.200000          1.500000
# 191             -1.000000              59.000000  0.200000          1.333333
# 192                   NaN               0.000000  0.000000               NaN
# 193                   NaN               0.000000  0.000000               NaN
# 194                   NaN               0.000000  0.000000               NaN
# 195                   NaN               0.000000       NaN               NaN

# %% [markdown]
# ### Targeted attack

# %%
##try sort by indegree 
temp_df = pd.DataFrame({'Node_indice':g.vs.indices,
                         'Nodes':g.vs['name'],
                         'In_Degree':g.indegree()})

# %%
#sort by largest degree 
temp_df = temp_df.sort_values(by='In_Degree',ascending=False)

# %%
temp_df.head(50)
# Out:
#      Node_indice                   Nodes  In_Degree
# 3              3  British Virgin Islands        183
# 15            15                  Panama        154
# 10            10               Hong Kong        144
# 4              4          United Kingdom        141
# 16            16                  Russia        130
# 5              5           United States        117
# 22            22                   China        110
# 18            18              Seychelles        105
# 37            37                  Cyprus        103
# 11            11                 Ireland        102
# 1              1                 Bahamas        101
# 25            25                  Canada         94
# 7              7          Cayman Islands         91
# 21            21                 Bermuda         81
# 24            24                Barbados         74
# 46            46               Singapore         74
# 26            26   Saint Kitts and Nevis         73
# 50            50    United Arab Emirates         72
# 14            14                    Niue         72
# 17            17                   Samoa         71
# 41            41                  Jersey         63
# 12            12                  Latvia         63
# 33            33        British Anguilla         58
# 122          122                  Taiwan         54
# 43            43              Luxembourg         54
# 30            30             Switzerland         53
# 36            36                  Belize         49
# 40            40             Isle of Man         49
# 8              8            Cook Islands         46
# 49            49                 Ukraine         45
# 44            44                Malaysia         43
# 81            81               Indonesia         41
# 45            45             Netherlands         40
# 13            13                  Nevada         39
# 53            53                   Malta         38
# 34            34               Australia         37
# 59            59               Mauritius         37
# 23            23     Antigua and Barbuda         36
# 52            52               Gibraltar         34
# 76            76                Thailand         34
# 39            39                 Germany         34
# 73            73                  Israel         34
# 85            85       US Virgin Islands         33
# 164          164             Philippines         33
# 125          125                   India         32
# 89            89                  France         31
# 29            29             New Zealand         31
# 48            48                  Sweden         31
# 191          191               Venezuela         31
# 38            38          Czech Republic         30

# %%
temp_df.tail(50)
# Out:
#      Node_indice                       Nodes  In_Degree
# 147          147                     Morocco          5
# 32            32                       Aruba          5
# 151          151                       Nauru          5
# 161          161            Papua New Guinea          4
# 179          179                    Suriname          4
# 158          158                        Oman          4
# 98            98                    Djibouti          4
# 54            54        Netherlands Antilles          4
# 145          145                    Mongolia          4
# 69            69                    Botswana          4
# 134          134                     Lesotho          4
# 75            75           State of Delaware          4
# 117          117                    Honduras          4
# 94            94                       Congo          4
# 95            95                        Cuba          4
# 150          150                     Namibia          4
# 153          153                   Nicaragua          3
# 109          109                       Gabon          3
# 2              2                     Algeria          3
# 20            20                      Angola          3
# 67            67                     Bolivia          3
# 68            68      Bosnia and Herzegovina          3
# 107          107               French Guiana          3
# 138          138                   Macedonia          3
# 115          115                      Guyana          3
# 166          166                 Puerto Rico          3
# 132          132                        Laos          3
# 112          112                        Guam          2
# 171          171                     Senegal          2
# 114          114                      Guinea          2
# 66            66                      Bhutan          2
# 116          116                       Haiti          2
# 87            87                        Chad          2
# 185          185                     Tunisia          2
# 148          148                  Mozambique          2
# 160          160                   Palestine          2
# 193          193                       Yemen          1
# 156          156    Northern Mariana Islands          1
# 155          155              Norfolk Island          1
# 188          188                      Uganda          1
# 194          194                      Zambia          1
# 189          189                       Dubai          1
# 169          169  Saint Martin (French part)          1
# 61            61                       Benin          1
# 141          141                        Mali          1
# 80            80                    Cameroon          1
# 86            86    Central African Republic          1
# 178          178                       Sudan          1
# 173          173   Sint Maarten (Dutch part)          1
# 0              0                     Albania          1

# %%
#extract out by Node
order_of_del = temp_df['Nodes'].tolist()

# %%
#print the list to check it
order_of_del
# Out:
# ['British Virgin Islands',
#  'Panama',
#  'Hong Kong',
#  'United Kingdom',
#  'Russia',
#  'United States',
#  'China',
#  'Seychelles',
#  'Cyprus',
#  'Ireland',
#  'Bahamas',
#  'Canada',
#  'Cayman Islands',
#  'Bermuda',
#  'Barbados',
#  'Singapore',
#  'Saint Kitts and Nevis',
#  'United Arab Emirates',
#  'Niue',
#  'Samoa',
#  'Jersey',
#  'Latvia',
#  'British Anguilla',
#  'Taiwan',
#  'Luxembourg',
#  'Switzerland',
#  'Belize',
#  'Isle of Man',
#  'Cook Islands',
#  'Ukraine',
#  'Malaysia',
#  'Indonesia',
#  'Netherlands',
#  'Nevada',
#  'Malta',
#  'Australia',
#  'Mauritius',
#  'Antigua and Barbuda',
#  'Gibraltar',
#  'Thailand',
#  'Germany',
#  'Israel',
#  'US Virgin Islands',
#  'Philippines',
#  'India',
#  'France',
#  'New Zealand',
#  'Sweden',
#  'Venezuela',
#  'Czech Republic',
#  'Uruguay',
#  'Guernsey',
#  'Japan',
#  'Spain',
#  'South Africa',
#  'Italy',
#  'Austria',
#  'Curaçao',
#  'Brazil',
#  'Colombia',
#  'Liechtenstein',
#  'South Korea',
#  'Belgium',
#  'Turks and Caicos Islands',
#  'Monaco',
#  'Costa Rica',
#  'Vietnam',
#  'Kazakhstan',
#  'Argentina',
#  'Ecuador',
#  'Macao',
#  'Greece',
#  'Saudi Arabia',
#  'Portugal',
#  'Chile',
#  'Pakistan',
#  'Hungary',
#  'Mexico',
#  'Finland',
#  'Andorra',
#  'Kuwait',
#  'Belarus',
#  'Dominican Republic',
#  'Turkey',
#  'Vanuatu',
#  'Sri Lanka',
#  'Poland',
#  'Croatia',
#  'Liberia',
#  'Lebanon',
#  'Peru',
#  'Labuan',
#  'Estonia',
#  'Kenya',
#  'Azerbaijan',
#  'Denmark',
#  'Norway',
#  'Egypt',
#  'Nigeria',
#  'Georgia',
#  'Bulgaria',
#  'Saint Vincent and the Grenadines',
#  'Saint Lucia',
#  'Romania',
#  'Serbia',
#  'Myanmar',
#  'Jordan',
#  'El Salvador',
#  'Tonga',
#  'Uzbekistan',
#  'Grenada',
#  'Slovenia',
#  'Wyoming',
#  'Fiji',
#  'Guatemala',
#  'Lithuania',
#  'Moldova',
#  "Côte d'Ivoire",
#  'Bahrain',
#  'Brunei',
#  'Marshall Islands',
#  'Paraguay',
#  'Syria',
#  'Jamaica',
#  'Bangladesh',
#  'Slovakia',
#  'Tanzania',
#  'Montenegro',
#  'Nepal',
#  'Malawi',
#  'French Polynesia',
#  'Iran',
#  'Cambodia',
#  'Qatar',
#  'Ghana',
#  'Armenia',
#  'Zimbabwe',
#  'Kyrgyzstan',
#  'Dominica',
#  'Trinidad and Tobago',
#  'Turkmenistan',
#  'Libya',
#  'Madagascar',
#  'Iceland',
#  'Sierra Leone',
#  'Tajikistan',
#  'Morocco',
#  'Aruba',
#  'Nauru',
#  'Papua New Guinea',
#  'Suriname',
#  'Oman',
#  'Djibouti',
#  'Netherlands Antilles',
#  'Mongolia',
#  'Botswana',
#  'Lesotho',
#  'State of Delaware',
#  'Honduras',
#  'Congo',
#  'Cuba',
#  'Namibia',
#  'Nicaragua',
#  'Gabon',
#  'Algeria',
#  'Angola',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'French Guiana',
#  'Macedonia',
#  'Guyana',
#  'Puerto Rico',
#  'Laos',
#  'Guam',
#  'Senegal',
#  'Guinea',
#  'Bhutan',
#  'Haiti',
#  'Chad',
#  'Tunisia',
#  'Mozambique',
#  'Palestine',
#  'Yemen',
#  'Northern Mariana Islands',
#  'Norfolk Island',
#  'Uganda',
#  'Zambia',
#  'Dubai',
#  'Saint Martin (French part)',
#  'Benin',
#  'Mali',
#  'Cameroon',
#  'Central African Republic',
#  'Sudan',
#  'Sint Maarten (Dutch part)',
#  'Albania']

# %%
def unweighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(order_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(order_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#Weighted on diameter
def weighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(order_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(order_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_weighted_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type2_unweighted = unweighted_Type2_targeted_del(g)
df_type2_unweighted.head()
# Out:
#    num_nodes_removed  prop_removed            node_removed  avg_betweenness  \
# 0                  1          0.01  British Virgin Islands        87.733333
# 1                  2          0.01                  Panama        84.860825
# 2                  3          0.02               Hong Kong        83.974093
# 3                  4          0.02          United Kingdom        86.869792
# 4                  5          0.03                  Russia        88.282723
#
#    diameter  assortativity_degree  avg_unweighted_indegree   density  \
# 0       4.0             -0.553123                22.615385  0.115385
# 1       4.0             -0.544523                21.154639  0.108485
# 2       4.0             -0.536278                19.792746  0.102024
# 3       4.0             -0.528282                18.458333  0.095639
# 4       4.0             -0.518999                17.235602  0.089769
#
#    average_path_len
# 0          1.962963
# 1          1.988591
# 2          2.006021
# 3          2.046952
# 4          2.082563

# %%
df_type2_unweighted.tail()
# Out:
#      num_nodes_removed  prop_removed               node_removed  \
# 191                192          0.98                   Cameroon
# 192                193          0.98   Central African Republic
# 193                194          0.99                      Sudan
# 194                195          0.99  Sint Maarten (Dutch part)
# 195                196          1.00                    Albania
#
#      avg_betweenness  diameter  assortativity_degree  avg_unweighted_indegree  \
# 191              0.0       0.0                   NaN                      0.0
# 192              0.0       0.0                   NaN                      0.0
# 193              0.0       0.0                   NaN                      0.0
# 194              0.0       0.0                   NaN                      0.0
# 195              0.0       NaN                   NaN                      0.0
#
#      density  average_path_len
# 191      0.0               NaN
# 192      0.0               NaN
# 193      0.0               NaN
# 194      0.0               NaN
# 195      NaN               NaN

# %%
df_type2_weighted = weighted_Type2_targeted_del(g)
df_type2_weighted.head(15)
# Out:
#     num_nodes_removed  prop_removed            node_removed  \
# 0                   1          0.01  British Virgin Islands
# 1                   2          0.01                  Panama
# 2                   3          0.02               Hong Kong
# 3                   4          0.02          United Kingdom
# 4                   5          0.03                  Russia
# 5                   6          0.03           United States
# 6                   7          0.04                   China
# 7                   8          0.04              Seychelles
# 8                   9          0.05                  Cyprus
# 9                  10          0.05                 Ireland
# 10                 11          0.06                 Bahamas
# 11                 12          0.06                  Canada
# 12                 13          0.07          Cayman Islands
# 13                 14          0.07                 Bermuda
# 14                 15          0.08                Barbados
#
#     avg_weighted_betweenness  diameter  assortativity_degree  \
# 0                 174.754582      22.0             -0.553123
# 1                 160.598104      22.0             -0.544523
# 2                 156.354125      22.0             -0.536278
# 3                 158.703257     138.0             -0.528282
# 4                 157.643487     273.0             -0.518999
# 5                 154.206277     381.0             -0.509981
# 6                 145.811544     381.0             -0.501048
# 7                 128.756140     381.0             -0.493502
# 8                 127.348891     381.0             -0.485394
# 9                 123.713680     381.0             -0.474682
# 10                118.487896     381.0             -0.464152
# 11                113.435960     381.0             -0.457196
# 12                105.377734     182.0             -0.449596
# 13                101.315036     182.0             -0.430735
# 14                 87.413584      47.0             -0.397350
#
#     avg_weighted_indegree   density  average_path_len
# 0             2724.338462  0.115385          1.962963
# 1             1711.592784  0.108485          1.988591
# 2             1261.699482  0.102024          2.006021
# 3             1072.458333  0.095639          2.046952
# 4              947.047120  0.089769          2.082563
# 5              855.963158  0.084541          2.104315
# 6              794.629630  0.079644          2.118907
# 7              597.574468  0.074975          2.105978
# 8              556.598930  0.070372          2.126905
# 9              538.161290  0.065781          2.159409
# 10             323.772973  0.061203          2.193201
# 11             309.326087  0.056992          2.218044
# 12             274.131148  0.052922          2.240932
# 13             261.115385  0.049421          2.286893
# 14             250.635359  0.046324          2.264887

# %%
df_type2_weighted.tail(15)
# Out:
#      num_nodes_removed  prop_removed                node_removed  \
# 181                182          0.93                   Palestine
# 182                183          0.93                       Yemen
# 183                184          0.94    Northern Mariana Islands
# 184                185          0.94              Norfolk Island
# 185                186          0.95                      Uganda
# 186                187          0.95                      Zambia
# 187                188          0.96                       Dubai
# 188                189          0.96  Saint Martin (French part)
# 189                190          0.97                       Benin
# 190                191          0.97                        Mali
# 191                192          0.98                    Cameroon
# 192                193          0.98    Central African Republic
# 193                194          0.99                       Sudan
# 194                195          0.99   Sint Maarten (Dutch part)
# 195                196          1.00                     Albania
#
#      avg_weighted_betweenness  diameter  assortativity_degree  \
# 181                       0.0       0.0                   NaN
# 182                       0.0       0.0                   NaN
# 183                       0.0       0.0                   NaN
# 184                       0.0       0.0                   NaN
# 185                       0.0       0.0                   NaN
# 186                       0.0       0.0                   NaN
# 187                       0.0       0.0                   NaN
# 188                       0.0       0.0                   NaN
# 189                       0.0       0.0                   NaN
# 190                       0.0       0.0                   NaN
# 191                       0.0       0.0                   NaN
# 192                       0.0       0.0                   NaN
# 193                       0.0       0.0                   NaN
# 194                       0.0       0.0                   NaN
# 195                       0.0       NaN                   NaN
#
#      avg_weighted_indegree  density  average_path_len
# 181                    0.0      0.0               NaN
# 182                    0.0      0.0               NaN
# 183                    0.0      0.0               NaN
# 184                    0.0      0.0               NaN
# 185                    0.0      0.0               NaN
# 186                    0.0      0.0               NaN
# 187                    0.0      0.0               NaN
# 188                    0.0      0.0               NaN
# 189                    0.0      0.0               NaN
# 190                    0.0      0.0               NaN
# 191                    0.0      0.0               NaN
# 192                    0.0      0.0               NaN
# 193                    0.0      0.0               NaN
# 194                    0.0      0.0               NaN
# 195                    0.0      NaN               NaN

# %% [markdown]
# #### Unweighted

# %%
#Try plotting unweighted
fig, ax = plt.subplots(1,2,figsize=(14,6),sharey=True)
ax2_1 = ax[0].twinx()
ax[0].plot('prop_removed','diameter',data=df_type1_unweighted,ls='--',color='darkblue')
ax[0].plot('prop_removed','density',data=df_type1_unweighted,ls='--',color='darkviolet')
ax[0].plot('prop_removed','avg_betweenness',data=df_type1_unweighted,ls='--',color='darkgreen')
ax2_1.plot('prop_removed','avg_unweighted_indegree',data=df_type1_unweighted,ls='--',color='darkred')
ax[0].plot('prop_removed','assortativity_degree',data=df_type1_unweighted,ls='--',color='darkturquoise')
ax[0].plot('prop_removed','average_path_len',data=df_type1_unweighted,ls='--',color='darkorange')
ax[0].legend(loc='upper right')
ax[0].set_xlabel('Proportion of nodes removed')
ax[0].set_title('Random deletion')
ax2_1.tick_params('y',colors='darkred')
ax2_1.set_ylabel('Avg inDegree')
ax2_1.legend(loc='upper left')

ax2_2 = ax[1].twinx()
ax[1].plot('prop_removed','diameter',data=df_type2_unweighted,ls='--',color='blue')
ax[1].plot('prop_removed','density',data=df_type2_unweighted,ls='--',color='violet')
ax[1].plot('prop_removed','avg_betweenness',data=df_type2_unweighted,ls='--',color='green')
ax2_2.plot('prop_removed','avg_unweighted_indegree',data=df_type2_unweighted,ls='--',color='red')
ax[1].plot('prop_removed','assortativity_degree',data=df_type2_unweighted,ls='--',color='turquoise')
ax[1].plot('prop_removed','average_path_len',data=df_type2_unweighted,ls='--',color='orange')
ax[1].legend(loc='upper right')
ax[1].set_xlabel('Proportion of nodes removed')
ax[1].set_title('Targeted deletion')
ax2_2.tick_params('y',colors='darkred')
ax2_2.set_ylabel('Avg inDegree')
ax2_2.legend(loc='upper left')
plt.show()

# %% [markdown]
# #### Weighted

# %% [markdown]
# Weighted has to set y-limit because of huge range

# %%
#Same but weighted
#Don't share y axis for type2
fig, ax = plt.subplots(2,2,figsize=(18,12),sharey=False)

#Random attack LHS graphs

ax[0,1].plot('prop_removed','diameter',data=df_type1_weighted,ls='-',color='darkblue')
ax[0,0].plot('prop_removed','density',data=df_type1_weighted,ls='-',color='darkviolet')
ax[0,0].plot('prop_removed','assortativity_degree',data=df_type1_weighted,ls='-',color='darkturquoise')
ax[0,0].plot('prop_removed','average_path_len',data=df_type1_weighted,ls='-',color='darkorange')
ax[0,0].legend(loc='upper right')
ax[0,0].set_xlabel('Proportion of nodes removed')
ax[0,0].set_title('Random deletion')

ax2_1 = ax[0,0].twinx()
ax2_1.plot('prop_removed','avg_weighted_indegree',data=df_type1_weighted,ls='-',color='darkred')
ax2_1.tick_params('y',colors='darkred')
ax2_1.set_ylabel('Avg inDegree')
ax2_1.legend(loc='upper left')

#Random attack RHS Graphs - Betweenness & Diameter
ax[0,1].set_title('Random deletion - Betweenness & Diameter')
ax[0,1].legend(loc='upper left')

ax_bet_rand = ax[0,1].twinx()
ax_bet_rand.plot('prop_removed','avg_weighted_betweenness',data=df_type1_weighted,ls='--',color='darkgreen')
ax_bet_rand.tick_params('y',colors='darkgreen')
ax_bet_rand.set_ylabel('Avg_weighted_betweenness')
ax_bet_rand.legend(loc='upper right')


#Targeted attack LHS Graphs

ax[1,1].plot('prop_removed','diameter',data=df_type2_weighted,ls='-',color='blue')
ax[1,0].plot('prop_removed','density',data=df_type2_weighted,ls='-',color='violet')
ax[1,0].plot('prop_removed','assortativity_degree',data=df_type2_weighted,ls='-',color='turquoise')
ax[1,0].plot('prop_removed','average_path_len',data=df_type2_weighted,ls='-',color='orange')
ax[1,0].legend(loc='upper right')
ax[1,0].set_xlabel('Proportion of nodes removed')
ax[1,0].set_title('Targeted deletion')

ax2_2 = ax[1,0].twinx()
ax2_2.plot('prop_removed','avg_weighted_indegree',data=df_type2_weighted,ls='-',color='darkred')
ax2_2.set_ylabel('Avg inDegree')
ax2_2.legend(loc='upper left')
ax2_2.tick_params('y',colors='darkred')


#Targeted attack RHS Graphs - Betweenness & Diameter 

ax[1,1].set_title('Targeted deletion - Betweenness & Diameter')
ax[1,1].legend(loc='upper left')

ax_bet_tar = ax[1,1].twinx()
ax_bet_tar.plot('prop_removed','avg_weighted_betweenness',data=df_type2_weighted,ls='--',color='green')
ax_bet_tar.tick_params('y',colors='green')
ax_bet_tar.set_ylabel('avg weighted betweenness')
ax_bet_tar.legend(loc='upper right')
plt.show()
