# %%
import pandas as pd
import numpy as np
import igraph as ig
import matplotlib.pyplot as plt

# %%
df_unweighted = pd.read_csv('../combined_final_unweighted.csv')
df_unweighted
# Out:
#           node_start                node_end        status
# 0          Hong Kong                   Samoa  jurisdiction
# 1          Hong Kong                   Samoa  jurisdiction
# 2          Hong Kong                   Samoa  jurisdiction
# 3          Hong Kong                   Samoa  jurisdiction
# 4          Hong Kong                   Samoa  jurisdiction
# ...              ...                     ...           ...
# 338127     Indonesia  British Virgin Islands  officer_base
# 338128  Cook Islands  British Virgin Islands  officer_base
# 338129     Hong Kong  British Virgin Islands  officer_base
# 338130  Cook Islands          United Kingdom  officer_base
# 338131     Hong Kong          United Kingdom  officer_base
#
# [338132 rows x 3 columns]

# %%
df_weighted = pd.read_csv('../combined_final_weighted.csv')
df_weighted
# Out:
#           node_start                node_end        status  weight
# 0          Hong Kong                   Samoa  jurisdiction     2.0
# 1          Hong Kong                   Samoa  jurisdiction     2.0
# 2          Hong Kong                   Samoa  jurisdiction     2.0
# 3          Hong Kong                   Samoa  jurisdiction     2.0
# 4          Hong Kong                   Samoa  jurisdiction     2.0
# ...              ...                     ...           ...     ...
# 338119     Indonesia  British Virgin Islands  officer_base     1.0
# 338120  Cook Islands  British Virgin Islands  officer_base     1.0
# 338121     Hong Kong  British Virgin Islands  officer_base     1.0
# 338122  Cook Islands          United Kingdom  officer_base     1.0
# 338123     Hong Kong          United Kingdom  officer_base     1.0
#
# [338124 rows x 4 columns]

# %%
df_dir = pd.read_csv('../combined_final_weighted_groupedby.csv')
df_dir
# Out:
#      node_start                node_end  weight
# 0       Albania                 Bahamas     4.0
# 1       Algeria  British Virgin Islands     2.0
# 2       Algeria          United Kingdom     2.0
# 3       Algeria           United States     1.0
# 4       Andorra                 Bahamas    52.0
# ...         ...                     ...     ...
# 2835   Zimbabwe               Hong Kong     3.0
# 2836   Zimbabwe                  Jersey     1.0
# 2837   Zimbabwe                  Panama     6.0
# 2838   Zimbabwe                  Russia     2.0
# 2839   Zimbabwe           United States     1.0
#
# [2840 rows x 3 columns]

# %%
g = ig.Graph.TupleList(df_dir.itertuples(index=False), directed=True, edge_attrs={'weight': "weight"})

# %%
ig.plot(g)

# %%
g.diameter()
# Out:
# 4

# %%
len(g.vs.indices)
# Out:
# 196

# %%
#g.vs.indices
df_dir['node_start'].value_counts()
# Out:
# Hong Kong                   60
# United States               55
# Taiwan                      53
# China                       53
# Singapore                   52
#                             ..
# Zambia                       1
# Mali                         1
# Northern Mariana Islands     1
# Yemen                        1
# Sudan                        1
# Name: node_start, Length: 190, dtype: int64

# %%
uni =df_dir['node_start'].unique()

# %%
len(uni)
# Out:
# 190

# %%
list(g.vs)
# Out:
# [igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 0, {'name': 'Albania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 2, {'name': 'Algeria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 6, {'name': 'Andorra'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 9, {'name': 'Costa Rica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 13, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 19, {'name': 'Uruguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 20, {'name': 'Angola'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 23, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 27, {'name': 'Argentina'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 28, {'name': 'Belarus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 29, {'name': 'New Zealand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 30, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 31, {'name': 'Armenia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 32, {'name': 'Aruba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 34, {'name': 'Australia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 35, {'name': 'Austria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 36, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 38, {'name': 'Czech Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 39, {'name': 'Germany'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 42, {'name': 'Labuan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 43, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 44, {'name': 'Malaysia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 45, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 47, {'name': 'South Africa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 48, {'name': 'Sweden'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 49, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 51, {'name': 'Azerbaijan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 52, {'name': 'Gibraltar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 53, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 54, {'name': 'Netherlands Antilles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 55, {'name': 'Saint Lucia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 56, {'name': 'Wyoming'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 57, {'name': 'Bahrain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 58, {'name': 'Bangladesh'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 59, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 60, {'name': 'Belgium'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 61, {'name': 'Benin'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 62, {'name': 'Liberia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 63, {'name': 'Liechtenstein'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 64, {'name': 'Turks and Caicos Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 65, {'name': 'Vanuatu'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 66, {'name': 'Bhutan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 67, {'name': 'Bolivia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 68, {'name': 'Bosnia and Herzegovina'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 69, {'name': 'Botswana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 70, {'name': 'Brazil'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 71, {'name': 'Croatia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 72, {'name': 'Curaçao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 73, {'name': 'Israel'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 74, {'name': 'Marshall Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 75, {'name': 'State of Delaware'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 76, {'name': 'Thailand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 77, {'name': 'Brunei'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 78, {'name': 'Bulgaria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 79, {'name': 'Cambodia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 80, {'name': 'Cameroon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 81, {'name': 'Indonesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 82, {'name': 'Grenada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 83, {'name': 'Guernsey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 84, {'name': 'Saint Vincent and the Grenadines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 85, {'name': 'US Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 86, {'name': 'Central African Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 87, {'name': 'Chad'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 88, {'name': 'Chile'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 89, {'name': 'France'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 90, {'name': 'Georgia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 91, {'name': 'Kazakhstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 92, {'name': 'Serbia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 93, {'name': 'Colombia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 94, {'name': 'Congo'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 95, {'name': 'Cuba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 96, {'name': "Côte d'Ivoire"}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 97, {'name': 'Denmark'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 98, {'name': 'Djibouti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 99, {'name': 'Dominica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 100, {'name': 'Dominican Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 101, {'name': 'Ecuador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 102, {'name': 'Egypt'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 103, {'name': 'El Salvador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 104, {'name': 'Estonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 105, {'name': 'Fiji'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 106, {'name': 'Finland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 107, {'name': 'French Guiana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 108, {'name': 'French Polynesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 109, {'name': 'Gabon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 110, {'name': 'Ghana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 111, {'name': 'Greece'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 112, {'name': 'Guam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 113, {'name': 'Guatemala'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 114, {'name': 'Guinea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 115, {'name': 'Guyana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 116, {'name': 'Haiti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 117, {'name': 'Honduras'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 118, {'name': 'Japan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 119, {'name': 'Kuwait'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 120, {'name': 'Portugal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 121, {'name': 'South Korea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 122, {'name': 'Taiwan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 123, {'name': 'Hungary'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 124, {'name': 'Iceland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 125, {'name': 'India'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 126, {'name': 'Iran'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 127, {'name': 'Italy'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 128, {'name': 'Jamaica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 129, {'name': 'Jordan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 130, {'name': 'Kenya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 131, {'name': 'Kyrgyzstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 132, {'name': 'Laos'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 133, {'name': 'Lebanon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 134, {'name': 'Lesotho'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 135, {'name': 'Libya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 136, {'name': 'Lithuania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 137, {'name': 'Macao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 138, {'name': 'Macedonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 139, {'name': 'Madagascar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 140, {'name': 'Malawi'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 141, {'name': 'Mali'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 142, {'name': 'Mexico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 143, {'name': 'Moldova'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 144, {'name': 'Monaco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 145, {'name': 'Mongolia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 146, {'name': 'Montenegro'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 147, {'name': 'Morocco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 148, {'name': 'Mozambique'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 149, {'name': 'Myanmar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 150, {'name': 'Namibia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 151, {'name': 'Nauru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 152, {'name': 'Nepal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 153, {'name': 'Nicaragua'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 154, {'name': 'Nigeria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 155, {'name': 'Norfolk Island'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 156, {'name': 'Northern Mariana Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 157, {'name': 'Norway'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 158, {'name': 'Oman'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 159, {'name': 'Pakistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 160, {'name': 'Palestine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 161, {'name': 'Papua New Guinea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 162, {'name': 'Paraguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 163, {'name': 'Peru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 164, {'name': 'Philippines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 165, {'name': 'Poland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 166, {'name': 'Puerto Rico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 167, {'name': 'Qatar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 168, {'name': 'Romania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 169, {'name': 'Saint Martin (French part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 170, {'name': 'Saudi Arabia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 171, {'name': 'Senegal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 172, {'name': 'Sierra Leone'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 173, {'name': 'Sint Maarten (Dutch part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 174, {'name': 'Slovakia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 175, {'name': 'Slovenia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 176, {'name': 'Spain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 177, {'name': 'Sri Lanka'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 178, {'name': 'Sudan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 179, {'name': 'Suriname'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 180, {'name': 'Syria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 181, {'name': 'Tajikistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 182, {'name': 'Tanzania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 183, {'name': 'Tonga'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 184, {'name': 'Trinidad and Tobago'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 185, {'name': 'Tunisia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 186, {'name': 'Turkey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 187, {'name': 'Turkmenistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 188, {'name': 'Uganda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 189, {'name': 'Dubai'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 190, {'name': 'Uzbekistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 191, {'name': 'Venezuela'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 192, {'name': 'Vietnam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 193, {'name': 'Yemen'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 194, {'name': 'Zambia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f9629329e50>, 195, {'name': 'Zimbabwe'})]

# %%
##similar to mini-proj, try a random target 
import random
random.seed(5104)
def unweighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'avg_betweenness':bet,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#try another function but this time with g.diameter having weight param 
#https://igraph.org/python/api/latest/igraph._igraph.GraphBase.html#diameter

random.seed(5104)
def weighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #try in-degree
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'avg_weighted_betweenness':bet,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type1_unweighted = unweighted_Type1_random_delete(g)
df_type1_unweighted.head()
# Out:
#    nodes_removed  avg_betweenness  prop_removed  diameter  \
# 0              1        74.107692          0.01       4.0
# 1              2        73.984536          0.01       4.0
# 2              3        73.943005          0.02       4.0
# 3              4        73.947917          0.02       4.0
# 4              5        73.869110          0.03       4.0
#
#    assortativity_degree  avg_unweighted_indegree   density  average_path_len
# 0             -0.470685                14.420513  0.073951          1.960455
# 1             -0.470699                14.474227  0.074609          1.959040
# 2             -0.469460                14.512953  0.075197          1.958686
# 3             -0.468696                14.526042  0.075656          1.958936
# 4             -0.469423                14.554974  0.076204          1.958101

# %%
df_type1_unweighted.tail()
# Out:
#      nodes_removed  avg_betweenness  prop_removed  diameter  \
# 191            192              0.0          0.98       0.0
# 192            193              0.0          0.98       0.0
# 193            194              0.0          0.99       0.0
# 194            195              0.0          0.99       0.0
# 195            196              0.0          1.00       NaN
#
#      assortativity_degree  avg_unweighted_indegree  density  average_path_len
# 191                   NaN                      0.0      0.0               NaN
# 192                   NaN                      0.0      0.0               NaN
# 193                   NaN                      0.0      0.0               NaN
# 194                   NaN                      0.0      0.0               NaN
# 195                   NaN                      0.0      NaN               NaN

# %%
df_type1_weighted = weighted_Type1_random_delete(g)
df_type1_weighted.head()
# Out:
#    nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 0              1          0.01      23.5                137.381474
# 1              2          0.01      23.5                135.948280
# 2              3          0.02      23.5                134.333279
# 3              4          0.02      23.5                133.320000
# 4              5          0.03      23.5                133.382297
#
#    assortativity_degree  avg_weighted_indegree   density  average_path_len
# 0             -0.469442            2838.284615  0.074504          1.957730
# 1             -0.468203            2850.811856  0.074344          1.958658
# 2             -0.466851            2843.453368  0.073881          1.960452
# 3             -0.466865            2857.734375  0.074083          1.960213
# 4             -0.465599            2872.562827  0.074642          1.959997

# %%
df_type1_weighted.tail(15)
# Out:
#      nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 181            182          0.93      52.0                  2.428571
# 182            183          0.93      52.0                  2.153846
# 183            184          0.94      52.0                  1.750000
# 184            185          0.94      48.0                  1.272727
# 185            186          0.95      48.0                  1.400000
# 186            187          0.95      38.0                  0.666667
# 187            188          0.96      38.0                  0.750000
# 188            189          0.96      38.0                  0.857143
# 189            190          0.97      38.0                  1.000000
# 190            191          0.97    4148.0                  0.000000
# 191            192          0.98      92.0                  0.000000
# 192            193          0.98       0.0                  0.000000
# 193            194          0.99       0.0                  0.000000
# 194            195          0.99       0.0                  0.000000
# 195            196          1.00       NaN                  0.000000
#
#      assortativity_degree  avg_weighted_indegree   density  average_path_len
# 181             -0.487487             376.357143  0.107143          1.536585
# 182             -0.502386             405.230769  0.118343          1.500000
# 183             -0.454813             438.833333  0.131944          1.419355
# 184             -0.459361             478.363636  0.148760          1.307692
# 185             -0.459361             526.200000  0.180000          1.307692
# 186             -0.125000             482.222222  0.111111          1.307692
# 187             -0.125000             542.500000  0.140625          1.307692
# 188             -0.125000             620.000000  0.183673          1.307692
# 189             -0.125000             723.333333  0.250000          1.307692
# 190                   NaN             853.200000  0.120000          1.000000
# 191                   NaN              29.500000  0.125000          1.000000
# 192                   NaN               0.000000  0.000000               NaN
# 193                   NaN               0.000000  0.000000               NaN
# 194                   NaN               0.000000  0.000000               NaN
# 195                   NaN               0.000000       NaN               NaN

# %% [markdown]
# ### Targeted attack

# %%
g.transitivity_avglocal_undirected()
# Out:
# 0.85808362695805

# %%
g.transitivity_undirected()
# Out:
# 0.3859593515919117

# %%
#use this 
g.transitivity_local_undirected(mode='zero',weights='weight')
# Out:
# [0.0,
#  0.7365345257545791,
#  2.0,
#  0.5732090934668445,
#  0.7679712643330471,
#  0.7937804521786107,
#  1.7368403304670377,
#  0.8228153975568234,
#  1.098830487500218,
#  1.4987888597421444,
#  0.7974203875866054,
#  0.7416885650581303,
#  1.1250428954467613,
#  0.7986424394319132,
#  0.6891306821568489,
#  0.5115701920426172,
#  0.7679335366923058,
#  0.8098656261773045,
#  0.6956506460402652,
#  1.524109398686205,
#  2.0,
#  0.7317644265274569,
#  0.8990323288529918,
#  0.8378468122786304,
#  0.6594915642719762,
#  0.8466353944199694,
#  0.8123980607959075,
#  1.773563811489508,
#  1.4507389162561577,
#  1.518181818181818,
#  1.3638487009873541,
#  2.0,
#  1.8583333333333334,
#  0.6060777633982948,
#  1.7437771466755763,
#  1.3412568306010928,
#  1.1475679909255407,
#  0.8706001417347503,
#  1.1855540293040292,
#  1.5759477741072834,
#  1.3602229711851554,
#  1.3016016792388454,
#  1.6692605168836068,
#  1.3413204857431333,
#  1.2687362460747225,
#  1.2182481660605606,
#  1.1218481835245455,
#  1.5620314302191465,
#  1.172521816961289,
#  1.296769796919722,
#  1.127925949147961,
#  1.9728915662650603,
#  1.6751840578579047,
#  1.2936894961736234,
#  1.8666666666666667,
#  1.8125,
#  1.1411411411411412,
#  1.926923076923077,
#  1.9755102040816326,
#  1.5905322519041092,
#  1.8685733741913517,
#  0.0,
#  1.3142857142857143,
#  1.8280558735974353,
#  1.1612090680100755,
#  1.707070707070707,
#  2.0,
#  2.0,
#  2.0,
#  2.0,
#  1.5912062927187482,
#  1.4187793427230047,
#  1.1363128491620111,
#  1.360918870896698,
#  1.2391975308641976,
#  2.0,
#  1.7053686497827065,
#  2.0,
#  1.9487394957983193,
#  2.0,
#  0.0,
#  1.6773266600509125,
#  1.7777777777777777,
#  1.7746501061289466,
#  1.8511627906976744,
#  1.824180594747124,
#  0.0,
#  2.0,
#  1.7223595320481133,
#  1.6564812367864694,
#  1.7006802721088434,
#  1.818822203437588,
#  1.5833333333333333,
#  1.7802375747481407,
#  2.0,
#  2.0,
#  1.7627551020408163,
#  1.8728070175438596,
#  2.0,
#  1.9884892086330934,
#  1.9519837375578297,
#  1.6149780524948492,
#  1.9516846789574063,
#  1.8268247326824734,
#  1.8738349084146104,
#  1.9473684210526316,
#  1.9505657093124456,
#  1.6333333333333333,
#  2.0,
#  2.0,
#  1.9166666666666667,
#  1.851138353765324,
#  2.0,
#  1.8762038523274478,
#  2.0,
#  2.0,
#  1.0,
#  2.0,
#  1.832545649838883,
#  1.6632266941864464,
#  1.6502525252525253,
#  1.8583447802197801,
#  1.4044951918307957,
#  1.6057464454976302,
#  1.9256756756756757,
#  1.8253055265377016,
#  1.9791666666666667,
#  1.3332498695878978,
#  1.9326145552560647,
#  1.9432866659541876,
#  1.9090909090909092,
#  1.9555555555555555,
#  2.0,
#  1.8644652160588415,
#  2.0,
#  2.0,
#  1.6266233766233766,
#  1.588529378721492,
#  2.0,
#  2.0,
#  1.9523809523809523,
#  0.0,
#  1.7515769044153324,
#  1.988888888888889,
#  1.8322414872399586,
#  2.0,
#  1.9867109634551494,
#  2.0,
#  2.0,
#  1.9257142857142857,
#  2.0,
#  2.0,
#  1.9870129870129871,
#  2.0,
#  1.9622377622377623,
#  0.0,
#  0.0,
#  1.9414715719063544,
#  2.0,
#  1.9495481927710843,
#  2.0,
#  1.8888888888888888,
#  1.8244274809160306,
#  1.8189349112426036,
#  1.81120527306968,
#  1.7234865725989987,
#  2.0,
#  1.736318407960199,
#  1.8863636363636365,
#  0.0,
#  1.889858614068773,
#  2.0,
#  1.8409090909090908,
#  0.0,
#  2.0,
#  1.8383838383838385,
#  1.6680616447455825,
#  1.9828104856037816,
#  0.0,
#  1.7619047619047619,
#  2.0,
#  2.0,
#  1.9727891156462585,
#  1.9017094017094016,
#  1.8196319018404907,
#  2.0,
#  1.9443694301917365,
#  2.0,
#  0.0,
#  0.0,
#  1.977124183006536,
#  1.7983373994759193,
#  1.9157744468236975,
#  0.0,
#  0.0,
#  2.0]

# %%
##try sort by transitivity 
temp_df = pd.DataFrame({'Node_indice':g.vs.indices,
                         'Nodes':g.vs['name'],
                         'transitivity':g.transitivity_local_undirected(mode='zero',weights='weight')})

# %%
#sort by largest degree 
temp_df = temp_df.sort_values(by='transitivity',ascending=False)

# %%
temp_df.head(50)
# Out:
#      Node_indice                   Nodes  transitivity
# 98            98                Djibouti      2.000000
# 135          135                   Libya      2.000000
# 132          132                    Laos      2.000000
# 117          117                Honduras      2.000000
# 115          115                  Guyana      2.000000
# 114          114                  Guinea      2.000000
# 112          112                    Guam      2.000000
# 109          109                   Gabon      2.000000
# 108          108        French Polynesia      2.000000
# 95            95                    Cuba      2.000000
# 94            94                   Congo      2.000000
# 87            87                    Chad      2.000000
# 79            79                Cambodia      2.000000
# 77            77                  Brunei      2.000000
# 75            75       State of Delaware      2.000000
# 69            69                Botswana      2.000000
# 68            68  Bosnia and Herzegovina      2.000000
# 134          134                 Lesotho      2.000000
# 138          138               Macedonia      2.000000
# 66            66                  Bhutan      2.000000
# 139          139              Madagascar      2.000000
# 187          187            Turkmenistan      2.000000
# 185          185                 Tunisia      2.000000
# 181          181              Tajikistan      2.000000
# 180          180                   Syria      2.000000
# 174          174                Slovakia      2.000000
# 171          171                 Senegal      2.000000
# 166          166             Puerto Rico      2.000000
# 160          160               Palestine      2.000000
# 158          158                    Oman      2.000000
# 153          153               Nicaragua      2.000000
# 151          151                   Nauru      2.000000
# 150          150                 Namibia      2.000000
# 148          148              Mozambique      2.000000
# 147          147                 Morocco      2.000000
# 145          145                Mongolia      2.000000
# 67            67                 Bolivia      2.000000
# 195          195                Zimbabwe      2.000000
# 20            20                  Angola      2.000000
# 31            31                 Armenia      2.000000
# 2              2                 Algeria      2.000000
# 143          143                 Moldova      1.988889
# 99            99                Dominica      1.988489
# 152          152                   Nepal      1.987013
# 146          146              Montenegro      1.986711
# 177          177               Sri Lanka      1.982810
# 126          126                    Iran      1.979167
# 190          190              Uzbekistan      1.977124
# 58            58              Bangladesh      1.975510
# 51            51              Azerbaijan      1.972892

# %%
temp_df.tail(50)
# Out:
#      Node_indice                       Nodes  transitivity
# 53            53                       Malta      1.293689
# 44            44                    Malaysia      1.268736
# 74            74            Marshall Islands      1.239198
# 45            45                 Netherlands      1.218248
# 38            38              Czech Republic      1.185554
# 48            48                      Sweden      1.172522
# 64            64    Turks and Caicos Islands      1.161209
# 36            36                      Belize      1.147568
# 56            56                     Wyoming      1.141141
# 72            72                     Curaçao      1.136313
# 50            50        United Arab Emirates      1.127926
# 12            12                      Latvia      1.125043
# 46            46                   Singapore      1.121848
# 8              8                Cook Islands      1.098830
# 116          116                       Haiti      1.000000
# 22            22                       China      0.899032
# 37            37                      Cyprus      0.870600
# 25            25                      Canada      0.846635
# 23            23         Antigua and Barbuda      0.837847
# 7              7              Cayman Islands      0.822815
# 26            26       Saint Kitts and Nevis      0.812398
# 17            17                       Samoa      0.809866
# 13            13                      Nevada      0.798642
# 10            10                   Hong Kong      0.797420
# 5              5               United States      0.793780
# 4              4              United Kingdom      0.767971
# 16            16                      Russia      0.767934
# 11            11                     Ireland      0.741689
# 1              1                     Bahamas      0.736535
# 21            21                     Bermuda      0.731764
# 18            18                  Seychelles      0.695651
# 14            14                        Niue      0.689131
# 24            24                    Barbados      0.659492
# 33            33            British Anguilla      0.606078
# 3              3      British Virgin Islands      0.573209
# 15            15                      Panama      0.511570
# 156          156    Northern Mariana Islands      0.000000
# 189          189                       Dubai      0.000000
# 194          194                      Zambia      0.000000
# 193          193                       Yemen      0.000000
# 61            61                       Benin      0.000000
# 155          155              Norfolk Island      0.000000
# 80            80                    Cameroon      0.000000
# 188          188                      Uganda      0.000000
# 178          178                       Sudan      0.000000
# 86            86    Central African Republic      0.000000
# 169          169  Saint Martin (French part)      0.000000
# 141          141                        Mali      0.000000
# 173          173   Sint Maarten (Dutch part)      0.000000
# 0              0                     Albania      0.000000

# %%
#extract out by Node
transitivity_of_del = temp_df['Nodes'].tolist()

# %%
#print the list to check it
transitivity_of_del
# Out:
# ['Djibouti',
#  'Libya',
#  'Laos',
#  'Honduras',
#  'Guyana',
#  'Guinea',
#  'Guam',
#  'Gabon',
#  'French Polynesia',
#  'Cuba',
#  'Congo',
#  'Chad',
#  'Cambodia',
#  'Brunei',
#  'State of Delaware',
#  'Botswana',
#  'Bosnia and Herzegovina',
#  'Lesotho',
#  'Macedonia',
#  'Bhutan',
#  'Madagascar',
#  'Turkmenistan',
#  'Tunisia',
#  'Tajikistan',
#  'Syria',
#  'Slovakia',
#  'Senegal',
#  'Puerto Rico',
#  'Palestine',
#  'Oman',
#  'Nicaragua',
#  'Nauru',
#  'Namibia',
#  'Mozambique',
#  'Morocco',
#  'Mongolia',
#  'Bolivia',
#  'Zimbabwe',
#  'Angola',
#  'Armenia',
#  'Algeria',
#  'Moldova',
#  'Dominica',
#  'Nepal',
#  'Montenegro',
#  'Sri Lanka',
#  'Iran',
#  'Uzbekistan',
#  'Bangladesh',
#  'Azerbaijan',
#  'Tanzania',
#  'Nigeria',
#  'Kyrgyzstan',
#  'Malawi',
#  'Dominican Republic',
#  'Egypt',
#  'Finland',
#  'Pakistan',
#  'Bulgaria',
#  'Fiji',
#  'Turkey',
#  'Jordan',
#  'Norway',
#  'Jamaica',
#  'Bahrain',
#  'Myanmar',
#  'Iceland',
#  'Ghana',
#  'Vietnam',
#  'Kenya',
#  'Tonga',
#  'Saudi Arabia',
#  'Papua New Guinea',
#  'Romania',
#  'Guatemala',
#  'Estonia',
#  'Denmark',
#  'Belgium',
#  'Netherlands Antilles',
#  'Lebanon',
#  'South Korea',
#  'Aruba',
#  'Saint Vincent and the Grenadines',
#  'Greece',
#  'Sierra Leone',
#  'Slovenia',
#  'Japan',
#  'Monaco',
#  'Liechtenstein',
#  'El Salvador',
#  'India',
#  'Paraguay',
#  'US Virgin Islands',
#  'Trinidad and Tobago',
#  'Peru',
#  'Kazakhstan',
#  'Saint Lucia',
#  'Philippines',
#  'Venezuela',
#  'Colombia',
#  'Grenada',
#  'Guernsey',
#  'Argentina',
#  "Côte d'Ivoire",
#  'Suriname',
#  'Mexico',
#  'Australia',
#  'Andorra',
#  'Qatar',
#  'Poland',
#  'Chile',
#  'Vanuatu',
#  'Thailand',
#  'Georgia',
#  'Indonesia',
#  'Gibraltar',
#  'Labuan',
#  'Spain',
#  'Kuwait',
#  'France',
#  'Portugal',
#  'French Guiana',
#  'Lithuania',
#  'Ecuador',
#  'Hungary',
#  'Brazil',
#  'Mauritius',
#  'Macao',
#  'Serbia',
#  'Germany',
#  'South Africa',
#  'Uruguay',
#  'New Zealand',
#  'Costa Rica',
#  'Belarus',
#  'Croatia',
#  'Taiwan',
#  'Switzerland',
#  'Israel',
#  'Isle of Man',
#  'Luxembourg',
#  'Austria',
#  'Italy',
#  'Liberia',
#  'Jersey',
#  'Ukraine',
#  'Malta',
#  'Malaysia',
#  'Marshall Islands',
#  'Netherlands',
#  'Czech Republic',
#  'Sweden',
#  'Turks and Caicos Islands',
#  'Belize',
#  'Wyoming',
#  'Curaçao',
#  'United Arab Emirates',
#  'Latvia',
#  'Singapore',
#  'Cook Islands',
#  'Haiti',
#  'China',
#  'Cyprus',
#  'Canada',
#  'Antigua and Barbuda',
#  'Cayman Islands',
#  'Saint Kitts and Nevis',
#  'Samoa',
#  'Nevada',
#  'Hong Kong',
#  'United States',
#  'United Kingdom',
#  'Russia',
#  'Ireland',
#  'Bahamas',
#  'Bermuda',
#  'Seychelles',
#  'Niue',
#  'Barbados',
#  'British Anguilla',
#  'British Virgin Islands',
#  'Panama',
#  'Northern Mariana Islands',
#  'Dubai',
#  'Zambia',
#  'Yemen',
#  'Benin',
#  'Norfolk Island',
#  'Cameroon',
#  'Uganda',
#  'Sudan',
#  'Central African Republic',
#  'Saint Martin (French part)',
#  'Mali',
#  'Sint Maarten (Dutch part)',
#  'Albania']

# %%
def unweighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(transitivity_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(transitivity_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#Weighted on diameter
def weighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(transitivity_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(transitivity_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_weighted_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type2_unweighted = unweighted_Type2_targeted_del(g)
df_type2_unweighted.head()
# Out:
#    num_nodes_removed  prop_removed node_removed  avg_betweenness  diameter  \
# 0                  1          0.01     Djibouti        73.892308       4.0
# 1                  2          0.01        Libya        73.778351       4.0
# 2                  3          0.02         Laos        73.673575       4.0
# 3                  4          0.02     Honduras        73.567708       4.0
# 4                  5          0.03       Guyana        73.392670       4.0
#
#    assortativity_degree  avg_unweighted_indegree   density  average_path_len
# 0             -0.468837                14.543590  0.074583          1.957663
# 1             -0.467896                14.592784  0.075221          1.956368
# 2             -0.467316                14.652850  0.075922          1.955193
# 3             -0.466976                14.708333  0.076606          1.954005
# 4             -0.466882                14.769634  0.077328          1.951922

# %%
df_type2_unweighted.tail()
# Out:
#      num_nodes_removed  prop_removed                node_removed  \
# 191                192          0.98    Central African Republic
# 192                193          0.98  Saint Martin (French part)
# 193                194          0.99                        Mali
# 194                195          0.99   Sint Maarten (Dutch part)
# 195                196          1.00                     Albania
#
#      avg_betweenness  diameter  assortativity_degree  avg_unweighted_indegree  \
# 191              0.0       0.0                   NaN                      0.0
# 192              0.0       0.0                   NaN                      0.0
# 193              0.0       0.0                   NaN                      0.0
# 194              0.0       0.0                   NaN                      0.0
# 195              0.0       NaN                   NaN                      0.0
#
#      density  average_path_len
# 191      0.0               NaN
# 192      0.0               NaN
# 193      0.0               NaN
# 194      0.0               NaN
# 195      NaN               NaN

# %%
df_type2_weighted = weighted_Type2_targeted_del(g)
df_type2_weighted.head(15)
# Out:
#     num_nodes_removed  prop_removed       node_removed  \
# 0                   1          0.01           Djibouti
# 1                   2          0.01              Libya
# 2                   3          0.02               Laos
# 3                   4          0.02           Honduras
# 4                   5          0.03             Guyana
# 5                   6          0.03             Guinea
# 6                   7          0.04               Guam
# 7                   8          0.04              Gabon
# 8                   9          0.05   French Polynesia
# 9                  10          0.05               Cuba
# 10                 11          0.06              Congo
# 11                 12          0.06               Chad
# 12                 13          0.07           Cambodia
# 13                 14          0.07             Brunei
# 14                 15          0.08  State of Delaware
#
#     avg_weighted_betweenness  diameter  assortativity_degree  \
# 0                 137.401154      23.5             -0.468837
# 1                 137.328050      23.5             -0.467896
# 2                 137.315388      23.5             -0.467316
# 3                 137.095503      23.5             -0.466976
# 4                 136.910488      23.5             -0.466882
# 5                 136.726538      23.5             -0.467592
# 6                 136.571387      23.5             -0.467163
# 7                 136.369639      23.5             -0.466306
# 8                 136.365628      23.5             -0.465497
# 9                 136.216158      23.5             -0.465283
# 10                136.177326      23.5             -0.465243
# 11                135.832276      23.5             -0.464564
# 12                135.887370      23.5             -0.463286
# 13                135.836363      23.5             -0.462381
# 14                134.509481      23.5             -0.460626
#
#     avg_weighted_indegree   density  average_path_len
# 0             2838.361538  0.074583          1.957663
# 1             2852.930412  0.075221          1.956368
# 2             2867.696891  0.075922          1.955193
# 3             2882.372396  0.076606          1.954005
# 4             2897.431937  0.077328          1.951922
# 5             2912.671053  0.078089          1.949543
# 6             2928.066138  0.078861          1.947892
# 7             2943.614362  0.079617          1.945948
# 8             2959.173797  0.080271          1.945439
# 9             2974.943548  0.081021          1.944088
# 10            2990.991892  0.081782          1.942510
# 11            3007.127717  0.082615          1.940421
# 12            3023.456284  0.083311          1.939798
# 13            3039.681319  0.083957          1.939383
# 14            3054.475138  0.084765          1.938395

# %%
df_type2_weighted.tail(15)
# Out:
#      num_nodes_removed  prop_removed                node_removed  \
# 181                182          0.93                      Panama
# 182                183          0.93    Northern Mariana Islands
# 183                184          0.94                       Dubai
# 184                185          0.94                      Zambia
# 185                186          0.95                       Yemen
# 186                187          0.95                       Benin
# 187                188          0.96              Norfolk Island
# 188                189          0.96                    Cameroon
# 189                190          0.97                      Uganda
# 190                191          0.97                       Sudan
# 191                192          0.98    Central African Republic
# 192                193          0.98  Saint Martin (French part)
# 193                194          0.99                        Mali
# 194                195          0.99   Sint Maarten (Dutch part)
# 195                196          1.00                     Albania
#
#      avg_weighted_betweenness  diameter  assortativity_degree  \
# 181                       0.0       0.0                   NaN
# 182                       0.0       0.0                   NaN
# 183                       0.0       0.0                   NaN
# 184                       0.0       0.0                   NaN
# 185                       0.0       0.0                   NaN
# 186                       0.0       0.0                   NaN
# 187                       0.0       0.0                   NaN
# 188                       0.0       0.0                   NaN
# 189                       0.0       0.0                   NaN
# 190                       0.0       0.0                   NaN
# 191                       0.0       0.0                   NaN
# 192                       0.0       0.0                   NaN
# 193                       0.0       0.0                   NaN
# 194                       0.0       0.0                   NaN
# 195                       0.0       NaN                   NaN
#
#      avg_weighted_indegree  density  average_path_len
# 181                    0.0      0.0               NaN
# 182                    0.0      0.0               NaN
# 183                    0.0      0.0               NaN
# 184                    0.0      0.0               NaN
# 185                    0.0      0.0               NaN
# 186                    0.0      0.0               NaN
# 187                    0.0      0.0               NaN
# 188                    0.0      0.0               NaN
# 189                    0.0      0.0               NaN
# 190                    0.0      0.0               NaN
# 191                    0.0      0.0               NaN
# 192                    0.0      0.0               NaN
# 193                    0.0      0.0               NaN
# 194                    0.0      0.0               NaN
# 195                    0.0      NaN               NaN

# %% [markdown]
# #### Unweighted

# %%
## Commented out to not confuse; use the weighted one below

#Try plotting unweighted
#fig, ax = plt.subplots(1,2,figsize=(14,6),sharey=True)
#ax2_1 = ax[0].twinx()
#ax[0].plot('prop_removed','diameter',data=df_type1_unweighted,ls='--',color='darkblue')
#ax[0].plot('prop_removed','density',data=df_type1_unweighted,ls='--',color='darkviolet')
#ax[0].plot('prop_removed','avg_betweenness',data=df_type1_unweighted,ls='--',color='darkgreen')
#ax2_1.plot('prop_removed','avg_unweighted_indegree',data=df_type1_unweighted,ls='--',color='darkred')
#ax[0].plot('prop_removed','assortativity_degree',data=df_type1_unweighted,ls='--',color='darkturquoise')
#ax[0].plot('prop_removed','average_path_len',data=df_type1_unweighted,ls='--',color='darkorange')
#ax[0].legend(loc='upper right')
#ax[0].set_xlabel('Proportion of nodes removed')
#ax[0].set_title('Random deletion')
#ax2_1.tick_params('y',colors='darkred')
#ax2_1.set_ylabel('Avg inDegree')
#ax2_1.legend(loc='upper left')

#ax2_2 = ax[1].twinx()
#ax[1].plot('prop_removed','diameter',data=df_type2_unweighted,ls='--',color='blue')
#ax[1].plot('prop_removed','density',data=df_type2_unweighted,ls='--',color='violet')
#ax[1].plot('prop_removed','avg_betweenness',data=df_type2_unweighted,ls='--',color='green')
#ax2_2.plot('prop_removed','avg_unweighted_indegree',data=df_type2_unweighted,ls='--',color='red')
#ax[1].plot('prop_removed','assortativity_degree',data=df_type2_unweighted,ls='--',color='turquoise')
#ax[1].plot('prop_removed','average_path_len',data=df_type2_unweighted,ls='--',color='orange')
#ax[1].legend(loc='upper right')
#ax[1].set_xlabel('Proportion of nodes removed')
#ax[1].set_title('Targeted deletion')
#ax2_2.tick_params('y',colors='darkred')
#ax2_2.set_ylabel('Avg inDegree')
#ax2_2.legend(loc='upper left')
#plt.show()

# %% [markdown]
# #### Weighted

# %%
#Same but weighted
#Don't share y axis for type2
fig, ax = plt.subplots(2,2,figsize=(18,12),sharey=False)

#Random attack LHS graphs

ax[0,1].plot('prop_removed','diameter',data=df_type1_weighted,ls='-',color='darkblue')
ax[0,0].plot('prop_removed','density',data=df_type1_weighted,ls='-',color='darkviolet')
ax[0,0].plot('prop_removed','assortativity_degree',data=df_type1_weighted,ls='-',color='darkturquoise')
ax[0,0].plot('prop_removed','average_path_len',data=df_type1_weighted,ls='-',color='darkorange')
ax[0,0].legend(loc='upper right')
ax[0,0].set_xlabel('Proportion of nodes removed')
ax[0,0].set_title('Random deletion')

ax2_1 = ax[0,0].twinx()
ax2_1.plot('prop_removed','avg_weighted_indegree',data=df_type1_weighted,ls='-',color='darkred')
ax2_1.tick_params('y',colors='darkred')
ax2_1.set_ylabel('Avg inDegree')
ax2_1.legend(loc='upper left')

#Random attack RHS Graphs - Betweenness & Diameter
ax[0,1].set_title('Random deletion - Betweenness & Diameter')
ax[0,1].legend(loc='upper left')

ax_bet_rand = ax[0,1].twinx()
ax_bet_rand.plot('prop_removed','avg_weighted_betweenness',data=df_type1_weighted,ls='--',color='darkgreen')
ax_bet_rand.tick_params('y',colors='darkgreen')
ax_bet_rand.set_ylabel('Avg_weighted_betweenness')
ax_bet_rand.legend(loc='upper right')


#Targeted attack LHS Graphs

ax[1,1].plot('prop_removed','diameter',data=df_type2_weighted,ls='-',color='blue')
ax[1,0].plot('prop_removed','density',data=df_type2_weighted,ls='-',color='violet')
ax[1,0].plot('prop_removed','assortativity_degree',data=df_type2_weighted,ls='-',color='turquoise')
ax[1,0].plot('prop_removed','average_path_len',data=df_type2_weighted,ls='-',color='orange')
ax[1,0].legend(loc='upper right')
ax[1,0].set_xlabel('Proportion of nodes removed')
ax[1,0].set_title('Targeted deletion')

ax2_2 = ax[1,0].twinx()
ax2_2.plot('prop_removed','avg_weighted_indegree',data=df_type2_weighted,ls='-',color='darkred')
ax2_2.set_ylabel('Avg inDegree')
ax2_2.legend(loc='upper left')
ax2_2.tick_params('y',colors='darkred')


#Targeted attack RHS Graphs - Betweenness & Diameter 

ax[1,1].set_title('Targeted deletion - Betweenness & Diameter')
ax[1,1].legend(loc='upper left')

ax_bet_tar = ax[1,1].twinx()
ax_bet_tar.plot('prop_removed','avg_weighted_betweenness',data=df_type2_weighted,ls='--',color='green')
ax_bet_tar.tick_params('y',colors='green')
ax_bet_tar.set_ylabel('avg weighted betweenness')
ax_bet_tar.legend(loc='upper right')
plt.show()

# %%
#see index 179, diameter jumps to 10000
df_type2_weighted.tail(40)
# Out:
#      num_nodes_removed  prop_removed                node_removed  \
# 156                157          0.80        United Arab Emirates
# 157                158          0.81                      Latvia
# 158                159          0.81                   Singapore
# 159                160          0.82                Cook Islands
# 160                161          0.82                       Haiti
# 161                162          0.83                       China
# 162                163          0.83                      Cyprus
# 163                164          0.84                      Canada
# 164                165          0.84         Antigua and Barbuda
# 165                166          0.85              Cayman Islands
# 166                167          0.85       Saint Kitts and Nevis
# 167                168          0.86                       Samoa
# 168                169          0.86                      Nevada
# 169                170          0.87                   Hong Kong
# 170                171          0.87               United States
# 171                172          0.88              United Kingdom
# 172                173          0.88                      Russia
# 173                174          0.89                     Ireland
# 174                175          0.89                     Bahamas
# 175                176          0.90                     Bermuda
# 176                177          0.90                  Seychelles
# 177                178          0.91                        Niue
# 178                179          0.91                    Barbados
# 179                180          0.92            British Anguilla
# 180                181          0.92      British Virgin Islands
# 181                182          0.93                      Panama
# 182                183          0.93    Northern Mariana Islands
# 183                184          0.94                       Dubai
# 184                185          0.94                      Zambia
# 185                186          0.95                       Yemen
# 186                187          0.95                       Benin
# 187                188          0.96              Norfolk Island
# 188                189          0.96                    Cameroon
# 189                190          0.97                      Uganda
# 190                191          0.97                       Sudan
# 191                192          0.98    Central African Republic
# 192                193          0.98  Saint Martin (French part)
# 193                194          0.99                        Mali
# 194                195          0.99   Sint Maarten (Dutch part)
# 195                196          1.00                     Albania
#
#      avg_weighted_betweenness  diameter  assortativity_degree  \
# 156                 40.740171      32.5             -0.320203
# 157                 40.224561      32.5             -0.318515
# 158                 38.219820      32.5             -0.329596
# 159                 39.574074      32.5             -0.339471
# 160                 39.376190      32.5             -0.344814
# 161                 36.911765      32.5             -0.356884
# 162                 35.484848      32.5             -0.365678
# 163                 34.328125      32.5             -0.373179
# 164                 30.370968      83.0             -0.379683
# 165                 26.750000      83.0             -0.392629
# 166                 25.103448      86.0             -0.397403
# 167                 22.750000      96.0             -0.403637
# 168                 21.148148      96.0             -0.385176
# 169                 19.000000      96.0             -0.401627
# 170                 16.800000      78.0             -0.437997
# 171                 14.958333      76.0             -0.448610
# 172                 13.217391      41.0             -0.469387
# 173                 11.863636      95.0             -0.474709
# 174                  8.761905      95.0             -0.512967
# 175                  6.550000     106.0             -0.528062
# 176                  4.421053      95.0             -0.591932
# 177                  3.222222      93.0             -0.471501
# 178                  1.705882     574.0             -0.411132
# 179                  0.562500    9791.5                   NaN
# 180                  0.000000       2.0                   NaN
# 181                  0.000000       0.0                   NaN
# 182                  0.000000       0.0                   NaN
# 183                  0.000000       0.0                   NaN
# 184                  0.000000       0.0                   NaN
# 185                  0.000000       0.0                   NaN
# 186                  0.000000       0.0                   NaN
# 187                  0.000000       0.0                   NaN
# 188                  0.000000       0.0                   NaN
# 189                  0.000000       0.0                   NaN
# 190                  0.000000       0.0                   NaN
# 191                  0.000000       0.0                   NaN
# 192                  0.000000       0.0                   NaN
# 193                  0.000000       0.0                   NaN
# 194                  0.000000       0.0                   NaN
# 195                  0.000000       NaN                   NaN
#
#      avg_weighted_indegree   density  average_path_len
# 156            6463.717949  0.295858          1.508671
# 157            6538.934211  0.290859          1.507444
# 158            6243.337838  0.278305          1.522029
# 159            6386.472222  0.270062          1.527378
# 160            6568.485714  0.284082          1.515602
# 161            6071.764706  0.268166          1.536232
# 162            5951.151515  0.254362          1.553415
# 163            6049.375000  0.239258          1.571702
# 164            6239.096774  0.234131          1.559748
# 165            6208.166667  0.220000          1.577367
# 166            6388.948276  0.208086          1.588235
# 167            6220.767857  0.195153          1.601140
# 168            6411.981481  0.201646          1.581538
# 169            3101.326923  0.181953          1.611111
# 170            2665.820000  0.166400          1.611570
# 171            1847.833333  0.147569          1.642857
# 172            1440.978261  0.128544          1.677778
# 173            1463.613636  0.111570          1.703947
# 174             989.380952  0.090703          1.739496
# 175            1012.175000  0.085000          1.697917
# 176             888.473684  0.072022          1.671429
# 177             733.333333  0.067901          1.615385
# 178             644.235294  0.055363          1.545455
# 179             645.937500  0.042969          1.450000
# 180               0.400000  0.013333          1.000000
# 181               0.000000  0.000000               NaN
# 182               0.000000  0.000000               NaN
# 183               0.000000  0.000000               NaN
# 184               0.000000  0.000000               NaN
# 185               0.000000  0.000000               NaN
# 186               0.000000  0.000000               NaN
# 187               0.000000  0.000000               NaN
# 188               0.000000  0.000000               NaN
# 189               0.000000  0.000000               NaN
# 190               0.000000  0.000000               NaN
# 191               0.000000  0.000000               NaN
# 192               0.000000  0.000000               NaN
# 193               0.000000  0.000000               NaN
# 194               0.000000  0.000000               NaN
# 195               0.000000       NaN               NaN
