# %%
import pandas as pd
import numpy as np
import igraph as ig
import matplotlib.pyplot as plt 
import collections

# %%
df_unweighted = pd.read_csv('../combined_final_unweighted.csv')
df_unweighted
# Out:
#           node_start                node_end        status
# 0          Hong Kong                   Samoa  jurisdiction
# 1          Hong Kong                   Samoa  jurisdiction
# 2          Hong Kong                   Samoa  jurisdiction
# 3          Hong Kong                   Samoa  jurisdiction
# 4          Hong Kong                   Samoa  jurisdiction
# ...              ...                     ...           ...
# 338127     Indonesia  British Virgin Islands  officer_base
# 338128  Cook Islands  British Virgin Islands  officer_base
# 338129     Hong Kong  British Virgin Islands  officer_base
# 338130  Cook Islands          United Kingdom  officer_base
# 338131     Hong Kong          United Kingdom  officer_base
#
# [338132 rows x 3 columns]

# %%
df_weighted = pd.read_csv('../combined_final_weighted.csv')
df_weighted
# Out:
#           node_start                node_end        status  weight
# 0          Hong Kong                   Samoa  jurisdiction     2.0
# 1          Hong Kong                   Samoa  jurisdiction     2.0
# 2          Hong Kong                   Samoa  jurisdiction     2.0
# 3          Hong Kong                   Samoa  jurisdiction     2.0
# 4          Hong Kong                   Samoa  jurisdiction     2.0
# ...              ...                     ...           ...     ...
# 338119     Indonesia  British Virgin Islands  officer_base     1.0
# 338120  Cook Islands  British Virgin Islands  officer_base     1.0
# 338121     Hong Kong  British Virgin Islands  officer_base     1.0
# 338122  Cook Islands          United Kingdom  officer_base     1.0
# 338123     Hong Kong          United Kingdom  officer_base     1.0
#
# [338124 rows x 4 columns]

# %%
df_weighted_jur = df_weighted[df_weighted['status'] == 'jurisdiction']
df_jur = df_weighted_jur.drop(['weight','status'], axis = 1)
df_jur
# Out:
#                     node_start      node_end
# 0                    Hong Kong         Samoa
# 1                    Hong Kong         Samoa
# 2                    Hong Kong         Samoa
# 3                    Hong Kong         Samoa
# 4                    Hong Kong         Samoa
# ...                        ...           ...
# 216554  British Virgin Islands  Cook Islands
# 216555  British Virgin Islands  Cook Islands
# 216556  British Virgin Islands  Cook Islands
# 216557  British Virgin Islands  Cook Islands
# 216558                 Vanuatu  Cook Islands
#
# [216559 rows x 2 columns]

# %%
df_jur_grouped = df_jur.groupby(['node_start','node_end'], as_index = False).size()
df_jur_grouped
# Out:
#      node_start                node_end  size
# 0       Albania                 Bahamas     2
# 1       Andorra                 Bahamas    26
# 2       Andorra  British Virgin Islands    39
# 3       Andorra          Cayman Islands     1
# 4       Andorra              Costa Rica     3
# ...         ...                     ...   ...
# 1212    Vietnam                  Panama     1
# 1213      Yemen                  Panama     1
# 1214     Zambia  British Virgin Islands     2
# 1215   Zimbabwe  British Virgin Islands     5
# 1216   Zimbabwe                  Panama     3
#
# [1217 rows x 3 columns]

# %% [markdown]
# ### Convert Data to an Undirected Edge List

# %%
#df_jur_grouped_list = df_jur_grouped.values.tolist()
#df_jur_grouped_list

# %%
#d = collections.defaultdict(int)
#for n1, n2, v in df_jur_grouped_list:
#    d[min(n1, n2), max(n1, n2)] += v
#result = [[k[0], k[1], v] for k, v in d.items()]

# %%
#df_net = pd.DataFrame(result)
#df_net

# %%
#df_net = df_net.rename(columns = {0:'node_1', 1:'node_2', 2: 'weight'})
#df_net

# %%
#import df_net to csv later

# %%
g = ig.Graph.TupleList(df_jur_grouped.itertuples(index=False), directed=True, edge_attrs={'weight': "weight"})

# %%
ig.plot(g)

# %%
g.diameter()
# Out:
# 5

# %%
len(g.vs.indices)
# Out:
# 174

# %%
#g.vs.indices
df_jur_grouped['node_start'].value_counts()
# Out:
# Cayman Islands    32
# Switzerland       23
# United States     23
# United Kingdom    22
# Jersey            21
#                   ..
# Djibouti           1
# Albania            1
# Fiji               1
# Namibia            1
# Suriname           1
# Name: node_start, Length: 168, dtype: int64

# %%
uni =df_jur_grouped['node_start'].unique()

# %%
len(uni)
# Out:
# 168

# %%
list(g.vs)
# Out:
# [igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 0, {'name': 'Albania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 2, {'name': 'Andorra'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 4, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 5, {'name': 'Costa Rica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 6, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 7, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 8, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 9, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 10, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 11, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 12, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 13, {'name': 'Uruguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 14, {'name': 'Angola'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 15, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 16, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 17, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 18, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 19, {'name': 'Argentina'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 20, {'name': 'New Zealand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 21, {'name': 'Aruba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 22, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 23, {'name': 'Australia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 24, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 25, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 26, {'name': 'Austria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 27, {'name': 'Azerbaijan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 28, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 29, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 30, {'name': 'Netherlands Antilles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 31, {'name': 'Wyoming'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 32, {'name': 'Bahrain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 33, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 34, {'name': 'Bangladesh'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 35, {'name': 'Belarus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 36, {'name': 'Belgium'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 37, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 38, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 39, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 40, {'name': 'Liberia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 41, {'name': 'Liechtenstein'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 42, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 43, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 44, {'name': 'Turks and Caicos Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 45, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 46, {'name': 'Bolivia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 47, {'name': 'Botswana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 48, {'name': 'Brazil'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 49, {'name': 'State of Delaware'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 50, {'name': 'Brunei'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 51, {'name': 'Bulgaria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 52, {'name': 'Cameroon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 53, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 54, {'name': 'Gibraltar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 55, {'name': 'Grenada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 56, {'name': 'Guernsey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 57, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 58, {'name': 'Marshall Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 59, {'name': 'Saint Vincent and the Grenadines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 60, {'name': 'US Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 61, {'name': 'Central African Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 62, {'name': 'Chad'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 63, {'name': 'Chile'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 64, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 65, {'name': 'Colombia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 66, {'name': 'Croatia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 67, {'name': 'Cuba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 68, {'name': 'Curaçao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 69, {'name': 'Czech Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 70, {'name': "Côte d'Ivoire"}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 71, {'name': 'Denmark'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 72, {'name': 'Djibouti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 73, {'name': 'Dominica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 74, {'name': 'Dominican Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 75, {'name': 'Ecuador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 76, {'name': 'Egypt'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 77, {'name': 'El Salvador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 78, {'name': 'Estonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 79, {'name': 'Fiji'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 80, {'name': 'Finland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 81, {'name': 'France'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 82, {'name': 'French Guiana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 83, {'name': 'Georgia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 84, {'name': 'Germany'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 85, {'name': 'Ghana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 86, {'name': 'Greece'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 87, {'name': 'Guam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 88, {'name': 'Guatemala'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 89, {'name': 'Guyana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 90, {'name': 'Haiti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 91, {'name': 'Honduras'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 92, {'name': 'Labuan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 93, {'name': 'Thailand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 94, {'name': 'Hungary'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 95, {'name': 'Iceland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 96, {'name': 'India'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 97, {'name': 'Indonesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 98, {'name': 'Iran'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 99, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 100, {'name': 'Israel'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 101, {'name': 'Italy'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 102, {'name': 'Jamaica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 103, {'name': 'Japan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 104, {'name': 'Jordan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 105, {'name': 'Kazakhstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 106, {'name': 'Kenya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 107, {'name': 'Kuwait'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 108, {'name': 'Kyrgyzstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 109, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 110, {'name': 'Lebanon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 111, {'name': 'Lesotho'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 112, {'name': 'Libya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 113, {'name': 'Lithuania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 114, {'name': 'Macao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 115, {'name': 'Macedonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 116, {'name': 'Malawi'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 117, {'name': 'Malaysia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 118, {'name': 'Mali'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 119, {'name': 'Mexico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 120, {'name': 'Moldova'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 121, {'name': 'Monaco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 122, {'name': 'Mongolia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 123, {'name': 'Montenegro'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 124, {'name': 'Morocco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 125, {'name': 'Mozambique'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 126, {'name': 'Namibia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 127, {'name': 'Nauru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 128, {'name': 'Nicaragua'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 129, {'name': 'Nigeria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 130, {'name': 'Norway'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 131, {'name': 'Oman'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 132, {'name': 'Pakistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 133, {'name': 'Paraguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 134, {'name': 'Peru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 135, {'name': 'Philippines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 136, {'name': 'Poland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 137, {'name': 'Portugal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 138, {'name': 'Puerto Rico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 139, {'name': 'Qatar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 140, {'name': 'Romania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 141, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 142, {'name': 'Saint Lucia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 143, {'name': 'Saint Martin (French part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 144, {'name': 'Saudi Arabia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 145, {'name': 'Senegal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 146, {'name': 'Sierra Leone'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 147, {'name': 'Vanuatu'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 148, {'name': 'Sint Maarten (Dutch part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 149, {'name': 'Slovakia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 150, {'name': 'Slovenia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 151, {'name': 'South Africa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 152, {'name': 'South Korea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 153, {'name': 'Spain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 154, {'name': 'Sri Lanka'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 155, {'name': 'Sudan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 156, {'name': 'Suriname'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 157, {'name': 'Sweden'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 158, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 159, {'name': 'Syria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 160, {'name': 'Taiwan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 161, {'name': 'Tanzania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 162, {'name': 'Trinidad and Tobago'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 163, {'name': 'Tunisia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 164, {'name': 'Turkey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 165, {'name': 'Uganda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 166, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 167, {'name': 'Dubai'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 168, {'name': 'Uzbekistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 169, {'name': 'Venezuela'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 170, {'name': 'Vietnam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 171, {'name': 'Yemen'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 172, {'name': 'Zambia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f8d8a335c70>, 173, {'name': 'Zimbabwe'})]

# %%
##similar to mini-proj, try a random target 
import random
random.seed(5104)
def unweighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
         #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'avg_betweenness':bet,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#try another function but this time with g.diameter having weight param 
#https://igraph.org/python/api/latest/igraph._igraph.GraphBase.html#diameter

random.seed(5104)
def weighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #try in-degree
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'avg_weighted_betweenness':bet,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type1_unweighted = unweighted_Type1_random_delete(g)
df_type1_unweighted.head()
# Out:
#    nodes_removed  avg_betweenness  prop_removed  diameter  \
# 0              1        58.751445          0.01       5.0
# 1              2        58.691860          0.01       5.0
# 2              3        57.912281          0.02       5.0
# 3              4        57.941176          0.02       5.0
# 4              5        57.863905          0.03       5.0
#
#    assortativity_degree  avg_unweighted_indegree   density  average_path_len
# 0             -0.452653                 7.028902  0.040629          2.248649
# 1             -0.453114                 7.023256  0.040833          2.247683
# 2             -0.451223                 7.005848  0.040970          2.249590
# 3             -0.450670                 7.023529  0.041315          2.250476
# 4             -0.450467                 7.035503  0.041630          2.249074

# %%
df_type1_unweighted.tail()
# Out:
#      nodes_removed  avg_betweenness  prop_removed  diameter  \
# 169            170              0.0          0.87       0.0
# 170            171              0.0          0.87       0.0
# 171            172              0.0          0.88       0.0
# 172            173              0.0          0.88       0.0
# 173            174              0.0          0.89       NaN
#
#      assortativity_degree  avg_unweighted_indegree  density  average_path_len
# 169                   NaN                      0.0      0.0               NaN
# 170                   NaN                      0.0      0.0               NaN
# 171                   NaN                      0.0      0.0               NaN
# 172                   NaN                      0.0      0.0               NaN
# 173                   NaN                      0.0      NaN               NaN

# %%
df_type1_weighted = weighted_Type1_random_delete(g)
df_type1_weighted.head()
# Out:
#    nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 0              1          0.01      32.0                104.235290
# 1              2          0.01      32.0                104.432879
# 2              3          0.02      32.0                104.570401
# 3              4          0.02      32.0                104.356894
# 4              5          0.03      32.0                104.422911
#
#    assortativity_degree  avg_weighted_indegree   density  average_path_len
# 0             -0.455171            1239.514451  0.040128          2.250815
# 1             -0.456073            1246.354651  0.040224          2.251956
# 2             -0.458828            1250.777778  0.040286          2.254125
# 3             -0.458779            1258.129412  0.040727          2.249936
# 4             -0.459692            1264.207101  0.040965          2.251221

# %%
df_type1_weighted.tail(15)
# Out:
#      nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 159            160          0.82     366.0                       0.0
# 160            161          0.82     366.0                       0.0
# 161            162          0.83     366.0                       0.0
# 162            163          0.83       0.0                       0.0
# 163            164          0.84       0.0                       0.0
# 164            165          0.84       0.0                       0.0
# 165            166          0.85       0.0                       0.0
# 166            167          0.85       0.0                       0.0
# 167            168          0.86       0.0                       0.0
# 168            169          0.86       0.0                       0.0
# 169            170          0.87       0.0                       0.0
# 170            171          0.87       0.0                       0.0
# 171            172          0.88       0.0                       0.0
# 172            173          0.88       0.0                       0.0
# 173            174          0.89       NaN                       0.0
#
#      assortativity_degree  avg_weighted_indegree   density  average_path_len
# 159                   NaN              28.142857  0.020408               1.0
# 160                   NaN              30.307692  0.023669               1.0
# 161                   NaN              32.833333  0.027778               1.0
# 162                   NaN               0.000000  0.000000               NaN
# 163                   NaN               0.000000  0.000000               NaN
# 164                   NaN               0.000000  0.000000               NaN
# 165                   NaN               0.000000  0.000000               NaN
# 166                   NaN               0.000000  0.000000               NaN
# 167                   NaN               0.000000  0.000000               NaN
# 168                   NaN               0.000000  0.000000               NaN
# 169                   NaN               0.000000  0.000000               NaN
# 170                   NaN               0.000000  0.000000               NaN
# 171                   NaN               0.000000  0.000000               NaN
# 172                   NaN               0.000000  0.000000               NaN
# 173                   NaN               0.000000       NaN               NaN

# %% [markdown]
# ### Targeted attack

# %%
##try sort by transitivity 
temp_df = pd.DataFrame({'Node_indice':g.vs.indices,
                         'Nodes':g.vs['name'],
                         'transitivity':g.transitivity_local_undirected(mode='zero',weights='weight')})

# %%
#sort by largest degree 
temp_df = temp_df.sort_values(by='transitivity',ascending=False)

# %%
temp_df.head(50)
# Out:
#      Node_indice                 Nodes  transitivity
# 173          173              Zimbabwe      2.000000
# 14            14                Angola      2.000000
# 46            46               Bolivia      2.000000
# 47            47              Botswana      2.000000
# 62            62                  Chad      2.000000
# 66            66               Croatia      2.000000
# 67            67                  Cuba      2.000000
# 73            73              Dominica      2.000000
# 91            91              Honduras      2.000000
# 102          102               Jamaica      2.000000
# 105          105            Kazakhstan      2.000000
# 34            34            Bangladesh      2.000000
# 112          112                 Libya      2.000000
# 163          163               Tunisia      2.000000
# 115          115             Macedonia      2.000000
# 124          124               Morocco      2.000000
# 145          145               Senegal      2.000000
# 138          138           Puerto Rico      2.000000
# 131          131                  Oman      2.000000
# 128          128             Nicaragua      2.000000
# 125          125            Mozambique      2.000000
# 162          162   Trinidad and Tobago      2.000000
# 35            35               Belarus      2.000000
# 123          123            Montenegro      2.000000
# 159          159                 Syria      2.000000
# 161          161              Tanzania      2.000000
# 109          109                Latvia      1.995655
# 60            60     US Virgin Islands      1.939394
# 104          104                Jordan      1.935893
# 80            80               Finland      1.933333
# 95            95               Iceland      1.911765
# 129          129               Nigeria      1.893333
# 51            51              Bulgaria      1.885000
# 76            76                 Egypt      1.878472
# 166          166               Ukraine      1.875300
# 30            30  Netherlands Antilles      1.866667
# 130          130                Norway      1.858333
# 170          170               Vietnam      1.851562
# 132          132              Pakistan      1.833333
# 74            74    Dominican Republic      1.802995
# 71            71               Denmark      1.800000
# 164          164                Turkey      1.792063
# 21            21                 Aruba      1.791667
# 144          144          Saudi Arabia      1.786765
# 142          142           Saint Lucia      1.784496
# 69            69        Czech Republic      1.783784
# 106          106                 Kenya      1.777778
# 19            19             Argentina      1.765328
# 107          107                Kuwait      1.747692
# 157          157                Sweden      1.726027

# %%
temp_df.tail(50)
# Out:
#      Node_indice                       Nodes  transitivity
# 6              6                   Hong Kong      1.031460
# 20            20                 New Zealand      1.029988
# 92            92                      Labuan      1.013953
# 90            90                       Haiti      1.000000
# 18            18       Saint Kitts and Nevis      0.891877
# 114          114                       Macao      0.838028
# 58            58            Marshall Islands      0.833333
# 10            10                       Samoa      0.695218
# 24            24                Cook Islands      0.659877
# 4              4              Cayman Islands      0.535636
# 17            17                    Barbados      0.530289
# 22            22            British Anguilla      0.517684
# 1              1                     Bahamas      0.499424
# 7              7                      Nevada      0.494048
# 8              8                        Niue      0.463648
# 11            11                  Seychelles      0.393662
# 117          117                    Malaysia      0.349608
# 9              9                      Panama      0.339103
# 15            15                     Bermuda      0.337527
# 3              3      British Virgin Islands      0.315305
# 171          171                       Yemen      0.000000
# 165          165                      Uganda      0.000000
# 156          156                    Suriname      0.000000
# 155          155                       Sudan      0.000000
# 172          172                      Zambia      0.000000
# 154          154                   Sri Lanka      0.000000
# 167          167                       Dubai      0.000000
# 168          168                  Uzbekistan      0.000000
# 0              0                     Albania      0.000000
# 149          149                    Slovakia      0.000000
# 108          108                  Kyrgyzstan      0.000000
# 50            50                      Brunei      0.000000
# 52            52                    Cameroon      0.000000
# 61            61    Central African Republic      0.000000
# 72            72                    Djibouti      0.000000
# 79            79                        Fiji      0.000000
# 83            83                     Georgia      0.000000
# 89            89                      Guyana      0.000000
# 98            98                        Iran      0.000000
# 111          111                     Lesotho      0.000000
# 148          148   Sint Maarten (Dutch part)      0.000000
# 116          116                      Malawi      0.000000
# 118          118                        Mali      0.000000
# 120          120                     Moldova      0.000000
# 122          122                    Mongolia      0.000000
# 126          126                     Namibia      0.000000
# 127          127                       Nauru      0.000000
# 143          143  Saint Martin (French part)      0.000000
# 146          146                Sierra Leone      0.000000
# 87            87                        Guam      0.000000

# %%
#extract out by Node
transitivity_of_del = temp_df['Nodes'].tolist()

# %%
#print the list to check it
transitivity_of_del
# Out:
# ['Zimbabwe',
#  'Angola',
#  'Bolivia',
#  'Botswana',
#  'Chad',
#  'Croatia',
#  'Cuba',
#  'Dominica',
#  'Honduras',
#  'Jamaica',
#  'Kazakhstan',
#  'Bangladesh',
#  'Libya',
#  'Tunisia',
#  'Macedonia',
#  'Morocco',
#  'Senegal',
#  'Puerto Rico',
#  'Oman',
#  'Nicaragua',
#  'Mozambique',
#  'Trinidad and Tobago',
#  'Belarus',
#  'Montenegro',
#  'Syria',
#  'Tanzania',
#  'Latvia',
#  'US Virgin Islands',
#  'Jordan',
#  'Finland',
#  'Iceland',
#  'Nigeria',
#  'Bulgaria',
#  'Egypt',
#  'Ukraine',
#  'Netherlands Antilles',
#  'Norway',
#  'Vietnam',
#  'Pakistan',
#  'Dominican Republic',
#  'Denmark',
#  'Turkey',
#  'Aruba',
#  'Saudi Arabia',
#  'Saint Lucia',
#  'Czech Republic',
#  'Kenya',
#  'Argentina',
#  'Kuwait',
#  'Sweden',
#  'Lebanon',
#  'Gibraltar',
#  'Russia',
#  'South Africa',
#  'Paraguay',
#  'Peru',
#  'Saint Vincent and the Grenadines',
#  'Azerbaijan',
#  'South Korea',
#  'Germany',
#  'Guatemala',
#  'Curaçao',
#  'Venezuela',
#  'El Salvador',
#  'Ghana',
#  'Qatar',
#  'Mexico',
#  'Andorra',
#  'Estonia',
#  'French Guiana',
#  'Monaco',
#  'Belgium',
#  'Greece',
#  'Indonesia',
#  'Lithuania',
#  'China',
#  'Thailand',
#  'Australia',
#  'Colombia',
#  'Luxembourg',
#  'Taiwan',
#  'Poland',
#  'Austria',
#  'Ireland',
#  'Portugal',
#  'Liechtenstein',
#  'France',
#  'Guernsey',
#  'Japan',
#  'State of Delaware',
#  'Turks and Caicos Islands',
#  'Philippines',
#  'Ecuador',
#  'Mauritius',
#  'Bahrain',
#  'Chile',
#  "Côte d'Ivoire",
#  'Canada',
#  'India',
#  'Netherlands',
#  'Hungary',
#  'Antigua and Barbuda',
#  'Switzerland',
#  'Slovenia',
#  'Spain',
#  'Jersey',
#  'Brazil',
#  'Israel',
#  'Romania',
#  'Costa Rica',
#  'United Arab Emirates',
#  'Vanuatu',
#  'United States',
#  'Singapore',
#  'Cyprus',
#  'Uruguay',
#  'United Kingdom',
#  'Malta',
#  'Belize',
#  'Isle of Man',
#  'Italy',
#  'Grenada',
#  'Liberia',
#  'Wyoming',
#  'Hong Kong',
#  'New Zealand',
#  'Labuan',
#  'Haiti',
#  'Saint Kitts and Nevis',
#  'Macao',
#  'Marshall Islands',
#  'Samoa',
#  'Cook Islands',
#  'Cayman Islands',
#  'Barbados',
#  'British Anguilla',
#  'Bahamas',
#  'Nevada',
#  'Niue',
#  'Seychelles',
#  'Malaysia',
#  'Panama',
#  'Bermuda',
#  'British Virgin Islands',
#  'Yemen',
#  'Uganda',
#  'Suriname',
#  'Sudan',
#  'Zambia',
#  'Sri Lanka',
#  'Dubai',
#  'Uzbekistan',
#  'Albania',
#  'Slovakia',
#  'Kyrgyzstan',
#  'Brunei',
#  'Cameroon',
#  'Central African Republic',
#  'Djibouti',
#  'Fiji',
#  'Georgia',
#  'Guyana',
#  'Iran',
#  'Lesotho',
#  'Sint Maarten (Dutch part)',
#  'Malawi',
#  'Mali',
#  'Moldova',
#  'Mongolia',
#  'Namibia',
#  'Nauru',
#  'Saint Martin (French part)',
#  'Sierra Leone',
#  'Guam']

# %%
def unweighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(transitivity_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(transitivity_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#Weighted on diameter
def weighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(transitivity_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(transitivity_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_weighted_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type2_unweighted = unweighted_Type2_targeted_del(g)
df_type2_unweighted.head()
# Out:
#    num_nodes_removed  prop_removed node_removed  avg_betweenness  diameter  \
# 0                  1          0.01     Zimbabwe        58.797688       5.0
# 1                  2          0.01       Angola        58.720930       5.0
# 2                  3          0.02      Bolivia        58.666667       5.0
# 3                  4          0.02     Botswana        58.570588       5.0
# 4                  5          0.03         Chad        58.467456       5.0
#
#    assortativity_degree  avg_unweighted_indegree   density  average_path_len
# 0             -0.451938                 7.023121  0.040596          2.249631
# 1             -0.451335                 7.052326  0.041002          2.248301
# 2             -0.451256                 7.076023  0.041380          2.247451
# 3             -0.449734                 7.100000  0.041765          2.245715
# 4             -0.448189                 7.130178  0.042190          2.243832

# %%
df_type2_unweighted.tail()
# Out:
#      num_nodes_removed  prop_removed                node_removed  \
# 169                170          0.87                     Namibia
# 170                171          0.87                       Nauru
# 171                172          0.88  Saint Martin (French part)
# 172                173          0.88                Sierra Leone
# 173                174          0.89                        Guam
#
#      avg_betweenness  diameter  assortativity_degree  avg_unweighted_indegree  \
# 169              0.0       0.0                   NaN                      0.0
# 170              0.0       0.0                   NaN                      0.0
# 171              0.0       0.0                   NaN                      0.0
# 172              0.0       0.0                   NaN                      0.0
# 173              0.0       NaN                   NaN                      0.0
#
#      density  average_path_len
# 169      0.0               NaN
# 170      0.0               NaN
# 171      0.0               NaN
# 172      0.0               NaN
# 173      NaN               NaN

# %%
df_type2_weighted = weighted_Type2_targeted_del(g)
df_type2_weighted.head(15)
# Out:
#     num_nodes_removed  prop_removed node_removed  avg_weighted_betweenness  \
# 0                   1          0.01     Zimbabwe                106.355645
# 1                   2          0.01       Angola                106.273411
# 2                   3          0.02      Bolivia                106.219454
# 3                   4          0.02     Botswana                106.100157
# 4                   5          0.03         Chad                105.897594
# 5                   6          0.03      Croatia                105.788849
# 6                   7          0.04         Cuba                105.867924
# 7                   8          0.04     Dominica                105.720542
# 8                   9          0.05     Honduras                105.830061
# 9                  10          0.05      Jamaica                105.654228
# 10                 11          0.06   Kazakhstan                105.563149
# 11                 12          0.06   Bangladesh                105.532778
# 12                 13          0.07        Libya                105.394886
# 13                 14          0.07      Tunisia                105.248917
# 14                 15          0.08    Macedonia                105.172889
#
#     diameter  assortativity_degree  avg_weighted_indegree   density  \
# 0       32.0             -0.451938            1251.739884  0.040596
# 1       32.0             -0.451335            1258.947674  0.041002
# 2       32.0             -0.451256            1265.754386  0.041380
# 3       32.0             -0.449734            1273.164706  0.041765
# 4       32.0             -0.448189            1280.633136  0.042190
# 5       32.0             -0.446855            1288.232143  0.042588
# 6       32.0             -0.445775            1295.868263  0.042956
# 7       32.0             -0.444460            1303.271084  0.043366
# 8       32.0             -0.443148            1311.018182  0.043747
# 9       32.0             -0.442469            1318.878049  0.044133
# 10      32.0             -0.441719            1326.914110  0.044601
# 11      32.0             -0.441006            1335.086420  0.045077
# 12      32.0             -0.439313            1343.366460  0.045562
# 13      32.0             -0.437615            1351.737500  0.046055
# 14      32.0             -0.436448            1360.226415  0.046557
#
#     average_path_len
# 0           2.249631
# 1           2.248301
# 2           2.247451
# 3           2.245715
# 4           2.243832
# 5           2.242052
# 6           2.242926
# 7           2.241118
# 8           2.241998
# 9           2.242889
# 10          2.241438
# 11          2.239968
# 12          2.237950
# 13          2.235906
# 14          2.232895

# %%
df_type2_weighted.tail(150)
# Out:
#      num_nodes_removed  prop_removed                node_removed  \
# 24                  25          0.13                       Syria
# 25                  26          0.13                    Tanzania
# 26                  27          0.14                      Latvia
# 27                  28          0.14           US Virgin Islands
# 28                  29          0.15                      Jordan
# ..                 ...           ...                         ...
# 169                170          0.87                     Namibia
# 170                171          0.87                       Nauru
# 171                172          0.88  Saint Martin (French part)
# 172                173          0.88                Sierra Leone
# 173                174          0.89                        Guam
#
#      avg_weighted_betweenness  diameter  assortativity_degree  \
# 24                 103.873642      32.0             -0.424894
# 25                 103.693734      32.0             -0.423052
# 26                 103.568182      32.0             -0.422575
# 27                 101.135478      32.0             -0.421798
# 28                 101.095280      32.0             -0.419711
# ..                        ...       ...                   ...
# 169                  0.000000       0.0                   NaN
# 170                  0.000000       0.0                   NaN
# 171                  0.000000       0.0                   NaN
# 172                  0.000000       0.0                   NaN
# 173                  0.000000       NaN                   NaN
#
#      avg_weighted_indegree   density  average_path_len
# 24             1450.322148  0.051935          2.213957
# 25             1460.101351  0.052547          2.211569
# 26             1460.639456  0.052987          2.210894
# 27             1470.575342  0.053434          2.202755
# 28             1469.986207  0.053936          2.202413
# ..                     ...       ...               ...
# 169               0.000000  0.000000               NaN
# 170               0.000000  0.000000               NaN
# 171               0.000000  0.000000               NaN
# 172               0.000000  0.000000               NaN
# 173               0.000000       NaN               NaN
#
# [150 rows x 9 columns]

# %% [markdown]
# #### Unweighted

# %%
## Commented out to not confuse; use the weighted one below

#Try plotting unweighted
#fig, ax = plt.subplots(1,2,figsize=(14,6),sharey=True)
#ax2_1 = ax[0].twinx()
#ax[0].plot('prop_removed','diameter',data=df_type1_unweighted,ls='--',color='darkblue')
#ax[0].plot('prop_removed','density',data=df_type1_unweighted,ls='--',color='darkviolet')
#set ylimit to 0 - 12 (to be same as type1; else there's a jump to 100)
#ax[0].set_ylim([0,12])
#ax[0].plot('prop_removed','avg_betweenness',data=df_type1_unweighted,ls='--',color='darkgreen')
#ax2_1.plot('prop_removed','avg_unweighted_indegree',data=df_type1_unweighted,ls='--',color='darkred')
#ax[0].plot('prop_removed','assortativity_degree',data=df_type1_unweighted,ls='--',color='darkturquoise')
#ax[0].plot('prop_removed','average_path_len',data=df_type1_unweighted,ls='--',color='darkorange')
#ax[0].legend(loc='upper right')
#ax[0].set_xlabel('Proportion of nodes removed')
#ax[0].set_title('Random deletion')
#ax2_1.tick_params('y',colors='darkred')
#ax2_1.set_ylabel('Avg inDegree')
#ax2_1.legend(loc='upper left')

#ax2_2 = ax[1].twinx()
#ax[1].plot('prop_removed','diameter',data=df_type2_unweighted,ls='--',color='blue')
#ax[1].plot('prop_removed','density',data=df_type2_unweighted,ls='--',color='violet')
#ax[1].plot('prop_removed','avg_betweenness',data=df_type2_unweighted,ls='--',color='green')
#ax2_2.plot('prop_removed','avg_unweighted_indegree',data=df_type2_unweighted,ls='--',color='red')
#ax[1].plot('prop_removed','assortativity_degree',data=df_type2_unweighted,ls='--',color='turquoise')
#ax[1].plot('prop_removed','average_path_len',data=df_type2_unweighted,ls='--',color='orange')
#ax[1].legend(loc='upper right')
#ax[1].set_xlabel('Proportion of nodes removed')
#ax[1].set_title('Targeted deletion')
#ax2_2.tick_params('y',colors='darkred')
#ax2_2.set_ylabel('Avg inDegree')
#ax2_2.legend(loc='upper left')
#plt.show()

# %% [markdown]
# #### Weighted

# %%
#Same but weighted
#Don't share y axis for type2
fig, ax = plt.subplots(2,2,figsize=(18,12),sharey=False)

#Random attack LHS graphs

ax[0,1].plot('prop_removed','diameter',data=df_type1_weighted,ls='-',color='darkblue')
ax[0,0].plot('prop_removed','density',data=df_type1_weighted,ls='-',color='darkviolet')
ax[0,0].plot('prop_removed','assortativity_degree',data=df_type1_weighted,ls='-',color='darkturquoise')
ax[0,0].plot('prop_removed','average_path_len',data=df_type1_weighted,ls='-',color='darkorange')
ax[0,0].legend(loc='upper right')
ax[0,0].set_xlabel('Proportion of nodes removed')
ax[0,0].set_title('Random deletion')

ax2_1 = ax[0,0].twinx()
ax2_1.plot('prop_removed','avg_weighted_indegree',data=df_type1_weighted,ls='-',color='darkred')
ax2_1.tick_params('y',colors='darkred')
ax2_1.set_ylabel('Avg inDegree')
ax2_1.legend(loc='upper left')

#Random attack RHS Graphs - Betweenness & Diameter
ax[0,1].set_title('Random deletion - Betweenness & Diameter')
ax[0,1].legend(loc='upper left')

ax_bet_rand = ax[0,1].twinx()
ax_bet_rand.plot('prop_removed','avg_weighted_betweenness',data=df_type1_weighted,ls='--',color='darkgreen')
ax_bet_rand.tick_params('y',colors='darkgreen')
ax_bet_rand.set_ylabel('Avg_weighted_betweenness')
ax_bet_rand.legend(loc='upper right')


#Targeted attack LHS Graphs

ax[1,1].plot('prop_removed','diameter',data=df_type2_weighted,ls='-',color='blue')
ax[1,0].plot('prop_removed','density',data=df_type2_weighted,ls='-',color='violet')
ax[1,0].plot('prop_removed','assortativity_degree',data=df_type2_weighted,ls='-',color='turquoise')
ax[1,0].plot('prop_removed','average_path_len',data=df_type2_weighted,ls='-',color='orange')
ax[1,0].legend(loc='upper right')
ax[1,0].set_xlabel('Proportion of nodes removed')
ax[1,0].set_title('Targeted deletion')

ax2_2 = ax[1,0].twinx()
ax2_2.plot('prop_removed','avg_weighted_indegree',data=df_type2_weighted,ls='-',color='darkred')
ax2_2.set_ylabel('Avg inDegree')
ax2_2.legend(loc='upper left')
ax2_2.tick_params('y',colors='darkred')


#Targeted attack RHS Graphs - Betweenness & Diameter 

ax[1,1].set_title('Targeted deletion - Betweenness & Diameter')
ax[1,1].legend(loc='upper left')

ax_bet_tar = ax[1,1].twinx()
ax_bet_tar.plot('prop_removed','avg_weighted_betweenness',data=df_type2_weighted,ls='--',color='green')
ax_bet_tar.tick_params('y',colors='green')
ax_bet_tar.set_ylabel('avg weighted betweenness')
ax_bet_tar.legend(loc='upper right')
plt.show()
