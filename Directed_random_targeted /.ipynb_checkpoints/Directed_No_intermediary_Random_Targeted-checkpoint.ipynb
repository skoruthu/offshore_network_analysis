# %%
import pandas as pd
import numpy as np
import igraph as ig
import matplotlib.pyplot as plt 
import collections

# %%
df_unweighted = pd.read_csv('../combined_final_unweighted.csv')
df_unweighted
# Out:
#           node_start                node_end        status
# 0          Hong Kong                   Samoa  jurisdiction
# 1          Hong Kong                   Samoa  jurisdiction
# 2          Hong Kong                   Samoa  jurisdiction
# 3          Hong Kong                   Samoa  jurisdiction
# 4          Hong Kong                   Samoa  jurisdiction
# ...              ...                     ...           ...
# 338127     Indonesia  British Virgin Islands  officer_base
# 338128  Cook Islands  British Virgin Islands  officer_base
# 338129     Hong Kong  British Virgin Islands  officer_base
# 338130  Cook Islands          United Kingdom  officer_base
# 338131     Hong Kong          United Kingdom  officer_base
#
# [338132 rows x 3 columns]

# %%
df_weighted = pd.read_csv('../combined_final_weighted.csv')
df_weighted
# Out:
#           node_start                node_end        status  weight
# 0          Hong Kong                   Samoa  jurisdiction     2.0
# 1          Hong Kong                   Samoa  jurisdiction     2.0
# 2          Hong Kong                   Samoa  jurisdiction     2.0
# 3          Hong Kong                   Samoa  jurisdiction     2.0
# 4          Hong Kong                   Samoa  jurisdiction     2.0
# ...              ...                     ...           ...     ...
# 338119     Indonesia  British Virgin Islands  officer_base     1.0
# 338120  Cook Islands  British Virgin Islands  officer_base     1.0
# 338121     Hong Kong  British Virgin Islands  officer_base     1.0
# 338122  Cook Islands          United Kingdom  officer_base     1.0
# 338123     Hong Kong          United Kingdom  officer_base     1.0
#
# [338124 rows x 4 columns]

# %%
## Replace intermediary jurisdiction with officer base
jurisdiction_status_list = ['jurisdiction','officer_base','officer_jurisdiction']

# %%
df_weighted_jur = df_weighted[df_weighted['status'].isin(jurisdiction_status_list)]
df_jur = df_weighted_jur.drop(['weight','status'], axis = 1)
df_jur
# Out:
#           node_start                node_end
# 0          Hong Kong                   Samoa
# 1          Hong Kong                   Samoa
# 2          Hong Kong                   Samoa
# 3          Hong Kong                   Samoa
# 4          Hong Kong                   Samoa
# ...              ...                     ...
# 338119     Indonesia  British Virgin Islands
# 338120  Cook Islands  British Virgin Islands
# 338121     Hong Kong  British Virgin Islands
# 338122  Cook Islands          United Kingdom
# 338123     Hong Kong          United Kingdom
#
# [329073 rows x 2 columns]

# %%
df_jur_grouped = df_jur.groupby(['node_start','node_end'], as_index = False).size()
df_jur_grouped
# Out:
#      node_start                node_end  size
# 0       Albania                 Bahamas     2
# 1       Algeria  British Virgin Islands     2
# 2       Algeria          United Kingdom     2
# 3       Algeria           United States     1
# 4       Andorra                 Bahamas    26
# ...         ...                     ...   ...
# 2750   Zimbabwe               Hong Kong     3
# 2751   Zimbabwe                  Jersey     1
# 2752   Zimbabwe                  Panama     3
# 2753   Zimbabwe                  Russia     2
# 2754   Zimbabwe           United States     1
#
# [2755 rows x 3 columns]

# %% [markdown]
# ### Convert Data to an Undirected Edge List

# %%
#df_jur_grouped_list = df_jur_grouped.values.tolist()
#df_jur_grouped_list

# %%
#d = collections.defaultdict(int)
#for n1, n2, v in df_jur_grouped_list:
#    d[min(n1, n2), max(n1, n2)] += v
#result = [[k[0], k[1], v] for k, v in d.items()]

# %%
#df_net = pd.DataFrame(result)
#df_net

# %%
#df_net = df_net.rename(columns = {0:'node_1', 1:'node_2', 2: 'weight'})
#df_net

# %%
#import df_net to csv later

# %%
#plot the unweighted graph (try unweighted first)
g = ig.Graph.TupleList(df_jur_grouped.itertuples(index=False), directed=True, edge_attrs={'weight': "weight"})

# %%
ig.plot(g)

# %%
g.diameter()
# Out:
# 4

# %%
len(g.vs.indices)
# Out:
# 195

# %%
#g.vs.indices
df_jur_grouped['node_start'].value_counts()
# Out:
# Hong Kong                    58
# Taiwan                       53
# China                        52
# Singapore                    50
# United States                49
#                              ..
# Albania                       1
# Central African Republic      1
# Benin                         1
# Uganda                        1
# Sint Maarten (Dutch part)     1
# Name: node_start, Length: 189, dtype: int64

# %%
uni =df_jur_grouped['node_start'].unique()

# %%
len(uni)
# Out:
# 189

# %%
list(g.vs)
# Out:
# [igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 0, {'name': 'Albania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 2, {'name': 'Algeria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 6, {'name': 'Andorra'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 8, {'name': 'Costa Rica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 9, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 10, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 11, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 12, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 13, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 14, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 15, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 16, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 17, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 18, {'name': 'Uruguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 19, {'name': 'Angola'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 20, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 21, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 22, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 23, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 24, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 25, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 26, {'name': 'Argentina'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 27, {'name': 'Belarus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 28, {'name': 'New Zealand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 29, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 30, {'name': 'Armenia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 31, {'name': 'Aruba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 32, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 33, {'name': 'Australia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 34, {'name': 'Austria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 35, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 36, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 38, {'name': 'Czech Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 39, {'name': 'Germany'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 42, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 43, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 44, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 45, {'name': 'South Africa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 46, {'name': 'Sweden'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 47, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 48, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 49, {'name': 'Azerbaijan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 50, {'name': 'Gibraltar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 51, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 52, {'name': 'Netherlands Antilles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 53, {'name': 'Wyoming'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 54, {'name': 'Bahrain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 55, {'name': 'Bangladesh'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 56, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 57, {'name': 'Belgium'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 58, {'name': 'Benin'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 59, {'name': 'Liberia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 60, {'name': 'Liechtenstein'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 61, {'name': 'Turks and Caicos Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 62, {'name': 'Vanuatu'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 63, {'name': 'Bhutan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 64, {'name': 'Bolivia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 65, {'name': 'Bosnia and Herzegovina'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 66, {'name': 'Botswana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 67, {'name': 'Brazil'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 68, {'name': 'Croatia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 69, {'name': 'Curaçao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 70, {'name': 'Israel'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 71, {'name': 'State of Delaware'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 72, {'name': 'Thailand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 73, {'name': 'Brunei'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 74, {'name': 'Bulgaria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 75, {'name': 'Cambodia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 76, {'name': 'Cameroon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 77, {'name': 'Grenada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 78, {'name': 'Guernsey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 79, {'name': 'Marshall Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 80, {'name': 'Saint Vincent and the Grenadines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 81, {'name': 'US Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 82, {'name': 'Central African Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 83, {'name': 'Chad'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 84, {'name': 'Chile'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 85, {'name': 'France'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 86, {'name': 'Georgia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 87, {'name': 'Kazakhstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 88, {'name': 'Labuan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 89, {'name': 'Malaysia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 90, {'name': 'Serbia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 91, {'name': 'Colombia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 92, {'name': 'Congo'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 93, {'name': 'Cuba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 94, {'name': "Côte d'Ivoire"}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 95, {'name': 'Denmark'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 96, {'name': 'Djibouti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 97, {'name': 'Dominica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 98, {'name': 'Dominican Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 99, {'name': 'Ecuador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 100, {'name': 'Egypt'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 101, {'name': 'El Salvador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 102, {'name': 'Estonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 103, {'name': 'Fiji'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 104, {'name': 'Finland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 105, {'name': 'French Guiana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 106, {'name': 'French Polynesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 107, {'name': 'Gabon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 108, {'name': 'Ghana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 109, {'name': 'Greece'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 110, {'name': 'Guam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 111, {'name': 'Guatemala'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 112, {'name': 'Guinea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 113, {'name': 'Guyana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 114, {'name': 'Haiti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 115, {'name': 'Honduras'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 116, {'name': 'Japan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 117, {'name': 'Kuwait'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 118, {'name': 'Portugal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 119, {'name': 'South Korea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 120, {'name': 'Hungary'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 121, {'name': 'Iceland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 122, {'name': 'India'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 123, {'name': 'Indonesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 124, {'name': 'Iran'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 125, {'name': 'Italy'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 126, {'name': 'Jamaica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 127, {'name': 'Jordan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 128, {'name': 'Kenya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 129, {'name': 'Kyrgyzstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 130, {'name': 'Laos'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 131, {'name': 'Lebanon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 132, {'name': 'Lesotho'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 133, {'name': 'Libya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 134, {'name': 'Lithuania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 135, {'name': 'Macao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 136, {'name': 'Macedonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 137, {'name': 'Madagascar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 138, {'name': 'Malawi'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 139, {'name': 'Mali'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 140, {'name': 'Mexico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 141, {'name': 'Moldova'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 142, {'name': 'Monaco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 143, {'name': 'Mongolia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 144, {'name': 'Montenegro'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 145, {'name': 'Morocco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 146, {'name': 'Mozambique'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 147, {'name': 'Myanmar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 148, {'name': 'Namibia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 149, {'name': 'Nauru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 150, {'name': 'Nepal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 151, {'name': 'Nicaragua'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 152, {'name': 'Nigeria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 153, {'name': 'Norfolk Island'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 154, {'name': 'Norway'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 155, {'name': 'Oman'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 156, {'name': 'Pakistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 157, {'name': 'Palestine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 158, {'name': 'Papua New Guinea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 159, {'name': 'Paraguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 160, {'name': 'Peru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 161, {'name': 'Philippines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 162, {'name': 'Poland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 163, {'name': 'Puerto Rico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 164, {'name': 'Qatar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 165, {'name': 'Romania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 166, {'name': 'Saint Lucia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 167, {'name': 'Saint Martin (French part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 168, {'name': 'Saudi Arabia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 169, {'name': 'Senegal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 170, {'name': 'Sierra Leone'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 171, {'name': 'Sint Maarten (Dutch part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 172, {'name': 'Slovakia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 173, {'name': 'Slovenia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 174, {'name': 'Spain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 175, {'name': 'Sri Lanka'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 176, {'name': 'Sudan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 177, {'name': 'Suriname'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 178, {'name': 'Syria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 179, {'name': 'Taiwan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 180, {'name': 'Tajikistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 181, {'name': 'Tanzania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 182, {'name': 'Tonga'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 183, {'name': 'Trinidad and Tobago'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 184, {'name': 'Tunisia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 185, {'name': 'Turkey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 186, {'name': 'Turkmenistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 187, {'name': 'Uganda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 188, {'name': 'Dubai'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 189, {'name': 'Uzbekistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 190, {'name': 'Venezuela'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 191, {'name': 'Vietnam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 192, {'name': 'Yemen'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 193, {'name': 'Zambia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fb1b03f6040>, 194, {'name': 'Zimbabwe'})]

# %%
##similar to mini-proj, try a random target 
import random
random.seed(5104)
def unweighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'avg_betweenness':bet,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#try another function but this time with g.diameter having weight param 
#https://igraph.org/python/api/latest/igraph._igraph.GraphBase.html#diameter

random.seed(5104)
def weighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #try in-degree
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'avg_weighted_betweenness':bet,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type1_unweighted = unweighted_Type1_random_delete(g)
df_type1_unweighted.head()
# Out:
#    nodes_removed  avg_betweenness  prop_removed  diameter  \
# 0              1        71.273196          0.01       4.0
# 1              2        71.233161          0.01       4.0
# 2              3        69.562500          0.02       4.0
# 3              4        68.335079          0.02       4.0
# 4              5        68.168421          0.03       4.0
#
#    assortativity_degree  avg_unweighted_indegree   density  average_path_len
# 0             -0.463328                14.149485  0.072935          1.959808
# 1             -0.463670                14.176166  0.073452          1.959453
# 2             -0.463227                14.223958  0.074083          1.949456
# 3             -0.463776                14.225131  0.074477          1.945318
# 4             -0.463716                14.284211  0.075180          1.943198

# %%
df_type1_unweighted.tail()
# Out:
#      nodes_removed  avg_betweenness  prop_removed  diameter  \
# 190            191              0.0          0.97       0.0
# 191            192              0.0          0.98       0.0
# 192            193              0.0          0.98       0.0
# 193            194              0.0          0.99       0.0
# 194            195              0.0          0.99       NaN
#
#      assortativity_degree  avg_unweighted_indegree  density  average_path_len
# 190                   NaN                      0.0      0.0               NaN
# 191                   NaN                      0.0      0.0               NaN
# 192                   NaN                      0.0      0.0               NaN
# 193                   NaN                      0.0      0.0               NaN
# 194                   NaN                      0.0      NaN               NaN

# %%
df_type1_weighted = weighted_Type1_random_delete(g)
df_type1_weighted.head()
# Out:
#    nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 0              1          0.01      13.0                128.677022
# 1              2          0.01      13.0                127.693250
# 2              3          0.02      13.0                126.518705
# 3              4          0.02      13.0                125.075750
# 4              5          0.03      13.0                125.161663
#
#    assortativity_degree  avg_weighted_indegree   density  average_path_len
# 0             -0.461188            1695.469072  0.072696          1.956959
# 1             -0.461467            1700.585492  0.072029          1.959304
# 2             -0.461109            1709.416667  0.072673          1.953667
# 3             -0.463428            1716.340314  0.072503          1.953149
# 4             -0.463183            1725.342105  0.073130          1.952374

# %%
df_type1_weighted.tail(15)
# Out:
#      nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 180            181          0.92      41.0                  5.357143
# 181            182          0.93      41.0                  5.461538
# 182            183          0.93      42.0                  5.333333
# 183            184          0.94      42.0                  5.818182
# 184            185          0.94      64.0                  3.300000
# 185            186          0.95      88.0                  2.111111
# 186            187          0.95      88.0                  2.000000
# 187            188          0.96      88.0                  1.857143
# 188            189          0.96      88.0                  2.000000
# 189            190          0.97   11626.0                  0.600000
# 190            191          0.97   11626.0                  0.500000
# 191            192          0.98       0.0                  0.000000
# 192            193          0.98       0.0                  0.000000
# 193            194          0.99       0.0                  0.000000
# 194            195          0.99       NaN                  0.000000
#
#      assortativity_degree  avg_weighted_indegree   density  average_path_len
# 180             -0.562860            1148.214286  0.158163          1.573770
# 181             -0.551767            1236.230769  0.171598          1.571429
# 182             -0.542218            1292.750000  0.173611          1.600000
# 183             -0.542218            1410.272727  0.206612          1.600000
# 184             -0.434520            1547.400000  0.220000          1.444444
# 185             -0.485363            1475.555556  0.148148          1.708333
# 186             -0.458171            1659.625000  0.171875          1.666667
# 187             -0.421464            1896.142857  0.204082          1.611111
# 188             -0.300000            1955.333333  0.194444          1.733333
# 189                   NaN            2343.200000  0.200000          1.375000
# 190                   NaN            2928.750000  0.250000          1.333333
# 191                   NaN               0.000000  0.000000               NaN
# 192                   NaN               0.000000  0.000000               NaN
# 193                   NaN               0.000000  0.000000               NaN
# 194                   NaN               0.000000       NaN               NaN

# %% [markdown]
# ### Targeted attack

# %%
##try sort by indegree 
temp_df = pd.DataFrame({'Node_indice':g.vs.indices,
                         'Nodes':g.vs['name'],
                         'In_Degree':g.strength(mode='in',weights='weight')})

# %%
#sort by largest degree 
temp_df = temp_df.sort_values(by='In_Degree',ascending=False)

# %%
temp_df.head(50)
# Out:
#     Node_indice                     Nodes  In_Degree
# 3             3    British Virgin Islands   161557.0
# 14           14                    Panama    47466.0
# 17           17                Seychelles    16514.0
# 4             4            United Kingdom    15594.0
# 1             1                   Bahamas    15547.0
# 9             9                 Hong Kong    13051.0
# 15           15                    Russia    10494.0
# 13           13                      Niue     9456.0
# 16           16                     Samoa     6255.0
# 5             5             United States     4136.0
# 32           32          British Anguilla     3240.0
# 37           37                    Cyprus     3216.0
# 10           10                   Ireland     3214.0
# 21           21                     China     2554.0
# 23           23                  Barbados     2361.0
# 20           20                   Bermuda     2331.0
# 24           24                    Canada     1439.0
# 7             7            Cayman Islands     1436.0
# 12           12                    Nevada     1260.0
# 11           11                    Latvia     1242.0
# 25           25     Saint Kitts and Nevis     1193.0
# 48           48      United Arab Emirates      860.0
# 44           44                 Singapore      499.0
# 88           88                    Labuan      432.0
# 42           42                Luxembourg      396.0
# 41           41                    Jersey      377.0
# 35           35                    Belize      299.0
# 40           40               Isle of Man      291.0
# 51           51                     Malta      240.0
# 36           36              Cook Islands      239.0
# 29           29               Switzerland      221.0
# 22           22       Antigua and Barbuda      198.0
# 71           71         State of Delaware      181.0
# 43           43               Netherlands      164.0
# 47           47                   Ukraine      154.0
# 56           56                 Mauritius      127.0
# 38           38            Czech Republic       82.0
# 46           46                    Sweden       82.0
# 8             8                Costa Rica       78.0
# 50           50                 Gibraltar       65.0
# 34           34                   Austria       62.0
# 60           60             Liechtenstein       42.0
# 39           39                   Germany       42.0
# 18           18                   Uruguay       40.0
# 53           53                   Wyoming       37.0
# 69           69                   Curaçao       37.0
# 61           61  Turks and Caicos Islands       31.0
# 28           28               New Zealand       30.0
# 70           70                    Israel       29.0
# 78           78                  Guernsey       25.0

# %%
temp_df.tail(50)
# Out:
#      Node_indice                   Nodes  In_Degree
# 76            76                Cameroon        0.0
# 75            75                Cambodia        0.0
# 74            74                Bulgaria        0.0
# 73            73                  Brunei        0.0
# 67            67                  Brazil        0.0
# 66            66                Botswana        0.0
# 65            65  Bosnia and Herzegovina        0.0
# 64            64                 Bolivia        0.0
# 63            63                  Bhutan        0.0
# 58            58                   Benin        0.0
# 57            57                 Belgium        0.0
# 55            55              Bangladesh        0.0
# 54            54                 Bahrain        0.0
# 49            49              Azerbaijan        0.0
# 30            30                 Armenia        0.0
# 26            26               Argentina        0.0
# 19            19                  Angola        0.0
# 6              6                 Andorra        0.0
# 2              2                 Algeria        0.0
# 96            96                Djibouti        0.0
# 98            98      Dominican Republic        0.0
# 99            99                 Ecuador        0.0
# 115          115                Honduras        0.0
# 131          131                 Lebanon        0.0
# 130          130                    Laos        0.0
# 129          129              Kyrgyzstan        0.0
# 128          128                   Kenya        0.0
# 127          127                  Jordan        0.0
# 126          126                 Jamaica        0.0
# 125          125                   Italy        0.0
# 124          124                    Iran        0.0
# 123          123               Indonesia        0.0
# 122          122                   India        0.0
# 121          121                 Iceland        0.0
# 120          120                 Hungary        0.0
# 114          114                   Haiti        0.0
# 100          100                   Egypt        0.0
# 113          113                  Guyana        0.0
# 112          112                  Guinea        0.0
# 111          111               Guatemala        0.0
# 110          110                    Guam        0.0
# 109          109                  Greece        0.0
# 108          108                   Ghana        0.0
# 107          107                   Gabon        0.0
# 106          106        French Polynesia        0.0
# 105          105           French Guiana        0.0
# 104          104                 Finland        0.0
# 103          103                    Fiji        0.0
# 101          101             El Salvador        0.0
# 194          194                Zimbabwe        0.0

# %%
#extract out by Node
order_of_del = temp_df['Nodes'].tolist()

# %%
#print the list to check it
order_of_del
# Out:
# ['British Virgin Islands',
#  'Panama',
#  'Seychelles',
#  'United Kingdom',
#  'Bahamas',
#  'Hong Kong',
#  'Russia',
#  'Niue',
#  'Samoa',
#  'United States',
#  'British Anguilla',
#  'Cyprus',
#  'Ireland',
#  'China',
#  'Barbados',
#  'Bermuda',
#  'Canada',
#  'Cayman Islands',
#  'Nevada',
#  'Latvia',
#  'Saint Kitts and Nevis',
#  'United Arab Emirates',
#  'Singapore',
#  'Labuan',
#  'Luxembourg',
#  'Jersey',
#  'Belize',
#  'Isle of Man',
#  'Malta',
#  'Cook Islands',
#  'Switzerland',
#  'Antigua and Barbuda',
#  'State of Delaware',
#  'Netherlands',
#  'Ukraine',
#  'Mauritius',
#  'Czech Republic',
#  'Sweden',
#  'Costa Rica',
#  'Gibraltar',
#  'Austria',
#  'Liechtenstein',
#  'Germany',
#  'Uruguay',
#  'Wyoming',
#  'Curaçao',
#  'Turks and Caicos Islands',
#  'New Zealand',
#  'Israel',
#  'Guernsey',
#  'Belarus',
#  'South Africa',
#  'Saint Vincent and the Grenadines',
#  'Croatia',
#  'Malaysia',
#  'Vanuatu',
#  'Grenada',
#  'Liberia',
#  'Thailand',
#  'Saint Lucia',
#  'Georgia',
#  'Netherlands Antilles',
#  'Serbia',
#  'Australia',
#  'US Virgin Islands',
#  'Mexico',
#  'Kuwait',
#  'Japan',
#  'France',
#  'Spain',
#  'Dubai',
#  'Aruba',
#  'Kazakhstan',
#  'Marshall Islands',
#  'Estonia',
#  'Portugal',
#  'South Korea',
#  'Philippines',
#  'Malawi',
#  'Peru',
#  'Paraguay',
#  'Papua New Guinea',
#  'Palestine',
#  'Macedonia',
#  'Madagascar',
#  'Pakistan',
#  'Oman',
#  'Norway',
#  'Norfolk Island',
#  'Nigeria',
#  'Mali',
#  'Nauru',
#  'Moldova',
#  'Monaco',
#  'Mongolia',
#  'Nicaragua',
#  'Nepal',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Albania',
#  'Taiwan',
#  'Poland',
#  'Puerto Rico',
#  'Zambia',
#  'Yemen',
#  'Vietnam',
#  'Venezuela',
#  'Uzbekistan',
#  'Uganda',
#  'Turkmenistan',
#  'Turkey',
#  'Tunisia',
#  'Trinidad and Tobago',
#  'Tonga',
#  'Tanzania',
#  'Tajikistan',
#  'Lithuania',
#  'Syria',
#  'Suriname',
#  'Sudan',
#  'Sri Lanka',
#  'Slovenia',
#  'Slovakia',
#  'Sint Maarten (Dutch part)',
#  'Sierra Leone',
#  'Senegal',
#  'Saudi Arabia',
#  'Saint Martin (French part)',
#  'Romania',
#  'Qatar',
#  'Macao',
#  'Dominica',
#  'Libya',
#  'Lesotho',
#  'Denmark',
#  "Côte d'Ivoire",
#  'Cuba',
#  'Congo',
#  'Colombia',
#  'Chile',
#  'Chad',
#  'Central African Republic',
#  'Cameroon',
#  'Cambodia',
#  'Bulgaria',
#  'Brunei',
#  'Brazil',
#  'Botswana',
#  'Bosnia and Herzegovina',
#  'Bolivia',
#  'Bhutan',
#  'Benin',
#  'Belgium',
#  'Bangladesh',
#  'Bahrain',
#  'Azerbaijan',
#  'Armenia',
#  'Argentina',
#  'Angola',
#  'Andorra',
#  'Algeria',
#  'Djibouti',
#  'Dominican Republic',
#  'Ecuador',
#  'Honduras',
#  'Lebanon',
#  'Laos',
#  'Kyrgyzstan',
#  'Kenya',
#  'Jordan',
#  'Jamaica',
#  'Italy',
#  'Iran',
#  'Indonesia',
#  'India',
#  'Iceland',
#  'Hungary',
#  'Haiti',
#  'Egypt',
#  'Guyana',
#  'Guinea',
#  'Guatemala',
#  'Guam',
#  'Greece',
#  'Ghana',
#  'Gabon',
#  'French Polynesia',
#  'French Guiana',
#  'Finland',
#  'Fiji',
#  'El Salvador',
#  'Zimbabwe']

# %%
def unweighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(order_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(order_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#Weighted on diameter
def weighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(order_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(order_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_weighted_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type2_unweighted = unweighted_Type2_targeted_del(g)
df_type2_unweighted.head()
# Out:
#    num_nodes_removed  prop_removed            node_removed  avg_betweenness  \
# 0                  1          0.01  British Virgin Islands        69.711340
# 1                  2          0.01                  Panama        67.580311
# 2                  3          0.02              Seychelles        65.302083
# 3                  4          0.02          United Kingdom        65.015707
# 4                  5          0.03                 Bahamas        64.678947
#
#    diameter  assortativity_degree  avg_unweighted_indegree   density  \
# 0       4.0             -0.445776                13.046392  0.067249
# 1       4.0             -0.437642                12.165803  0.063035
# 2       4.0             -0.442518                11.588542  0.060357
# 3       4.0             -0.435826                10.759162  0.056331
# 4       4.0             -0.439107                10.200000  0.053684
#
#    average_path_len
# 0          1.982563
# 1          1.993147
# 2          1.990207
# 3          2.011897
# 4          2.027508

# %%
df_type2_unweighted.tail()
# Out:
#      num_nodes_removed  prop_removed   node_removed  avg_betweenness  \
# 190                191          0.97  French Guiana              0.0
# 191                192          0.98        Finland              0.0
# 192                193          0.98           Fiji              0.0
# 193                194          0.99    El Salvador              0.0
# 194                195          0.99       Zimbabwe              0.0
#
#      diameter  assortativity_degree  avg_unweighted_indegree  density  \
# 190       0.0                   NaN                      0.0      0.0
# 191       0.0                   NaN                      0.0      0.0
# 192       0.0                   NaN                      0.0      0.0
# 193       0.0                   NaN                      0.0      0.0
# 194       NaN                   NaN                      0.0      NaN
#
#      average_path_len
# 190               NaN
# 191               NaN
# 192               NaN
# 193               NaN
# 194               NaN

# %%
df_type2_weighted = weighted_Type2_targeted_del(g)
df_type2_weighted.head(15)
# Out:
#     num_nodes_removed  prop_removed            node_removed  \
# 0                   1          0.01  British Virgin Islands
# 1                   2          0.01                  Panama
# 2                   3          0.02              Seychelles
# 3                   4          0.02          United Kingdom
# 4                   5          0.03                 Bahamas
# 5                   6          0.03               Hong Kong
# 6                   7          0.04                  Russia
# 7                   8          0.04                    Niue
# 8                   9          0.05                   Samoa
# 9                  10          0.05           United States
# 10                 11          0.06        British Anguilla
# 11                 12          0.06                  Cyprus
# 12                 13          0.07                 Ireland
# 13                 14          0.07                   China
# 14                 15          0.08                Barbados
#
#     avg_weighted_betweenness  diameter  assortativity_degree  \
# 0                 123.318340      10.0             -0.445776
# 1                 118.358212      10.0             -0.437642
# 2                 114.208219      10.0             -0.442518
# 3                 113.084191      69.0             -0.435826
# 4                 111.079491      69.0             -0.439107
# 5                 104.790214     180.0             -0.416024
# 6                 102.270380     180.0             -0.405745
# 7                 101.286951     180.0             -0.410094
# 8                  99.828589     180.0             -0.417516
# 9                  95.845050     234.0             -0.404343
# 10                 93.815041     234.0             -0.410560
# 11                 91.693228     234.0             -0.410632
# 12                 86.564393     234.0             -0.405710
# 13                 78.923460     234.0             -0.377771
# 14                 70.808002     122.0             -0.360012
#
#     avg_weighted_indegree   density  average_path_len
# 0              835.108247  0.067249          1.982563
# 1              568.476684  0.063035          1.993147
# 2              490.895833  0.060357          1.990207
# 3              399.968586  0.056331          2.011897
# 4              330.778947  0.053684          2.027508
# 5              207.301587  0.049047          2.099261
# 6              161.154255  0.045213          2.127274
# 7              131.828877  0.043839          2.134736
# 8              116.784946  0.042259          2.144483
# 9               86.881081  0.038714          2.188102
# 10              79.635870  0.037659          2.187153
# 11              66.726776  0.034847          2.210002
# 12              55.681319  0.032273          2.205579
# 13              42.867403  0.028601          2.315600
# 14              38.511111  0.026914          2.284885

# %%
df_type2_weighted.tail(150)
# Out:
#      num_nodes_removed  prop_removed              node_removed  \
# 45                  46          0.23                   Curaçao
# 46                  47          0.24  Turks and Caicos Islands
# 47                  48          0.24               New Zealand
# 48                  49          0.25                    Israel
# 49                  50          0.26                  Guernsey
# ..                 ...           ...                       ...
# 190                191          0.97             French Guiana
# 191                192          0.98                   Finland
# 192                193          0.98                      Fiji
# 193                194          0.99               El Salvador
# 194                195          0.99                  Zimbabwe
#
#      avg_weighted_betweenness  diameter  assortativity_degree  \
# 45                   0.010067      10.0             -0.397806
# 46                   0.003378      10.0             -0.419788
# 47                   0.003401      10.0             -0.339761
# 48                   0.003425      10.0             -0.316980
# 49                   0.003448      10.0             -0.358262
# ..                        ...       ...                   ...
# 190                  0.000000       0.0                   NaN
# 191                  0.000000       0.0                   NaN
# 192                  0.000000       0.0                   NaN
# 193                  0.000000       0.0                   NaN
# 194                  0.000000       NaN                   NaN
#
#      avg_weighted_indegree   density  average_path_len
# 45                0.503356  0.001892           1.02439
# 46                0.445946  0.001780           1.00000
# 47                0.346939  0.001573           1.00000
# 48                0.308219  0.001360           1.00000
# 49                0.296552  0.001332           1.00000
# ..                     ...       ...               ...
# 190               0.000000  0.000000               NaN
# 191               0.000000  0.000000               NaN
# 192               0.000000  0.000000               NaN
# 193               0.000000  0.000000               NaN
# 194               0.000000       NaN               NaN
#
# [150 rows x 9 columns]

# %% [markdown]
# #### Unweighted

# %%
## Commented out to not confuse; use the weighted one below

#Try plotting unweighted

#fig, ax = plt.subplots(1,2,figsize=(14,6),sharey=True)
#ax2_1 = ax[0].twinx()
#ax[0].plot('prop_removed','diameter',data=df_type1_unweighted,ls='--',color='darkblue')
#ax[0].plot('prop_removed','density',data=df_type1_unweighted,ls='--',color='darkviolet')
#ax[0].plot('prop_removed','avg_betweenness',data=df_type1_unweighted,ls='--',color='darkgreen')
#ax2_1.plot('prop_removed','avg_unweighted_indegree',data=df_type1_unweighted,ls='--',color='darkred')
#ax[0].plot('prop_removed','assortativity_degree',data=df_type1_unweighted,ls='--',color='darkturquoise')
#ax[0].plot('prop_removed','average_path_len',data=df_type1_unweighted,ls='--',color='darkorange')
#ax[0].legend(loc='upper right')
#ax[0].set_xlabel('Proportion of nodes removed')
#ax[0].set_title('Random deletion')
#ax2_1.tick_params('y',colors='darkred')
#ax2_1.set_ylabel('Avg inDegree')
#ax2_1.legend(loc='upper left')

#ax2_2 = ax[1].twinx()
#ax[1].plot('prop_removed','diameter',data=df_type2_unweighted,ls='--',color='blue')
#ax[1].plot('prop_removed','density',data=df_type2_unweighted,ls='--',color='violet')
#ax[1].plot('prop_removed','avg_betweenness',data=df_type2_unweighted,ls='--',color='green')
#ax2_2.plot('prop_removed','avg_unweighted_indegree',data=df_type2_unweighted,ls='--',color='red')
#ax[1].plot('prop_removed','assortativity_degree',data=df_type2_unweighted,ls='--',color='turquoise')
#ax[1].plot('prop_removed','average_path_len',data=df_type2_unweighted,ls='--',color='orange')
#ax[1].legend(loc='upper right')
#ax[1].set_xlabel('Proportion of nodes removed')
#ax[1].set_title('Targeted deletion')
#ax2_2.tick_params('y',colors='darkred')
#ax2_2.set_ylabel('Avg inDegree')
#ax2_2.legend(loc='upper left')
#plt.show()

# %% [markdown]
# #### Weighted

# %%
#Same but weighted
#Don't share y axis for type2
fig, ax = plt.subplots(2,2,figsize=(18,12),sharey=False)

#Random attack LHS graphs

ax[0,1].plot('prop_removed','diameter',data=df_type1_weighted,ls='-',color='darkblue')
ax[0,0].plot('prop_removed','density',data=df_type1_weighted,ls='-',color='darkviolet')
ax[0,0].plot('prop_removed','assortativity_degree',data=df_type1_weighted,ls='-',color='darkturquoise')
ax[0,0].plot('prop_removed','average_path_len',data=df_type1_weighted,ls='-',color='darkorange')
ax[0,0].legend(loc='upper right')
ax[0,0].set_xlabel('Proportion of nodes removed')
ax[0,0].set_title('Random deletion')

ax2_1 = ax[0,0].twinx()
ax2_1.plot('prop_removed','avg_weighted_indegree',data=df_type1_weighted,ls='-',color='darkred')
ax2_1.tick_params('y',colors='darkred')
ax2_1.set_ylabel('Avg inDegree')
ax2_1.legend(loc='upper left')

#Random attack RHS Graphs - Betweenness & Diameter
ax[0,1].set_title('Random deletion - Betweenness & Diameter')
ax[0,1].legend(loc='upper left')

ax_bet_rand = ax[0,1].twinx()
ax_bet_rand.plot('prop_removed','avg_weighted_betweenness',data=df_type1_weighted,ls='--',color='darkgreen')
ax_bet_rand.tick_params('y',colors='darkgreen')
ax_bet_rand.set_ylabel('Avg_weighted_betweenness')
ax_bet_rand.legend(loc='upper right')


#Targeted attack LHS Graphs

ax[1,1].plot('prop_removed','diameter',data=df_type2_weighted,ls='-',color='blue')
ax[1,0].plot('prop_removed','density',data=df_type2_weighted,ls='-',color='violet')
ax[1,0].plot('prop_removed','assortativity_degree',data=df_type2_weighted,ls='-',color='turquoise')
ax[1,0].plot('prop_removed','average_path_len',data=df_type2_weighted,ls='-',color='orange')
ax[1,0].legend(loc='upper right')
ax[1,0].set_xlabel('Proportion of nodes removed')
ax[1,0].set_title('Targeted deletion')

ax2_2 = ax[1,0].twinx()
ax2_2.plot('prop_removed','avg_weighted_indegree',data=df_type2_weighted,ls='-',color='darkred')
ax2_2.set_ylabel('Avg inDegree')
ax2_2.legend(loc='upper left')
ax2_2.tick_params('y',colors='darkred')


#Targeted attack RHS Graphs - Betweenness & Diameter 

ax[1,1].set_title('Targeted deletion - Betweenness & Diameter')
ax[1,1].legend(loc='upper left')

ax_bet_tar = ax[1,1].twinx()
ax_bet_tar.plot('prop_removed','avg_weighted_betweenness',data=df_type2_weighted,ls='--',color='green')
ax_bet_tar.tick_params('y',colors='green')
ax_bet_tar.set_ylabel('avg weighted betweenness')
ax_bet_tar.legend(loc='upper right')
plt.show()
