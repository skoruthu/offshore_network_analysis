# %%
import pandas as pd
import numpy as np
import igraph as ig
import matplotlib.pyplot as plt 
import collections

# %%
df_unweighted = pd.read_csv('../combined_final_unweighted.csv')
df_unweighted
# Out:
#           node_start                node_end        status
# 0          Hong Kong                   Samoa  jurisdiction
# 1          Hong Kong                   Samoa  jurisdiction
# 2          Hong Kong                   Samoa  jurisdiction
# 3          Hong Kong                   Samoa  jurisdiction
# 4          Hong Kong                   Samoa  jurisdiction
# ...              ...                     ...           ...
# 338127     Indonesia  British Virgin Islands  officer_base
# 338128  Cook Islands  British Virgin Islands  officer_base
# 338129     Hong Kong  British Virgin Islands  officer_base
# 338130  Cook Islands          United Kingdom  officer_base
# 338131     Hong Kong          United Kingdom  officer_base
#
# [338132 rows x 3 columns]

# %%
df_weighted = pd.read_csv('../combined_final_weighted.csv')
df_weighted
# Out:
#           node_start                node_end        status  weight
# 0          Hong Kong                   Samoa  jurisdiction     2.0
# 1          Hong Kong                   Samoa  jurisdiction     2.0
# 2          Hong Kong                   Samoa  jurisdiction     2.0
# 3          Hong Kong                   Samoa  jurisdiction     2.0
# 4          Hong Kong                   Samoa  jurisdiction     2.0
# ...              ...                     ...           ...     ...
# 338119     Indonesia  British Virgin Islands  officer_base     1.0
# 338120  Cook Islands  British Virgin Islands  officer_base     1.0
# 338121     Hong Kong  British Virgin Islands  officer_base     1.0
# 338122  Cook Islands          United Kingdom  officer_base     1.0
# 338123     Hong Kong          United Kingdom  officer_base     1.0
#
# [338124 rows x 4 columns]

# %%
df_weighted_jur = df_weighted[df_weighted['status'] == 'jurisdiction']
df_jur = df_weighted_jur.drop(['weight','status'], axis = 1)
df_jur
# Out:
#                     node_start      node_end
# 0                    Hong Kong         Samoa
# 1                    Hong Kong         Samoa
# 2                    Hong Kong         Samoa
# 3                    Hong Kong         Samoa
# 4                    Hong Kong         Samoa
# ...                        ...           ...
# 216554  British Virgin Islands  Cook Islands
# 216555  British Virgin Islands  Cook Islands
# 216556  British Virgin Islands  Cook Islands
# 216557  British Virgin Islands  Cook Islands
# 216558                 Vanuatu  Cook Islands
#
# [216559 rows x 2 columns]

# %%
df_jur_grouped = df_jur.groupby(['node_start','node_end'], as_index = False).size()
df_jur_grouped
# Out:
#      node_start                node_end  size
# 0       Albania                 Bahamas     2
# 1       Andorra                 Bahamas    26
# 2       Andorra  British Virgin Islands    39
# 3       Andorra          Cayman Islands     1
# 4       Andorra              Costa Rica     3
# ...         ...                     ...   ...
# 1212    Vietnam                  Panama     1
# 1213      Yemen                  Panama     1
# 1214     Zambia  British Virgin Islands     2
# 1215   Zimbabwe  British Virgin Islands     5
# 1216   Zimbabwe                  Panama     3
#
# [1217 rows x 3 columns]

# %% [markdown]
# ### Convert Data to an Undirected Edge List

# %%
#df_jur_grouped_list = df_jur_grouped.values.tolist()
#df_jur_grouped_list

# %%
#d = collections.defaultdict(int)
#for n1, n2, v in df_jur_grouped_list:
#    d[min(n1, n2), max(n1, n2)] += v
#result = [[k[0], k[1], v] for k, v in d.items()]

# %%
#df_net = pd.DataFrame(result)
#df_net

# %%
#df_net = df_net.rename(columns = {0:'node_1', 1:'node_2', 2: 'weight'})
#df_net

# %%
#import df_net to csv later

# %%
#plot the unweighted graph (try unweighted first)
g = ig.Graph.TupleList(df_jur_grouped.itertuples(index=False), directed=True, edge_attrs={'weight': "weight"})

# %%
ig.plot(g)

# %%
g.diameter()
# Out:
# 5

# %%
len(g.vs.indices)
# Out:
# 174

# %%
#g.vs.indices
df_jur_grouped['node_start'].value_counts()
# Out:
# Cayman Islands    32
# United States     23
# Switzerland       23
# United Kingdom    22
# Jersey            21
#                   ..
# Slovakia           1
# Sri Lanka          1
# Yemen              1
# Kyrgyzstan         1
# Guyana             1
# Name: node_start, Length: 168, dtype: int64

# %%
uni =df_jur_grouped['node_start'].unique()

# %%
len(uni)
# Out:
# 168

# %%
list(g.vs)
# Out:
# [igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 0, {'name': 'Albania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 2, {'name': 'Andorra'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 4, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 5, {'name': 'Costa Rica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 6, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 7, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 8, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 9, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 10, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 11, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 12, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 13, {'name': 'Uruguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 14, {'name': 'Angola'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 15, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 16, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 17, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 18, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 19, {'name': 'Argentina'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 20, {'name': 'New Zealand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 21, {'name': 'Aruba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 22, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 23, {'name': 'Australia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 24, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 25, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 26, {'name': 'Austria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 27, {'name': 'Azerbaijan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 28, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 29, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 30, {'name': 'Netherlands Antilles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 31, {'name': 'Wyoming'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 32, {'name': 'Bahrain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 33, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 34, {'name': 'Bangladesh'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 35, {'name': 'Belarus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 36, {'name': 'Belgium'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 37, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 38, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 39, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 40, {'name': 'Liberia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 41, {'name': 'Liechtenstein'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 42, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 43, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 44, {'name': 'Turks and Caicos Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 45, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 46, {'name': 'Bolivia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 47, {'name': 'Botswana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 48, {'name': 'Brazil'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 49, {'name': 'State of Delaware'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 50, {'name': 'Brunei'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 51, {'name': 'Bulgaria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 52, {'name': 'Cameroon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 53, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 54, {'name': 'Gibraltar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 55, {'name': 'Grenada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 56, {'name': 'Guernsey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 57, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 58, {'name': 'Marshall Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 59, {'name': 'Saint Vincent and the Grenadines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 60, {'name': 'US Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 61, {'name': 'Central African Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 62, {'name': 'Chad'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 63, {'name': 'Chile'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 64, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 65, {'name': 'Colombia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 66, {'name': 'Croatia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 67, {'name': 'Cuba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 68, {'name': 'Curaçao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 69, {'name': 'Czech Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 70, {'name': "Côte d'Ivoire"}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 71, {'name': 'Denmark'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 72, {'name': 'Djibouti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 73, {'name': 'Dominica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 74, {'name': 'Dominican Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 75, {'name': 'Ecuador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 76, {'name': 'Egypt'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 77, {'name': 'El Salvador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 78, {'name': 'Estonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 79, {'name': 'Fiji'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 80, {'name': 'Finland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 81, {'name': 'France'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 82, {'name': 'French Guiana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 83, {'name': 'Georgia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 84, {'name': 'Germany'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 85, {'name': 'Ghana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 86, {'name': 'Greece'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 87, {'name': 'Guam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 88, {'name': 'Guatemala'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 89, {'name': 'Guyana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 90, {'name': 'Haiti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 91, {'name': 'Honduras'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 92, {'name': 'Labuan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 93, {'name': 'Thailand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 94, {'name': 'Hungary'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 95, {'name': 'Iceland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 96, {'name': 'India'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 97, {'name': 'Indonesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 98, {'name': 'Iran'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 99, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 100, {'name': 'Israel'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 101, {'name': 'Italy'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 102, {'name': 'Jamaica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 103, {'name': 'Japan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 104, {'name': 'Jordan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 105, {'name': 'Kazakhstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 106, {'name': 'Kenya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 107, {'name': 'Kuwait'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 108, {'name': 'Kyrgyzstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 109, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 110, {'name': 'Lebanon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 111, {'name': 'Lesotho'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 112, {'name': 'Libya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 113, {'name': 'Lithuania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 114, {'name': 'Macao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 115, {'name': 'Macedonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 116, {'name': 'Malawi'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 117, {'name': 'Malaysia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 118, {'name': 'Mali'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 119, {'name': 'Mexico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 120, {'name': 'Moldova'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 121, {'name': 'Monaco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 122, {'name': 'Mongolia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 123, {'name': 'Montenegro'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 124, {'name': 'Morocco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 125, {'name': 'Mozambique'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 126, {'name': 'Namibia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 127, {'name': 'Nauru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 128, {'name': 'Nicaragua'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 129, {'name': 'Nigeria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 130, {'name': 'Norway'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 131, {'name': 'Oman'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 132, {'name': 'Pakistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 133, {'name': 'Paraguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 134, {'name': 'Peru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 135, {'name': 'Philippines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 136, {'name': 'Poland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 137, {'name': 'Portugal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 138, {'name': 'Puerto Rico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 139, {'name': 'Qatar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 140, {'name': 'Romania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 141, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 142, {'name': 'Saint Lucia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 143, {'name': 'Saint Martin (French part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 144, {'name': 'Saudi Arabia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 145, {'name': 'Senegal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 146, {'name': 'Sierra Leone'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 147, {'name': 'Vanuatu'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 148, {'name': 'Sint Maarten (Dutch part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 149, {'name': 'Slovakia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 150, {'name': 'Slovenia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 151, {'name': 'South Africa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 152, {'name': 'South Korea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 153, {'name': 'Spain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 154, {'name': 'Sri Lanka'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 155, {'name': 'Sudan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 156, {'name': 'Suriname'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 157, {'name': 'Sweden'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 158, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 159, {'name': 'Syria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 160, {'name': 'Taiwan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 161, {'name': 'Tanzania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 162, {'name': 'Trinidad and Tobago'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 163, {'name': 'Tunisia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 164, {'name': 'Turkey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 165, {'name': 'Uganda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 166, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 167, {'name': 'Dubai'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 168, {'name': 'Uzbekistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 169, {'name': 'Venezuela'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 170, {'name': 'Vietnam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 171, {'name': 'Yemen'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 172, {'name': 'Zambia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fce20481040>, 173, {'name': 'Zimbabwe'})]

# %%
##similar to mini-proj, try a random target 
import random
random.seed(5104)
def unweighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'avg_betweenness':bet,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#try another function but this time with g.diameter having weight param 
#https://igraph.org/python/api/latest/igraph._igraph.GraphBase.html#diameter

random.seed(5104)
def weighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #try in-degree
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'avg_weighted_betweenness':bet,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type1_unweighted = unweighted_Type1_random_delete(g)
df_type1_unweighted.head()
# Out:
#    nodes_removed  avg_betweenness  prop_removed  diameter  \
# 0              1        58.751445          0.01       5.0
# 1              2        58.691860          0.01       5.0
# 2              3        57.912281          0.02       5.0
# 3              4        57.941176          0.02       5.0
# 4              5        57.863905          0.03       5.0
#
#    assortativity_degree  avg_unweighted_indegree   density  average_path_len
# 0             -0.452653                 7.028902  0.040629          2.248649
# 1             -0.453114                 7.023256  0.040833          2.247683
# 2             -0.451223                 7.005848  0.040970          2.249590
# 3             -0.450670                 7.023529  0.041315          2.250476
# 4             -0.450467                 7.035503  0.041630          2.249074

# %%
df_type1_unweighted.tail()
# Out:
#      nodes_removed  avg_betweenness  prop_removed  diameter  \
# 169            170              0.0          0.87       0.0
# 170            171              0.0          0.87       0.0
# 171            172              0.0          0.88       0.0
# 172            173              0.0          0.88       0.0
# 173            174              0.0          0.89       NaN
#
#      assortativity_degree  avg_unweighted_indegree  density  average_path_len
# 169                   NaN                      0.0      0.0               NaN
# 170                   NaN                      0.0      0.0               NaN
# 171                   NaN                      0.0      0.0               NaN
# 172                   NaN                      0.0      0.0               NaN
# 173                   NaN                      0.0      NaN               NaN

# %%
df_type1_weighted = weighted_Type1_random_delete(g)
df_type1_weighted.head()
# Out:
#    nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 0              1          0.01      32.0                104.235290
# 1              2          0.01      32.0                104.432879
# 2              3          0.02      32.0                104.570401
# 3              4          0.02      32.0                104.356894
# 4              5          0.03      32.0                104.422911
#
#    assortativity_degree  avg_weighted_indegree   density  average_path_len
# 0             -0.455171            1239.514451  0.040128          2.250815
# 1             -0.456073            1246.354651  0.040224          2.251956
# 2             -0.458828            1250.777778  0.040286          2.254125
# 3             -0.458779            1258.129412  0.040727          2.249936
# 4             -0.459692            1264.207101  0.040965          2.251221

# %%
df_type1_weighted.tail(15)
# Out:
#      nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 159            160          0.82     366.0                       0.0
# 160            161          0.82     366.0                       0.0
# 161            162          0.83     366.0                       0.0
# 162            163          0.83       0.0                       0.0
# 163            164          0.84       0.0                       0.0
# 164            165          0.84       0.0                       0.0
# 165            166          0.85       0.0                       0.0
# 166            167          0.85       0.0                       0.0
# 167            168          0.86       0.0                       0.0
# 168            169          0.86       0.0                       0.0
# 169            170          0.87       0.0                       0.0
# 170            171          0.87       0.0                       0.0
# 171            172          0.88       0.0                       0.0
# 172            173          0.88       0.0                       0.0
# 173            174          0.89       NaN                       0.0
#
#      assortativity_degree  avg_weighted_indegree   density  average_path_len
# 159                   NaN              28.142857  0.020408               1.0
# 160                   NaN              30.307692  0.023669               1.0
# 161                   NaN              32.833333  0.027778               1.0
# 162                   NaN               0.000000  0.000000               NaN
# 163                   NaN               0.000000  0.000000               NaN
# 164                   NaN               0.000000  0.000000               NaN
# 165                   NaN               0.000000  0.000000               NaN
# 166                   NaN               0.000000  0.000000               NaN
# 167                   NaN               0.000000  0.000000               NaN
# 168                   NaN               0.000000  0.000000               NaN
# 169                   NaN               0.000000  0.000000               NaN
# 170                   NaN               0.000000  0.000000               NaN
# 171                   NaN               0.000000  0.000000               NaN
# 172                   NaN               0.000000  0.000000               NaN
# 173                   NaN               0.000000       NaN               NaN

# %% [markdown]
# ### Targeted attack

# %%
##try sort by indegree 
temp_df = pd.DataFrame({'Node_indice':g.vs.indices,
                         'Nodes':g.vs['name'],
                         'In_Degree':g.strength(mode='in',weights='weight')})

# %%
#sort by largest degree 
temp_df = temp_df.sort_values(by='In_Degree',ascending=False)

# %%
temp_df.head(50)
# Out:
#      Node_indice                             Nodes  In_Degree
# 3              3            British Virgin Islands   114858.0
# 9              9                            Panama    42243.0
# 1              1                           Bahamas    15532.0
# 11            11                        Seychelles    14920.0
# 8              8                              Niue     9456.0
# 10            10                             Samoa     6237.0
# 22            22                  British Anguilla     3240.0
# 17            17                          Barbados     2361.0
# 15            15                           Bermuda     2331.0
# 4              4                    Cayman Islands     1434.0
# 7              7                            Nevada     1260.0
# 6              6                         Hong Kong      516.0
# 92            92                            Labuan      430.0
# 25            25                       Isle of Man      291.0
# 24            24                      Cook Islands      232.0
# 49            49                 State of Delaware      181.0
# 29            29                             Malta      146.0
# 18            18             Saint Kitts and Nevis      140.0
# 37            37                            Belize      130.0
# 12            12                    United Kingdom       97.0
# 5              5                        Costa Rica       78.0
# 28            28                            Cyprus       77.0
# 45            45                     United States       43.0
# 41            41                     Liechtenstein       42.0
# 13            13                           Uruguay       40.0
# 31            31                           Wyoming       37.0
# 39            39                            Jersey       36.0
# 43            43                         Singapore       33.0
# 20            20                       New Zealand       29.0
# 56            56                          Guernsey       25.0
# 38            38                         Mauritius       19.0
# 59            59  Saint Vincent and the Grenadines       14.0
# 42            42                       Netherlands        7.0
# 40            40                           Liberia        6.0
# 30            30              Netherlands Antilles        5.0
# 142          142                       Saint Lucia        5.0
# 117          117                          Malaysia        5.0
# 33            33              United Arab Emirates        3.0
# 44            44          Turks and Caicos Islands        3.0
# 16            16               Antigua and Barbuda        3.0
# 55            55                           Grenada        3.0
# 60            60                 US Virgin Islands        2.0
# 21            21                             Aruba        2.0
# 167          167                             Dubai        2.0
# 57            57                        Luxembourg        1.0
# 147          147                           Vanuatu        1.0
# 58            58                  Marshall Islands        1.0
# 93            93                          Thailand        1.0
# 54            54                         Gibraltar        1.0
# 123          123                        Montenegro        0.0

# %%
temp_df.tail(50)
# Out:
#      Node_indice               Nodes  In_Degree
# 53            53              Canada        0.0
# 52            52            Cameroon        0.0
# 51            51            Bulgaria        0.0
# 50            50              Brunei        0.0
# 48            48              Brazil        0.0
# 47            47            Botswana        0.0
# 46            46             Bolivia        0.0
# 36            36             Belgium        0.0
# 35            35             Belarus        0.0
# 34            34          Bangladesh        0.0
# 32            32             Bahrain        0.0
# 27            27          Azerbaijan        0.0
# 26            26             Austria        0.0
# 23            23           Australia        0.0
# 19            19           Argentina        0.0
# 14            14              Angola        0.0
# 2              2             Andorra        0.0
# 73            73            Dominica        0.0
# 74            74  Dominican Republic        0.0
# 75            75             Ecuador        0.0
# 94            94             Hungary        0.0
# 107          107              Kuwait        0.0
# 106          106               Kenya        0.0
# 105          105          Kazakhstan        0.0
# 104          104              Jordan        0.0
# 103          103               Japan        0.0
# 102          102             Jamaica        0.0
# 101          101               Italy        0.0
# 100          100              Israel        0.0
# 99            99             Ireland        0.0
# 98            98                Iran        0.0
# 97            97           Indonesia        0.0
# 96            96               India        0.0
# 95            95             Iceland        0.0
# 91            91            Honduras        0.0
# 76            76               Egypt        0.0
# 90            90               Haiti        0.0
# 89            89              Guyana        0.0
# 88            88           Guatemala        0.0
# 86            86              Greece        0.0
# 85            85               Ghana        0.0
# 84            84             Germany        0.0
# 83            83             Georgia        0.0
# 82            82       French Guiana        0.0
# 81            81              France        0.0
# 80            80             Finland        0.0
# 79            79                Fiji        0.0
# 78            78             Estonia        0.0
# 77            77         El Salvador        0.0
# 173          173            Zimbabwe        0.0

# %%
#extract out by Node
order_of_del = temp_df['Nodes'].tolist()

# %%
#print the list to check it
order_of_del
# Out:
# ['British Virgin Islands',
#  'Panama',
#  'Bahamas',
#  'Seychelles',
#  'Niue',
#  'Samoa',
#  'British Anguilla',
#  'Barbados',
#  'Bermuda',
#  'Cayman Islands',
#  'Nevada',
#  'Hong Kong',
#  'Labuan',
#  'Isle of Man',
#  'Cook Islands',
#  'State of Delaware',
#  'Malta',
#  'Saint Kitts and Nevis',
#  'Belize',
#  'United Kingdom',
#  'Costa Rica',
#  'Cyprus',
#  'United States',
#  'Liechtenstein',
#  'Uruguay',
#  'Wyoming',
#  'Jersey',
#  'Singapore',
#  'New Zealand',
#  'Guernsey',
#  'Mauritius',
#  'Saint Vincent and the Grenadines',
#  'Netherlands',
#  'Liberia',
#  'Netherlands Antilles',
#  'Saint Lucia',
#  'Malaysia',
#  'United Arab Emirates',
#  'Turks and Caicos Islands',
#  'Antigua and Barbuda',
#  'Grenada',
#  'US Virgin Islands',
#  'Aruba',
#  'Dubai',
#  'Luxembourg',
#  'Vanuatu',
#  'Marshall Islands',
#  'Thailand',
#  'Gibraltar',
#  'Montenegro',
#  'Nigeria',
#  'Libya',
#  'Portugal',
#  'Poland',
#  'Philippines',
#  'Peru',
#  'Lithuania',
#  'Paraguay',
#  'Pakistan',
#  'Oman',
#  'Norway',
#  'Macao',
#  'Nicaragua',
#  'Morocco',
#  'Nauru',
#  'Macedonia',
#  'Malawi',
#  'Mali',
#  'Mexico',
#  'Moldova',
#  'Qatar',
#  'Namibia',
#  'Monaco',
#  'Mongolia',
#  'Mozambique',
#  'Puerto Rico',
#  'Albania',
#  'Romania',
#  'Russia',
#  'Zambia',
#  'Yemen',
#  'Vietnam',
#  'Venezuela',
#  'Uzbekistan',
#  'Ukraine',
#  'Uganda',
#  'Turkey',
#  'Tunisia',
#  'Trinidad and Tobago',
#  'Tanzania',
#  'Taiwan',
#  'Syria',
#  'Switzerland',
#  'Sweden',
#  'Suriname',
#  'Lebanon',
#  'Sudan',
#  'Sri Lanka',
#  'Spain',
#  'South Korea',
#  'South Africa',
#  'Slovenia',
#  'Slovakia',
#  'Sint Maarten (Dutch part)',
#  'Sierra Leone',
#  'Senegal',
#  'Saudi Arabia',
#  'Saint Martin (French part)',
#  'Lesotho',
#  'Guam',
#  'Latvia',
#  'Kyrgyzstan',
#  'Djibouti',
#  'Denmark',
#  "Côte d'Ivoire",
#  'Czech Republic',
#  'Curaçao',
#  'Cuba',
#  'Croatia',
#  'Colombia',
#  'China',
#  'Chile',
#  'Chad',
#  'Central African Republic',
#  'Canada',
#  'Cameroon',
#  'Bulgaria',
#  'Brunei',
#  'Brazil',
#  'Botswana',
#  'Bolivia',
#  'Belgium',
#  'Belarus',
#  'Bangladesh',
#  'Bahrain',
#  'Azerbaijan',
#  'Austria',
#  'Australia',
#  'Argentina',
#  'Angola',
#  'Andorra',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Hungary',
#  'Kuwait',
#  'Kenya',
#  'Kazakhstan',
#  'Jordan',
#  'Japan',
#  'Jamaica',
#  'Italy',
#  'Israel',
#  'Ireland',
#  'Iran',
#  'Indonesia',
#  'India',
#  'Iceland',
#  'Honduras',
#  'Egypt',
#  'Haiti',
#  'Guyana',
#  'Guatemala',
#  'Greece',
#  'Ghana',
#  'Germany',
#  'Georgia',
#  'French Guiana',
#  'France',
#  'Finland',
#  'Fiji',
#  'Estonia',
#  'El Salvador',
#  'Zimbabwe']

# %%
def unweighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(order_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(order_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#Weighted on diameter
def weighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(order_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(order_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_weighted_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type2_unweighted = unweighted_Type2_targeted_del(g)
df_type2_unweighted.head()
# Out:
#    num_nodes_removed  prop_removed            node_removed  avg_betweenness  \
# 0                  1          0.01  British Virgin Islands        54.722543
# 1                  2          0.01                  Panama        50.424419
# 2                  3          0.02                 Bahamas        53.461988
# 3                  4          0.02              Seychelles        47.041176
# 4                  5          0.03                    Niue        46.798817
#
#    diameter  assortativity_degree  avg_unweighted_indegree   density  \
# 0       6.0             -0.432098                 6.121387  0.035384
# 1       6.0             -0.410127                 5.313953  0.030895
# 2       6.0             -0.412675                 4.707602  0.027530
# 3       6.0             -0.407399                 4.194118  0.024671
# 4       6.0             -0.416286                 3.816568  0.022583
#
#    average_path_len
# 0          2.279497
# 1          2.316684
# 2          2.449041
# 3          2.418914
# 4          2.435911

# %%
df_type2_unweighted.tail()
# Out:
#      num_nodes_removed  prop_removed node_removed  avg_betweenness  diameter  \
# 169                170          0.87      Finland              0.0       0.0
# 170                171          0.87         Fiji              0.0       0.0
# 171                172          0.88      Estonia              0.0       0.0
# 172                173          0.88  El Salvador              0.0       0.0
# 173                174          0.89     Zimbabwe              0.0       NaN
#
#      assortativity_degree  avg_unweighted_indegree  density  average_path_len
# 169                   NaN                      0.0      0.0               NaN
# 170                   NaN                      0.0      0.0               NaN
# 171                   NaN                      0.0      0.0               NaN
# 172                   NaN                      0.0      0.0               NaN
# 173                   NaN                      0.0      NaN               NaN

# %%
df_type2_weighted = weighted_Type2_targeted_del(g)
df_type2_weighted.head(15)
# Out:
#     num_nodes_removed  prop_removed            node_removed  \
# 0                   1          0.01  British Virgin Islands
# 1                   2          0.01                  Panama
# 2                   3          0.02                 Bahamas
# 3                   4          0.02              Seychelles
# 4                   5          0.03                    Niue
# 5                   6          0.03                   Samoa
# 6                   7          0.04        British Anguilla
# 7                   8          0.04                Barbados
# 8                   9          0.05                 Bermuda
# 9                  10          0.05          Cayman Islands
# 10                 11          0.06                  Nevada
# 11                 12          0.06               Hong Kong
# 12                 13          0.07                  Labuan
# 13                 14          0.07             Isle of Man
# 14                 15          0.08            Cook Islands
#
#     avg_weighted_betweenness  diameter  assortativity_degree  \
# 0                  98.116731      33.0             -0.432098
# 1                  87.201172     140.0             -0.410127
# 2                  83.262049     141.0             -0.412675
# 3                  72.577372     141.0             -0.407399
# 4                  71.809548     141.0             -0.416286
# 5                  69.471341     141.0             -0.427183
# 6                  63.975661     141.0             -0.427621
# 7                  53.494389      38.0             -0.415720
# 8                  46.390837     141.0             -0.387987
# 9                  31.286789     125.0             -0.220815
# 10                 30.582004     125.0             -0.224689
# 11                 20.627572     125.0             -0.211532
# 12                 19.680124     125.0             -0.208388
# 13                 16.228125     125.0             -0.114183
# 14                 15.836478     124.0             -0.071337
#
#     avg_weighted_indegree   density  average_path_len
# 0              579.705202  0.035384          2.279497
# 1              309.081395  0.030895          2.316684
# 2              223.660819  0.027530          2.449041
# 3              145.241176  0.024671          2.418914
# 4               99.905325  0.022583          2.435911
# 5               65.922619  0.020904          2.446347
# 6               48.838323  0.019291          2.387490
# 7               41.692771  0.016984          2.299363
# 8               27.636364  0.014178          2.287112
# 9               16.975610  0.010931          2.625112
# 10              11.650307  0.009711          2.659407
# 11               9.592593  0.008040          2.722083
# 12               6.993789  0.008063          2.690850
# 13               5.187500  0.006563          3.041133
# 14               4.553459  0.005973          3.100775

# %%
df_type2_weighted.tail(150)
# Out:
#      num_nodes_removed  prop_removed node_removed  avg_weighted_betweenness  \
# 24                  25          0.13      Uruguay                  1.194631
# 25                  26          0.13      Wyoming                  0.945946
# 26                  27          0.14       Jersey                  0.258503
# 27                  28          0.14    Singapore                  0.054795
# 28                  29          0.15  New Zealand                  0.055172
# ..                 ...           ...          ...                       ...
# 169                170          0.87      Finland                  0.000000
# 170                171          0.87         Fiji                  0.000000
# 171                172          0.88      Estonia                  0.000000
# 172                173          0.88  El Salvador                  0.000000
# 173                174          0.89     Zimbabwe                  0.000000
#
#      diameter  assortativity_degree  avg_weighted_indegree   density  \
# 24       16.0             -0.316628               0.617450  0.001937
# 25       16.0             -0.357809               0.567568  0.001735
# 26        9.0             -0.362064               0.462585  0.001435
# 27        9.0             -0.362164               0.280822  0.000891
# 28        3.0              0.125000               0.179310  0.000666
# ..        ...                   ...                    ...       ...
# 169       0.0                   NaN               0.000000  0.000000
# 170       0.0                   NaN               0.000000  0.000000
# 171       0.0                   NaN               0.000000  0.000000
# 172       0.0                   NaN               0.000000  0.000000
# 173       NaN                   NaN               0.000000       NaN
#
#      average_path_len
# 24           2.190476
# 25           2.104000
# 26           1.560606
# 27           1.291667
# 28           1.368421
# ..                ...
# 169               NaN
# 170               NaN
# 171               NaN
# 172               NaN
# 173               NaN
#
# [150 rows x 9 columns]

# %% [markdown]
# #### Unweighted

# %%
## Commented out to not confuse; use the weighted one below

#Try plotting unweighted

#fig, ax = plt.subplots(1,2,figsize=(14,6),sharey=True)
#ax2_1 = ax[0].twinx()
#ax[0].plot('prop_removed','diameter',data=df_type1_unweighted,ls='--',color='darkblue')
#ax[0].plot('prop_removed','density',data=df_type1_unweighted,ls='--',color='darkviolet')
#ax[0].plot('prop_removed','avg_betweenness',data=df_type1_unweighted,ls='--',color='darkgreen')
#ax2_1.plot('prop_removed','avg_unweighted_indegree',data=df_type1_unweighted,ls='--',color='darkred')
#ax[0].plot('prop_removed','assortativity_degree',data=df_type1_unweighted,ls='--',color='darkturquoise')
#ax[0].plot('prop_removed','average_path_len',data=df_type1_unweighted,ls='--',color='darkorange')
#ax[0].legend(loc='upper right')
#ax[0].set_xlabel('Proportion of nodes removed')
#ax[0].set_title('Random deletion')
#ax2_1.tick_params('y',colors='darkred')
#ax2_1.set_ylabel('Avg inDegree')
#ax2_1.legend(loc='upper left')

#ax2_2 = ax[1].twinx()
#ax[1].plot('prop_removed','diameter',data=df_type2_unweighted,ls='--',color='blue')
#ax[1].plot('prop_removed','density',data=df_type2_unweighted,ls='--',color='violet')
#ax[1].plot('prop_removed','avg_betweenness',data=df_type2_unweighted,ls='--',color='green')
#ax2_2.plot('prop_removed','avg_unweighted_indegree',data=df_type2_unweighted,ls='--',color='red')
#ax[1].plot('prop_removed','assortativity_degree',data=df_type2_unweighted,ls='--',color='turquoise')
#ax[1].plot('prop_removed','average_path_len',data=df_type2_unweighted,ls='--',color='orange')
#ax[1].legend(loc='upper right')
#ax[1].set_xlabel('Proportion of nodes removed')
#ax[1].set_title('Targeted deletion')
#ax2_2.tick_params('y',colors='darkred')
#ax2_2.set_ylabel('Avg inDegree')
#ax2_2.legend(loc='upper left')
#plt.show()

# %% [markdown]
# #### Weighted

# %%
#Same but weighted
#Don't share y axis for type2
fig, ax = plt.subplots(2,2,figsize=(18,12),sharey=False)

#Random attack LHS graphs

ax[0,1].plot('prop_removed','diameter',data=df_type1_weighted,ls='-',color='darkblue')
ax[0,0].plot('prop_removed','density',data=df_type1_weighted,ls='-',color='darkviolet')
ax[0,0].plot('prop_removed','assortativity_degree',data=df_type1_weighted,ls='-',color='darkturquoise')
ax[0,0].plot('prop_removed','average_path_len',data=df_type1_weighted,ls='-',color='darkorange')
ax[0,0].legend(loc='upper right')
ax[0,0].set_xlabel('Proportion of nodes removed')
ax[0,0].set_title('Random deletion')

ax2_1 = ax[0,0].twinx()
ax2_1.plot('prop_removed','avg_weighted_indegree',data=df_type1_weighted,ls='-',color='darkred')
ax2_1.tick_params('y',colors='darkred')
ax2_1.set_ylabel('Avg inDegree')
ax2_1.legend(loc='upper left')

#Random attack RHS Graphs - Betweenness & Diameter
ax[0,1].set_title('Random deletion - Betweenness & Diameter')
ax[0,1].legend(loc='upper left')

ax_bet_rand = ax[0,1].twinx()
ax_bet_rand.plot('prop_removed','avg_weighted_betweenness',data=df_type1_weighted,ls='--',color='darkgreen')
ax_bet_rand.tick_params('y',colors='darkgreen')
ax_bet_rand.set_ylabel('Avg_weighted_betweenness')
ax_bet_rand.legend(loc='upper right')


#Targeted attack LHS Graphs

ax[1,1].plot('prop_removed','diameter',data=df_type2_weighted,ls='-',color='blue')
ax[1,0].plot('prop_removed','density',data=df_type2_weighted,ls='-',color='violet')
ax[1,0].plot('prop_removed','assortativity_degree',data=df_type2_weighted,ls='-',color='turquoise')
ax[1,0].plot('prop_removed','average_path_len',data=df_type2_weighted,ls='-',color='orange')
ax[1,0].legend(loc='upper right')
ax[1,0].set_xlabel('Proportion of nodes removed')
ax[1,0].set_title('Targeted deletion')

ax2_2 = ax[1,0].twinx()
ax2_2.plot('prop_removed','avg_weighted_indegree',data=df_type2_weighted,ls='-',color='darkred')
ax2_2.set_ylabel('Avg inDegree')
ax2_2.legend(loc='upper left')
ax2_2.tick_params('y',colors='darkred')


#Targeted attack RHS Graphs - Betweenness & Diameter 

ax[1,1].set_title('Targeted deletion - Betweenness & Diameter')
ax[1,1].legend(loc='upper left')

ax_bet_tar = ax[1,1].twinx()
ax_bet_tar.plot('prop_removed','avg_weighted_betweenness',data=df_type2_weighted,ls='--',color='green')
ax_bet_tar.tick_params('y',colors='green')
ax_bet_tar.set_ylabel('avg weighted betweenness')
ax_bet_tar.legend(loc='upper right')
plt.show()
