# %%
import pandas as pd
import numpy as np
import igraph as ig
import matplotlib.pyplot as plt

# %%
df_unweighted = pd.read_csv('../combined_final_unweighted.csv')
df_unweighted
# Out:
#           node_start                node_end        status
# 0          Hong Kong                   Samoa  jurisdiction
# 1          Hong Kong                   Samoa  jurisdiction
# 2          Hong Kong                   Samoa  jurisdiction
# 3          Hong Kong                   Samoa  jurisdiction
# 4          Hong Kong                   Samoa  jurisdiction
# ...              ...                     ...           ...
# 338127     Indonesia  British Virgin Islands  officer_base
# 338128  Cook Islands  British Virgin Islands  officer_base
# 338129     Hong Kong  British Virgin Islands  officer_base
# 338130  Cook Islands          United Kingdom  officer_base
# 338131     Hong Kong          United Kingdom  officer_base
#
# [338132 rows x 3 columns]

# %%
df_weighted = pd.read_csv('../combined_final_weighted.csv')
df_weighted
# Out:
#           node_start                node_end        status  weight
# 0          Hong Kong                   Samoa  jurisdiction     2.0
# 1          Hong Kong                   Samoa  jurisdiction     2.0
# 2          Hong Kong                   Samoa  jurisdiction     2.0
# 3          Hong Kong                   Samoa  jurisdiction     2.0
# 4          Hong Kong                   Samoa  jurisdiction     2.0
# ...              ...                     ...           ...     ...
# 338119     Indonesia  British Virgin Islands  officer_base     1.0
# 338120  Cook Islands  British Virgin Islands  officer_base     1.0
# 338121     Hong Kong  British Virgin Islands  officer_base     1.0
# 338122  Cook Islands          United Kingdom  officer_base     1.0
# 338123     Hong Kong          United Kingdom  officer_base     1.0
#
# [338124 rows x 4 columns]

# %%
df_dir = pd.read_csv('../combined_final_weighted_groupedby.csv')
df_dir
# Out:
#      node_start                node_end  weight
# 0       Albania                 Bahamas     4.0
# 1       Algeria  British Virgin Islands     2.0
# 2       Algeria          United Kingdom     2.0
# 3       Algeria           United States     1.0
# 4       Andorra                 Bahamas    52.0
# ...         ...                     ...     ...
# 2835   Zimbabwe               Hong Kong     3.0
# 2836   Zimbabwe                  Jersey     1.0
# 2837   Zimbabwe                  Panama     6.0
# 2838   Zimbabwe                  Russia     2.0
# 2839   Zimbabwe           United States     1.0
#
# [2840 rows x 3 columns]

# %%
#plot the unweighted graph (try unweighted first)
g = ig.Graph.TupleList(df_dir.itertuples(index=False), directed=True, edge_attrs={'weight': "weight"})

# %%
ig.plot(g)

# %%
g.diameter()
# Out:
# 4

# %%
len(g.vs.indices)
# Out:
# 196

# %%
#g.vs.indices
df_dir['node_start'].value_counts()
# Out:
# Hong Kong                    60
# United States                55
# Taiwan                       53
# China                        53
# Singapore                    52
#                              ..
# Sudan                         1
# Mali                          1
# Central African Republic      1
# Zambia                        1
# Sint Maarten (Dutch part)     1
# Name: node_start, Length: 190, dtype: int64

# %%
uni =df_dir['node_start'].unique()

# %%
len(uni)
# Out:
# 190

# %%
list(g.vs)
# Out:
# [igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 0, {'name': 'Albania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 2, {'name': 'Algeria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 4, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 5, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 6, {'name': 'Andorra'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 7, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 8, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 9, {'name': 'Costa Rica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 10, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 11, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 12, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 13, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 14, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 15, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 16, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 17, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 18, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 19, {'name': 'Uruguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 20, {'name': 'Angola'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 21, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 22, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 23, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 24, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 25, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 26, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 27, {'name': 'Argentina'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 28, {'name': 'Belarus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 29, {'name': 'New Zealand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 30, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 31, {'name': 'Armenia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 32, {'name': 'Aruba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 33, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 34, {'name': 'Australia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 35, {'name': 'Austria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 36, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 37, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 38, {'name': 'Czech Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 39, {'name': 'Germany'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 40, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 42, {'name': 'Labuan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 43, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 44, {'name': 'Malaysia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 45, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 46, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 47, {'name': 'South Africa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 48, {'name': 'Sweden'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 49, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 50, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 51, {'name': 'Azerbaijan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 52, {'name': 'Gibraltar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 53, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 54, {'name': 'Netherlands Antilles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 55, {'name': 'Saint Lucia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 56, {'name': 'Wyoming'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 57, {'name': 'Bahrain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 58, {'name': 'Bangladesh'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 59, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 60, {'name': 'Belgium'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 61, {'name': 'Benin'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 62, {'name': 'Liberia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 63, {'name': 'Liechtenstein'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 64, {'name': 'Turks and Caicos Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 65, {'name': 'Vanuatu'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 66, {'name': 'Bhutan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 67, {'name': 'Bolivia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 68, {'name': 'Bosnia and Herzegovina'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 69, {'name': 'Botswana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 70, {'name': 'Brazil'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 71, {'name': 'Croatia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 72, {'name': 'Curaçao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 73, {'name': 'Israel'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 74, {'name': 'Marshall Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 75, {'name': 'State of Delaware'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 76, {'name': 'Thailand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 77, {'name': 'Brunei'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 78, {'name': 'Bulgaria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 79, {'name': 'Cambodia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 80, {'name': 'Cameroon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 81, {'name': 'Indonesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 82, {'name': 'Grenada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 83, {'name': 'Guernsey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 84, {'name': 'Saint Vincent and the Grenadines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 85, {'name': 'US Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 86, {'name': 'Central African Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 87, {'name': 'Chad'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 88, {'name': 'Chile'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 89, {'name': 'France'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 90, {'name': 'Georgia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 91, {'name': 'Kazakhstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 92, {'name': 'Serbia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 93, {'name': 'Colombia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 94, {'name': 'Congo'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 95, {'name': 'Cuba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 96, {'name': "Côte d'Ivoire"}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 97, {'name': 'Denmark'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 98, {'name': 'Djibouti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 99, {'name': 'Dominica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 100, {'name': 'Dominican Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 101, {'name': 'Ecuador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 102, {'name': 'Egypt'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 103, {'name': 'El Salvador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 104, {'name': 'Estonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 105, {'name': 'Fiji'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 106, {'name': 'Finland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 107, {'name': 'French Guiana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 108, {'name': 'French Polynesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 109, {'name': 'Gabon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 110, {'name': 'Ghana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 111, {'name': 'Greece'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 112, {'name': 'Guam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 113, {'name': 'Guatemala'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 114, {'name': 'Guinea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 115, {'name': 'Guyana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 116, {'name': 'Haiti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 117, {'name': 'Honduras'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 118, {'name': 'Japan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 119, {'name': 'Kuwait'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 120, {'name': 'Portugal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 121, {'name': 'South Korea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 122, {'name': 'Taiwan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 123, {'name': 'Hungary'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 124, {'name': 'Iceland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 125, {'name': 'India'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 126, {'name': 'Iran'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 127, {'name': 'Italy'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 128, {'name': 'Jamaica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 129, {'name': 'Jordan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 130, {'name': 'Kenya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 131, {'name': 'Kyrgyzstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 132, {'name': 'Laos'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 133, {'name': 'Lebanon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 134, {'name': 'Lesotho'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 135, {'name': 'Libya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 136, {'name': 'Lithuania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 137, {'name': 'Macao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 138, {'name': 'Macedonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 139, {'name': 'Madagascar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 140, {'name': 'Malawi'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 141, {'name': 'Mali'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 142, {'name': 'Mexico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 143, {'name': 'Moldova'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 144, {'name': 'Monaco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 145, {'name': 'Mongolia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 146, {'name': 'Montenegro'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 147, {'name': 'Morocco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 148, {'name': 'Mozambique'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 149, {'name': 'Myanmar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 150, {'name': 'Namibia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 151, {'name': 'Nauru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 152, {'name': 'Nepal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 153, {'name': 'Nicaragua'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 154, {'name': 'Nigeria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 155, {'name': 'Norfolk Island'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 156, {'name': 'Northern Mariana Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 157, {'name': 'Norway'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 158, {'name': 'Oman'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 159, {'name': 'Pakistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 160, {'name': 'Palestine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 161, {'name': 'Papua New Guinea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 162, {'name': 'Paraguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 163, {'name': 'Peru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 164, {'name': 'Philippines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 165, {'name': 'Poland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 166, {'name': 'Puerto Rico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 167, {'name': 'Qatar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 168, {'name': 'Romania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 169, {'name': 'Saint Martin (French part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 170, {'name': 'Saudi Arabia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 171, {'name': 'Senegal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 172, {'name': 'Sierra Leone'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 173, {'name': 'Sint Maarten (Dutch part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 174, {'name': 'Slovakia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 175, {'name': 'Slovenia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 176, {'name': 'Spain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 177, {'name': 'Sri Lanka'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 178, {'name': 'Sudan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 179, {'name': 'Suriname'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 180, {'name': 'Syria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 181, {'name': 'Tajikistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 182, {'name': 'Tanzania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 183, {'name': 'Tonga'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 184, {'name': 'Trinidad and Tobago'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 185, {'name': 'Tunisia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 186, {'name': 'Turkey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 187, {'name': 'Turkmenistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 188, {'name': 'Uganda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 189, {'name': 'Dubai'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 190, {'name': 'Uzbekistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 191, {'name': 'Venezuela'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 192, {'name': 'Vietnam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 193, {'name': 'Yemen'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 194, {'name': 'Zambia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd925b29e50>, 195, {'name': 'Zimbabwe'})]

# %%
##similar to mini-proj, try a random target 
import random
random.seed(5104)
def unweighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'avg_betweenness':bet,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#try another function but this time with g.diameter having weight param 
#https://igraph.org/python/api/latest/igraph._igraph.GraphBase.html#diameter

random.seed(5104)
def weighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #try in-degree
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'avg_weighted_betweenness':bet,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type1_unweighted = unweighted_Type1_random_delete(g)
df_type1_unweighted.head()
# Out:
#    nodes_removed  avg_betweenness  prop_removed  diameter  \
# 0              1        74.107692          0.01       4.0
# 1              2        73.984536          0.01       4.0
# 2              3        73.943005          0.02       4.0
# 3              4        73.947917          0.02       4.0
# 4              5        73.869110          0.03       4.0
#
#    assortativity_degree  avg_unweighted_indegree   density  average_path_len
# 0             -0.470685                14.420513  0.073951          1.960455
# 1             -0.470699                14.474227  0.074609          1.959040
# 2             -0.469460                14.512953  0.075197          1.958686
# 3             -0.468696                14.526042  0.075656          1.958936
# 4             -0.469423                14.554974  0.076204          1.958101

# %%
df_type1_unweighted.tail()
# Out:
#      nodes_removed  avg_betweenness  prop_removed  diameter  \
# 191            192              0.0          0.98       0.0
# 192            193              0.0          0.98       0.0
# 193            194              0.0          0.99       0.0
# 194            195              0.0          0.99       0.0
# 195            196              0.0          1.00       NaN
#
#      assortativity_degree  avg_unweighted_indegree  density  average_path_len
# 191                   NaN                      0.0      0.0               NaN
# 192                   NaN                      0.0      0.0               NaN
# 193                   NaN                      0.0      0.0               NaN
# 194                   NaN                      0.0      0.0               NaN
# 195                   NaN                      0.0      NaN               NaN

# %%
df_type1_weighted = weighted_Type1_random_delete(g)
df_type1_weighted.head()
# Out:
#    nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 0              1          0.01      23.5                137.381474
# 1              2          0.01      23.5                135.948280
# 2              3          0.02      23.5                134.333279
# 3              4          0.02      23.5                133.320000
# 4              5          0.03      23.5                133.382297
#
#    assortativity_degree  avg_weighted_indegree   density  average_path_len
# 0             -0.469442            2838.284615  0.074504          1.957730
# 1             -0.468203            2850.811856  0.074344          1.958658
# 2             -0.466851            2843.453368  0.073881          1.960452
# 3             -0.466865            2857.734375  0.074083          1.960213
# 4             -0.465599            2872.562827  0.074642          1.959997

# %%
df_type1_weighted.tail(15)
# Out:
#      nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 181            182          0.93      52.0                  2.428571
# 182            183          0.93      52.0                  2.153846
# 183            184          0.94      52.0                  1.750000
# 184            185          0.94      48.0                  1.272727
# 185            186          0.95      48.0                  1.400000
# 186            187          0.95      38.0                  0.666667
# 187            188          0.96      38.0                  0.750000
# 188            189          0.96      38.0                  0.857143
# 189            190          0.97      38.0                  1.000000
# 190            191          0.97    4148.0                  0.000000
# 191            192          0.98      92.0                  0.000000
# 192            193          0.98       0.0                  0.000000
# 193            194          0.99       0.0                  0.000000
# 194            195          0.99       0.0                  0.000000
# 195            196          1.00       NaN                  0.000000
#
#      assortativity_degree  avg_weighted_indegree   density  average_path_len
# 181             -0.487487             376.357143  0.107143          1.536585
# 182             -0.502386             405.230769  0.118343          1.500000
# 183             -0.454813             438.833333  0.131944          1.419355
# 184             -0.459361             478.363636  0.148760          1.307692
# 185             -0.459361             526.200000  0.180000          1.307692
# 186             -0.125000             482.222222  0.111111          1.307692
# 187             -0.125000             542.500000  0.140625          1.307692
# 188             -0.125000             620.000000  0.183673          1.307692
# 189             -0.125000             723.333333  0.250000          1.307692
# 190                   NaN             853.200000  0.120000          1.000000
# 191                   NaN              29.500000  0.125000          1.000000
# 192                   NaN               0.000000  0.000000               NaN
# 193                   NaN               0.000000  0.000000               NaN
# 194                   NaN               0.000000  0.000000               NaN
# 195                   NaN               0.000000       NaN               NaN

# %% [markdown]
# ### Targeted attack

# %%
##try sort by indegree 
temp_df = pd.DataFrame({'Node_indice':g.vs.indices,
                         'Nodes':g.vs['name'],
                         'In_Degree':g.strength(mode='in',weights='weight')})

# %%
#sort by largest degree 
temp_df = temp_df.sort_values(by='In_Degree',ascending=False)

# %%
temp_df.head(50)
# Out:
#     Node_indice                     Nodes  In_Degree
# 3             3    British Virgin Islands   280925.0
# 15           15                    Panama    89885.0
# 18           18                Seychelles    31501.5
# 1             1                   Bahamas    31085.0
# 14           14                      Niue    18912.0
# 4             4            United Kingdom    16320.0
# 10           10                 Hong Kong    14145.0
# 17           17                     Samoa    12807.0
# 16           16                    Russia    10958.0
# 33           33          British Anguilla     6480.0
# 24           24                  Barbados     4722.0
# 21           21                   Bermuda     4662.0
# 5             5             United States     4337.0
# 37           37                    Cyprus     3465.0
# 11           11                   Ireland     3316.0
# 7             7            Cayman Islands     2926.5
# 22           22                     China     2598.0
# 13           13                    Nevada     2520.0
# 25           25                    Canada     1486.0
# 26           26     Saint Kitts and Nevis     1371.0
# 12           12                    Latvia     1299.0
# 50           50      United Arab Emirates      891.0
# 42           42                    Labuan      883.5
# 46           46                 Singapore      690.5
# 40           40               Isle of Man      582.0
# 8             8              Cook Islands      534.0
# 36           36                    Belize      436.0
# 41           41                    Jersey      426.0
# 43           43                Luxembourg      405.0
# 53           53                     Malta      390.0
# 75           75         State of Delaware      362.0
# 30           30               Switzerland      226.0
# 23           23       Antigua and Barbuda      214.0
# 45           45               Netherlands      173.0
# 59           59                 Mauritius      159.0
# 49           49                   Ukraine      158.0
# 9             9                Costa Rica      156.0
# 38           38            Czech Republic       87.0
# 48           48                    Sweden       84.0
# 63           63             Liechtenstein       84.0
# 19           19                   Uruguay       80.0
# 56           56                   Wyoming       74.0
# 52           52                 Gibraltar       66.0
# 35           35                   Austria       63.0
# 44           44                  Malaysia       60.5
# 29           29               New Zealand       59.0
# 83           83                  Guernsey       50.0
# 39           39                   Germany       45.0
# 72           72                   Curaçao       40.0
# 64           64  Turks and Caicos Islands       34.0

# %%
temp_df.tail(50)
# Out:
#      Node_indice                   Nodes  In_Degree
# 80            80                Cameroon        0.0
# 79            79                Cambodia        0.0
# 78            78                Bulgaria        0.0
# 77            77                  Brunei        0.0
# 70            70                  Brazil        0.0
# 68            68  Bosnia and Herzegovina        0.0
# 99            99                Dominica        0.0
# 67            67                 Bolivia        0.0
# 66            66                  Bhutan        0.0
# 61            61                   Benin        0.0
# 60            60                 Belgium        0.0
# 58            58              Bangladesh        0.0
# 57            57                 Bahrain        0.0
# 51            51              Azerbaijan        0.0
# 31            31                 Armenia        0.0
# 27            27               Argentina        0.0
# 20            20                  Angola        0.0
# 6              6                 Andorra        0.0
# 2              2                 Algeria        0.0
# 97            97                 Denmark        0.0
# 100          100      Dominican Republic        0.0
# 134          134                 Lesotho        0.0
# 116          116                   Haiti        0.0
# 133          133                 Lebanon        0.0
# 132          132                    Laos        0.0
# 131          131              Kyrgyzstan        0.0
# 130          130                   Kenya        0.0
# 129          129                  Jordan        0.0
# 128          128                 Jamaica        0.0
# 127          127                   Italy        0.0
# 126          126                    Iran        0.0
# 125          125                   India        0.0
# 124          124                 Iceland        0.0
# 123          123                 Hungary        0.0
# 117          117                Honduras        0.0
# 115          115                  Guyana        0.0
# 101          101                 Ecuador        0.0
# 114          114                  Guinea        0.0
# 113          113               Guatemala        0.0
# 112          112                    Guam        0.0
# 111          111                  Greece        0.0
# 110          110                   Ghana        0.0
# 109          109                   Gabon        0.0
# 108          108        French Polynesia        0.0
# 107          107           French Guiana        0.0
# 106          106                 Finland        0.0
# 105          105                    Fiji        0.0
# 103          103             El Salvador        0.0
# 102          102                   Egypt        0.0
# 195          195                Zimbabwe        0.0

# %%
#extract out by Node
order_of_del = temp_df['Nodes'].tolist()

# %%
#print the list to check it
order_of_del
# Out:
# ['British Virgin Islands',
#  'Panama',
#  'Seychelles',
#  'Bahamas',
#  'Niue',
#  'United Kingdom',
#  'Hong Kong',
#  'Samoa',
#  'Russia',
#  'British Anguilla',
#  'Barbados',
#  'Bermuda',
#  'United States',
#  'Cyprus',
#  'Ireland',
#  'Cayman Islands',
#  'China',
#  'Nevada',
#  'Canada',
#  'Saint Kitts and Nevis',
#  'Latvia',
#  'United Arab Emirates',
#  'Labuan',
#  'Singapore',
#  'Isle of Man',
#  'Cook Islands',
#  'Belize',
#  'Jersey',
#  'Luxembourg',
#  'Malta',
#  'State of Delaware',
#  'Switzerland',
#  'Antigua and Barbuda',
#  'Netherlands',
#  'Mauritius',
#  'Ukraine',
#  'Costa Rica',
#  'Czech Republic',
#  'Sweden',
#  'Liechtenstein',
#  'Uruguay',
#  'Wyoming',
#  'Gibraltar',
#  'Austria',
#  'Malaysia',
#  'New Zealand',
#  'Guernsey',
#  'Germany',
#  'Curaçao',
#  'Turks and Caicos Islands',
#  'Israel',
#  'Saint Vincent and the Grenadines',
#  'Belarus',
#  'South Africa',
#  'Saint Lucia',
#  'Croatia',
#  'Liberia',
#  'Vanuatu',
#  'Netherlands Antilles',
#  'Thailand',
#  'Grenada',
#  'Marshall Islands',
#  'Taiwan',
#  'Indonesia',
#  'Georgia',
#  'US Virgin Islands',
#  'Australia',
#  'Serbia',
#  'Dubai',
#  'Aruba',
#  'Mexico',
#  'Japan',
#  'Kuwait',
#  'France',
#  'Spain',
#  'Kazakhstan',
#  'Philippines',
#  'Estonia',
#  'Portugal',
#  'South Korea',
#  'Malawi',
#  'Papua New Guinea',
#  'Macedonia',
#  'Palestine',
#  'Pakistan',
#  'Oman',
#  'Madagascar',
#  'Norway',
#  'Northern Mariana Islands',
#  'Norfolk Island',
#  'Nigeria',
#  'Nicaragua',
#  'Mali',
#  'Paraguay',
#  'Moldova',
#  'Nepal',
#  'Nauru',
#  'Namibia',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Albania',
#  'Tanzania',
#  'Peru',
#  'Poland',
#  'Zambia',
#  'Yemen',
#  'Vietnam',
#  'Venezuela',
#  'Uzbekistan',
#  'Uganda',
#  'Turkmenistan',
#  'Turkey',
#  'Tunisia',
#  'Trinidad and Tobago',
#  'Tonga',
#  'Lithuania',
#  'Tajikistan',
#  'Syria',
#  'Suriname',
#  'Sudan',
#  'Sri Lanka',
#  'Slovenia',
#  'Slovakia',
#  'Sint Maarten (Dutch part)',
#  'Sierra Leone',
#  'Senegal',
#  'Saudi Arabia',
#  'Saint Martin (French part)',
#  'Romania',
#  'Qatar',
#  'Puerto Rico',
#  'Macao',
#  'Djibouti',
#  'Libya',
#  'Botswana',
#  "Côte d'Ivoire",
#  'Cuba',
#  'Congo',
#  'Colombia',
#  'Chile',
#  'Chad',
#  'Central African Republic',
#  'Cameroon',
#  'Cambodia',
#  'Bulgaria',
#  'Brunei',
#  'Brazil',
#  'Bosnia and Herzegovina',
#  'Dominica',
#  'Bolivia',
#  'Bhutan',
#  'Benin',
#  'Belgium',
#  'Bangladesh',
#  'Bahrain',
#  'Azerbaijan',
#  'Armenia',
#  'Argentina',
#  'Angola',
#  'Andorra',
#  'Algeria',
#  'Denmark',
#  'Dominican Republic',
#  'Lesotho',
#  'Haiti',
#  'Lebanon',
#  'Laos',
#  'Kyrgyzstan',
#  'Kenya',
#  'Jordan',
#  'Jamaica',
#  'Italy',
#  'Iran',
#  'India',
#  'Iceland',
#  'Hungary',
#  'Honduras',
#  'Guyana',
#  'Ecuador',
#  'Guinea',
#  'Guatemala',
#  'Guam',
#  'Greece',
#  'Ghana',
#  'Gabon',
#  'French Polynesia',
#  'French Guiana',
#  'Finland',
#  'Fiji',
#  'El Salvador',
#  'Egypt',
#  'Zimbabwe']

# %%
def unweighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(order_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(order_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#Weighted on diameter
def weighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(order_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(order_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_weighted_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type2_unweighted = unweighted_Type2_targeted_del(g)
df_type2_unweighted.head()
# Out:
#    num_nodes_removed  prop_removed            node_removed  avg_betweenness  \
# 0                  1          0.01  British Virgin Islands        71.923077
# 1                  2          0.01                  Panama        69.654639
# 2                  3          0.02              Seychelles        67.290155
# 3                  4          0.02                 Bahamas        66.791667
# 4                  5          0.03                    Niue        66.120419
#
#    diameter  assortativity_degree  avg_unweighted_indegree   density  \
# 0       4.0             -0.452126                13.389744  0.068665
# 1       4.0             -0.444601                12.510309  0.064486
# 2       4.0             -0.449322                11.932642  0.061827
# 3       4.0             -0.453574                11.369792  0.059218
# 4       4.0             -0.456955                11.062827  0.057921
#
#    average_path_len
# 0          1.980358
# 1          1.989456
# 2          1.985805
# 3          1.997899
# 4          2.001745

# %%
df_type2_unweighted.tail()
# Out:
#      num_nodes_removed  prop_removed node_removed  avg_betweenness  diameter  \
# 191                192          0.98      Finland              0.0       0.0
# 192                193          0.98         Fiji              0.0       0.0
# 193                194          0.99  El Salvador              0.0       0.0
# 194                195          0.99        Egypt              0.0       0.0
# 195                196          1.00     Zimbabwe              0.0       NaN
#
#      assortativity_degree  avg_unweighted_indegree  density  average_path_len
# 191                   NaN                      0.0      0.0               NaN
# 192                   NaN                      0.0      0.0               NaN
# 193                   NaN                      0.0      0.0               NaN
# 194                   NaN                      0.0      0.0               NaN
# 195                   NaN                      0.0      NaN               NaN

# %%
df_type2_weighted = weighted_Type2_targeted_del(g)
df_type2_weighted.head(15)
# Out:
#     num_nodes_removed  prop_removed            node_removed  \
# 0                   1          0.01  British Virgin Islands
# 1                   2          0.01                  Panama
# 2                   3          0.02              Seychelles
# 3                   4          0.02                 Bahamas
# 4                   5          0.03                    Niue
# 5                   6          0.03          United Kingdom
# 6                   7          0.04               Hong Kong
# 7                   8          0.04                   Samoa
# 8                   9          0.05                  Russia
# 9                  10          0.05        British Anguilla
# 10                 11          0.06                Barbados
# 11                 12          0.06                 Bermuda
# 12                 13          0.07           United States
# 13                 14          0.07                  Cyprus
# 14                 15          0.08                 Ireland
#
#     avg_weighted_betweenness  diameter  assortativity_degree  \
# 0                 129.964080      17.0             -0.452126
# 1                 124.322810      17.0             -0.444601
# 2                 119.392408      17.0             -0.449322
# 3                 116.745495      17.0             -0.453574
# 4                 114.916335      17.0             -0.456955
# 5                 114.163654     135.0             -0.449271
# 6                 107.520361     357.0             -0.427684
# 7                 106.474707     357.0             -0.433746
# 8                 104.794011     357.0             -0.425701
# 9                 103.367399     357.0             -0.432080
# 10                 97.660127     135.0             -0.432755
# 11                 95.562103     136.0             -0.440840
# 12                 93.786067     245.0             -0.418790
# 13                 91.374941     245.0             -0.412669
# 14                 88.322086     245.0             -0.401226
#
#     avg_weighted_indegree   density  average_path_len
# 0             1362.169231  0.068665          1.980358
# 1              855.796392  0.064486          1.989456
# 2              708.611399  0.061827          1.985805
# 3              557.848958  0.059218          1.997899
# 4              479.010471  0.057921          2.001745
# 5              390.973684  0.053823          2.025374
# 6              239.023810  0.049159          2.087336
# 7              208.335106  0.047306          2.096617
# 8              162.032086  0.043467          2.128360
# 9              147.306452  0.042462          2.132719
# 10             136.302703  0.040847          2.111579
# 11             118.048913  0.038693          2.125954
# 12              89.035519  0.034907          2.218426
# 13              75.087912  0.031971          2.242528
# 14              63.596685  0.029364          2.249669

# %%
df_type2_weighted.tail(15)
# Out:
#      num_nodes_removed  prop_removed      node_removed  \
# 181                182          0.93            Guyana
# 182                183          0.93           Ecuador
# 183                184          0.94            Guinea
# 184                185          0.94         Guatemala
# 185                186          0.95              Guam
# 186                187          0.95            Greece
# 187                188          0.96             Ghana
# 188                189          0.96             Gabon
# 189                190          0.97  French Polynesia
# 190                191          0.97     French Guiana
# 191                192          0.98           Finland
# 192                193          0.98              Fiji
# 193                194          0.99       El Salvador
# 194                195          0.99             Egypt
# 195                196          1.00          Zimbabwe
#
#      avg_weighted_betweenness  diameter  assortativity_degree  \
# 181                       0.0       0.0                   NaN
# 182                       0.0       0.0                   NaN
# 183                       0.0       0.0                   NaN
# 184                       0.0       0.0                   NaN
# 185                       0.0       0.0                   NaN
# 186                       0.0       0.0                   NaN
# 187                       0.0       0.0                   NaN
# 188                       0.0       0.0                   NaN
# 189                       0.0       0.0                   NaN
# 190                       0.0       0.0                   NaN
# 191                       0.0       0.0                   NaN
# 192                       0.0       0.0                   NaN
# 193                       0.0       0.0                   NaN
# 194                       0.0       0.0                   NaN
# 195                       0.0       NaN                   NaN
#
#      avg_weighted_indegree  density  average_path_len
# 181                    0.0      0.0               NaN
# 182                    0.0      0.0               NaN
# 183                    0.0      0.0               NaN
# 184                    0.0      0.0               NaN
# 185                    0.0      0.0               NaN
# 186                    0.0      0.0               NaN
# 187                    0.0      0.0               NaN
# 188                    0.0      0.0               NaN
# 189                    0.0      0.0               NaN
# 190                    0.0      0.0               NaN
# 191                    0.0      0.0               NaN
# 192                    0.0      0.0               NaN
# 193                    0.0      0.0               NaN
# 194                    0.0      0.0               NaN
# 195                    0.0      NaN               NaN

# %% [markdown]
# #### Unweighted

# %%
## Commented out to not confuse; use the weighted one below 

#Try plotting unweighted
#fig, ax = plt.subplots(1,2,figsize=(14,6),sharey=True)
#ax2_1 = ax[0].twinx()
#ax[0].plot('prop_removed','diameter',data=df_type1_unweighted,ls='--',color='darkblue')
#ax[0].plot('prop_removed','density',data=df_type1_unweighted,ls='--',color='darkviolet')
#ax[0].plot('prop_removed','avg_betweenness',data=df_type1_unweighted,ls='--',color='darkgreen')
#ax2_1.plot('prop_removed','avg_unweighted_indegree',data=df_type1_unweighted,ls='--',color='darkred')
#ax[0].plot('prop_removed','assortativity_degree',data=df_type1_unweighted,ls='--',color='darkturquoise')
#ax[0].plot('prop_removed','average_path_len',data=df_type1_unweighted,ls='--',color='darkorange')
#ax[0].legend(loc='upper right')
#ax[0].set_xlabel('Proportion of nodes removed')
#ax[0].set_title('Random deletion')
#ax2_1.tick_params('y',colors='darkred')
#ax2_1.set_ylabel('Avg inDegree')
#ax2_1.legend(loc='upper left')

#ax2_2 = ax[1].twinx()
#ax[1].plot('prop_removed','diameter',data=df_type2_unweighted,ls='--',color='blue')
#ax[1].plot('prop_removed','density',data=df_type2_unweighted,ls='--',color='violet')
#ax[1].plot('prop_removed','avg_betweenness',data=df_type2_unweighted,ls='--',color='green')
#ax2_2.plot('prop_removed','avg_unweighted_indegree',data=df_type2_unweighted,ls='--',color='red')
#ax[1].plot('prop_removed','assortativity_degree',data=df_type2_unweighted,ls='--',color='turquoise')
#ax[1].plot('prop_removed','average_path_len',data=df_type2_unweighted,ls='--',color='orange')
#ax[1].legend(loc='upper right')
#ax[1].set_xlabel('Proportion of nodes removed')
#ax[1].set_title('Targeted deletion')
#ax2_2.tick_params('y',colors='darkred')
#ax2_2.set_ylabel('Avg inDegree')
#ax2_2.legend(loc='upper left')
#plt.show()

# %% [markdown]
# #### Weighted

# %% [markdown]
# Weighted has to set y-limit because of huge range

# %%
#Same but weighted
#Don't share y axis for type2
fig, ax = plt.subplots(2,2,figsize=(18,12),sharey=False)

#Random attack LHS graphs

ax[0,1].plot('prop_removed','diameter',data=df_type1_weighted,ls='-',color='darkblue')
ax[0,0].plot('prop_removed','density',data=df_type1_weighted,ls='-',color='darkviolet')
ax[0,0].plot('prop_removed','assortativity_degree',data=df_type1_weighted,ls='-',color='darkturquoise')
ax[0,0].plot('prop_removed','average_path_len',data=df_type1_weighted,ls='-',color='darkorange')
ax[0,0].legend(loc='upper right')
ax[0,0].set_xlabel('Proportion of nodes removed')
ax[0,0].set_title('Random deletion')

ax2_1 = ax[0,0].twinx()
ax2_1.plot('prop_removed','avg_weighted_indegree',data=df_type1_weighted,ls='-',color='darkred')
ax2_1.tick_params('y',colors='darkred')
ax2_1.set_ylabel('Avg inDegree')
ax2_1.legend(loc='upper left')

#Random attack RHS Graphs - Betweenness & Diameter
ax[0,1].set_title('Random deletion - Betweenness & Diameter')
ax[0,1].legend(loc='upper left')

ax_bet_rand = ax[0,1].twinx()
ax_bet_rand.plot('prop_removed','avg_weighted_betweenness',data=df_type1_weighted,ls='--',color='darkgreen')
ax_bet_rand.tick_params('y',colors='darkgreen')
ax_bet_rand.set_ylabel('Avg_weighted_betweenness')
ax_bet_rand.legend(loc='upper right')


#Targeted attack LHS Graphs

ax[1,1].plot('prop_removed','diameter',data=df_type2_weighted,ls='-',color='blue')
ax[1,0].plot('prop_removed','density',data=df_type2_weighted,ls='-',color='violet')
ax[1,0].plot('prop_removed','assortativity_degree',data=df_type2_weighted,ls='-',color='turquoise')
ax[1,0].plot('prop_removed','average_path_len',data=df_type2_weighted,ls='-',color='orange')
ax[1,0].legend(loc='upper right')
ax[1,0].set_xlabel('Proportion of nodes removed')
ax[1,0].set_title('Targeted deletion')

ax2_2 = ax[1,0].twinx()
ax2_2.plot('prop_removed','avg_weighted_indegree',data=df_type2_weighted,ls='-',color='darkred')
ax2_2.set_ylabel('Avg inDegree')
ax2_2.legend(loc='upper left')
ax2_2.tick_params('y',colors='darkred')


#Targeted attack RHS Graphs - Betweenness & Diameter 

ax[1,1].set_title('Targeted deletion - Betweenness & Diameter')
ax[1,1].legend(loc='upper left')

ax_bet_tar = ax[1,1].twinx()
ax_bet_tar.plot('prop_removed','avg_weighted_betweenness',data=df_type2_weighted,ls='--',color='green')
ax_bet_tar.tick_params('y',colors='green')
ax_bet_tar.set_ylabel('avg weighted betweenness')
ax_bet_tar.legend(loc='upper right')
plt.show()
