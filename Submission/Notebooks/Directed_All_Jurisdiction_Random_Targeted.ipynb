# %%
import pandas as pd
import numpy as np
import igraph as ig
import matplotlib.pyplot as plt 
import collections

# %%
df_unweighted = pd.read_csv('../combined_final_unweighted.csv')
df_unweighted
# Out:
#           node_start                node_end        status
# 0          Hong Kong                   Samoa  jurisdiction
# 1          Hong Kong                   Samoa  jurisdiction
# 2          Hong Kong                   Samoa  jurisdiction
# 3          Hong Kong                   Samoa  jurisdiction
# 4          Hong Kong                   Samoa  jurisdiction
# ...              ...                     ...           ...
# 338127     Indonesia  British Virgin Islands  officer_base
# 338128  Cook Islands  British Virgin Islands  officer_base
# 338129     Hong Kong  British Virgin Islands  officer_base
# 338130  Cook Islands          United Kingdom  officer_base
# 338131     Hong Kong          United Kingdom  officer_base
#
# [338132 rows x 3 columns]

# %%
df_weighted = pd.read_csv('../combined_final_weighted.csv')
df_weighted
# Out:
#           node_start                node_end        status  weight
# 0          Hong Kong                   Samoa  jurisdiction     2.0
# 1          Hong Kong                   Samoa  jurisdiction     2.0
# 2          Hong Kong                   Samoa  jurisdiction     2.0
# 3          Hong Kong                   Samoa  jurisdiction     2.0
# 4          Hong Kong                   Samoa  jurisdiction     2.0
# ...              ...                     ...           ...     ...
# 338119     Indonesia  British Virgin Islands  officer_base     1.0
# 338120  Cook Islands  British Virgin Islands  officer_base     1.0
# 338121     Hong Kong  British Virgin Islands  officer_base     1.0
# 338122  Cook Islands          United Kingdom  officer_base     1.0
# 338123     Hong Kong          United Kingdom  officer_base     1.0
#
# [338124 rows x 4 columns]

# %%
## Have all Jurisdiction from Susan's
jurisdiction_status_list = ['jurisdiction', 'intermediary_jurisdiction', 'officer_jurisdiction']

# %%
df_weighted_jur = df_weighted[df_weighted['status'].isin(jurisdiction_status_list)]
df_jur = df_weighted_jur.drop(['weight','status'], axis = 1)
df_jur
# Out:
#           node_start                node_end
# 0          Hong Kong                   Samoa
# 1          Hong Kong                   Samoa
# 2          Hong Kong                   Samoa
# 3          Hong Kong                   Samoa
# 4          Hong Kong                   Samoa
# ...              ...                     ...
# 221140         China  British Virgin Islands
# 221175   New Zealand  British Virgin Islands
# 221176  Cook Islands  British Virgin Islands
# 221177     Singapore  British Virgin Islands
# 221178        Russia               Singapore
#
# [218952 rows x 2 columns]

# %%
df_jur_grouped = df_jur.groupby(['node_start','node_end'], as_index = False).size()
df_jur_grouped
# Out:
#      node_start                node_end  size
# 0       Albania                 Bahamas     2
# 1       Andorra                 Bahamas    26
# 2       Andorra  British Virgin Islands    39
# 3       Andorra          Cayman Islands     1
# 4       Andorra            Cook Islands     1
# ...         ...                     ...   ...
# 1293    Vietnam                  Panama     1
# 1294      Yemen                  Panama     1
# 1295     Zambia  British Virgin Islands     2
# 1296   Zimbabwe  British Virgin Islands     5
# 1297   Zimbabwe                  Panama     3
#
# [1298 rows x 3 columns]

# %% [markdown]
# ### Convert Data to an Undirected Edge List

# %%
#df_jur_grouped_list = df_jur_grouped.values.tolist()
#df_jur_grouped_list

# %%
#d = collections.defaultdict(int)
#for n1, n2, v in df_jur_grouped_list:
#    d[min(n1, n2), max(n1, n2)] += v
#result = [[k[0], k[1], v] for k, v in d.items()]

# %%
#df_net = pd.DataFrame(result)
#df_net

# %%
#df_net = df_net.rename(columns = {0:'node_1', 1:'node_2', 2: 'weight'})
#df_net

# %%
#import df_net to csv later

# %%
#plot the unweighted graph (try unweighted first)
g = ig.Graph.TupleList(df_jur_grouped.itertuples(index=False), directed=True, edge_attrs={'weight': "weight"})

# %%
ig.plot(g)

# %%
g.diameter()
# Out:
# 5

# %%
len(g.vs.indices)
# Out:
# 175

# %%
#g.vs.indices
df_jur_grouped['node_start'].value_counts()
# Out:
# Cayman Islands    32
# United States     27
# United Kingdom    24
# Switzerland       23
# Hong Kong         21
#                   ..
# Nauru              1
# Sri Lanka          1
# Djibouti           1
# Malawi             1
# Lesotho            1
# Name: node_start, Length: 169, dtype: int64

# %%
uni =df_jur_grouped['node_start'].unique()

# %%
len(uni)
# Out:
# 169

# %%
list(g.vs)
# Out:
# [igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 0, {'name': 'Albania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 1, {'name': 'Bahamas'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 2, {'name': 'Andorra'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 3, {'name': 'British Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 4, {'name': 'Cayman Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 5, {'name': 'Cook Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 6, {'name': 'Costa Rica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 7, {'name': 'Hong Kong'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 8, {'name': 'Nevada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 9, {'name': 'Niue'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 10, {'name': 'Panama'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 11, {'name': 'Samoa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 12, {'name': 'Seychelles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 13, {'name': 'United Kingdom'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 14, {'name': 'Uruguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 15, {'name': 'Angola'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 16, {'name': 'Bermuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 17, {'name': 'Antigua and Barbuda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 18, {'name': 'Barbados'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 19, {'name': 'Saint Kitts and Nevis'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 20, {'name': 'Argentina'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 21, {'name': 'New Zealand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 22, {'name': 'Aruba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 23, {'name': 'British Anguilla'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 24, {'name': 'Australia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 25, {'name': 'Isle of Man'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 26, {'name': 'Labuan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 27, {'name': 'Austria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 28, {'name': 'Azerbaijan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 29, {'name': 'Cyprus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 30, {'name': 'Malta'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 31, {'name': 'Netherlands Antilles'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 32, {'name': 'Saint Lucia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 33, {'name': 'Wyoming'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 34, {'name': 'Bahrain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 35, {'name': 'United Arab Emirates'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 36, {'name': 'Bangladesh'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 37, {'name': 'Belarus'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 38, {'name': 'Belgium'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 39, {'name': 'Belize'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 40, {'name': 'Mauritius'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 41, {'name': 'Jersey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 42, {'name': 'Liberia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 43, {'name': 'Liechtenstein'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 44, {'name': 'Netherlands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 45, {'name': 'Singapore'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 46, {'name': 'Turks and Caicos Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 47, {'name': 'United States'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 48, {'name': 'Bolivia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 49, {'name': 'Botswana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 50, {'name': 'Brazil'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 51, {'name': 'Marshall Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 52, {'name': 'State of Delaware'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 53, {'name': 'Brunei'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 54, {'name': 'Bulgaria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 55, {'name': 'Cameroon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 56, {'name': 'Canada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 57, {'name': 'Gibraltar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 58, {'name': 'Grenada'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 59, {'name': 'Guernsey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 60, {'name': 'Luxembourg'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 61, {'name': 'Saint Vincent and the Grenadines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 62, {'name': 'US Virgin Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 63, {'name': 'Central African Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 64, {'name': 'Chad'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 65, {'name': 'Chile'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 66, {'name': 'China'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 67, {'name': 'Colombia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 68, {'name': 'Croatia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 69, {'name': 'Cuba'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 70, {'name': 'Curaçao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 71, {'name': 'Czech Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 72, {'name': "Côte d'Ivoire"}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 73, {'name': 'Denmark'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 74, {'name': 'Djibouti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 75, {'name': 'Dominica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 76, {'name': 'Dominican Republic'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 77, {'name': 'Ecuador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 78, {'name': 'Egypt'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 79, {'name': 'El Salvador'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 80, {'name': 'Estonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 81, {'name': 'Fiji'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 82, {'name': 'Finland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 83, {'name': 'France'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 84, {'name': 'French Guiana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 85, {'name': 'Georgia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 86, {'name': 'Germany'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 87, {'name': 'Ghana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 88, {'name': 'Greece'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 89, {'name': 'Guam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 90, {'name': 'Guatemala'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 91, {'name': 'Guyana'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 92, {'name': 'Haiti'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 93, {'name': 'Honduras'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 94, {'name': 'Thailand'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 95, {'name': 'Vanuatu'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 96, {'name': 'Hungary'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 97, {'name': 'Iceland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 98, {'name': 'India'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 99, {'name': 'Indonesia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 100, {'name': 'Iran'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 101, {'name': 'Ireland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 102, {'name': 'Israel'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 103, {'name': 'Italy'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 104, {'name': 'Jamaica'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 105, {'name': 'Japan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 106, {'name': 'Jordan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 107, {'name': 'Kazakhstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 108, {'name': 'Kenya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 109, {'name': 'Kuwait'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 110, {'name': 'Kyrgyzstan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 111, {'name': 'Latvia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 112, {'name': 'Lebanon'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 113, {'name': 'Lesotho'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 114, {'name': 'Libya'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 115, {'name': 'Lithuania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 116, {'name': 'Macao'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 117, {'name': 'Macedonia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 118, {'name': 'Malawi'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 119, {'name': 'Malaysia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 120, {'name': 'Mali'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 121, {'name': 'Mexico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 122, {'name': 'Moldova'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 123, {'name': 'Monaco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 124, {'name': 'Mongolia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 125, {'name': 'Montenegro'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 126, {'name': 'Morocco'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 127, {'name': 'Mozambique'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 128, {'name': 'Namibia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 129, {'name': 'Nauru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 130, {'name': 'Nicaragua'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 131, {'name': 'Nigeria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 132, {'name': 'Northern Mariana Islands'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 133, {'name': 'Norway'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 134, {'name': 'Oman'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 135, {'name': 'Pakistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 136, {'name': 'Paraguay'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 137, {'name': 'Peru'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 138, {'name': 'Philippines'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 139, {'name': 'Poland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 140, {'name': 'Portugal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 141, {'name': 'Puerto Rico'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 142, {'name': 'Qatar'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 143, {'name': 'Romania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 144, {'name': 'Russia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 145, {'name': 'Saint Martin (French part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 146, {'name': 'Saudi Arabia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 147, {'name': 'Senegal'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 148, {'name': 'Sierra Leone'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 149, {'name': 'Sint Maarten (Dutch part)'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 150, {'name': 'Slovakia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 151, {'name': 'Slovenia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 152, {'name': 'South Africa'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 153, {'name': 'South Korea'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 154, {'name': 'Spain'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 155, {'name': 'Sri Lanka'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 156, {'name': 'Sudan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 157, {'name': 'Suriname'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 158, {'name': 'Sweden'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 159, {'name': 'Switzerland'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 160, {'name': 'Syria'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 161, {'name': 'Taiwan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 162, {'name': 'Tanzania'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 163, {'name': 'Trinidad and Tobago'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 164, {'name': 'Tunisia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 165, {'name': 'Turkey'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 166, {'name': 'Uganda'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 167, {'name': 'Ukraine'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 168, {'name': 'Dubai'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 169, {'name': 'Uzbekistan'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 170, {'name': 'Venezuela'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 171, {'name': 'Vietnam'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 172, {'name': 'Yemen'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 173, {'name': 'Zambia'}),
#  igraph.Vertex(<igraph.Graph object at 0x7f7bf95aeb80>, 174, {'name': 'Zimbabwe'})]

# %%
##similar to mini-proj, try a random target 
import random
random.seed(5104)
def unweighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'avg_betweenness':bet,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#try another function but this time with g.diameter having weight param 
#https://igraph.org/python/api/latest/igraph._igraph.GraphBase.html#diameter

random.seed(5104)
def weighted_Type1_random_delete(G):
    g = G.copy()
    
    nodes_removed =[]
    prop_removed =[]
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    pr = []
    auth = []
    for i in range(len(g.vs)):
        sample = random.sample(g.vs.indices,1)
        #print(sample)
        g.delete_vertices(sample)
        
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        #try pagerank 
        page = g.pagerank(directed=True, weights='weight')
        page = sum(page)/max(len(page),1)
        pr.append(page)
        
        #authority score normalised by default
        kleinberg = g.authority_score(weights='weight')
        kleinberg = sum(kleinberg)/max(len(kleinberg),1)
        auth.append(kleinberg)
        
        #try in-degree
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        nodes_removed.append(i+1)
        
        


    df = pd.DataFrame({'nodes_removed':nodes_removed,
                       'prop_removed':prop_removed,
                       'diameter':dia,
                       'avg_weighted_betweenness':bet,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'avg_PageRank':pr,
                       'avg_Authority':auth,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type1_unweighted = unweighted_Type1_random_delete(g)
df_type1_unweighted.head()
# Out:
#    nodes_removed  avg_betweenness  prop_removed  diameter  \
# 0              1        54.540230          0.01       5.0
# 1              2        52.971098          0.01       5.0
# 2              3        52.023256          0.02       5.0
# 3              4        52.128655          0.02       5.0
# 4              5        51.923529          0.03       5.0
#
#    assortativity_degree  avg_unweighted_indegree   density  average_path_len
# 0             -0.453080                 7.448276  0.042806          2.158872
# 1             -0.453601                 7.410405  0.042835          2.149235
# 2             -0.451261                 7.430233  0.043199          2.146151
# 3             -0.452733                 7.385965  0.043193          2.148711
# 4             -0.452726                 7.423529  0.043668          2.144431

# %%
df_type1_unweighted.tail()
# Out:
#      nodes_removed  avg_betweenness  prop_removed  diameter  \
# 170            171              0.0          0.87       0.0
# 171            172              0.0          0.88       0.0
# 172            173              0.0          0.88       0.0
# 173            174              0.0          0.89       0.0
# 174            175              0.0          0.89       NaN
#
#      assortativity_degree  avg_unweighted_indegree  density  average_path_len
# 170                   NaN                      0.0      0.0               NaN
# 171                   NaN                      0.0      0.0               NaN
# 172                   NaN                      0.0      0.0               NaN
# 173                   NaN                      0.0      0.0               NaN
# 174                   NaN                      0.0      NaN               NaN

# %%
df_type1_weighted = weighted_Type1_random_delete(g)
df_type1_weighted.head()
# Out:
#    nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 0              1          0.01      32.0                 98.879440
# 1              2          0.01      32.0                 98.840621
# 2              3          0.02      32.0                 98.981167
# 3              4          0.02      32.0                 97.353558
# 4              5          0.03      32.0                 97.495119
#
#    assortativity_degree  avg_weighted_indegree   density  avg_PageRank  \
# 0             -0.452211            1174.580460  0.041848      0.005747
# 1             -0.451616            1181.352601  0.042267      0.005780
# 2             -0.454009            1185.366279  0.042320      0.005814
# 3             -0.450841            1191.239766  0.042680      0.005848
# 4             -0.451780            1197.105882  0.042768      0.005882
#
#    avg_Authority  average_path_len
# 0       0.009466          2.161182
# 1       0.009520          2.159644
# 2       0.009575          2.161746
# 3       0.009630          2.163402
# 4       0.009687          2.165435

# %%
df_type1_weighted.tail(15)
# Out:
#      nodes_removed  prop_removed  diameter  avg_weighted_betweenness  \
# 160            161          0.82     880.0                  0.857143
# 161            162          0.83     880.0                  0.923077
# 162            163          0.83     880.0                  0.583333
# 163            164          0.84     880.0                  0.454545
# 164            165          0.84     880.0                  0.300000
# 165            166          0.85      27.0                  0.111111
# 166            167          0.85      27.0                  0.125000
# 167            168          0.86       0.0                  0.000000
# 168            169          0.86       0.0                  0.000000
# 169            170          0.87       0.0                  0.000000
# 170            171          0.87       0.0                  0.000000
# 171            172          0.88       0.0                  0.000000
# 172            173          0.88       0.0                  0.000000
# 173            174          0.89       0.0                  0.000000
# 174            175          0.89       NaN                  0.000000
#
#      assortativity_degree  avg_weighted_indegree   density  avg_PageRank  \
# 160             -0.408248              73.642857  0.045918      0.071429
# 161             -0.408248              79.307692  0.053254      0.076923
# 162             -1.000000              77.416667  0.041667      0.083333
# 163             -1.000000              84.363636  0.041322      0.090909
# 164             -1.000000              92.700000  0.040000      0.100000
# 165                   NaN               3.000000  0.024691      0.111111
# 166                   NaN               3.375000  0.031250      0.125000
# 167                   NaN               0.000000  0.000000      0.142857
# 168                   NaN               0.000000  0.000000      0.166667
# 169                   NaN               0.000000  0.000000      0.200000
# 170                   NaN               0.000000  0.000000      0.250000
# 171                   NaN               0.000000  0.000000      0.333333
# 172                   NaN               0.000000  0.000000      0.500000
# 173                   NaN               0.000000  0.000000      1.000000
# 174                   NaN               0.000000       NaN      0.000000
#
#      avg_Authority  average_path_len
# 160       0.079223          1.631579
# 161       0.085317          1.631579
# 162       0.083333          1.538462
# 163       0.090909          1.500000
# 164       0.100000          1.428571
# 165       0.111111          1.333333
# 166       0.125000          1.333333
# 167       1.000000               NaN
# 168       1.000000               NaN
# 169       1.000000               NaN
# 170       1.000000               NaN
# 171       1.000000               NaN
# 172       1.000000               NaN
# 173       1.000000               NaN
# 174       0.000000               NaN

# %% [markdown]
# ### Targeted attack

# %%
##try sort by indegree 
temp_df = pd.DataFrame({'Node_indice':g.vs.indices,
                         'Nodes':g.vs['name'],
                         'In_Degree':g.strength(mode='in',weights='weight')})

# %%
#sort by largest degree 
temp_df = temp_df.sort_values(by='In_Degree',ascending=False)

# %%
temp_df.head(50)
# Out:
#      Node_indice                             Nodes  In_Degree
# 3              3            British Virgin Islands   116692.0
# 10            10                            Panama    42245.0
# 1              1                           Bahamas    15536.0
# 12            12                        Seychelles    14945.0
# 9              9                              Niue     9456.0
# 11            11                             Samoa     6459.0
# 23            23                  British Anguilla     3240.0
# 18            18                          Barbados     2361.0
# 16            16                           Bermuda     2331.0
# 4              4                    Cayman Islands     1453.0
# 8              8                            Nevada     1260.0
# 7              7                         Hong Kong      552.0
# 26            26                            Labuan      477.0
# 5              5                      Cook Islands      344.0
# 25            25                       Isle of Man      291.0
# 52            52                 State of Delaware      181.0
# 30            30                             Malta      146.0
# 19            19             Saint Kitts and Nevis      140.0
# 39            39                            Belize      130.0
# 45            45                         Singapore      104.0
# 13            13                    United Kingdom       97.0
# 29            29                            Cyprus       79.0
# 6              6                        Costa Rica       78.0
# 47            47                     United States       43.0
# 43            43                     Liechtenstein       42.0
# 14            14                           Uruguay       40.0
# 33            33                           Wyoming       37.0
# 41            41                            Jersey       36.0
# 21            21                       New Zealand       29.0
# 40            40                         Mauritius       27.0
# 59            59                          Guernsey       25.0
# 61            61  Saint Vincent and the Grenadines       14.0
# 32            32                       Saint Lucia        9.0
# 44            44                       Netherlands        7.0
# 42            42                           Liberia        6.0
# 119          119                          Malaysia        6.0
# 51            51                  Marshall Islands        5.0
# 31            31              Netherlands Antilles        5.0
# 17            17               Antigua and Barbuda        3.0
# 35            35              United Arab Emirates        3.0
# 58            58                           Grenada        3.0
# 95            95                           Vanuatu        3.0
# 46            46          Turks and Caicos Islands        3.0
# 62            62                 US Virgin Islands        2.0
# 168          168                             Dubai        2.0
# 22            22                             Aruba        2.0
# 60            60                        Luxembourg        1.0
# 57            57                         Gibraltar        1.0
# 94            94                          Thailand        1.0
# 137          137                              Peru        0.0

# %%
temp_df.tail(50)
# Out:
#      Node_indice               Nodes  In_Degree
# 56            56              Canada        0.0
# 55            55            Cameroon        0.0
# 53            53              Brunei        0.0
# 75            75            Dominica        0.0
# 50            50              Brazil        0.0
# 49            49            Botswana        0.0
# 48            48             Bolivia        0.0
# 38            38             Belgium        0.0
# 37            37             Belarus        0.0
# 36            36          Bangladesh        0.0
# 34            34             Bahrain        0.0
# 28            28          Azerbaijan        0.0
# 27            27             Austria        0.0
# 24            24           Australia        0.0
# 20            20           Argentina        0.0
# 15            15              Angola        0.0
# 2              2             Andorra        0.0
# 74            74            Djibouti        0.0
# 76            76  Dominican Republic        0.0
# 109          109              Kuwait        0.0
# 93            93            Honduras        0.0
# 108          108               Kenya        0.0
# 107          107          Kazakhstan        0.0
# 106          106              Jordan        0.0
# 105          105               Japan        0.0
# 104          104             Jamaica        0.0
# 103          103               Italy        0.0
# 102          102              Israel        0.0
# 101          101             Ireland        0.0
# 100          100                Iran        0.0
# 99            99           Indonesia        0.0
# 98            98               India        0.0
# 97            97             Iceland        0.0
# 96            96             Hungary        0.0
# 92            92               Haiti        0.0
# 77            77             Ecuador        0.0
# 91            91              Guyana        0.0
# 90            90           Guatemala        0.0
# 89            89                Guam        0.0
# 88            88              Greece        0.0
# 86            86             Germany        0.0
# 85            85             Georgia        0.0
# 84            84       French Guiana        0.0
# 83            83              France        0.0
# 82            82             Finland        0.0
# 81            81                Fiji        0.0
# 80            80             Estonia        0.0
# 79            79         El Salvador        0.0
# 78            78               Egypt        0.0
# 174          174            Zimbabwe        0.0

# %%
#extract out by Node
order_of_del = temp_df['Nodes'].tolist()

# %%
#print the list to check it
order_of_del
# Out:
# ['British Virgin Islands',
#  'Panama',
#  'Bahamas',
#  'Seychelles',
#  'Niue',
#  'Samoa',
#  'British Anguilla',
#  'Barbados',
#  'Bermuda',
#  'Cayman Islands',
#  'Nevada',
#  'Hong Kong',
#  'Labuan',
#  'Cook Islands',
#  'Isle of Man',
#  'State of Delaware',
#  'Malta',
#  'Saint Kitts and Nevis',
#  'Belize',
#  'Singapore',
#  'United Kingdom',
#  'Cyprus',
#  'Costa Rica',
#  'United States',
#  'Liechtenstein',
#  'Uruguay',
#  'Wyoming',
#  'Jersey',
#  'New Zealand',
#  'Mauritius',
#  'Guernsey',
#  'Saint Vincent and the Grenadines',
#  'Saint Lucia',
#  'Netherlands',
#  'Liberia',
#  'Malaysia',
#  'Marshall Islands',
#  'Netherlands Antilles',
#  'Antigua and Barbuda',
#  'United Arab Emirates',
#  'Grenada',
#  'Vanuatu',
#  'Turks and Caicos Islands',
#  'US Virgin Islands',
#  'Dubai',
#  'Aruba',
#  'Luxembourg',
#  'Gibraltar',
#  'Thailand',
#  'Peru',
#  'Mozambique',
#  'Poland',
#  'Pakistan',
#  'Paraguay',
#  'Namibia',
#  'Philippines',
#  'Oman',
#  'Northern Mariana Islands',
#  'Nicaragua',
#  'Nigeria',
#  'Norway',
#  'Nauru',
#  'Albania',
#  'Morocco',
#  'Montenegro',
#  'Mongolia',
#  'Monaco',
#  'Moldova',
#  'Puerto Rico',
#  'Mexico',
#  'Mali',
#  'Malawi',
#  'Macedonia',
#  'Macao',
#  'Lithuania',
#  'Libya',
#  'Lesotho',
#  'Portugal',
#  'Sweden',
#  'Qatar',
#  'Romania',
#  'Zambia',
#  'Yemen',
#  'Vietnam',
#  'Venezuela',
#  'Uzbekistan',
#  'Ukraine',
#  'Uganda',
#  'Turkey',
#  'Tunisia',
#  'Trinidad and Tobago',
#  'Tanzania',
#  'Taiwan',
#  'Syria',
#  'Switzerland',
#  'Latvia',
#  'Suriname',
#  'Sudan',
#  'Sri Lanka',
#  'Spain',
#  'South Korea',
#  'South Africa',
#  'Slovenia',
#  'Slovakia',
#  'Sint Maarten (Dutch part)',
#  'Sierra Leone',
#  'Senegal',
#  'Saudi Arabia',
#  'Saint Martin (French part)',
#  'Russia',
#  'Lebanon',
#  'Ghana',
#  'Kyrgyzstan',
#  'Bulgaria',
#  'Denmark',
#  "Côte d'Ivoire",
#  'Czech Republic',
#  'Curaçao',
#  'Cuba',
#  'Croatia',
#  'Colombia',
#  'China',
#  'Chile',
#  'Chad',
#  'Central African Republic',
#  'Canada',
#  'Cameroon',
#  'Brunei',
#  'Dominica',
#  'Brazil',
#  'Botswana',
#  'Bolivia',
#  'Belgium',
#  'Belarus',
#  'Bangladesh',
#  'Bahrain',
#  'Azerbaijan',
#  'Austria',
#  'Australia',
#  'Argentina',
#  'Angola',
#  'Andorra',
#  'Djibouti',
#  'Dominican Republic',
#  'Kuwait',
#  'Honduras',
#  'Kenya',
#  'Kazakhstan',
#  'Jordan',
#  'Japan',
#  'Jamaica',
#  'Italy',
#  'Israel',
#  'Ireland',
#  'Iran',
#  'Indonesia',
#  'India',
#  'Iceland',
#  'Hungary',
#  'Haiti',
#  'Ecuador',
#  'Guyana',
#  'Guatemala',
#  'Guam',
#  'Greece',
#  'Germany',
#  'Georgia',
#  'French Guiana',
#  'France',
#  'Finland',
#  'Fiji',
#  'Estonia',
#  'El Salvador',
#  'Egypt',
#  'Zimbabwe']

# %%
def unweighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    for i in range(len(g.vs)):
        g.delete_vertices(order_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True)
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        between = g.betweenness(directed=True)
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        #use strength
        deg = g.strength(mode='in')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(order_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_unweighted_indegree':degree,
                       'density':density,
                       'average_path_len':apl})
    
    return(df)

# %%
#Weighted on diameter
def weighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    pr = []
    auth = []
    for i in range(len(g.vs)):
        g.delete_vertices(order_of_del[i])
        #print(order_of_del[i])
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        #try pagerank 
        page = g.pagerank(directed=True, weights='weight')
        page = sum(page)/max(len(page),1)
        pr.append(page)
        #authority score normalised by default
        kleinberg = g.authority_score(weights='weight')
        kleinberg = sum(kleinberg)/max(len(kleinberg),1)
        auth.append(kleinberg)
        
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/196,2)
        prop_removed.append(prop)
        node_removed.append(order_of_del[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_weighted_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'avg_PageRank':pr,
                       'avg_Authority':auth,
                       'average_path_len':apl})
    
    return(df)

# %%
df_type2_unweighted = unweighted_Type2_targeted_del(g)
df_type2_unweighted.head()
# Out:
#    num_nodes_removed  prop_removed            node_removed  avg_betweenness  \
# 0                  1          0.01  British Virgin Islands        51.666667
# 1                  2          0.01                  Panama        47.624277
# 2                  3          0.02                 Bahamas        51.023256
# 3                  4          0.02              Seychelles        44.654971
# 4                  5          0.03                    Niue        44.435294
#
#    diameter  assortativity_degree  avg_unweighted_indegree   density  \
# 0       5.0             -0.424345                 6.494253  0.037323
# 1       5.0             -0.399495                 5.687861  0.032878
# 2       6.0             -0.399878                 5.075581  0.029509
# 3       6.0             -0.394677                 4.561404  0.026675
# 4       6.0             -0.404222                 4.188235  0.024637
#
#    average_path_len
# 0          2.215029
# 1          2.250797
# 2          2.391029
# 3          2.354862
# 4          2.371460

# %%
df_type2_unweighted.tail()
# Out:
#      num_nodes_removed  prop_removed node_removed  avg_betweenness  diameter  \
# 170                171          0.87         Fiji              0.0       0.0
# 171                172          0.88      Estonia              0.0       0.0
# 172                173          0.88  El Salvador              0.0       0.0
# 173                174          0.89        Egypt              0.0       0.0
# 174                175          0.89     Zimbabwe              0.0       NaN
#
#      assortativity_degree  avg_unweighted_indegree  density  average_path_len
# 170                   NaN                      0.0      0.0               NaN
# 171                   NaN                      0.0      0.0               NaN
# 172                   NaN                      0.0      0.0               NaN
# 173                   NaN                      0.0      0.0               NaN
# 174                   NaN                      0.0      NaN               NaN

# %%
df_type2_weighted = weighted_Type2_targeted_del(g)
df_type2_weighted.head(15)
# Out:
#     num_nodes_removed  prop_removed            node_removed  \
# 0                   1          0.01  British Virgin Islands
# 1                   2          0.01                  Panama
# 2                   3          0.02                 Bahamas
# 3                   4          0.02              Seychelles
# 4                   5          0.03                    Niue
# 5                   6          0.03                   Samoa
# 6                   7          0.04        British Anguilla
# 7                   8          0.04                Barbados
# 8                   9          0.05                 Bermuda
# 9                  10          0.05          Cayman Islands
# 10                 11          0.06                  Nevada
# 11                 12          0.06               Hong Kong
# 12                 13          0.07                  Labuan
# 13                 14          0.07            Cook Islands
# 14                 15          0.08             Isle of Man
#
#     avg_weighted_betweenness  diameter  assortativity_degree  \
# 0                  94.177466      33.0             -0.424345
# 1                  81.625771     141.0             -0.399495
# 2                  78.925175     141.0             -0.399878
# 3                  69.133727     141.0             -0.394677
# 4                  68.372193     141.0             -0.404222
# 5                  66.701754     141.0             -0.415059
# 6                  62.197995     141.0             -0.417391
# 7                  52.513652      38.0             -0.404300
# 8                  48.590381      62.0             -0.383412
# 9                  34.710823      50.0             -0.250539
# 10                 33.852352      50.0             -0.258139
# 11                 22.818507     125.0             -0.243252
# 12                 22.108539     125.0             -0.257581
# 13                 21.627847     125.0             -0.235574
# 14                 16.781250     124.0             -0.168329
#
#     avg_weighted_indegree   density  avg_PageRank  avg_Authority  \
# 0              579.534483  0.037323      0.005747       0.009940
# 1              310.456647  0.032878      0.005780       0.018338
# 2              225.505814  0.029509      0.005814       0.014490
# 3              147.409357  0.026675      0.005848       0.014152
# 4              102.352941  0.024637      0.005882       0.010355
# 5               67.289941  0.022583      0.005917       0.013055
# 6               50.315476  0.021010      0.005952       0.013459
# 7               43.221557  0.018753      0.005988       0.011855
# 8               29.259036  0.016004      0.006024       0.010837
# 9               18.539394  0.012782      0.006061       0.006553
# 10              13.256098  0.011600      0.006098       0.006415
# 11              10.613497  0.009598      0.006135       0.006336
# 12               7.858025  0.009297      0.006173       0.015462
# 13               6.714286  0.008140      0.006211       0.013663
# 14               4.906250  0.006641      0.006250       0.006658
#
#     average_path_len
# 0           2.215029
# 1           2.250797
# 2           2.391029
# 3           2.354862
# 4           2.371460
# 5           2.386416
# 6           2.341120
# 7           2.256481
# 8           2.279685
# 9           2.558046
# 10          2.587065
# 11          2.636313
# 12          2.641279
# 13          2.683283
# 14          2.940299

# %%
df_type2_weighted.tail(150)
# Out:
#      num_nodes_removed  prop_removed node_removed  avg_weighted_betweenness  \
# 25                  26          0.13      Uruguay                  0.281879
# 26                  27          0.14      Wyoming                  0.155405
# 27                  28          0.14       Jersey                  0.061224
# 28                  29          0.15  New Zealand                  0.061644
# 29                  30          0.15    Mauritius                  0.048276
# ..                 ...           ...          ...                       ...
# 170                171          0.87         Fiji                  0.000000
# 171                172          0.88      Estonia                  0.000000
# 172                173          0.88  El Salvador                  0.000000
# 173                174          0.89        Egypt                  0.000000
# 174                175          0.89     Zimbabwe                  0.000000
#
#      diameter  assortativity_degree  avg_weighted_indegree   density  \
# 25       11.0             -0.186753               0.463087  0.001531
# 26       11.0             -0.234658               0.412162  0.001324
# 27        9.0             -0.190554               0.312925  0.001064
# 28        3.0              0.157532               0.212329  0.000844
# 29        3.0             -0.228218               0.144828  0.000666
# ..        ...                   ...                    ...       ...
# 170       0.0                   NaN               0.000000  0.000000
# 171       0.0                   NaN               0.000000  0.000000
# 172       0.0                   NaN               0.000000  0.000000
# 173       0.0                   NaN               0.000000  0.000000
# 174       NaN                   NaN               0.000000       NaN
#
#      avg_PageRank  avg_Authority  average_path_len
# 25       0.006711       0.007087          1.629032
# 26       0.006757       0.006757          1.456522
# 27       0.006803       0.006803          1.275862
# 28       0.006849       0.009752          1.333333
# 29       0.006897       0.006897          1.368421
# ..            ...            ...               ...
# 170      0.250000       1.000000               NaN
# 171      0.333333       1.000000               NaN
# 172      0.500000       1.000000               NaN
# 173      1.000000       1.000000               NaN
# 174      0.000000       0.000000               NaN
#
# [150 rows x 11 columns]

# %% [markdown]
# #### Unweighted

# %%
## Commented out to not confuse; use the weighted one below

#Try plotting unweighted

#fig, ax = plt.subplots(1,2,figsize=(14,6),sharey=True)
#ax2_1 = ax[0].twinx()
#ax[0].plot('prop_removed','diameter',data=df_type1_unweighted,ls='--',color='darkblue')
#ax[0].plot('prop_removed','density',data=df_type1_unweighted,ls='--',color='darkviolet')
#ax[0].plot('prop_removed','avg_betweenness',data=df_type1_unweighted,ls='--',color='darkgreen')
#ax2_1.plot('prop_removed','avg_unweighted_indegree',data=df_type1_unweighted,ls='--',color='darkred')
#ax[0].plot('prop_removed','assortativity_degree',data=df_type1_unweighted,ls='--',color='darkturquoise')
#ax[0].plot('prop_removed','average_path_len',data=df_type1_unweighted,ls='--',color='darkorange')
#ax[0].legend(loc='upper right')
#ax[0].set_xlabel('Proportion of nodes removed')
#ax[0].set_title('Random deletion')
#ax2_1.tick_params('y',colors='darkred')
#ax2_1.set_ylabel('Avg inDegree')
#ax2_1.legend(loc='upper left')

#ax2_2 = ax[1].twinx()
#ax[1].plot('prop_removed','diameter',data=df_type2_unweighted,ls='--',color='blue')
#ax[1].plot('prop_removed','density',data=df_type2_unweighted,ls='--',color='violet')
#ax[1].plot('prop_removed','avg_betweenness',data=df_type2_unweighted,ls='--',color='green')
#ax2_2.plot('prop_removed','avg_unweighted_indegree',data=df_type2_unweighted,ls='--',color='red')
#ax[1].plot('prop_removed','assortativity_degree',data=df_type2_unweighted,ls='--',color='turquoise')
#ax[1].plot('prop_removed','average_path_len',data=df_type2_unweighted,ls='--',color='orange')
#ax[1].legend(loc='upper right')
#ax[1].set_xlabel('Proportion of nodes removed')
#ax[1].set_title('Targeted deletion')
#ax2_2.tick_params('y',colors='darkred')
#ax2_2.set_ylabel('Avg inDegree')
#ax2_2.legend(loc='upper left')
#plt.show()

# %% [markdown]
# #### Weighted

# %%
#Same but weighted
#Don't share y axis for type2
fig, ax = plt.subplots(2,2,figsize=(18,12),sharey=False)

#Random attack LHS graphs

ax[0,1].plot('prop_removed','diameter',data=df_type1_weighted,ls='-',color='darkblue')
ax[0,0].plot('prop_removed','density',data=df_type1_weighted,ls='-',color='darkviolet')
#remove assortativity degree, replace with pagerank
ax[0,0].plot('prop_removed','avg_PageRank',data=df_type1_weighted,ls='-',color='darkturquoise')
#add in authority score
ax[0,0].plot('prop_removed','avg_Authority',data=df_type1_weighted,ls='-',color='slategray')
ax[0,0].plot('prop_removed','average_path_len',data=df_type1_weighted,ls='-',color='darkorange')
ax[0,0].legend(loc='upper right')
ax[0,0].set_xlabel('Proportion of nodes removed')
ax[0,0].set_title('Random deletion - All Jurisdiction')

ax2_1 = ax[0,0].twinx()
ax2_1.plot('prop_removed','avg_weighted_indegree',data=df_type1_weighted,ls='-',color='darkred')
ax2_1.tick_params('y',colors='darkred')
ax2_1.set_ylabel('Avg inDegree')
ax2_1.legend(loc='upper left')

#Random attack RHS Graphs - Betweenness & Diameter
ax[0,1].set_title('Random deletion - Betweenness & Diameter')
ax[0,1].legend(loc='upper left')

ax_bet_rand = ax[0,1].twinx()
ax_bet_rand.plot('prop_removed','avg_weighted_betweenness',data=df_type1_weighted,ls='--',color='darkgreen')
ax_bet_rand.tick_params('y',colors='darkgreen')
ax_bet_rand.set_ylabel('Avg_weighted_betweenness')
ax_bet_rand.legend(loc='upper right')


#Targeted attack LHS Graphs

ax[1,1].plot('prop_removed','diameter',data=df_type2_weighted,ls='-',color='blue')
ax[1,0].plot('prop_removed','density',data=df_type2_weighted,ls='-',color='violet')
#remove assortativity degree, replace with pagerank
ax[1,0].plot('prop_removed','avg_PageRank',data=df_type2_weighted,ls='-',color='turquoise')
# add in Authority
ax[1,0].plot('prop_removed','avg_Authority',data=df_type2_weighted,ls='-',color='lightslategray')
ax[1,0].plot('prop_removed','average_path_len',data=df_type2_weighted,ls='-',color='orange')
ax[1,0].legend(loc='upper right')
ax[1,0].set_xlabel('Proportion of nodes removed')
ax[1,0].set_title('Targeted deletion - All Jurisdiction')

ax2_2 = ax[1,0].twinx()
ax2_2.plot('prop_removed','avg_weighted_indegree',data=df_type2_weighted,ls='-',color='darkred')
ax2_2.set_ylabel('Avg inDegree')
ax2_2.legend(loc='upper left')
ax2_2.tick_params('y',colors='darkred')


#Targeted attack RHS Graphs - Betweenness & Diameter 

ax[1,1].set_title('Targeted deletion - Betweenness & Diameter')
ax[1,1].legend(loc='upper left')

ax_bet_tar = ax[1,1].twinx()
ax_bet_tar.plot('prop_removed','avg_weighted_betweenness',data=df_type2_weighted,ls='--',color='green')
ax_bet_tar.tick_params('y',colors='green')
ax_bet_tar.set_ylabel('avg weighted betweenness')
ax_bet_tar.legend(loc='upper right')
plt.savefig('Directed_All_Jurisdiction_nodes.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Directd all jur

# %%
#because the g.es only shows the edge ID, we need to get the vertex source and target
##sv = source vertex 
##st = source target 
sv = []
st = []
for edge in g.es:
    source_vertex_id = edge.source
    target_vertex_id = edge.target
    source_vertex = g.vs[source_vertex_id]
    sv.append(source_vertex)
    target_vertex = g.vs[target_vertex_id]
    st.append(target_vertex)

# %%
##get name of source vertices. sv and st each is an igraph object so need to slice them to get the names

sv_name = []
for i in range(len(sv)):
    name = sv[i]['name']
    sv_name.append(name)
    
st_name = []
for i in range(len(st)):
    target_name = st[i]['name']
    st_name.append(target_name)

# %%
## new df with edges
edge_df = pd.DataFrame({'Edge_indice':g.es.indices,
                         'Edges_weight':g.es['weight'],
                         'Vertex_source':sv_name,
                         'Vertex_target':st_name,
                          'edge_betweenness':g.edge_betweenness(directed=True,weights=g.es['weight'])}) #weights=g.es['weight']

# %%
##sort by descending weight
edge_df = edge_df.sort_values(by='edge_betweenness',ascending=False)

# %%
edge_df.head(10)
# Out:
#      Edge_indice  Edges_weight           Vertex_source         Vertex_target  \
# 599          599             1             Isle of Man  United Arab Emirates
# 885          885             1                  Panama          Cook Islands
# 291          291             1            Cook Islands               Bermuda
# 781          781             1        Marshall Islands        Cayman Islands
# 972          972             1   Saint Kitts and Nevis        Cayman Islands
# 114          114             1                  Belize        Cayman Islands
# 225          225             1          Cayman Islands            Luxembourg
# 775          775             1                   Malta           Isle of Man
# 525          525             1               Hong Kong      Marshall Islands
# 168          168             1  British Virgin Islands                Belize
#
#      edge_betweenness
# 599        603.372161
# 885        598.739286
# 291        583.089683
# 781        531.529376
# 972        507.015090
# 114        442.991775
# 225        395.886830
# 775        387.495946
# 525        377.469888
# 168        362.841270

# %%
edge_df.tail(10)
# Out:
#      Edge_indice  Edges_weight   Vertex_source  \
# 729          729            11      Luxembourg
# 717          717            11   Liechtenstein
# 266          266            12           China
# 701          701            12         Lebanon
# 948          948            12           Qatar
# 587          587            12     Isle of Man
# 692          692            12          Latvia
# 234          234            12  Cayman Islands
# 820          820            12      Montenegro
# 520          520         28007       Hong Kong
#
#                         Vertex_target  edge_betweenness
# 729                          Barbados               0.0
# 717                         Hong Kong               0.0
# 266                              Niue               0.0
# 701                             Samoa               0.0
# 948                            Panama               0.0
# 587                    Cayman Islands               0.0
# 692                            Panama               0.0
# 234  Saint Vincent and the Grenadines               0.0
# 820            British Virgin Islands               0.0
# 520            British Virgin Islands               0.0

# %%
russia = edge_df.loc[edge_df['Vertex_source']=='Russia']
russia
# Out:
#      Edge_indice  Edges_weight Vertex_source           Vertex_target  \
# 958          958          2336        Russia  British Virgin Islands
# 954          954          1335        Russia                 Bahamas
# 962          962           366        Russia                    Niue
# 963          963            94        Russia                  Panama
# 957          957            73        Russia        British Anguilla
# 956          956            25        Russia                 Bermuda
# 966          966            21        Russia              Seychelles
# 965          965             9        Russia                   Samoa
# 960          960             8        Russia            Cook Islands
# 961          961             8        Russia               Hong Kong
# 959          959             6        Russia          Cayman Islands
# 955          955             3        Russia                  Belize
# 968          968             2        Russia                 Uruguay
# 967          967             1        Russia               Singapore
# 964          964             1        Russia   Saint Kitts and Nevis
#
#      edge_betweenness
# 958          3.090909
# 954          3.324242
# 962          1.000000
# 963          2.990909
# 957          1.090909
# 956          4.457576
# 966          1.090909
# 965          1.200000
# 960          1.000000
# 961          4.674242
# 959         14.707576
# 955          1.590909
# 968          2.400000
# 967          4.874242
# 964          1.507576

# %%
edge_deletelist = edge_df['Edge_indice'].tolist()

# %%
#Weighted on diameter
def Edges_weighted_Type2_targeted_del(G):
    g = G.copy()
    
    num_node_removed = []
    prop_removed=[]
    node_removed = []
    dia = []
    assort_deg = []
    degree = []
    density = []
    apl = []
    bet = []
    pr = []
    auth = []
    for i in range(len(g.es)):
        try:
            g.delete_edges(edge_deletelist[i])
        except:
            continue
        #print(order_of_del[i])
        diameter = g.diameter(directed=True, weights='weight')
        dia.append(diameter)
        
        asdeg = g.assortativity_degree()
        assort_deg.append(asdeg)
        
        dense = g.density(loops=True)
        density.append(dense)
        
        between = g.betweenness(directed=True, weights='weight')
        between = sum(between)/max(len(between),1)
        bet.append(between)
        
        #try pagerank 
        page = g.pagerank(directed=True, weights='weight')
        page = sum(page)/max(len(page),1)
        pr.append(page)
        #authority score normalised by default
        kleinberg = g.authority_score(weights='weight')
        kleinberg = sum(kleinberg)/max(len(kleinberg),1)
        auth.append(kleinberg)
        
        #use strength
        deg = g.strength(mode='in',weights='weight')
        deg = sum(deg)/max(len(deg),1)
        degree.append(deg)
        
        avgpl = g.average_path_length()
        apl.append(avgpl)
        
        num_node_removed.append(i+1)
        prop = round((i+1)/len(edge_deletelist),2) #2840 is ttotal rows in df
        prop_removed.append(prop)
        node_removed.append(edge_deletelist[i])


    df = pd.DataFrame({'num_nodes_removed':num_node_removed,
                       'prop_removed':prop_removed,
                       'node_removed':node_removed,
                       'avg_weighted_betweenness':bet,
                       'diameter':dia,
                       'assortativity_degree':assort_deg,
                       'avg_weighted_indegree':degree,
                       'density':density,
                       'avg_PageRank':pr,
                       'avg_Authority':auth,
                       'average_path_len':apl})
    
    return(df)

# %%
jur_all= Edges_weighted_Type2_targeted_del(g)

# %%
jur_all
# Out:
#      num_nodes_removed  prop_removed  node_removed  avg_weighted_betweenness  \
# 0                    1          0.00           520                100.611849
# 1                    2          0.00          1094                100.611849
# 2                    3          0.00          1105                100.611849
# 3                    4          0.00           647                100.611849
# 4                    5          0.00           741                100.611849
# ..                 ...           ...           ...                       ...
# 812               1245          0.96           429                104.049048
# 813               1246          0.96           431                104.066190
# 814               1247          0.96           432                104.066190
# 815               1248          0.96           433                104.326190
# 816               1298          1.00           419                104.331905
#
#      diameter  assortativity_degree  avg_weighted_indegree   density  \
# 0        32.0             -0.456292            1091.114286  0.042351
# 1        32.0             -0.456729            1090.874286  0.042318
# 2        32.0             -0.457195            1081.548571  0.042286
# 3        32.0             -0.457412            1081.491429  0.042253
# 4        32.0             -0.457485            1073.371429  0.042220
# ..        ...                   ...                    ...       ...
# 812     436.0             -0.325440             388.674286  0.015837
# 813     436.0             -0.323932             388.657143  0.015804
# 814     436.0             -0.327316             388.651429  0.015771
# 815     436.0             -0.328826             388.640000  0.015739
# 816     436.0             -0.326752             388.628571  0.015706
#
#      avg_PageRank  avg_Authority  average_path_len
# 0        0.005714       0.010756          2.161447
# 1        0.005714       0.010749          2.162175
# 2        0.005714       0.010439          2.162297
# 3        0.005714       0.010438          2.163146
# 4        0.005714       0.010375          2.163268
# ..            ...            ...               ...
# 812      0.005714       0.006080          2.853492
# 813      0.005714       0.006080          2.853682
# 814      0.005714       0.006080          2.853682
# 815      0.005714       0.006080          2.859171
# 816      0.005714       0.006080          2.859360
#
# [817 rows x 11 columns]

# %%
fig, ax = plt.subplots(1,2,figsize=(14,8),sharey=False)

#Targeted attack LHS Graphs

    
ax[0].plot('prop_removed','density',data=jur_all,ls='-',color='violet')
#remove assortativity degree, replace with pagerank
ax[0].plot('prop_removed','avg_PageRank',data=jur_all,ls='-',color='turquoise')
# add in Authority
ax[0].plot('prop_removed','avg_Authority',data=jur_all,ls='-',color='lightslategray')
ax[0].plot('prop_removed','average_path_len',data=jur_all,ls='-',color='orange')
ax[0].legend(loc='upper right')
ax[0].set_xlabel('Proportion of edges removed')
ax[0].set_title('Targeted deletion - All Jurisdiction')

ax2_2 = ax[0].twinx()
ax2_2.plot('prop_removed','avg_weighted_indegree',data=jur_all,ls='-',color='darkred')
ax2_2.set_ylabel('Avg inDegree')
ax2_2.legend(loc='upper left')
ax2_2.tick_params('y',colors='darkred')


#Targeted attack RHS Graphs - Betweenness & Diameter 

ax[1].plot('prop_removed','diameter',data=jur_all,ls='-',color='blue')
ax[1].set_title('Targeted deletion - Betweenness & Diameter')
ax[1].legend(loc='upper left')
    
    
ax_bet_tar = ax[1].twinx()
ax_bet_tar.plot('prop_removed','avg_weighted_betweenness',data=jur_all,ls='--',color='green')
ax_bet_tar.tick_params('y',colors='green')
ax_bet_tar.set_ylabel('avg weighted betweenness')
ax_bet_tar.legend(loc='upper right')
plt.savefig('Directed_All_Jurisdiction_edges.png', dpi=300, bbox_inches='tight')
plt.show()
